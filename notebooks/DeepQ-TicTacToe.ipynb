# %% [markdown]
# ## Tic-Tac-Toe with Deep-Q Learning
# #### ELEC-ENG 473: Final Project
# Yemi Kelani
#
# ---

# %% [markdown]
# ##### **Background and Motivation**
# In Reinforcement Learning, agents learn to make decisions by interacting with their environments. Typically, an environment will produce an observation (also referred to as a state), the agent will take an action based on the observation, and the environment will supply the agent with a reward (either positive, neutral, or negative). Over time, the agent will learn to take actions the help it to maximize its potential rewards. This greedy approach is called exploitation. Alternatively, the agent will sometimes opt to make random choices. This is known as exploration.
#
# In Tic-Tac-Toe, the game board contains 9 separate cells, with each cell taking the form of an "X", an "O", or an empty space. This means there are 19,683 (3 ^ 9) possible states (Note: States and game sequences are different; There are well over 200,000 ways a game can be played.). Here, the term state refers to any possible configuration of the aforementioned values on the game board. Given that not all of these states are valid configurations of the game board, we can assume there are strictly less than 19,683 valid states in the search space. A state is considered valid if there exists at most one more "X" than "O" on the board at any given time; we assume that "X" always takes the first turn.
#
# ##### **Project Goals and Objectives**
# Reinforcement Learning is a powerful tool for training agents to optimize actions within a given environment. In order for agents to maximize the value of their actions, they need some sort of mechanism for determining the values of states and/or state-action pairs. Deep-Q Learning is a non-tabular method of approximating these values. With this project, I aim to familiarize myself with the core principles of Deep-Q Learning by developing a Tic-Tac-Toe learning system from scratch.
#
# ---

# %%
import torch
import torch.nn as nn

# torch config
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")

import random
import numpy as np
from tqdm import tqdm
from pathlib import Path
from collections import deque
from datetime import datetime

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ##### **Method**
# I created two classes for this project: A `TicTacToeGame` class which served as an enviornment for game board, and a `DeepQAgent` class which served as the agent. Implementations for both classes can be viewed below.
#
# I trained four agents for a varying number of episodes each against different combinations of opponent levels. Disregaring failed training sessions, I trained them for a total of 14,000 episodes. I used a hidden layer size of 100. The rest of the parameters used can be viewed below.
#
# Note that the `opponent_move` method in the `TicTacToeGame` class has two levels: *easy* and *hard*. The easy mode randomly selects a valid next move for the opponent while the hard mode selects the optimal valid move using the `minmax` algorithm. The issue with hard mode is that is inefficient and slow at the start of the game. As moves are made, it gets faster (because the search space reduces). To combat this issue, if hard mode is selected, it will play naively for the first one or two moves and then, when the search space is computationally acceptable, it makes the optimal moves.
#
# ---

# %%
class TicTacToeGame():
  def __init__(self, device, opponent_level="easy"):
    self.device = device
    self.positions = {-1: "X", 1: "O", 0: " "}
    self.opponent_level = opponent_level
    self.board = torch.zeros((3, 3))
    self.player1 = -1   # the agent
    self.player2 = 1    # the opponent
    self.winner = None
    self.minmaxWinner = None

  def get_state(self):
    return torch.clone(self.board).to(self.device)
  
  def take_action(self, action):
    i = action % 3
    j = action // 3
    if self.is_valid_move(i, j):
      self.board[j][i] = self.player1
      reward, done = self.is_game_over()

      if not done:
        self.opponent_move()
        reward, done = self.is_game_over()
    else:
      reward, done = -10, True

    next_state = torch.clone(self.board).to(self.device)
    return next_state, reward, done

  def is_valid_move(self, i, j):
    # check if the cell is empty
    if self.board[j][i] != 0:
      print(f"action {(3*j)+i} is not valid.")
      self.print_board()
      return False

    # check to see if the Xs and Os are balanced
    board_sum = self.board.sum() + self.player1
    balanced = board_sum >= -1 and board_sum <= 1
    if not balanced:
      print(f"board is unbalanced.")
      self.print_board()

    return balanced

  def get_valid_moves(self, board=None):
    board = self.board if board == None else board
    valid_moves, indicies = [], []
    mask = torch.zeros((9,)).to(self.device)
    for i in range(3):
      for j in range(3):
        if board[j][i] == 0:
          valid_moves.append((j, i))
          index = (3 * j) + i
          indicies.append(index)
          mask[index] = 1

    return valid_moves, mask, indicies

  def opponent_move(self):
    # with torch.no_grad():
    valid_moves, _, _ = self.get_valid_moves()

    force_naive_move = True
    num_moves = len(valid_moves)
    if num_moves == 0:
      return
    elif num_moves <= 7:
      force_naive_move = False

    if self.opponent_level == "easy" or force_naive_move:
      # random choice
      move = valid_moves[np.random.choice(num_moves)]
    elif self.opponent_level == "hard":
      # optimal choice
      scores = []
      board = torch.clone(self.board).detach()
      moves, _, _ = self.get_valid_moves(board=board)
      for move in moves:
        board[move[0]][move[1]] = self.player2 
        scores.append(self.minmax(self.player2, self.player1, board))
        board[move[0]][move[1]] = 0

      move = moves[np.argmax(scores)]
    
    self.board[move[0]][move[1]] = self.player2
  
  def minmax(self, role, player, board):
    _, done = self.is_game_over(board)
    if done:
      # NOTE: minmax rewards != Q value rewards
      if self.minmaxWinner != None:
        # return 1 if role wins else return -1
        # -1 *  1 = -1 [role "X" loses to "O"]
        # -1 * -1 =  1 [role "X" beats op "O"]
        #  1 *  1 =  1 [role "O" beats op "X"]
        #  1 * -1 = -1 [role "O" loses to "X"]
        return role * self.minmaxWinner

      # return 0 in case of a tie
      return 0

    scores = []
    moves, _, _ = self.get_valid_moves(board=board)
    next_player = self.player1 if player == self.player2 else self.player2
    for move in moves:
      board[move[0]][move[1]] = player                     # make move
      scores.append(self.minmax(role, next_player, board)) # score move
      board[move[0]][move[1]] = 0                          # revert board

    return max(scores) if player == role else min(scores)

  def is_game_over(self, board=None):
    revertWinner = False if board == None else True
    board = self.board if board == None else board

    # check rows and columns
    for i in range(self.board.size()[0]):
      if board[i][0] == board[i][1] == board[i][2] != 0:
        self.winner = board[i][0]
      elif board[0][i] == board[1][i] == board[2][i] != 0:
        self.winner = board[0][i]
    
    # check diagonals
    if board[0][0] == board[1][1] == board[2][2] != 0:
      self.winner = board[0][0]
    elif board[0][2] == board[1][1] == board[2][0] != 0:
      self.winner = board[0][2]

    # check if there's a tie
    tie = torch.where(board != 0, 1.0, 0.0).sum() == 9

    reward = -1 if tie else 0
    if self.winner != None:
      if self.winner == self.player1:
        reward = 1  # reward for winning
      else:
        reward = -2 # reward for losing

    done = self.winner != None or tie

    # if this function is being used for minmax, 
    # revert the stored winner to None
    if revertWinner:
      self.minmaxWinner = self.winner
      self.winner = None

    return reward, done

  def reset(self):
    self.board = torch.zeros((3, 3))
    self.player1 = -1   # the agent
    self.player2 = 1    # the opponent
    self.winner = None
    self.minmaxWinner = None

  def print_board(self, board=None):
    board = self.board if board == None else board
    print("_______")
    for a in range(board.size()[0]):
      row = r""
      for b in range(board.size()[1]):
        row += "|" + self.positions[board[a][b].item()]
        row += "|" if b == board.size()[1] - 1 else ""
      print(row)
    print("‾‾‾‾‾‾‾")

# %%
class DeepQAgent(nn.Module):
  def __init__(
      self,
      device,
      epsilon:float, 
      gamma:float,
      state_space:int, 
      action_space:int, 
      hidden_size:int = 100,
      dropout:float = 0.15,
      train_start:int = 50,
      batch_size:int = 64,
  ):
    
    super(DeepQAgent, self).__init__()

    self.epsilon = epsilon
    self.epsilon_min = 0.001 * epsilon
    self.epsilon_decay_rate = 0.999
    self.gamma = gamma
    self.state_space = state_space
    self.action_space = action_space
    self.train_start = train_start
    self.batch_size = batch_size
    self.memory = deque(maxlen=2000)
    self.device = device
    
    self.model = nn.Sequential(
        nn.Linear(state_space, hidden_size),
        nn.Dropout(dropout),
        nn.Tanh(),
        nn.Linear(hidden_size, hidden_size),
        nn.Dropout(dropout),
        nn.Tanh(),
        nn.Linear(hidden_size, action_space)
    )

  def forward(self, state):
    return self.model(torch.flatten(state))

  def select_action(self, state, mask, indicies):
    # select action greedily with respect to state
    # or select randomly from uniform distribution
    if np.random.rand() <= self.epsilon:
      return np.random.choice(indicies)
    else:
      q_values = self.forward(state)
      q_masked = torch.where(mask != 0, q_values, -1000)
      return torch.argmax(q_masked)

  def decay_epsilon(self):
    if len(self.memory) > self.train_start:
      if self.epsilon > self.epsilon_min:
        self.epsilon *= self.epsilon_decay_rate

  def remember(self, state, action, reward, next_state, done):
    self.memory.append((state, action, reward, next_state, done))
  
  def replay(self, optimizer, criterion):
    if len(self.memory) > self.train_start:

      batch = random.sample(self.memory, min(len(self.memory), self.batch_size))
      for state, action, reward, next_state, done in batch:

        q_values = self.forward(state)
        q_values_next = self.forward(next_state)

        if done:
          q_values[action] = reward
        else:
          q_values[action] = reward + (self.gamma * torch.max(q_values_next))

        # optimize the model
        loss = criterion(self.forward(state), q_values)
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
      
      self.decay_epsilon()
  
  def save_model(self, path):
    torch.save(self.state_dict(), path)
    print(f"Model saved to {path}")

# %%
# DeepQ parameters
BATCH_SIZE    = 64
NUM_EPISODES  = 5000 if torch.cuda.is_available() else 100
STATE_SPACE   = 9
ACTION_SPACE  = 9
EPSILON       = 1.0
GAMMA         = 0.95
HIDDEN_SIZE   = 100
LEARNING_RATE = 0.001
DROPOUT       = 0.15
TRAIN_START   = 1000

# save path
MODEL_PATH = "/content/drive/MyDrive/EE 473/TicTacToeAgent.pt"

# helper functions
def supply_model(overwrite:bool=False):
  model = DeepQAgent(
      device        = DEVICE,
      epsilon       = EPSILON, 
      gamma         = GAMMA,
      state_space   = STATE_SPACE, 
      action_space  = ACTION_SPACE, 
      hidden_size   = HIDDEN_SIZE,
      dropout       = DROPOUT,
      train_start   = TRAIN_START,
      batch_size    = BATCH_SIZE
  )

  if Path(MODEL_PATH).exists() and not overwrite:
    # load saved parameters
    print("Loading Model Parameters...")
    model.load_state_dict(torch.load(MODEL_PATH))
  else:
    # initialize parameters
    print("Initializing Model Parameters...")
    for p in model.parameters():
      if p.dim() > 1:
          nn.init.xavier_uniform_(p)
  
  model = model.to(DEVICE)

  # create optimizer and criterion
  optimizer = torch.optim.Adam(model.parameters(), lr=LEARNING_RATE)
  criterion = nn.SmoothL1Loss() # Huber Loss

  return model, optimizer, criterion

def train_agent(
    agent,
    num_episodes: int,
    epsilon,
    optimizer,
    criterion,
    device,
    save_path:str = "DeepQAgent.pt",
    opponent_level:str = "easy"
):
  reward_history = []
  environment = TicTacToeGame(device, opponent_level)
  for episode in range(num_episodes):
    state = environment.get_state()
    reward_total, done = 0, False
    steps = 0

    while not done:
      _, mask, indicies = environment.get_valid_moves()
      action = agent.select_action(state, mask, indicies)
      next_state, reward, done = environment.take_action(action)
      reward_total += reward
      agent.remember(state, action, reward, next_state, done)
      state = next_state.to(device) if next_state is not None else None
      agent.replay(optimizer, criterion)
      steps += 1

    timestampStr = datetime.now().strftime("%H:%M:%S")
    print(
        "episode: {}/{}, steps: {}, reward_total: {}, e: {:.2}, time: {}"
        .format(episode+1, num_episodes, steps, reward_total, agent.epsilon, timestampStr)
    )

    reward_history.append(reward_total)
    environment.print_board()
    environment.reset()
  
  agent.save_model(save_path)

def test(model, num_episodes, device, opponent_level="easy"):
  model.eval()
  with torch.no_grad():
    agent = model
    environment = TicTacToeGame(device, opponent_level)
    games_won = 0
    games_drawn = 0
    games_lost = 0
    for episode in tqdm(range(num_episodes)):
      state = environment.get_state()
      done = False
      steps = 0

      while not done:
        _, mask, _ = environment.get_valid_moves()
        q_values = agent.forward(state)
        q_masked = torch.where(mask != 0, q_values, -1000)
        action = torch.argmax(q_masked)
        next_state, reward, done = environment.take_action(action)

        steps += 1
        if done:
          # print(
          #   "episode: {}/{}, steps: {}, reward: {}"
          #   .format(episode+1, num_episodes, steps, reward)
          # )

          if reward == 1:
            games_won += 1
          elif reward == -1:
            games_drawn += 1
          elif reward == -2:
            games_lost += 1
          
          break
      
      # environment.print_board()
      environment.reset()
    
    print()
    print(f"Win rate: {round((games_won/num_episodes) * 100, 4)}%")
    print(f"Draw rate: {round((games_drawn/num_episodes) * 100, 4)}%")
    print(f"Loss rate: {round((games_lost/num_episodes) * 100, 4)}%")

# %% [markdown]
# #### **Results**
# **Baseline: Untrained Model** \
# Versus EASY opponent: Win rate: 50.42%, Draw rate: 22.52%, Loss rate: 27.06% \
# Versus HARD opponent: Win rate: 0.0%, Draw rate: 22.5%, Loss rate: 77.5%
#
# **Model 1: Naive Agent** - 6,000 episodes vs EASY \
# Versus EASY opponent: Win rate: 84.72%, Draw rate: 7.03%, Loss rate: 8.25% \
# Versus HARD opponent: Win rate: 24.6%, Draw rate: 0.0%, Loss rate: 75.4%
#
# **Model 2: Mixed Agent 1** - 11,000 episodes (6,000 vs EASY, 5,000 vs HARD) \
# Versus EASY opponent: Win rate: 76.86%, Draw rate: 8.01%, Loss rate: 15.13% \
# Versus HARD opponent: Win rate: 48.6%, Draw rate: 26.6%, Loss rate: 24.8%
#
# **Model 3: HARD Agent** - 2,000 episodes vs HARD \
# Versus EASY opponent: Win rate: 75.55%, Draw rate: 12.89%, Loss rate: 11.56% \
# Versus HARD opponent: Win rate: 25.2%, Draw rate: 25.8%, Loss rate: 49.0%
#
# **Model 4: Mixed Agent 2** - 3,000 episodes (2,000 vs HARD, 1,000 vs EASY) \
# Versus EASY opponent: Win rate: 53.3%, Draw rate: 6.95%, Loss rate: 39.75% \
# Versus HARD opponent: Win rate: 0.0%, Draw rate: 13.6%, Loss rate: 86.4%
#
# #### **Obstacles**
# Does a naive opponent make for a dull model? The answer is still unclear. I trained my agent against a naive opponent that made its moves randomly by selecting from a list of valid next moves. While the agent did learn to beat the opponent most of the time, it seemed to really love diagonals and had a hard time recognizing better moves. This led me to create an optimal opponent (hard mode).
#
# As I mentioned, the state space contains, in total, 19,683 states. This is a large space to search, but relatively feasible compared to that of something like Chess or Go. I assumed that my agent would be able to learn not to take actions that led to invalid states by punishing them with a large negative reward (i.e. -10). I was sorely mistaken. I trained the model for about 15,000 games with little to no improvement in output. Eventually, I opted to constrain the agents actions to only valid moves using a mask. Only then did I begin to see massive improvements in performance. I suspect the first method requires significantly more games to be played as well as a robust opponent to play against in order to make progress.
#
# #### **Conclusion**
# Surprisingly, the Naive Agent performed best against the easy opponent with a win rate of 84.72%. The Mixed Agent 1 had the second-best performance with a win rate of 76.86%. It also led in performance against the hard opponent with a win rate of 48.6%. For comparison, and untrained model had a win rate of 0.0% against the hard opponent while the Naive agent had half the performance with a win rate of 24.6%. It seems that a combination training against the easy and hard opponent can produce strong results when trained in that order. Conversely the Mixed Agent 2, which trained in the opposite order produced worse results, with a win rate of 0.0% against the hard opponent.
#
# As for next steps, I would test out more training configurations and even compare this to a tabular method.

# %% [markdown]
# ##### **Appendix**
# You can see the results for training against an easy opponent and a hard opponent here.
#
# ---

# %%
model, optimizer, criterion = supply_model(overwrite=False)
# Out:
# Loading Model Parameters...

# %%
train_agent(
    model,
    num_episodes    = NUM_EPISODES,
    epsilon         = EPSILON,
    optimizer       = optimizer,
    criterion       = criterion,
    device          = DEVICE,
    save_path       = MODEL_PATH,
    opponent_level  = "hard"
)
# Out:
# Streaming output truncated to the last 5000 lines.
# ‾‾‾‾‾‾‾
# episode: 4168/5000, steps: 5, reward_total: -1, e: 0.001, time: 00:42:40
# _______
# |O|X|O|
# |O|X|X|
# |X|O|X|
# ‾‾‾‾‾‾‾
# episode: 4169/5000, steps: 5, reward_total: -1, e: 0.001, time: 00:42:42
# _______
# |O|X|X|
# |X|O|O|
# |X|O|X|
# ‾‾‾‾‾‾‾
# episode: 4170/5000, steps: 3, reward_total: 1, e: 0.001, time: 00:42:43
# _______
# |O|O|X|
# |O|X| |
# |X| | |
# ‾‾‾‾‾‾‾
# episode: 4171/5000, steps: 3, reward_total: 1, e: 0.001, time: 00:42:43
# _______
# |O|O|X|
# |O|X| |
# |X| | |
# ‾‾‾‾‾‾‾
# episode: 4172/5000, steps: 4, reward_total: -2, e: 0.001, time: 00:42:45
# _______
# |O|O|X|
# |X|O|X|
# |X|O| |
# ‾‾‾‾‾‾‾
# episode: 4173/5000, steps: 4, reward_total: -2, e: 0.001, time: 00:42:46
# _______
# |X|O|X|
# |O|O|X|
# |X|O| |
# ‾‾‾‾‾‾‾
# episode: 4174/5000, steps: 3, reward_total: 1, e: 0.001, time: 00:42:48
# _______
# |O| |X|
# |O|X|O|
# |X| | |
# ‾‾‾‾‾‾‾
# episode: 4175/5000, steps: 3, reward_total: 1, e: 0.001, time: 00:42:49
# _______
# |O|O|X|
# |O|X| |
# |X| | |
# ‾‾‾‾‾‾‾
# episode: 4176/5000, steps: 4, reward_total: -2, e: 0.001, time: 00:42:50
# _______
# |X|O|X|
# |O|O|O|
# |X|X| |
# ‾‾‾‾‾‾‾
# episode: 4177/5000, steps: 5, reward_total: -1, e: 0.001, time: 00:42:51
# _______
# |O|X|X|
# |X|O|O|
# |X|O|X|
# ‾‾‾‾‾‾‾
# episode: 4178/5000, steps: 4, reward_total: -2, e: 0.001, time: 00:42:52
# _______
# |O|X|X|
# |X|O| |
# |X|O|O|
# ‾‾‾‾‾‾‾
# episode: 4179/5000, steps: 5, reward_total: -1, e: 0.001, time: 00:42:53
# _______
# |O|X|X|
# |X|O|O|
# |X|O|X|
# ‾‾‾‾‾‾‾
# episode: 4180/5000, steps: 3, reward_total: 1, e: 0.001, time: 00:42:54
# _______
# |O|O|X|
# |O|X| |
# |X| | |
# ‾‾‾‾‾‾‾
# episode: 4181/5000, steps: 5, reward_total: -1, e: 0.001, time: 00:42:55
# _______
# |X|O|X|
# |X|X|O|
# |O|X|O|
# ‾‾‾‾‾‾‾
# episode: 4182/5000, steps: 4, reward_total: -2, e: 0.001, time: 00:42:56
# _______
# |X|O|X|
# |O|O|O|
# |X|X| |
# ‾‾‾‾‾‾‾
# episode: 4183/5000, steps: 5, reward_total: -1, e: 0.001, time: 00:42:58
# _______
# |X|O|X|
# |O|X|X|
# |O|X|O|
# ‾‾‾‾‾‾‾
# episode: 4184/5000, steps: 3, reward_total: 1, e: 0.001, time: 00:42:59
# _______
# |O| |X|
# |O|X| |
# |X|O| |
# ‾‾‾‾‾‾‾
# episode: 4185/5000, steps: 3, reward_total: 1, e: 0.001, time: 00:43:00
# _______
# |O| |X|
# |O|X|O|
# |X| | |
# ‾‾‾‾‾‾‾
# episode: 4186/5000, steps: 3, reward_total: 1, e: 0.001, time: 00:43:01
# _______
# |O| |X|
# |O|X| |
# |X| |O|
# ‾‾‾‾‾‾‾
# episode: 4187/5000, steps: 4, reward_total: -2, e: 0.001, time: 00:43:03
# _______
# |X|O|X|
# |O|O|O|
# |X|X| |
# ‾‾‾‾‾‾‾
# episode: 4188/5000, steps: 3, reward_total: 1, e: 0.001, time: 00:43:04
# _______
# |O| |X|
# |O|X|O|
# |X| | |
# ‾‾‾‾‾‾‾
# episode: 4189/5000, steps: 4, reward_total: -2, e: 0.001, time: 00:43:05
# _______
# |X|O|X|
# |O|O|X|
# |X|O| |
# ‾‾‾‾‾‾‾
# episode: 4190/5000, steps: 3, reward_total: 1, e: 0.001, time: 00:43:06
# _______
# |O| |X|
# |O|X|O|
# |X| | |
# ‾‾‾‾‾‾‾
# episode: 4191/5000, steps: 5, reward_total: -1, e: 0.001, time: 00:43:07
# _______
# |X|O|X|
# |O|X|X|
# |O|X|O|
# ‾‾‾‾‾‾‾
# episode: 4192/5000, steps: 5, reward_total: -1, e: 0.001, time: 00:43:08
# _______
# |O|O|X|
# |X|X|O|
# |O|X|X|
# ‾‾‾‾‾‾‾
# episode: 4193/5000, steps: 5, reward_total: -1, e: 0.001, time: 00:43:10
# _______
# |O|O|X|
# |X|X|O|
# |O|X|X|
# ‾‾‾‾‾‾‾
# episode: 4194/5000, steps: 5, reward_total: -1, e: 0.001, time: 00:43:11
# _______
# |O|X|O|
# |O|X|X|
# |X|O|X|
# ‾‾‾‾‾‾‾
# episode: 4195/5000, steps: 3, reward_total: 1, e: 0.001, time: 00:43:12
# _______
# |O|O|X|
# |O|X| |
# |X| | |
# ‾‾‾‾‾‾‾
# episode: 4196/5000, steps: 5, reward_total: -1, e: 0.001, time: 00:43:14
# _______
# |O|X|X|
# |X|O|O|
# |X|O|X|
# ‾‾‾‾‾‾‾
# episode: 4197/5000, steps: 3, reward_total: 1, e: 0.001, time: 00:43:15
# _______
# |O| |X|
# |O|X|O|
# |X| | |
# ‾‾‾‾‾‾‾
# episode: 4198/5000, steps: 3, reward_total: 1, e: 0.001, time: 00:43:16
# _______
# |O|O|X|
# |O|X| |
# |X| | |
# ‾‾‾‾‾‾‾
# episode: 4199/5000, steps: 5, reward_total: -1, e: 0.001, time: 00:43:18
# _______
# |O|O|X|
# |X|X|O|
# |O|X|X|
# ‾‾‾‾‾‾‾
# episode: 4200/5000, steps: 5, reward_total: -1, e: 0.001, time: 00:43:19
# _______
# |O|X|O|
# |O|X|X|
# |X|O|X|
# ‾‾‾‾‾‾‾
# episode: 4201/5000, steps: 4, reward_total: -2, e: 0.001, time: 00:43:20
# _______
# |O|X|X|
# |X|O| |
# |X|O|O|
# ‾‾‾‾‾‾‾
# episode: 4202/5000, steps: 3, reward_total: -2, e: 0.001, time: 00:43:21
# _______
# |X|O|X|
# |X|O| |
# | |O| |
# ‾‾‾‾‾‾‾
# episode: 4203/5000, steps: 3, reward_total: 1, e: 0.001, time: 00:43:22
# _______
# |O| |X|
# |O|X|O|
# |X| | |
# ‾‾‾‾‾‾‾
# episode: 4204/5000, steps: 4, reward_total: -2, e: 0.001, time: 00:43:23
# _______
# |X|O|X|
# |O|O|O|
# |X|X| |
# ‾‾‾‾‾‾‾
# episode: 4205/5000, steps: 3, reward_total: 1, e: 0.001, time: 00:43:24
# _______
# |O|O|X|
# |O|X| |
# |X| | |
# ‾‾‾‾‾‾‾
# episode: 4206/5000, steps: 3, reward_total: 1, e: 0.001, time: 00:43:25
# _______
# |O| |X|
# |O|X| |
# |X| |O|
# ‾‾‾‾‾‾‾
# episode: 4207/5000, steps: 3, reward_total: 1, e: 0.001, time: 00:43:26
# _______
# |O|O|X|
# |O|X| |
# |X| | |
# ‾‾‾‾‾‾‾
# episode: 4208/5000, steps: 4, reward_total: -2, e: 0.001, time: 00:43:28
# _______
# |X|O|X|
# |O|O|O|
# |X|X| |
# ‾‾‾‾‾‾‾
# episode: 4209/5000, steps: 5, reward_total: -1, e: 0.001, time: 00:43:29
# _______
# |X|O|X|
# |O|X|X|
# |O|X|O|
# ‾‾‾‾‾‾‾
# episode: 4210/5000, steps: 4, reward_total: -2, e: 0.001, time: 00:43:30
# _______
# |X|O|X|
# |O|O| |
# |X|O|X|
# ‾‾‾‾‾‾‾
# episode: 4211/5000, steps: 4, reward_total: -2, e: 0.001, time: 00:43:32
# _______
# |X|O|X|
# |O|O|X|
# |X|O| |
# ‾‾‾‾‾‾‾
# episode: 4212/5000, steps: 3, reward_total: 1, e: 0.001, time: 00:43:33
# _______
# |O|O|X|
# |O|X| |
# |X| | |
# ‾‾‾‾‾‾‾
# episode: 4213/5000, steps: 5, reward_total: -1, e: 0.001, time: 00:43:34
# _______
# |O|O|X|
# |X|X|O|
# |O|X|X|
# ‾‾‾‾‾‾‾
# episode: 4214/5000, steps: 5, reward_total: -1, e: 0.001, time: 00:43:35
# _______
# |O|O|X|
# |X|X|O|
# |O|X|X|
# ‾‾‾‾‾‾‾
# episode: 4215/5000, steps: 4, reward_total: -2, e: 0.001, time: 00:43:37
# _______
# |X|O|X|
# |O|O| |
# |X|O|X|
# ‾‾‾‾‾‾‾
# episode: 4216/5000, steps: 4, reward_total: -2, e: 0.001, time: 00:43:38
# _______
# |O|X|X|
# |X|O| |
# |X|O|O|
# ‾‾‾‾‾‾‾
# episode: 4217/5000, steps: 3, reward_total: 1, e: 0.001, time: 00:43:39
# _______
# |O|O|X|
# |O|X| |
# |X| | |
# ‾‾‾‾‾‾‾
# episode: 4218/5000, steps: 3, reward_total: 1, e: 0.001, time: 00:43
# _______
# |O| |X|
# |O|X| |
# |X| |O|
# ‾‾‾‾‾‾‾
# episode: 4993/5000, steps: 5, reward_total: -1, e: 0.001, time: 00:58:49
# _______
# |O|O|X|
# |X|X|O|
# |O|X|X|
# ‾‾‾‾‾‾‾
# episode: 4994/5000, steps: 3, reward_total: 1, e: 0.001, time: 00:58:50
# _______
# |O| |X|
# |O|X| |
# |X|O| |
# ‾‾‾‾‾‾‾
# episode: 4995/5000, steps: 3, reward_total: 1, e: 0.001, time: 00:58:51
# _______
# |O| |X|
# |O|X| |
# |X|O| |
# ‾‾‾‾‾‾‾
# episode: 4996/5000, steps: 3, reward_total: 1, e: 0.001, time: 00:58:52
# _______
# |O|O|X|
# |O|X| |
# |X| | |
# ‾‾‾‾‾‾‾
# episode: 4997/5000, steps: 3, reward_total: 1, e: 0.001, time: 00:58:53
# _______
# |O|O|X|
# |O|X| |
# |X| | |
# ‾‾‾‾‾‾‾
# episode: 4998/5000, steps: 3, reward_total: 1, e: 0.001, time: 00:58:53
# _______
# |O|O|X|
# |O|X| |
# |X| | |
# ‾‾‾‾‾‾‾
# episode: 4999/5000, steps: 3, reward_total: 1, e: 0.001, time: 00:58:54
# _______
# |O|O|X|
# |O|X| |
# |X| | |
# ‾‾‾‾‾‾‾
# episode: 5000/5000, steps: 3, reward_total: 1, e: 0.001, time: 00:58:56
# _______
# |O|O|X|
# |O|X| |
# |X| | |
# ‾‾‾‾‾‾‾
# Model saved to /content/drive/MyDrive/EE 473/TicTacToeAgent.pt

# %%
test(model, 10000, DEVICE, opponent_level="easy")
# Out:
# 100%|██████████| 10000/10000 [00:54<00:00, 182.15it/s]
# Win rate: 76.86%
# Draw rate: 8.01%
# Loss rate: 15.13%

# %%
test(model, 1000, DEVICE, opponent_level="hard")
# Out:
# 100%|██████████| 1000/1000 [06:45<00:00,  2.47it/s]
# Win rate: 48.6%
# Draw rate: 26.6%
# Loss rate: 24.8%

# %%
print("Untrained Model Results:")
# Out:
# Untrained Model Results:

# %%
# For comparison, this is how an untrained model
# performs against a naive opponent
test_model, _, _ = supply_model(overwrite=True)
test(test_model, 10000, DEVICE, opponent_level="easy")
# Out:
# Initializing Model Parameters...
# 100%|██████████| 10000/10000 [01:09<00:00, 143.77it/s]
# Win rate: 50.42%
# Draw rate: 22.52%
# Loss rate: 27.06%

# %%
# untrained model versus HARD opponent
test_model, _, _ = supply_model(overwrite=True)
test(test_model, 1000, DEVICE, opponent_level="hard")
# Out:
# Initializing Model Parameters...
# 100%|██████████| 1000/1000 [09:14<00:00,  1.80it/s]
# Win rate: 0.0%
# Draw rate: 22.5%
# Loss rate: 77.5%

# %%
def test_saved_model(opponent_level="easy"):
  test_model, _, _ = supply_model(overwrite=False)
  num_episodes = 10000 if opponent_level == "easy" else 1000
  test(test_model, num_episodes, DEVICE, opponent_level)

MODEL_PATH="/content/drive/MyDrive/EE 473/TicTacToeAgent-6000-episodes-naive.pt"
print("Naive Opponent Model (6000 episodes) Results:")
test_saved_model(opponent_level="easy")
test_saved_model(opponent_level="hard")
# Out:
# Naive Opponent Model (6000 episodes) Results:
# Loading Model Parameters...
# 100%|██████████| 10000/10000 [00:48<00:00, 205.77it/s]
# Win rate: 84.72%
# Draw rate: 7.03%
# Loss rate: 8.25%
# Loading Model Parameters...
# 100%|██████████| 1000/1000 [06:51<00:00,  2.43it/s]
# Win rate: 24.6%
# Draw rate: 0.0%
# Loss rate: 75.4%

# %%
model, optimizer, criterion = supply_model(overwrite=False)
# Out:
# Initializing Model Parameters...

# %%
train_agent(
    model,
    num_episodes    = 1000,
    epsilon         = EPSILON,
    optimizer       = optimizer,
    criterion       = criterion,
    device          = DEVICE,
    save_path       = MODEL_PATH,
    opponent_level  = "hard"
)
# Out:
# Streaming output truncated to the last 5000 lines.
# ‾‾‾‾‾‾‾
# episode: 168/1000, steps: 3, reward_total: 1, e: 0.034, time: 01:54:21
# _______
# |O|O|X|
# |O|X| |
# |X| | |
# ‾‾‾‾‾‾‾
# episode: 169/1000, steps: 3, reward_total: -2, e: 0.034, time: 01:54:22
# _______
# |O|O|O|
# |X|X| |
# | | |X|
# ‾‾‾‾‾‾‾
# episode: 170/1000, steps: 3, reward_total: -2, e: 0.034, time: 01:54:23
# _______
# | | |O|
# |X|X|O|
# |X| |O|
# ‾‾‾‾‾‾‾
# episode: 171/1000, steps: 5, reward_total: -1, e: 0.034, time: 01:54:24
# _______
# |X|O|X|
# |O|X|X|
# |O|X|O|
# ‾‾‾‾‾‾‾
# episode: 172/1000, steps: 3, reward_total: 1, e: 0.034, time: 01:54:25
# _______
# |O| |X|
# |O|X| |
# |X|O| |
# ‾‾‾‾‾‾‾
# episode:
# _______
# |O|O|X|
# |O|X| |
# |X| | |
# ‾‾‾‾‾‾‾
# episode: 285/1000, steps: 4, reward_total: -2, e: 0.023, time: 01:56:20
# _______
# |X|O|O|
# |X|O|X|
# |O|X| |
# ‾‾‾‾‾‾‾
# episode: 286/1000, steps: 3, reward_total: 1, e: 0.023, time: 01:56:21
# _______
# |O| |X|
# |O|X| |
# |X|O| |
# ‾‾‾‾‾‾‾
# episode: 287/1000, steps: 5, reward_total: -1, e: 0.023, time: 01:56:22
# _______
# |O|X|O|
# |O|X|X|
# |X|O|X|
# ‾‾‾‾‾‾‾
# episode: 288/1000, steps: 3, reward_total: 1, e: 0.023, time: 01:56:23
# _______
# |O|O|X|
# |O|X| |
# |X| | |
# ‾‾‾‾‾‾‾
# episode: 289/1000, steps: 5, reward_total: -1, e: 0.023, time: 01:56:24
# _______
# |O|X|O|
# |X|X|O|
# |X|O|X|
# ‾‾‾‾‾‾‾
# episode: 290/1000, steps: 3, reward_total: 1, e: 0.023, time: 01:56:25
# _______
# |O| |X|
# |O|X| |
# |X|O| |
# ‾‾‾‾‾‾‾
# episode: 291/1000, steps: 3, reward_total: -2, e: 0.022, time: 01:56:26
# _______
# | |X|X|
# |O|O|O|
# | | |X|
# ‾‾‾‾‾‾‾
# episode: 292/1000, steps: 5, reward_total: -1, e: 0.022, time: 01:56:27
# _______
# |O|X|O|
# |O|X|X|
# |X|O|X|
# ‾‾‾‾‾‾‾
# episode: 293/1000, steps: 5, reward_total: -1, e: 0.022, time: 01:56:28
# _______
# |O|X|O|
# |O|X|X|
# |X|O|X|
# ‾‾‾‾‾‾‾
# episode: 294/1000, steps: 3, reward_total: 1, e: 0.022, time: 01:56:29
# _______
# |O| |X|
# |O|X|O|
# |X| | |
# ‾‾‾‾‾‾‾
# episode: 295/1000, steps: 3, reward_total: -2, e: 0.022, time: 01:56:30
# _______
# | |X|O|
# | |X|O|
# |X| |O|
# ‾‾‾‾‾‾‾
# episode: 296/1000, steps: 3, reward_total: -2, e: 0.022, time: 01:56:31
# _______
# |O|X|X|
# |O|X| |
# |O| | |
# ‾‾‾‾‾‾‾
# episode: 297/1000, steps: 3, reward_total: 1, e: 0.022, time: 01:56:32
# _______
# |O| |X|
# |O|X| |
# |X|O| |
# ‾‾‾‾‾‾‾
# episode: 298/1000, steps: 3, reward_total: -2, e: 0.022, time: 01:56:33
# _______
# | |X|O|
# | |X|O|
# |X| |O|
# ‾‾‾‾‾‾‾
# episode: 299/1000, steps: 3, reward_total: -2, e: 0.022, time: 01:56:34
# _______
# | |X|O|
# | |X|O|
# |X| |O|
# ‾‾‾‾‾‾‾
# episode: 300/1000, steps: 5, reward_total: -1, e: 0.022, time: 01:56:36
# _______
# |O|O|X|
# |X|X|O|
# |O|X|X|
# ‾‾‾‾‾‾‾
# episode: 301/1000, steps: 3, reward_total: 1, e: 0.022, time: 01:56:37
# _______
# |O| |X|
# |O|X|O|
# |X| | |
# ‾‾‾‾‾‾‾
# episode: 302/1000, steps: 5, reward_total: -1, e: 0.022, time: 01:56:38
# _______
# |O|O|X|
# |X|X|O|
# |O|X|X|
# ‾‾‾‾‾‾‾
# episode: 303/1000, steps: 4, reward_total: -2, e: 0.021, time: 01:56:39
# _______
# |O|O|O|
# | |X|X|
# |X|X|O|
# ‾‾‾‾‾‾‾
# episode: 304/1000, steps: 3, reward_total: 1, e: 0.021, time: 01:56:40
# _______
# |O|O|X|
# |O|X| |
# |X| | |
# ‾‾‾‾‾‾‾
# episode: 305/1000, steps: 4, reward_total: -2, e: 0.021, time: 01:56:41
# _______
# |X|X|X|
# |O|X| |
# |O|O|O|
# ‾‾‾‾‾‾‾
# episode: 306/1000, steps: 5, reward_total: -1, e: 0.021, time: 01:56:42
# _______
# |O|X|O|
# |O|X|X|
# |X|O|X|
# ‾‾‾‾‾‾‾
# episode: 307/1000, steps: 5, reward_total: -1, e: 0.021, time: 01:56:43
# _______
# |O|O|X|
# |X|X|O|
# |O|X|X|
# ‾‾‾‾‾‾‾
# episode: 308/1000, steps: 3, reward_total: 1, e: 0.021, time: 01:56:44
# _______
# |O|O|X|
# |O|X| |
# |X| | |
# ‾‾‾‾‾‾‾
# episode: 309/1000, steps: 3, reward_total: -2, e: 0.021, time: 01:56:45
# _______
# | |X|O|
# | |X|O|
# |X| |O|
# ‾‾‾‾‾‾‾
# episode: 310/1000, steps: 3, reward_total: 1, e: 0.021, time: 01:56:46
# _______
# |O|O|X|
# |O|X| |
# |X| | |
# ‾‾‾‾‾‾‾
# episode: 311/1000, steps: 3, reward_total: 1, e: 0.021, time: 01:56:47
# _______
# |O|O|X|
# |O|X| |
# |X| | |
# ‾‾‾‾‾‾‾
# episode: 312/1000, steps: 5, reward_total: -1, e: 0.021, time: 01:56:49
# _______
# |O|X|O|
# |O|X|X|
# |X|O|X|
# ‾‾‾‾‾‾‾
# episode: 313/1000, steps: 3, reward_total: -2, e: 0.021, time: 01:56:49
# _______
# | |X|O|
# | |X|O|
# |X| |O|
# ‾‾‾‾‾‾‾
# episode: 314/1000, steps: 3, reward_total: 1, e: 0.021, time: 01:56:50
# _______
# |O| |X|
# |O|X|O|
# |X| | |
# ‾‾‾‾‾‾‾
# episode: 315/1000, steps: 3, reward_total: 1, e: 0.021, time: 01:56:51
# _______
# |O|O|X|
# |O|X| |
# |X| | |
# ‾‾‾‾‾‾‾
# episode: 316/1000, steps: 5, reward_total: -1, e: 0.02, time: 01:56:52
# _______
# |O|X|O|
# |O|X|X|
# |X|O|X|
# ‾‾‾‾‾‾‾
# episode: 317/1000, steps: 5, reward_total: -1, e: 0.02, time: 01:56:54
# _______
# |O|X|O|
# |O|X|X|
# |X|O|X|
# ‾‾‾‾‾‾‾
# episode: 318/1000, steps: 5, reward_total: -1, e: 0.02, time: 01:56:55
# _______
# |O|X|O|
# |O|X|X|
# |X|O|X|
# ‾‾‾‾‾‾‾
# episode: 319/1000, steps: 3, reward_total: 1, e: 0.02, time: 01:56:56
# _______
# |O| |X|
# |O|X| |
# |X|O| |
# ‾‾‾‾‾‾‾
# episode: 320/1000, steps: 3, reward_total: 1, e: 0.02, time: 01:56:56
# _______
# |O|O|X|
# |O|X| |
# |X| | |
# ‾‾‾‾‾‾‾
# episode: 321/1000, steps: 3, reward_total: 1, e: 0.02, time: 01:56:57
# _______
# |O| |X|
# |O|X|O|
# |X| | |
# ‾‾‾‾‾‾‾
# episode: 322/1000, steps: 3, reward_total: 1, e: 0.02, time: 01:56:59
# _______
# |O| |X|
# |O|X|O|
# |X| | |
# ‾‾‾‾‾‾‾
# episode:
# _______
# |O| |X|
# |O|X| |
# |X|O| |
# ‾‾‾‾‾‾‾
# episode: 976/1000, steps: 4, reward_total: 1, e: 0.0014, time: 02:08:56
# _______
# |O|O|X|
# |O|X| |
# |X|O|X|
# ‾‾‾‾‾‾‾
# episode: 977/1000, steps: 5, reward_total: -1, e: 0.0014, time: 02:08:58
# _______
# |O|X|O|
# |O|X|X|
# |X|O|X|
# ‾‾‾‾‾‾‾
# episode: 978/1000, steps: 4, reward_total: 1, e: 0.0014, time: 02:08:59
# _______
# |O|O|X|
# |O|X|O|
# |X|X| |
# ‾‾‾‾‾‾‾
# episode: 979/1000, steps: 5, reward_total: -1, e: 0.0014, time: 02:09:00
# _______
# |O|X|O|
# |X|X|O|
# |X|O|X|
# ‾‾‾‾‾‾‾
# episode: 980/1000, steps: 4, reward_total: 1, e: 0.0014, time: 02:09:01
# _______
# |O|O|X|
# |O|X| |
# |X|O|X|
# ‾‾‾‾‾‾‾
# episode: 981/1000, steps: 4, reward_total: 1, e: 0.0014, time: 02:09:02
# _______
# |O|O|X|
# |O|X|O|
# |X|X| |
# ‾‾‾‾‾‾‾
# episode: 982/1000, steps: 4, reward_total: 1, e: 0.0014, time: 02:09:03
# _______
# |O|O|X|
# |O|X|X|
# |X|O| |
# ‾‾‾‾‾‾‾
# episode: 983/1000, steps: 5, reward_total: -1, e: 0.0014, time: 02:09:04
# _______
# |O|X|O|
# |O|X|X|
# |X|O|X|
# ‾‾‾‾‾‾‾
# episode: 984/1000, steps: 4, reward_total: 1, e: 0.0014, time: 02:09:05
# _______
# |O|O|X|
# |O|X|O|
# |X|X| |
# ‾‾‾‾‾‾‾
# episode: 985/1000, steps: 5, reward_total: -1, e: 0.0014, time: 02:09:06
# _______
# |O|X|O|
# |O|X|X|
# |X|O|X|
# ‾‾‾‾‾‾‾
# episode: 986/1000, steps: 5, reward_total: -1, e: 0.0014, time: 02:09:07
# _______
# |O|X|O|
# |O|X|X|
# |X|O|X|
# ‾‾‾‾‾‾‾
# episode: 987/1000, steps: 5, reward_total: -1, e: 0.0013, time: 02:09:08
# _______
# |O|X|O|
# |O|X|X|
# |X|O|X|
# ‾‾‾‾‾‾‾
# episode: 988/1000, steps: 4, reward_total: 1, e: 0.0013, time: 02:09:10
# _______
# |O|O| |
# |O|X|O|
# |X|X|X|
# ‾‾‾‾‾‾‾
# episode: 989/1000, steps: 4, reward_total: 1, e: 0.0013, time: 02:09:11
# _______
# |O|O|X|
# |O|X|O|
# |X|X| |
# ‾‾‾‾‾‾‾
# episode: 990/1000, steps: 4, reward_total: 1, e: 0.0013, time: 02:09:12
# _______
# |O|O|X|
# |O|X|O|
# |X|X| |
# ‾‾‾‾‾‾‾
# episode: 991/1000, steps: 3, reward_total: 1, e: 0.0013, time: 02:09:13
# _______
# |O|O|X|
# |O|X| |
# |X| | |
# ‾‾‾‾‾‾‾
# episode: 992/1000, steps: 5, reward_total: -1, e: 0.0013, time: 02:09:14
# _______
# |O|X|O|
# |X|X|O|
# |X|O|X|
# ‾‾‾‾‾‾‾
# episode: 993/1000, steps: 5, reward_total: -1, e: 0.0013, time: 02:09:15
# _______
# |X|O|O|
# |O|X|X|
# |X|X|O|
# ‾‾‾‾‾‾‾
# episode: 994/1000, steps: 3, reward_total: 1, e: 0.0013, time: 02:09:16
# _______
# |O|O|X|
# |O|X| |
# |X| | |
# ‾‾‾‾‾‾‾
# episode: 995/1000, steps: 4, reward_total: 1, e: 0.0013, time: 02:09:17
# _______
# |O|O|X|
# |O|X|O|
# |X|X| |
# ‾‾‾‾‾‾‾
# episode: 996/1000, steps: 5, reward_total: -1, e: 0.0013, time: 02:09:18
# _______
# |O|X|O|
# |O|X|X|
# |X|O|X|
# ‾‾‾‾‾‾‾
# episode: 997/1000, steps: 5, reward_total: -1, e: 0.0013, time: 02:09:19
# _______
# |X|O|X|
# |O|X|X|
# |O|X|O|
# ‾‾‾‾‾‾‾
# episode: 998/1000, steps: 3, reward_total: 1, e: 0.0013, time: 02:09:20
# _______
# |O| |X|
# |O|X| |
# |X|O| |
# ‾‾‾‾‾‾‾
# episode: 999/1000, steps: 4, reward_total: 1, e: 0.0013, time: 02:09:21
# _______
# |O|O| |
# |O|X|O|
# |X|X|X|
# ‾‾‾‾‾‾‾
# episode: 1000/1000, steps: 5, reward_total: -1, e: 0.0013, time: 02:09:22
# _______
# |O|X|O|
# |O|X|X|
# |X|O|X|
# ‾‾‾‾‾‾‾
# Model saved to /content/drive/MyDrive/EE 473/TicTacToeAgent-6000-episodes-naive.pt

# %%
test(model, 10000, DEVICE, opponent_level="easy")
# Out:
# 100%|██████████| 10000/10000 [00:56<00:00, 175.82it/s]
# Win rate: 75.55%
# Draw rate: 12.89%
# Loss rate: 11.56%

# %%
test(model, 1000, DEVICE, opponent_level="hard")
# Out:
# 100%|██████████| 1000/1000 [06:35<00:00,  2.53it/s]
# Win rate: 25.2%
# Draw rate: 25.8%
# Loss rate: 49.0%

# %%
model.epsilon = 1.0
train_agent(
    model,
    num_episodes    = 1000,
    epsilon         = EPSILON,
    optimizer       = optimizer,
    criterion       = criterion,
    device          = DEVICE,
    save_path       = MODEL_PATH,
    opponent_level  = "easy"
)
# Out:
# Streaming output truncated to the last 5000 lines.
# ‾‾‾‾‾‾‾
# episode: 168/1000, steps: 3, reward_total: -2, e: 0.49, time: 02:18:52
# _______
# | |O| |
# |X|O| |
# |X|O|X|
# ‾‾‾‾‾‾‾
# episode: 169/1000, steps: 5, reward_total: 1, e: 0.49, time: 02:18:53
# _______
# |X|O|O|
# |O|X|X|
# |O|X|X|
# ‾‾‾‾‾‾‾
# episode: 170/1000, steps: 4, reward_total: 1, e: 0.49, time: 02:18:53
# _______
# |X|O|X|
# | |X|O|
# |X|O|O|
# ‾‾‾‾‾‾‾
# episode: 171/1000, steps: 5, reward_total: 1, e: 0.49, time: 02:18:54
# _______
# |X|O|O|
# |X|X|X|
# |O|O|X|
# ‾‾‾‾‾‾‾
# episode: 172/1000, steps: 4, reward_total: -2, e: 0.48, time: 02:18:55
# _______
# |X|O|X|
# |O|O| |
# |X|O|X|
# ‾‾‾‾‾‾‾
# episode: 173/1000, steps: 5, reward_total: 1, e: 0.48, time: 02:18:55
# _______
# |X|O|O|
# |X|X|X|
# |O|X|O|
# ‾‾‾‾‾‾‾
# episode: 174/1000, steps: 4, reward_total: 1, e: 0.48, time: 02:18:56
# _______
# |O|X|O|
# |O|X|O|
# |X|X| |
# ‾‾‾‾‾‾‾
# episode: 175/1000, steps: 4, reward_total: 1, e: 0.48, time: 02:18:57
# _______
# |X|O|O|
# |X|X| |
# |O|O|X|
# ‾‾‾‾‾‾‾
# episode: 176/1000, steps: 4, reward_total: 1, e: 0.48, time: 02:18:57
# _______
# |X|X|O|
# | |X|O|
# |O|O|X|
# ‾‾‾‾‾‾‾
# episode: 177/1000, steps: 4, reward_total: 1, e: 0.47, time: 02:18:58
# _______
# |X|O| |
# |X|X|O|
# |O|O|X|
# ‾‾‾‾‾‾‾
# episode: 178/1000, steps: 4, reward_total: 1, e: 0.47, time: 02:18:59
# _______
# |X|O|O|
# |O|O| |
# |X|X|X|
# ‾‾‾‾‾‾‾
# episode: 179/1000, steps: 4, reward_total: -2, e: 0.47, time: 02:18:59
# _______
# |X| |O|
# |X|X|X|
# |O|O|O|
# ‾‾‾‾‾‾‾
# episode: 180/1000, steps: 4, reward_total: 1, e: 0.47, time: 02:19:00
# _______
# |O|O| |
# |X|X|X|
# |X|O|O|
# ‾‾‾‾‾‾‾
# episode: 181/1000, steps: 4, reward_total: 1, e: 0.47, time: 02:19:00
# _______
# |O|O| |
# |O|X|O|
# |X|X|X|
# ‾‾‾‾‾‾‾
# episode: 182/1000, steps: 5, reward_total: -1, e: 0.46, time: 02:19:01
# _______
# |O|O|X|
# |X|X|O|
# |O|X|X|
# ‾‾‾‾‾‾‾
# episode: 183/1000, steps: 4, reward_total: 1, e: 0.46, time: 02:19:02
# _______
# |O|O|O|
# |X|X|X|
# |O|X| |
# ‾‾‾‾‾‾‾
# episode: 184/1000, steps: 3, reward_total: 1, e: 0.46, time: 02:19:03
# _______
# |X| |O|
# | |X|O|
# |O| |X|
# ‾‾‾‾‾‾‾
# episode: 185/1000, steps: 4, reward_total: -2, e: 0.46, time: 02:19:03
# _______
# |X| |X|
# |O|X|X|
# |O|O|O|
# ‾‾‾‾‾‾‾
# episode: 186/1000, steps: 4, reward_total: 1, e: 0.46, time: 02:19:04
# _______
# |O| |X|
# |O|X|O|
# |X|X|O|
# ‾‾‾‾‾‾‾
# episode: 187/1000, steps: 5, reward_total: 1, e: 0.46, time: 02:19:05
# _______
# |O|O|X|
# |X|X|X|
# |O|X|O|
# ‾‾‾‾‾‾‾
# episode: 188/1000, steps: 4, reward_total: 1, e: 0.45, time: 02:19:06
# _______
# |X|O|O|
# |X|X|O|
# |X|O| |
# ‾‾‾‾‾‾‾
# episode: 189/1000, steps: 3, reward_total: 1, e: 0.45, time: 02:19:06
# _______
# | |O|O|
# | |O| |
# |X|X|X|
# ‾‾‾‾‾‾‾
# episode: 190/1000, steps: 3, reward_total: 1, e: 0.45, time: 02:19:07
# _______
# |X|O| |
# |O|X|O|
# | | |X|
# ‾‾‾‾‾‾‾
# episode: 191/1000, steps: 4, reward_total: -2, e: 0.45, time: 02:19:07
# _______
# |O| |O|
# |O|X|X|
# |O|X|X|
# ‾‾‾‾‾‾‾
# episode: 192/1000, steps: 4, reward_total: 1, e: 0.45, time: 02:19:08
# _______
# |X|O|O|
# |O|X| |
# |X|O|X|
# ‾‾‾‾‾‾‾
# episode: 193/1000, steps: 4, reward_total: 1, e: 0.45, time: 02:19:09
# _______
# |O|O|O|
# |X| |O|
# |X|X|X|
# ‾‾‾‾‾‾‾
# episode: 194/1000, steps: 3, reward_total: 1, e: 0.44, time: 02:19:09
# _______
# |O| | |
# |X|X|X|
# | |O|O|
# ‾‾‾‾‾‾‾
# episode: 195/1000, steps: 4, reward_total: -2, e: 0.44, time: 02:19:10
# _______
# |X|O|X|
# |X|O|O|
# |X|O| |
# ‾‾‾‾‾‾‾
# episode: 196/1000, steps: 4, reward_total: 1, e: 0.44, time: 02:19:10
# _______
# |X|X|X|
# |O| |O|
# |O|X|O|
# ‾‾‾‾‾‾‾
# episode: 197/1000, steps: 4, reward_total: 1, e: 0.44, time: 02:19:11
# _______
# |X|X| |
# |O|X|O|
# |O|X|O|
# ‾‾‾‾‾‾‾
# episode: 198/1000, steps: 4, reward_total: 1, e: 0.44, time: 02:19:12
# _______
# |O| |X|
# |O|X|O|
# |X|O|X|
# ‾‾‾‾‾‾‾
# episode: 199/1000, steps: 4, reward_total: 1, e: 0.44, time: 02:19:12
# _______
# |X|O|O|
# | |O|O|
# |X|X|X|
# ‾‾‾‾‾‾‾
# episode: 200/1000, steps: 4, reward_total: 1, e: 0.43, time: 02:19:13
# _______
# |X|X|X|
# |O|X|O|
# |O|O| |
# ‾‾‾‾‾‾‾
# episode: 201/1000, steps: 4, reward_total: -2, e: 0.43, time: 02:19:13
# _______
# |O| |O|
# |O|X|X|
# |O|X|X|
# ‾‾‾‾‾‾‾
# episode: 202/1000, steps: 4, reward_total: 1, e: 0.43, time: 02:19:14
# _______
# |X|X|X|
# |O|X|O|
# | |O|O|
# ‾‾‾‾‾‾‾
# episode: 203/1000, steps: 4, reward_total: 1, e: 0.43, time: 02:19:15
# _______
# |X|O| |
# |O|X|O|
# |X|O|X|
# ‾‾‾‾‾‾‾
# episode: 204/1000, steps: 5, reward_total: 1, e: 0.43, time: 02:19:16
# _______
# |O|X|O|
# |X|X|X|
# |O|X|O|
# ‾‾‾‾‾‾‾
# episode: 205/1000, steps: 4, reward_total: -2, e: 0.42, time: 02:19:17
# _______
# |O|O|X|
# |O|X| |
# |O|X|X|
# ‾‾‾‾‾‾‾
# episode: 206/1000, steps: 4, reward_total: -2, e: 0.42, time: 02:19:17
# _______
# |O| |X|
# |O|X|O|
# |O|X|X|
# ‾‾‾‾‾‾‾
# episode: 207/1000, steps: 4, reward_total: 1, e: 0.42, time: 02:19:18
# _______
# |X|O|O|
# |X|X|X|
# |O|O| |
# ‾‾‾‾‾‾‾
# episode: 208/1000, steps: 5, reward_total: -1, e: 0.42, time: 02:19:19
# _______
# |X|X|O|
# |O|O|X|
# |X|X|O|
# ‾‾‾‾‾‾‾
# episode: 209/1000, steps: 3, reward_total: 1, e: 0.42, time: 02:19:19
# _______
# |O|O|X|
# | |X| |
# |X|O| |
# ‾‾‾‾‾‾‾
# episode: 210/1000, steps: 4, reward_total: -2, e: 0.42, time: 02:19:20
# _______
# | |X|X|
# |X|X|O|
# |O|O|O|
# ‾‾‾‾‾‾‾
# episode: 211/1000, steps: 4, reward_total: 1, e: 0.41, time: 02:19:21
# _______
# |X|O|X|
# | |X|O|
# |O|O|X|
# ‾‾‾‾‾‾‾
# episode: 212/1000, steps: 4, reward_total: -2, e: 0.41, time: 02:19:21
# _______
# |X| |X|
# |O|O|O|
# |X|X|O|
# ‾‾‾‾‾‾‾
# episode: 213/1000, steps: 4, reward_total: 1, e: 0.41, time: 02:19:22
# _______
# |X|O| |
# |O|X|O|
# |X|O|X|
# ‾‾‾‾‾‾‾
# episode: 214/1000, steps: 5, reward_total: -1, e: 0.41, time: 02:19:23
# _______
# |X|O|X|
# |O|O|X|
# |X|X|O|
# ‾‾‾‾‾‾‾
# episode: 215/1000, steps: 4, reward_total: -2, e: 0.41, time: 02:19:23
# _______
# |O|O|O|
# |X| |X|
# |O|X|X|
# ‾‾‾‾‾‾‾
# episode: 216/1000, steps: 4, reward_total: 1, e: 0.41, time: 02:19:24
# _______
# |O|X|O|
# | |O|O|
# |X|X|X|
# ‾‾‾‾‾‾‾
# episode: 217/1000, steps: 4, reward_total: -2, e: 0.4, time: 02:19:25
# _______
# |O|O|O|
# |X|O|X|
# | |X|X|
# ‾‾‾‾‾‾‾
# episode: 218/1000, steps: 5, reward_total: 1, e: 0.4, time: 02:19:25
# _______
# |X|X|O|
# |O|X|X|
# |O|X|O|
# ‾‾‾‾‾‾‾
# episode: 219/1000, steps: 4, reward_total: -2, e: 0.4, time: 02:19:26
# _______
# |X|X|X|
# | |X|O|
# |O|O|O|
# ‾‾‾‾‾‾‾
# episode: 220/1000, steps: 5, reward_total: 1, e: 0.4, time: 02:19:27
# _______
# |X|X|O|
# |O|X|O|
# |X|O|X|
# ‾‾‾‾‾‾‾
# episode: 221/1000, steps: 5, reward_total: -1, e: 0.4, time: 02:19:27
# _______
# |X|X|O|
# |O|O|X|
# |X|O|X|
# ‾‾‾‾‾‾‾
# episode: 222/1000, steps: 3, reward_total: 1, e: 0.4, time: 02:19:28
# _______
# |O| |X|
# | |X|O|
# |X| |O|
# ‾‾‾‾‾‾‾
# episode: 223/1000, steps: 4, reward_total: -2, e: 0.39, time: 02:19:29
# _______
# |X|O|X|
# |O|O|X|
# |X|O| |
# ‾‾‾‾‾‾‾
# episode: 224/1000, steps: 5, reward_total: -1, e: 0.39, time: 02:19:30
# _______
# |X|O|O|
# |O|X|X|
# |X|X|O|
# ‾‾‾‾‾‾‾
# episode: 225/1000, steps: 4, reward_total: 1, e: 0.39, time: 02:19:31
# _______
# |X|O|O|
# |O| |O|
# |X|X|X|
# ‾‾‾‾‾‾‾
# episode: 226/1000, steps: 3, reward_total: 1, e: 0.39, time: 02:19:31
# _______
# |X| |O|
# | |X|O|
# |O| |X|
# ‾‾‾‾‾‾‾
# episode: 227/1000, steps: 3, reward_total: -2, e: 0.39, time: 02:19:32
# _______
# |X|X|X|
# | | | |
# |O|O|O|
# ‾‾‾‾‾‾‾
# episode: 228/1000, steps: 4, reward_total: -2, e: 0.39, time: 02:19:32
# _______
# |O|O|O|
# |X| |X|
# |O|X|X|
# ‾‾‾‾‾‾‾
# episode: 229/1000, steps: 4, reward_total: 1, e: 0.39, time: 02:19:33
# _______
# |O|X| |
# |X|X|O|
# |O|X|O|
# ‾‾‾‾‾‾‾
# episode: 230/1000, steps: 4, reward_total: -2, e: 0.38, time: 02:19:34
# _______
# |X|O|X|
# |X|X| |
# |O|O|O|
# ‾‾‾‾‾‾‾
# episode: 231/1000, steps: 5, reward_total: 1, e: 0.38, time: 02:19:34
# _______
# |X|O|X|
# |O|X|O|
# |X|X|O|
# ‾‾‾‾‾‾‾
# episode: 232/1000, steps: 5, reward_total: -1, e: 0.38, time: 02:19:35
# _______
# |X|O|X|
# |O|X|X|
# |O|X|O|
# ‾‾‾‾‾‾‾
# episode: 233/1000, steps: 4, reward_total: -2, e: 0.38, time: 02:19:36
# _______
# |X|O|O|
# |X|X|O|
# | |X|O|
# ‾‾‾‾‾‾‾
# episode: 234/1000, steps: 5, reward_total: 1, e: 0.38, time: 02:19:37
# _______
# |O|X|X|
# |O|X|X|
# |X|O|O|
# ‾‾‾‾‾‾‾
# episode: 235/1000, steps: 4, reward_total: -2, e: 0.37, time: 02:19:37
# _______
# |X| |X|
# |O|X|X|
# |O|O|O|
# ‾‾‾‾‾‾‾
# episode: 236/1000, steps: 5, reward_total: 1, e: 0.37, time: 02:19:38
# _______
# |X|O|O|
# |X|X|O|
# |O|X|X|
# ‾‾‾‾‾‾‾
# episode: 237/1000, steps: 4, reward_total: 1, e: 0.37, time: 02:19:39
# _______
# |O|O|X|
# |O| |O|
# |X|X|X|
# ‾‾‾‾‾‾‾
# episode: 238/1000, steps: 5, reward_total: 1, e: 0.37, time: 02:19:39
# _______
# |X|O|O|
# |X|O|O|
# |X|X|X|
# ‾‾‾‾‾‾‾
# episode: 239/1000, steps: 4, reward_total: -2, e: 0.37, time: 02:19:40
# _______
# |X| |O|
# |X|X|X|
# |O|O|O|
# ‾‾‾‾‾‾‾
# episode: 240/1000, steps: 5, reward_total: 1, e: 0.37, time: 02:19:41
# _______
# |X|X|O|
# |X|X|O|
# |O|O|X|
# ‾‾‾‾‾‾‾
# episode: 241/1000, steps: 5, reward_total: -1, e: 0.36, time: 02:19:42
# _______
# |O|O|X|
# |X|X|O|
# |O|X|X|
# ‾‾‾‾‾‾‾
# episode: 242/1000, steps: 4, reward_total: 1, e: 0.36, time: 02:19:42
# _______
# |O| |X|
# |O|X|O|
# |X|X|O|
# ‾‾‾‾‾‾‾
# episode: 243/1000, steps: 4, reward_total: 1, e: 0.36, time: 02:19:43
# _______
# |X| |O|
# |X|X|O|
# |O|O|X|
# ‾‾‾‾‾‾‾
# episode: 244/1000, steps: 4, reward_total: 1, e: 0.36, time: 02:19:44
# _______
# |O|O|X|
# | |O|O|
# |X|X|X|
# ‾‾‾‾‾‾‾
# episode: 245/1000, steps: 4, reward_total: -2, e: 0.36, time: 02:19:45
# _______
# |X|O| |
# |X|O|O|
# |X|O|X|
# ‾‾‾‾‾‾‾
# episode: 246/1000, steps: 4, reward_total: -2, e: 0.36, time: 02:19:45
# _______
# |X|X|O|
# | |X|O|
# |X|O|O|
# ‾‾‾‾‾‾‾
# episode: 247/1000, steps: 4, reward_total: -2, e: 0.36, time: 02:19:46
# _______
# |X|X|O|
# | |O|X|
# |O|O|X|
# ‾‾‾‾‾‾‾
# episode: 248/1000, steps: 3, reward_total: 1, e: 0.35, time: 02:19:47
# _______
# |X|O| |
# |X| |O|
# |X| |O|
# ‾‾‾‾‾‾‾
# episode: 249/1000, steps: 5, reward_total: -1, e: 0.35, time: 02:19:47
# _______
# |O|X|O|
# |O|X|X|
# |X|O|X|
# ‾‾‾‾‾‾‾
# episode: 250/1000, steps: 4, reward_total: 1, e: 0.35, time: 02:19:48
# _______
# |X|X|X|
# |O|X|O|
# |O|O| |
# ‾‾‾‾‾‾‾
# episode: 251/1000, steps: 5, reward_total: -1, e: 0.35, time: 02:19:49
# _______
# |X|X|O|
# |O|O|X|
# |X|O|X|
# ‾‾‾‾‾‾‾
# episode: 252/1000, steps: 4, reward_total: -2, e: 0.35, time: 02:19:49
# _______
# |X|X|O|
# | |X|O|
# |X|O|O|
# ‾‾‾‾‾‾‾
# episode: 253/1000, steps: 5, reward_total: 1, e: 0.35, time: 02:19:50
# _______
# |O|X|O|
# |X|X|X|
# |X|O|O|
# ‾‾‾‾‾‾‾
# episode: 254/1000, steps: 3, reward_total: -2, e: 0.35, time: 02:19:51
# _______
# |O|X| |
# |X|O| |
# |X| |O|
# ‾‾‾‾‾‾‾
# episode: 255/1000, steps: 4, reward_total: 1, e: 0.34, time: 02:19:51
# _______
# | |O|O|
# |X|O|O|
# |X|X|X|
# ‾‾‾‾‾‾‾
# episode: 256/1000, steps: 3, reward_total: 1, e: 0.34, time: 02:19:52
# _______
# | | |X|
# |O|X|O|
# |X| |O|
# ‾‾‾‾‾‾‾
# episode: 257/1000, steps: 4, reward_total: -2, e: 0.34, time: 02:19:52
# _______
# |O|O| |
# |X|O|X|
# |X|O|X|
# ‾‾‾‾‾‾‾
# episode: 258/1000, steps: 4, reward_total: 1, e: 0.34, time: 02:19:53
# _______
# | |O|X|
# |O|X|O|
# |X|X|O|
# ‾‾‾‾‾‾‾
# episode: 259/1000, steps: 3, reward_total: -2, e: 0.34, time: 02:19:53
# _______
# |X| |O|
# |X|O| |
# |O| |X|
# ‾‾‾‾‾‾‾
# episode: 260/1000, steps: 4, reward_total: 1, e: 0.34, time: 02:19:54
# _______
# |X|O|O|
# |O|O| |
# |X|X|X|
# ‾‾‾‾‾‾‾
# episode: 261/1000, steps: 5, reward_total: 1, e: 0.34, time: 02:19:55
# _______
# |X|O|O|
# |X|X|O|
# |O|X|X|
# ‾‾‾‾‾‾‾
# episode: 262/1000, steps: 3, reward_total: -2, e: 0.34, time: 02:19:55
# _______
# | | |O|
# |X|O| |
# |O|X|X|
# ‾‾‾‾‾‾‾
# episode: 263/1000, steps: 4, reward_total: 1, e: 0.33, time: 02:19:56
# _______
# |O|O| |
# |X|X|X|
# |O|X|O|
# ‾‾‾‾‾‾‾
# episode: 264/1000, steps: 4, reward_total: -2, e: 0.33, time: 02:19:57
# _______
# |X|X|O|
# |X|O| |
# |O|X|O|
# ‾‾‾‾‾‾‾
# episode: 265/1000, steps: 3, reward_total: -2, e: 0.33, time: 02:19:58
# _______
# |X|O| |
# | |O|X|
# |X|O| |
# ‾‾‾‾‾‾‾
# episode: 266/1000, steps: 5, reward_total: 1, e: 0.33, time: 02:19:58
# _______
# |O|O|X|
# |O|X|X|
# |X|X|O|
# ‾‾‾‾‾‾‾
# episode: 267/1000, steps: 3, reward_total: 1, e: 0.33, time: 02:19:59
# _______
# | | |X|
# | |X|O|
# |X|O|O|
# ‾‾‾‾‾‾‾
# episode: 268/1000, steps: 4, reward_total: 1, e: 0.33, time: 02:20:00
# _______
# |X|X| |
# |O|X|O|
# |O|X|O|
# ‾‾‾‾‾‾‾
# episode: 269/1000, steps: 4, reward_total: -2, e: 0.33, time: 02:20:00
# _______
# |O|O|O|
# |X| |X|
# |X|X|O|
# ‾‾‾‾‾‾‾
# episode: 270/1000, steps: 3, reward_total: 1, e: 0.33, time: 02:20:01
# _______
# |O| |X|
# |O|X| |
# |X| |O|
# ‾‾‾‾‾‾‾
# episode: 271/1000, steps: 4, reward_total: 1, e: 0.32, time: 02:20:01
# _______
# |X|O|O|
# |O|X|X|
# | |O|X|
# ‾‾‾‾‾‾‾
# episode: 272/1000, steps: 3, reward_total: -2, e: 0.32, time: 02:20:02
# _______
# |O| |X|
# |O|X| |
# |O|X| |
# ‾‾‾‾‾‾‾
# episode: 273/1000, steps: 3, reward_total: 1, e: 0.32, time: 02:20:02
# _______
# |X| | |
# |O|X|O|
# |O| |X|
# ‾‾‾‾‾‾‾
# episode: 274/1000, steps: 3, reward_total: 1, e: 0.32, time: 02:20:03
# _______
# | |O|X|
# |O|X| |
# |X|O| |
# ‾‾‾‾‾‾‾
# episode: 275/1000, steps: 4, reward_total: 1, e: 0.32, time: 02:20:03
# _______
# |X|X|X|
# |O|X|O|
# |O|O| |
# ‾‾‾‾‾‾‾
# episode: 276/1000, steps: 5, reward_total: 1, e: 0.32, time: 02:20:04
# _______
# |X|X|O|
# |O|X|X|
# |O|X|O|
# ‾‾‾‾‾‾‾
# episode: 277/1000, steps: 5, reward_total: -1, e: 0.32, time: 02:20:05
# _______
# |X|X|O|
# |O|X|X|
# |X|O|O|
# ‾‾‾‾‾‾‾
# episode: 278/1000, steps: 3, reward_total: 1, e: 0.32, time: 02:20:05
# _______
# |X| | |
# |O|X|O|
# |O| |X|
# ‾‾‾‾‾‾‾
# episode: 279/1000, steps: 3, reward_total: 1, e: 0.31, time: 02:20:06
# _______
# |O|X|O|
# |O|X| |
# | |X| |
# ‾‾‾‾‾‾‾
# episode: 280/1000, steps: 5, reward_total: -1, e: 0.31, time: 02:20:06
# _______
# |X|X|O|
# |O|X|X|
# |X|O|O|
# ‾‾‾‾‾‾‾
# episode: 281/1000, steps: 5, reward_total: 1, e: 0.31, time: 02:20:07
# _______
# |X|O|O|
# |O|O|X|
# |X|X|X|
# ‾‾‾‾‾‾‾
# episode: 282/1000, steps: 4, reward_total: -2, e: 0.31, time: 02:20:08
# _______
# |X|X|O|
# |O|X|O|
# |X| |O|
# ‾‾‾‾‾‾‾
# episode: 283/1000, steps: 3, reward_total: 1, e: 0.31, time: 02:20:08
# _______
# |O| | |
# |X|X|X|
# |O|O| |
# ‾‾‾‾‾‾‾
# episode: 284/1000, steps: 5, reward_total: -1, e: 0.31, time: 02:20:09
# _______
# |X|X|O|
# |O|O|X|
# |X|O|X|
# ‾‾‾‾‾‾‾
# episode: 285/1000, steps: 5, reward_total: -1, e: 0.31, time: 02:20:10
# _______
# |O|O|X|
# |X|X|O|
# |O|X|X|
# ‾‾‾‾‾‾‾
# episode: 286/1000, steps: 4, reward_total: 1, e: 0.31, time: 02:20:11
# _______
# |O|O|X|
# |O|X| |
# |X|X|O|
# ‾‾‾‾‾‾‾
# episode: 287/1000, steps: 3, reward_total: 1, e: 0.3, time: 02:20:12
# _______
# |X| |O|
# |X|O| |
# |X|O| |
# ‾‾‾‾‾‾‾
# episode: 288/1000, steps: 5, reward_total: 1, e: 0.3, time: 02:20:12
# _______
# |X|O|O|
# |X|X|X|
# |O|X|O|
# ‾‾‾‾‾‾‾
# episode: 289/1000, steps: 4, reward_total: -2, e: 0.3, time: 02:20:13
# _______
# |X| |O|
# |X|X|O|
# |X|O|O|
# ‾‾‾‾‾‾‾
# episode: 290/1000, steps: 4, reward_total: -2, e: 0.3, time: 02:20:14
# _______
# |O|X|X|
# |O|X|O|
# |O| |X|
# ‾‾‾‾‾‾‾
# episode: 291/1000, steps: 4, reward_total: -2, e: 0.3, time: 02:20:14
# _______
# |X|O|O|
# |X|O| |
# |O|X|X|
# ‾‾‾‾‾‾‾
# episode: 292/1000, steps: 4, reward_total: 1, e: 0.3, time: 02:20:15
# _______
# |X|O|X|
# | |X|O|
# |X|O|O|
# ‾‾‾‾‾‾‾
# episode: 293/1000, steps: 3, reward_total: -2, e: 0.3, time: 02:20:15
# _______
# |X| |O|
# | |O|X|
# |O|X| |
# ‾‾‾‾‾‾‾
# episode: 294/1000, steps: 4, reward_total: 1, e: 0.3, time: 02:20:16
# _______
# | |X|X|
# |O|X|O|
# |X|O|O|
# ‾‾‾‾‾‾‾
# episode: 295/1000, steps: 3, reward_total: 1, e: 0.3, time: 02:20:16
# _______
# |X| |O|
# | |X|O|
# |O| |X|
# ‾‾‾‾‾‾‾
# episode: 296/1000, steps: 4, reward_total: 1, e: 0.29, time: 02:20:17
# _______
# |O|O|X|
# |O|O| |
# |X|X|X|
# ‾‾‾‾‾‾‾
# episode: 297/1000, steps: 5, reward_total: -1, e: 0.29, time: 02:20:18
# _______
# |X|O|X|
# |O|O|X|
# |X|X|O|
# ‾‾‾‾‾‾‾
# episode: 298/1000, steps: 4, reward_total: -2, e: 0.29, time: 02:20:18
# _______
# |X|O|O|
# |X|O|X|
# |O|X| |
# ‾‾‾‾‾‾‾
# episode: 299/1000, steps: 4, reward_total: -2, e: 0.29, time: 02:20:19
# _______
# |X|O|X|
# | |O|O|
# |X|O|X|
# ‾‾‾‾‾‾‾
# episode: 300/1000, steps: 4, reward_total: -2, e: 0.29, time: 02:20:20
# _______
# |O|O|O|
# |X| |X|
# |O|X|X|
# ‾‾‾‾‾‾‾
# episode: 301/1000, steps: 4, reward_total: -2, e: 0.29, time: 02:20:20
# _______
# |O|O| |
# |X|O|X|
# |X|X|O|
# ‾‾‾‾‾‾‾
# episode: 302/1000, steps: 5, reward_total: 1, e: 0.29, time: 02:20:21
# _______
# |X|O|O|
# |X|X|O|
# |X|O|X|
# ‾‾‾‾‾‾‾
# episode: 303/1000, steps: 4, reward_total: 1, e: 0.29, time: 02:20:22
# _______
# | |O|O|
# |X|O|O|
# |X|X|X|
# ‾‾‾‾‾‾‾
# episode: 304/1000, steps: 5, reward_total: -1, e: 0.28, time: 02:20:23
# _______
# |X|O|X|
# |X|X|O|
# |O|X|O|
# ‾‾‾‾‾‾‾
# episode: 305/1000, steps: 4, reward_total: -2, e: 0.28, time: 02:20:23
# _______
# |X|X| |
# |O|O|O|
# |O|X|X|
# ‾‾‾‾‾‾‾
# episode: 306/1000, steps: 3, reward_total: 1, e: 0.28, time: 02:20:24
# _______
# |O|O|X|
# | |X| |
# |X| |O|
# ‾‾‾‾‾‾‾
# episode: 307/1000, steps: 4, reward_total: 1, e: 0.28, time: 02:20:25
# _______
# |O|O|X|
# | |X|O|
# |X|O|X|
# ‾‾‾‾‾‾‾
# episode: 308/1000, steps: 3, reward_total: 1, e: 0.28, time: 02:20:25
# _______
# |X|O|O|
# | |X| |
# | |O|X|
# ‾‾‾‾‾‾‾
# episode: 309/1000, steps: 3, reward_total: 1, e: 0.28, time: 02:20:26
# _______
# | | | |
# |O|O|O|
# |X|X|X|
# ‾‾‾‾‾‾‾
# episode: 310/1000, steps: 4, reward_total: 1, e: 0.28, time: 02:20:26
# _______
# |X|O|X|
# |O|X|O|
# |X| |O|
# ‾‾‾‾‾‾‾
# episode: 311/1000, steps: 3, reward_total: 1, e: 0.28, time: 02:20:27
# _______
# | |O| |
# | |O|O|
# |X|X|X|
# ‾‾‾‾‾‾‾
# episode: 312/1000, steps: 4, reward_total: 1, e: 0.28, time: 02:20:27
# _______
# |X| |O|
# |X|O|X|
# |X|O|O|
# ‾‾‾‾‾‾‾
# episode: 313/1000, steps: 3, reward_total: -2, e: 0.28, time: 02:20:28
# _______
# |X| |O|
# | |O|X|
# |O|X| |
# ‾‾‾‾‾‾‾
# episode: 314/1000, steps: 4, reward_total: 1, e: 0.27, time: 02:20:28
# _______
# |O|O|X|
# |O|X| |
# |X|O|X|
# ‾‾‾‾‾‾‾
# episode: 315/1000, steps: 5, reward_total: -1, e: 0.27, time: 02:20:29
# _______
# |X|X|O|
# |O|X|X|
# |X|O|O|
# ‾‾‾‾‾‾‾
# episode: 316/1000, steps: 4, reward_total: 1, e: 0.27, time: 02:20:30
# _______
# |O|O|O|
# |X|X|X|
# |X|O| |
# ‾‾‾‾‾‾‾
# episode: 317/1000, steps: 4, reward_total: -2, e: 0.27, time: 02:20:30
# _______
# |X|O|X|
# |O|O| |
# |X|O|X|
# ‾‾‾‾‾‾‾
# episode: 318/1000, steps: 4, reward_total: 1, e: 0.27, time: 02:20:31
# _______
# |X|O| |
# |X|X|O|
# |X|O|O|
# ‾‾‾‾‾‾‾
# episode: 319/1000, steps: 4, reward_total: -2, e: 0.27, time: 02:20:32
# _______
# |X| |O|
# |X|X|O|
# |O|X|O|
# ‾‾‾‾‾‾‾
# episode: 320/1000, steps: 4, reward_total: 1, e: 0.27, time: 02:20:32
# _______
# |O|O|X|
# |O|X|O|
# |X| |X|
# ‾‾‾‾‾‾‾
# episode: 321/1000, steps: 3, reward_total: -2, e: 0.27, time: 02:20:33
# _______
# |X| | |
# |O|O|O|
# |X| |X|
# ‾‾‾‾‾‾‾
# episode: 322/1000, steps: 3, reward_total: 1, e: 0.27, time: 02:20:33
# _______
# |X| |O|
# |O|X|O|
# | | |X|
# ‾‾‾‾‾‾‾
# episode: 323/1000, steps: 3, reward_total: 1, e: 0.26, time: 02:20:34
# _______
# |X|O| |
# | |X|O|
# | |O|X|
# ‾‾‾‾‾‾‾
# episode: 324/1000, steps: 4, reward_total: -2, e: 0.26, time: 02:20:34
# _______
# |X| |O|
# |X|O|X|
# |O|X|O|
# ‾‾‾‾‾‾‾
# episode: 325/1000, steps: 4, reward_total: 1, e: 0.26, time: 02:20:35
# _______
# | |O|O|
# |O|X|O|
# |X|X|X|
# ‾‾‾‾‾‾‾
# episode: 326/1000, steps: 4, reward_total: 1, e: 0.26, time: 02:20:36
# _______
# |O|O|X|
# |O|X|O|
# |X|X| |
# ‾‾‾‾‾‾‾
# episode: 327/1000, steps: 3, reward_total: 1, e: 0.26, time: 02:20:36
# _______
# |X|O|O|
# | |X|O|
# | | |X|
# ‾‾‾‾‾‾‾
# episode: 328/1000, steps: 3, reward_total: 1, e: 0.26, time: 02:20:37
# _______
# |X|O|O|
# | |X|O|
# | | |X|
# ‾‾‾‾‾‾‾
# episode: 329/1000, steps: 4, reward_total: 1, e: 0.26, time: 02:20:38
# _______
# |X|O|O|
# |O| |O|
# |X|X|X|
# ‾‾‾‾‾‾‾
# episode: 330/1000, steps: 3, reward_total: 1, e: 0.26, time: 02:20:38
# _______
# |O| |O|
# |O| | |
# |X|X|X|
# ‾‾‾‾‾‾‾
# episode: 331/1000, steps: 5, reward_total: -1, e: 0.26, time: 02:20:39
# _______
# |O|X|O|
# |X|X|O|
# |X|O|X|
# ‾‾‾‾‾‾‾
# episode: 332/1000, steps: 3, reward_total: 1, e: 0.26, time: 02:20:40
# _______
# |O| |O|
# |X|X|X|
# | | |O|
# ‾‾‾‾‾‾‾
# episode: 333/1000, steps: 4, reward_total: -2, e: 0.26, time: 02:20:40
# _______
# |X| |O|
# |X|X|O|
# |O|X|O|
# ‾‾‾‾‾‾‾
# episode: 334/1000, steps: 4, reward_total: 1, e: 0.25, time: 02:20:41
# _______
# |O|X| |
# |X|X|O|
# |O|X|O|
# ‾‾‾‾‾‾‾
# episode: 335/1000, steps: 3, reward_total: 1, e: 0.25, time: 02:20:41
# _______
# |O| |X|
# | |X| |
# |X|O|O|
# ‾‾‾‾‾‾‾
# episode: 336/1000, steps: 4, reward_total: -2, e: 0.25, time: 02:20:42
# _______
# |X| |O|
# |X|O|X|
# |O|X|O|
# ‾‾‾‾‾‾‾
# episode: 337/1000, steps: 4, reward_total: 1, e: 0.25, time: 02:20:42
# _______
# |X|O|O|
# |O|X| |
# |O|X|X|
# ‾‾‾‾‾‾‾
# episode: 338/1000, steps: 4, reward_total: 1, e: 0.25, time: 02:20:43
# _______
# |X|O|O|
# |O|X| |
# |O|X|X|
# ‾‾‾‾‾‾‾
# episode: 339/1000, steps: 5, reward_total: 1, e: 0.25, time: 02:20:44
# _______
# |X|O|O|
# |O|X|X|
# |X|O|X|
# ‾‾‾‾‾‾‾
# episode: 340/1000, steps: 5, reward_total: -1, e: 0.25, time: 02:20:45
# _______
# |O|X|X|
# |X|X|O|
# |O|O|X|
# ‾‾‾‾‾‾‾
# episode: 341/1000, steps: 4, reward_total: -2, e: 0.25, time: 02:20:45
# _______
# |X|X|O|
# | |X|O|
# |O|X|O|
# ‾‾‾‾‾‾‾
# episode: 342/1000, steps: 5, reward_total: -1, e: 0.25, time: 02:20:46
# _______
# |X|X|O|
# |O|X|X|
# |X|O|O|
# ‾‾‾‾‾‾‾
# episode: 343/1000, steps: 4, reward_total: -2, e: 0.24, time: 02:20:47
# _______
# |X|O|O|
# | |O|X|
# |O|X|X|
# ‾‾‾‾‾‾‾
# episode: 344/1000, steps: 4, reward_total: 1, e: 0.24, time: 02:20:47
# _______
# |O|O|O|
# | |X|O|
# |X|X|X|
# ‾‾‾‾‾‾‾
# episode: 345/1000, steps: 4, reward_total: 1, e: 0.24, time: 02:20:48
# _______
# |O|X|O|
# | |O|O|
# |X|X|X|
# ‾‾‾‾‾‾‾
# episode: 346/1000, steps: 4, reward_total: 1, e: 0.24, time: 02:20:49
# _______
# |X|O|O|
# |O|X| |
# |O|X|X|
# ‾‾‾‾‾‾‾
# episode: 347/1000, steps: 4, reward_total: -2, e: 0.24, time: 02:20:49
# _______
# |X| |O|
# |O|X|O|
# |X|X|O|
# ‾‾‾‾‾‾‾
# episode: 348/1000, steps: 4, reward_total: 1, e: 0.24, time: 02:20:50
# _______
# |O|X| |
# |X|X|O|
# |O|X|O|
# ‾‾‾‾‾‾‾
# episode: 349/1000, steps: 4, reward_total: 1, e: 0.24, time: 02:20:51
# _______
# |X|O|O|
# | |X|O|
# |X|O|X|
# ‾‾‾‾‾‾‾
# episode: 350/1000, steps: 5, reward_total: 1, e: 0.24, time: 02:20:52
# _______
# |X|O|X|
# |O|X|X|
# |X|O|O|
# ‾‾‾‾‾‾‾
# episode: 351/1000, steps: 3, reward_total: -2, e: 0.24, time: 02:20:52
# _______
# | | |O|
# |X|X|O|
# |X| |O|
# ‾‾‾‾‾‾‾
# episode: 352/1000, steps: 4, reward_total: -2, e: 0.24, time: 02:20:53
# _______
# |O|O|O|
# | |X|X|
# |X|X|O|
# ‾‾‾‾‾‾‾
# episode: 353/1000, steps: 4, reward_total: 1, e: 0.24, time: 02:20:53
# _______
# |X|O|O|
# |X|X|X|
# | |O|O|
# ‾‾‾‾‾‾‾
# episode: 354/1000, steps: 5, reward_total: -1, e: 0.23, time: 02:20:54
# _______
# |X|X|O|
# |O|X|X|
# |X|O|O|
# ‾‾‾‾‾‾‾
# episode: 355/1000, steps: 4, reward_total: 1, e: 0.23, time: 02:20:55
# _______
# |X|O|O|
# |O|X|O|
# | |X|X|
# ‾‾‾‾‾‾‾
# episode: 356/1000, steps: 5, reward_total: -1, e: 0.23, time: 02:20:56
# _______
# |O|O|X|
# |X|X|O|
# |O|X|X|
# ‾‾‾‾‾‾‾
# episode: 357/1000, steps: 4, reward_total: 1, e: 0.23, time: 02:20:56
# _______
# |O|O|O|
# |X|O| |
# |X|X|X|
# ‾‾‾‾‾‾‾
# episode: 358/1000, steps: 5, reward_total: 1, e: 0.23, time: 02:20:57
# _______
# |O|X|O|
# |O|X|X|
# |X|X|O|
# ‾‾‾‾‾‾‾
# episode: 359/1000, steps: 4, reward_total: 1, e: 0.23, time: 02:20:58
# _______
# |O|O| |
# |X|X|X|
# |O|O|X|
# ‾‾‾‾‾‾‾
# episode: 360/1000, steps: 5, reward_total: 1, e: 0.23, time: 02:20:58
# _______
# |O|X|X|
# |O|X|X|
# |X|O|O|
# ‾‾‾‾‾‾‾
# episode: 361/1000, steps: 5, reward_total: -1, e: 0.23, time: 02:20:59
# _______
# |O|X|O|
# |X|X|O|
# |X|O|X|
# ‾‾‾‾‾‾‾
# episode: 362/1000, steps: 3, reward_total: -2, e: 0.23, time: 02:20:59
# _______
# |X| |O|
# | |X|O|
# |X| |O|
# ‾‾‾‾‾‾‾
# episode: 363/1000, steps: 5, reward_total: 1, e: 0.22, time: 02:21:00
# _______
# |X|X|X|
# |O|X|O|
# |O|X|O|
# ‾‾‾‾‾‾‾
# episode: 364/1000, steps: 3, reward_total: 1, e: 0.22, time: 02:21:01
# _______
# |O|O|X|
# | | |X|
# | |O|X|
# ‾‾‾‾‾‾‾
# episode: 365/1000, steps: 5, reward_total: -1, e: 0.22, time: 02:21:02
# _______
# |X|O|X|
# |O|O|X|
# |X|X|O|
# ‾‾‾‾‾‾‾
# episode: 366/1000, steps: 3, reward_total: -2, e: 0.22, time: 02:21:02
# _______
# |O|O|O|
# |X| | |
# | |X|X|
# ‾‾‾‾‾‾‾
# episode: 367/1000, steps: 4, reward_total: 1, e: 0.22, time: 02:21:03
# _______
# |O| |O|
# |X|O|O|
# |X|X|X|
# ‾‾‾‾‾‾‾
# episode: 368/1000, steps: 4, reward_total: 1, e: 0.22, time: 02:21:04
# _______
# |X|O|X|
# |O|X| |
# |X|O|O|
# ‾‾‾‾‾‾‾
# episode: 369/1000, steps: 5, reward_total: -1, e: 0.22, time: 02:21:05
# _______
# |O|X|O|
# |O|X|X|
# |X|O|X|
# ‾‾‾‾‾‾‾
# episode: 370/1000, steps: 3, reward_total: 1, e: 0.22, time: 02:21:05
# _______
# |X|O|O|
# |O|X| |
# | | |X|
# ‾‾‾‾‾‾‾
# episode: 371/1000, steps: 5, reward_total: -1, e: 0.22, time: 02:21:06
# _______
# |X|X|O|
# |O|X|X|
# |X|O|O|
# ‾‾‾‾‾‾‾
# episode: 372/1000, steps: 4, reward_total: 1, e: 0.22, time: 02:21:07
# _______
# |O| |X|
# |O|X|O|
# |X|X|O|
# ‾‾‾‾‾‾‾
# episode: 373/1000, steps: 3, reward_total: 1, e: 0.22, time: 02:21:07
# _______
# |O| |X|
# |O|X| |
# |X| |O|
# ‾‾‾‾‾‾‾
# episode: 374/1000, steps: 4, reward_total: 1, e: 0.22, time: 02:21:08
# _______
# |O|X|X|
# |O|X|O|
# |X| |O|
# ‾‾‾‾‾‾‾
# episode: 375/1000, steps: 5, reward_total: 1, e: 0.21, time: 02:21:08
# _______
# |O|X|O|
# |X|X|X|
# |X|O|O|
# ‾‾‾‾‾‾‾
# episode: 376/1000, steps: 4, reward_total: -2, e: 0.21, time: 02:21:09
# _______
# |X| |O|
# |X|O|O|
# |O|X|X|
# ‾‾‾‾‾‾‾
# episode: 377/1000, steps: 3, reward_total: -2, e: 0.21, time: 02:21:10
# _______
# |O|O|O|
# |X|X| |
# | |X| |
# ‾‾‾‾‾‾‾
# episode: 378/1000, steps: 3, reward_total: 1, e: 0.21, time: 02:21:10
# _______
# | |O|X|
# |O|X|O|
# |X| | |
# ‾‾‾‾‾‾‾
# episode: 379/1000, steps: 3, reward_total: 1, e: 0.21, time: 02:21:10
# _______
# |O|X|O|
# | |X| |
# |O|X| |
# ‾‾‾‾‾‾‾
# episode: 380/1000, steps: 4, reward_total: 1, e: 0.21, time: 02:21:11
# _______
# |X|O|O|
# |X|X|X|
# |O| |O|
# ‾‾‾‾‾‾‾
# episode: 381/1000, steps: 4, reward_total: -2, e: 0.21, time: 02:21:12
# _______
# | |X|O|
# |X|O|X|
# |O|X|O|
# ‾‾‾‾‾‾‾
# episode: 382/1000, steps: 4, reward_total: 1, e: 0.21, time: 02:21:12
# _______
# |O| |X|
# |O|X|O|
# |X|X|O|
# ‾‾‾‾‾‾‾
# episode: 383/1000, steps: 4, reward_total: 1, e: 0.21, time: 02:21:13
# _______
# |O|O|X|
# | |O|X|
# |O|X|X|
# ‾‾‾‾‾‾‾
# episode: 384/1000, steps: 3, reward_total: 1, e: 0.21, time: 02:21:13
# _______
# |O|O|X|
# | |X| |
# |X| |O|
# ‾‾‾‾‾‾‾
# episode: 385/1000, steps: 4, reward_total: 1, e: 0.21, time: 02:21:14
# _______
# |O|O| |
# |X|X|X|
# |X|O|O|
# ‾‾‾‾‾‾‾
# episode: 386/1000, steps: 3, reward_total: 1, e: 0.21, time: 02:21:14
# _______
# |X|O|O|
# | |X| |
# |O| |X|
# ‾‾‾‾‾‾‾
# episode: 387/1000, steps: 5, reward_total: 1, e: 0.2, time: 02:21:15
# _______
# |O|X|O|
# |X|X|O|
# |O|X|X|
# ‾‾‾‾‾‾‾
# episode: 388/1000, steps: 3, reward_total: 1, e: 0.2, time: 02:21:16
# _______
# |O|X| |
# | |X| |
# |O|X|O|
# ‾‾‾‾‾‾‾
# episode: 389/1000, steps: 5, reward_total: -1, e: 0.2, time: 02:21:17
# _______
# |O|X|O|
# |X|X|O|
# |X|O|X|
# ‾‾‾‾‾‾‾
# episode: 390/1000, steps: 4, reward_total: -2, e: 0.2, time: 02:21:18
# _______
# |X|O|O|
# | |X|O|
# |X|X|O|
# ‾‾‾‾‾‾‾
# episode: 391/1000, steps: 3, reward_total: 1, e: 0.2, time: 02:21:18
# _______
# | |O| |
# |X|X|X|
# | |O|O|
# ‾‾‾‾‾‾‾
# episode: 392/1000, steps: 5, reward_total: -1, e: 0.2, time: 02:21:19
# _______
# |X|O|O|
# |O|X|X|
# |X|X|O|
# ‾‾‾‾‾‾‾
# episode: 393/1000, steps: 3, reward_total: 1, e: 0.2, time: 02:21:19
# _______
# |X|O| |
# |O|X| |
# | |O|X|
# ‾‾‾‾‾‾‾
# episode: 394/1000, steps: 5, reward_total: 1, e: 0.2, time: 02:21:20
# _______
# |O|X|X|
# |O|X|O|
# |X|O|X|
# ‾‾‾‾‾‾‾
# episode: 395/1000, steps: 5, reward_total: 1, e: 0.2, time: 02:21:21
# _______
# |X|O|O|
# |O|O|X|
# |X|X|X|
# ‾‾‾‾‾‾‾
# episode: 396/1000, steps: 5, reward_total: 1, e: 0.2, time: 02:21:22
# _______
# |O|O|X|
# |X|X|O|
# |X|X|O|
# ‾‾‾‾‾‾‾
# episode: 397/1000, steps: 5, reward_total: 1, e: 0.2, time: 02:21:22
# _______
# |X|X|O|
# |O|X|X|
# |O|X|O|
# ‾‾‾‾‾‾‾
# episode: 398/1000, steps: 3, reward_total: 1, e: 0.2, time: 02:21:23
# _______
# | |O|X|
# |O|X| |
# |X| |O|
# ‾‾‾‾‾‾‾
# episode: 399/1000, steps: 4, reward_total: 1, e: 0.19, time: 02:21:24
# _______
# |X|O|O|
# | |X|O|
# |O|X|X|
# ‾‾‾‾‾‾‾
# episode: 400/1000, steps: 3, reward_total: -2, e: 0.19, time: 02:21:24
# _______
# | | |O|
# |X|X|O|
# |X| |O|
# ‾‾‾‾‾‾‾
# episode: 401/1000, steps: 3, reward_total: 1, e: 0.19, time: 02:21:24
# _______
# | |O|O|
# |X|X|X|
# | | |O|
# ‾‾‾‾‾‾‾
# episode: 402/1000, steps: 3, reward_total: 1, e: 0.19, time: 02:21:25
# _______
# | |O| |
# |X|X|X|
# | |O|O|
# ‾‾‾‾‾‾‾
# episode: 403/1000, steps: 4, reward_total: 1, e: 0.19, time: 02:21:26
# _______
# |O|X|O|
# | |X|X|
# |O|X|O|
# ‾‾‾‾‾‾‾
# episode: 404/1000, steps: 3, reward_total: 1, e: 0.19, time: 02:21:26
# _______
# |O|X| |
# |O|X| |
# |O|X| |
# ‾‾‾‾‾‾‾
# episode: 405/1000, steps: 4, reward_total: -2, e: 0.19, time: 02:21:27
# _______
# |X|X|O|
# |X|O|O|
# |O|X| |
# ‾‾‾‾‾‾‾
# episode: 406/1000, steps: 5, reward_total: -1, e: 0.19, time: 02:21:27
# _______
# |O|X|O|
# |X|X|O|
# |X|O|X|
# ‾‾‾‾‾‾‾
# episode: 407/1000, steps: 5, reward_total: 1, e: 0.19, time: 02:21:28
# _______
# |O|X|O|
# |O|X|X|
# |X|X|O|
# ‾‾‾‾‾‾‾
# episode: 408/1000, steps: 3, reward_total: 1, e: 0.19, time: 02:21:29
# _______
# |O| |O|
# |X|X|X|
# | | |O|
# ‾‾‾‾‾‾‾
# episode: 409/1000, steps: 5, reward_total: 1, e: 0.19, time: 02:21:30
# _______
# |X|X|O|
# |O|X|X|
# |O|X|O|
# ‾‾‾‾‾‾‾
# episode: 410/1000, steps: 4, reward_total: 1, e: 0.19, time: 02:21:31
# _______
# |X|O| |
# |X|X|O|
# |O|O|X|
# ‾‾‾‾‾‾‾
# episode: 411/1000, steps: 5, reward_total: -1, e: 0.19, time: 02:21:31
# _______
# |X|X|O|
# |O|O|X|
# |X|O|X|
# ‾‾‾‾‾‾‾
# episode: 412/1000, steps: 4, reward_total: 1, e: 0.19, time: 02:21:32
# _______
# |O|O|X|
# |O|X| |
# |X|X|O|
# ‾‾‾‾‾‾‾
# episode: 413/1000, steps: 5, reward_total: -1, e: 0.18, time: 02:21:33
# _______
# |O|X|O|
# |O|X|X|
# |X|O|X|
# ‾‾‾‾‾‾‾
# episode: 414/1000, steps: 5, reward_total: 1, e: 0.18, time: 02:21:34
# _______
# |X|X|O|
# |X|O|X|
# |X|O|O|
# ‾‾‾‾‾‾‾
# episode: 415/1000, steps: 4, reward_total: 1, e: 0.18, time: 02:21:34
# _______
# |X|O|O|
# | |X|O|
# |X|O|X|
# ‾‾‾‾‾‾‾
# episode: 416/1000, steps: 5, reward_total: -1, e: 0.18, time: 02:21:35
# _______
# |X|O|X|
# |O|X|X|
# |O|X|O|
# ‾‾‾‾‾‾‾
# episode: 417/1000, steps: 3, reward_total: 1, e: 0.18, time: 02:21:35
# _______
# |O| |O|
# |X|X|X|
# |O| | |
# ‾‾‾‾‾‾‾
# episode: 418/1000, steps: 5, reward_total: 1, e: 0.18, time: 02:21:36
# _______
# |X|O|O|
# |X|X|X|
# |O|X|O|
# ‾‾‾‾‾‾‾
# episode: 419/1000, steps: 4, reward_total: 1, e: 0.18, time: 02:21:37
# _______
# |X|X|O|
# | |X|O|
# |O|O|X|
# ‾‾‾‾‾‾‾
# episode: 420/1000, steps: 5, reward_total: 1, e: 0.18, time: 02:21:38
# _______
# |O|X|X|
# |X|X|O|
# |X|O|O|
# ‾‾‾‾‾‾‾
# episode: 421/1000, steps: 3, reward_total: 1, e: 0.18, time: 02:21:38
# _______
# | |X| |
# |O|X|O|
# | |X|O|
# ‾‾‾‾‾‾‾
# episode: 422/1000, steps: 4, reward_total: 1, e: 0.18, time: 02:21:39
# _______
# | |O|O|
# |X|X|X|
# |O|O|X|
# ‾‾‾‾‾‾‾
# episode: 423/1000, steps: 5, reward_total: -1, e: 0.18, time: 02:21:39
# _______
# |X|X|O|
# |O|X|X|
# |X|O|O|
# ‾‾‾‾‾‾‾
# episode: 424/1000, steps: 5, reward_total: 1, e: 0.18, time: 02:21:40
# _______
# |X|O|O|
# |X|O|X|
# |X|X|O|
# ‾‾‾‾‾‾‾
# episode: 425/1000, steps: 3, reward_total: 1, e: 0.18, time: 02:21:41
# _______
# | | |O|
# |O|O| |
# |X|X|X|
# ‾‾‾‾‾‾‾
# episode: 426/1000, steps: 3, reward_total: 1, e: 0.17, time: 02:21:41
# _______
# | |O|X|
# | |X| |
# |X|O|O|
# ‾‾‾‾‾‾‾
# episode: 427/1000, steps: 4, reward_total: 1, e: 0.17, time: 02:21:42
# _______
# |X|O|O|
# | |X|X|
# |O|O|X|
# ‾‾‾‾‾‾‾
# episode: 428/1000, steps: 4, reward_total: 1, e: 0.17, time: 02:21:43
# _______
# | |O|X|
# |O|X|O|
# |X|X|O|
# ‾‾‾‾‾‾‾
# episode: 429/1000, steps: 4, reward_total: 1, e: 0.17, time: 02:21:44
# _______
# |O| |O|
# |O|X|O|
# |X|X|X|
# ‾‾‾‾‾‾‾
# episode: 430/1000, steps: 4, reward_total: 1, e: 0.17, time: 02:21:44
# _______
# |X|O|X|
# |O|X|O|
# |X|O| |
# ‾‾‾‾‾‾‾
# episode: 431/1000, steps: 4, reward_total: 1, e: 0.17, time: 02:21:45
# _______
# |X|O|O|
# |X|X|O|
# | |O|X|
# ‾‾‾‾‾‾‾
# episode: 432/1000, steps: 4, reward_total: 1, e: 0.17, time: 02:21:46
# _______
# |X|O|O|
# |X|X|O|
# | |O|X|
# ‾‾‾‾‾‾‾
# episode: 433/1000, steps: 3, reward_total: 1, e: 0.17, time: 02:21:46
# _______
# | |O|O|
# |X|X|X|
# |O| | |
# ‾‾‾‾‾‾‾
# episode: 434/1000, steps: 3, reward_total: 1, e: 0.17, time: 02:21:47
# _______
# |X|O| |
# |O|X| |
# | |O|X|
# ‾‾‾‾‾‾‾
# episode: 435/1000, steps: 3, reward_total: 1, e: 0.17, time: 02:21:47
# _______
# |O|X| |
# |O|X|O|
# | |X| |
# ‾‾‾‾‾‾‾
# episode: 436/1000, steps: 4, reward_total: 1, e: 0.17, time: 02:21:48
# _______
# |X|X|X|
# |O|O|X|
# |O| |O|
# ‾‾‾‾‾‾‾
# episode: 437/1000, steps: 4, reward_total: -2, e: 0.17, time: 02:21:48
# _______
# |X|X|X|
# | |X|O|
# |O|O|O|
# ‾‾‾‾‾‾‾
# episode: 438/1000, steps: 3, reward_total: 1, e: 0.17, time: 02:21:49
# _______
# |O| |O|
# |X|X|X|
# | | |O|
# ‾‾‾‾‾‾‾
# episode: 439/1000, steps: 5, reward_total: -1, e: 0.17, time: 02:21:49
# _______
# |O|X|O|
# |O|X|X|
# |X|O|X|
# ‾‾‾‾‾‾‾
# episode: 440/1000, steps: 4, reward_total: 1, e: 0.17, time: 02:21:50
# _______
# |O| |X|
# |O|X|O|
# |X|X|O|
# ‾‾‾‾‾‾‾
# episode: 441/1000, steps: 5, reward_total: 1, e: 0.16, time: 02:21:51
# _______
# |O|O|X|
# |O|X|X|
# |X|X|O|
# ‾‾‾‾‾‾‾
# episode: 442/1000, steps: 5, reward_total: -1, e: 0.16, time: 02:21:51
# _______
# |O|X|O|
# |O|X|X|
# |X|O|X|
# ‾‾‾‾‾‾‾
# episode: 443/1000, steps: 5, reward_total: -1, e: 0.16, time: 02:21:52
# _______
# |O|O|X|
# |X|X|O|
# |O|X|X|
# ‾‾‾‾‾‾‾
# episode: 444/1000, steps: 5, reward_total: 1, e: 0.16, time: 02:21:53
# _______
# |O|O|X|
# |O|X|X|
# |X|X|O|
# ‾‾‾‾‾‾‾
# episode: 445/1000, steps: 3, reward_total: -2, e: 0.16, time: 02:21:53
# _______
# |O|O|O|
# | |X| |
# |X|X| |
# ‾‾‾‾‾‾‾
# episode: 446/1000, steps: 4, reward_total: -2, e: 0.16, time: 02:21:54
# _______
# |X|X|X|
# | |X|O|
# |O|O|O|
# ‾‾‾‾‾‾‾
# episode: 447/1000, steps: 4, reward_total: 1, e: 0.16, time: 02:21:55
# _______
# |X|O|O|
# |X|X|X|
# |O| |O|
# ‾‾‾‾‾‾‾
# episode: 448/1000, steps: 3, reward_total: 1, e: 0.16, time: 02:21:55
# _______
# |X| | |
# | |X|O|
# |O|O|X|
# ‾‾‾‾‾‾‾
# episode: 449/1000, steps: 5, reward_total: -1, e: 0.16, time: 02:21:56
# _______
# |O|X|X|
# |X|X|O|
# |O|O|X|
# ‾‾‾‾‾‾‾
# episode: 450/1000, steps: 5, reward_total: 1, e: 0.16, time: 02:21:57
# _______
# |X|X|X|
# |O|O|X|
# |O|O|X|
# ‾‾‾‾‾‾‾
# episode: 451/1000, steps: 5, reward_total: -1, e: 0.16, time: 02:21:58
# _______
# |O|X|X|
# |X|O|O|
# |X|O|X|
# ‾‾‾‾‾‾‾
# episode: 452/1000, steps: 3, reward_total: 1, e: 0.16, time: 02:21:59
# _______
# |O|O| |
# |X|X|X|
# | | |O|
# ‾‾‾‾‾‾‾
# episode: 453/1000, steps: 4, reward_total: 1, e: 0.16, time: 02:21:59
# _______
# | |X|X|
# |O|X|O|
# |O|X|O|
# ‾‾‾‾‾‾‾
# episode: 454/1000, steps: 4, reward_total: 1, e: 0.16, time: 02:22:00
# _______
# |O|X|O|
# |O|X|X|
# | |X|O|
# ‾‾‾‾‾‾‾
# episode: 455/1000, steps: 5, reward_total: -1, e: 0.16, time: 02:22:01
# _______
# |X|O|X|
# |O|O|X|
# |X|X|O|
# ‾‾‾‾‾‾‾
# episode: 456/1000, steps: 4, reward_total: -2, e: 0.15, time: 02:22:01
# _______
# |O|X| |
# |X|O|O|
# |X|X|O|
# ‾‾‾‾‾‾‾
# episode: 457/1000, steps: 5, reward_total: 1, e: 0.15, time: 02:22:02
# _______
# |X|X|O|
# |X|O|O|
# |X|O|X|
# ‾‾‾‾‾‾‾
# episode: 458/1000, steps: 4, reward_total: -2, e: 0.15, time: 02:22:03
# _______
# |O|O|O|
# | |X|X|
# |X|O|X|
# ‾‾‾‾‾‾‾
# episode: 459/1000, steps: 5, reward_total: 1, e: 0.15, time: 02:22:03
# _______
# |X|O|O|
# |O|X|X|
# |O|X|X|
# ‾‾‾‾‾‾‾
# episode: 460/1000, steps: 5, reward_total: 1, e: 0.15, time: 02:22:04
# _______
# |X|O|O|
# |X|X|X|
# |X|O|O|
# ‾‾‾‾‾‾‾
# episode: 461/1000, steps: 5, reward_total: -1, e: 0.15, time: 02:22:05
# _______
# |X|O|O|
# |O|X|X|
# |X|X|O|
# ‾‾‾‾‾‾‾
# episode: 462/1000, steps: 3, reward_total: 1, e: 0.15, time: 02:22:05
# _______
# |X| |O|
# |X|O| |
# |X| |O|
# ‾‾‾‾‾‾‾
# episode: 463/1000, steps: 3, reward_total: 1, e: 0.15, time: 02:22:06
# _______
# | |X| |
# |O|X|O|
# |O|X| |
# ‾‾‾‾‾‾‾
# episode: 464/1000, steps: 4, reward_total: 1, e: 0.15, time: 02:22:06
# _______
# |X|O|O|
# | |X|X|
# |O|O|X|
# ‾‾‾‾‾‾‾
# episode: 465/1000, steps: 3, reward_total: 1, e: 0.15, time: 02:22:07
# _______
# | |O| |
# |X|X|X|
# |O|O| |
# ‾‾‾‾‾‾‾
# episode: 466/1000, steps: 3, reward_total: 1, e: 0.15, time: 02:22:07
# _______
# | |X|O|
# | |X|O|
# |O|X| |
# ‾‾‾‾‾‾‾
# episode: 467/1000, steps: 4, reward_total: 1, e: 0.15, time: 02:22:08
# _______
# |O|X| |
# |X|X|O|
# |O|X|O|
# ‾‾‾‾‾‾‾
# episode: 468/1000, steps: 4, reward_total: 1, e: 0.15, time: 02:22:09
# _______
# |X|O|O|
# |O|X| |
# |X|O|X|
# ‾‾‾‾‾‾‾
# episode: 469/1000, steps: 5, reward_total: -1, e: 0.15, time: 02:22:10
# _______
# |O|X|O|
# |O|X|X|
# |X|O|X|
# ‾‾‾‾‾‾‾
# episode: 470/1000, steps: 4, reward_total: -2, e: 0.15, time: 02:22:11
# _______
# |O|O|O|
# |X|X|O|
# | |X|X|
# ‾‾‾‾‾‾‾
# episode: 471/1000, steps: 3, reward_total: -2, e: 0.15, time: 02:22:11
# _______
# | |X| |
# | |X|X|
# |O|O|O|
# ‾‾‾‾‾‾‾
# episode: 472/1000, steps: 4, reward_total: 1, e: 0.15, time: 02:22:12
# _______
# |O|X|X|
# |O|X|O|
# |X| |O|
# ‾‾‾‾‾‾‾
# episode: 473/1000, steps: 4, reward_total: 1, e: 0.14, time: 02:22:12
# _______
# |O|X|O|
# |X|X|X|
# |O| |O|
# ‾‾‾‾‾‾‾
# episode: 474/1000, steps: 3, reward_total: -2, e: 0.14, time: 02:22:13
# _______
# |O|O|O|
# |X|X| |
# | |X| |
# ‾‾‾‾‾‾‾
# episode: 475/1000, steps: 4, reward_total: -2, e: 0.14, time: 02:22:13
# _______
# |O| |X|
# |O|X|X|
# |O|X|O|
# ‾‾‾‾‾‾‾
# episode: 476/1000, steps: 4, reward_total: -2, e: 0.14, time: 02:22:14
# _______
# |O| |X|
# |X|X|X|
# |O|O|O|
# ‾‾‾‾‾‾‾
# episode: 477/1000, steps: 3, reward_total: 1, e: 0.14, time: 02:22:14
# _______
# | |X| |
# |O|X| |
# |O|X|O|
# ‾‾‾‾‾‾‾
# episode: 478/1000, steps: 4, reward_total: -2, e: 0.14, time: 02:22:15
# _______
# |O| |X|
# |O|X|X|
# |O|X|O|
# ‾‾‾‾‾‾‾
# episode: 479/1000, steps: 4, reward_total: 1, e: 0.14, time: 02:22:16
# _______
# | |O|X|
# |O|X|X|
# |X|O|O|
# ‾‾‾‾‾‾‾
# episode: 480/1000, steps: 4, reward_total: -2, e: 0.14, time: 02:22:16
# _______
# |X|X|X|
# | |X|O|
# |O|O|O|
# ‾‾‾‾‾‾‾
# episode: 481/1000, steps: 5, reward_total: 1, e: 0.14, time: 02:22:17
# _______
# |O|X|O|
# |X|X|X|
# |O|O|X|
# ‾‾‾‾‾‾‾
# episode: 482/1000, steps: 5, reward_total: -1, e: 0.14, time: 02:22:18
# _______
# |X|O|X|
# |O|O|X|
# |X|X|O|
# ‾‾‾‾‾‾‾
# episode: 483/1000, steps: 5, reward_total: -1, e: 0.14, time: 02:22:19
# _______
# |X|O|X|
# |O|O|X|
# |X|X|O|
# ‾‾‾‾‾‾‾
# episode: 484/1000, steps: 4, reward_total: 1, e: 0.14, time: 02:22:19
# _______
# | |X|O|
# |O|X|O|
# |O|X|X|
# ‾‾‾‾‾‾‾
# episode: 485/1000, steps: 4, reward_total: -2, e: 0.14, time: 02:22:20
# _______
# |O|O|X|
# |O|X|X|
# |O|X| |
# ‾‾‾‾‾‾‾
# episode: 486/1000, steps: 4, reward_total: -2, e: 0.14, time: 02:22:20
# _______
# |O|O|X|
# |O|X|X|
# |O|X| |
# ‾‾‾‾‾‾‾
# episode: 487/1000, steps: 3, reward_total: 1, e: 0.14, time: 02:22:21
# _______
# | | |O|
# | |O|O|
# |X|X|X|
# ‾‾‾‾‾‾‾
# episode: 488/1000, steps: 3, reward_total: 1, e: 0.14, time: 02:22:21
# _______
# |O| | |
# | |O|O|
# |X|X|X|
# ‾‾‾‾‾‾‾
# episode: 489/1000, steps: 3, reward_total: 1, e: 0.14, time: 02:22:22
# _______
# |O|O|X|
# | |X| |
# |X|O| |
# ‾‾‾‾‾‾‾
# episode: 490/1000, steps: 4, reward_total: 1, e: 0.14, time: 02:22:23
# _______
# |X|O|O|
# | |O|O|
# |X|X|X|
# ‾‾‾‾‾‾‾
# episode: 491/1000, steps: 5, reward_total: -1, e: 0.13, time: 02:22:24
# _______
# |X|O|X|
# |O|X|X|
# |O|X|O|
# ‾‾‾‾‾‾‾
# episode: 492/1000, steps: 5, reward_total: 1, e: 0.13, time: 02:22:25
# _______
# |X|X|X|
# |O|O|X|
# |O|X|O|
# ‾‾‾‾‾‾‾
# episode: 493/1000, steps: 3, reward_total: 1, e: 0.13, time: 02:22:25
# _______
# |X|O|O|
# |X| | |
# |X| |O|
# ‾‾‾‾‾‾‾
# episode: 494/1000, steps: 4, reward_total: 1, e: 0.13, time: 02:22:26
# _______
# |O|O|X|
# |O|X|O|
# |X|X| |
# ‾‾‾‾‾‾‾
# episode: 495/1000, steps: 5, reward_total: 1, e: 0.13, time: 02:22:27
# _______
# |X|X|O|
# |X|O|O|
# |X|O|X|
# ‾‾‾‾‾‾‾
# episode: 496/1000, steps: 5, reward_total: -1, e: 0.13, time: 02:22:27
# _______
# |X|X|O|
# |O|O|X|
# |X|O|X|
# ‾‾‾‾‾‾‾
# episode: 497/1000, steps: 3, reward_total: 1, e: 0.13, time: 02:22:28
# _______
# |X|X|X|
# |O| |O|
# | | |O|
# ‾‾‾‾‾‾‾
# episode: 498/1000, steps: 5, reward_total: -1, e: 0.13, time: 02:22:28
# _______
# |X|O|X|
# |O|O|X|
# |X|X|O|
# ‾‾‾‾‾‾‾
# episode: 499/1000, steps: 4, reward_total: 1, e: 0.13, time: 02:22:29
# _______
# |O|O|X|
# | |X|O|
# |X|X|O|
# ‾‾‾‾‾‾‾
# episode: 500/1000, steps: 4, reward_total: 1, e: 0.13, time: 02:22:30
# _______
# |O|X| |
# |O|X|O|
# |X|X|O|
# ‾‾‾‾‾‾‾
# episode: 501/1000, steps: 5, reward_total: -1, e: 0.13, time: 02:22:30
# _______
# |X|X|O|
# |O|O|X|
# |X|O|X|
# ‾‾‾‾‾‾‾
# episode: 502/1000, steps: 4, reward_total: -2, e: 0.13, time: 02:22:31
# _______
# |O|X|X|
# |X|O| |
# |X|O|O|
# ‾‾‾‾‾‾‾
# episode: 503/1000, steps: 3, reward_total: 1, e: 0.13, time: 02:22:32
# _______
# |O| | |
# | |O|O|
# |X|X|X|
# ‾‾‾‾‾‾‾
# episode: 504/1000, steps: 5, reward_total: 1, e: 0.13, time: 02:22:32
# _______
# |O|X|O|
# |X|X|X|
# |O|O|X|
# ‾‾‾‾‾‾‾
# episode: 505/1000, steps: 5, reward_total: 1, e: 0.13, time: 02:22:33
# _______
# |X|O|X|
# |O|X|O|
# |X|X|O|
# ‾‾‾‾‾‾‾
# episode: 506/1000, steps: 5, reward_total: -1, e: 0.13, time: 02:22:34
# _______
# |X|O|X|
# |O|O|X|
# |X|X|O|
# ‾‾‾‾‾‾‾
# episode: 507/1000, steps: 3, reward_total: 1, e: 0.13, time: 02:22:34
# _______
# |X| |O|
# |X|O|O|
# |X| | |
# ‾‾‾‾‾‾‾
# episode: 508/1000, steps: 4, reward_total: 1, e: 0.13, time: 02:22:35
# _______
# |O|O| |
# |X|X|X|
# |O|X|O|
# ‾‾‾‾‾‾‾
# episode: 509/1000, steps: 4, reward_total: 1, e: 0.12, time: 02:22:36
# _______
# |O|O| |
# |X|X|X|
# |O|O|X|
# ‾‾‾‾‾‾‾
# episode: 510/1000, steps: 3, reward_total: 1, e: 0.12, time: 02:22:37
# _______
# |O| | |
# | |O|O|
# |X|X|X|
# ‾‾‾‾‾‾‾
# episode: 511/1000, steps: 5, reward_total: 1, e: 0.12, time: 02:22:38
# _______
# |X|X|O|
# |O|X|X|
# |O|X|O|
# ‾‾‾‾‾‾‾
# episode: 512/1000, steps: 4, reward_total: 1, e: 0.12, time: 02:22:38
# _______
# |X|O|O|
# |O|O| |
# |X|X|X|
# ‾‾‾‾‾‾‾
# episode: 513/1000, steps: 4, reward_total: 1, e: 0.12, time: 02:22:39
# _______
# |X|O| |
# |X|X|O|
# |O|O|X|
# ‾‾‾‾‾‾‾
# episode: 514/1000, steps: 4, reward_total: 1, e: 0.12, time: 02:22:39
# _______
# |X|O|O|
# |X|X|O|
# |O| |X|
# ‾‾‾‾‾‾‾
# episode: 515/1000, steps: 3, reward_total: 1, e: 0.12, time: 02:22:40
# _______
# | |O| |
# | |O|O|
# |X|X|X|
# ‾‾‾‾‾‾‾
# episode: 516/1000, steps: 3, reward_total: 1, e: 0.12, time: 02:22:40
# _______
# | | |X|
# |O|X|O|
# |X|O| |
# ‾‾‾‾‾‾‾
# episode: 517/1000, steps: 3, reward_total: 1, e: 0.12, time: 02:22:41
# _______
# |O|O|X|
# | |X| |
# |X|O| |
# ‾‾‾‾‾‾‾
# episode: 518/1000, steps: 5, reward_total: 1, e: 0.12, time: 02:22:42
# _______
# |X|X|O|
# |O|X|O|
# |X|O|X|
# ‾‾‾‾‾‾‾
# episode: 519/1000, steps: 4, reward_total: 1, e: 0.12, time: 02:22:42
# _______
# |O| |X|
# |X|X|O|
# |X|O|O|
# ‾‾‾‾‾‾‾
# episode: 520/1000, steps: 4, reward_total: -2, e: 0.12, time: 02:22:43
# _______
# |X|X|O|
# |O|O|O|
# |X| |X|
# ‾‾‾‾‾‾‾
# episode: 521/1000, steps: 4, reward_total: 1, e: 0.12, time: 02:22:43
# _______
# |X|X|O|
# | |X|O|
# |O|O|X|
# ‾‾‾‾‾‾‾
# episode: 522/1000, steps: 3, reward_total: 1, e: 0.12, time: 02:22:44
# _______
# | | | |
# |O|O|O|
# |X|X|X|
# ‾‾‾‾‾‾‾
# episode: 523/1000, steps: 3, reward_total: -2, e: 0.12, time: 02:22:44
# _______
# |O|O|O|
# |X| |X|
# |X| | |
# ‾‾‾‾‾‾‾
# episode: 524/1000, steps: 5, reward_total: 1, e: 0.12, time: 02:22:45
# _______
# |X|O|O|
# |X|X|X|
# |O|O|X|
# ‾‾‾‾‾‾‾
# episode: 525/1000, steps: 4, reward_total: 1, e: 0.12, time: 02:22:46
# _______
# |O|X|X|
# |O|X|O|
# |X| |O|
# ‾‾‾‾‾‾‾
# episode: 526/1000, steps: 3, reward_total: 1, e: 0.12, time: 02:22:46
# _______
# | |O|X|
# |O|X| |
# |X| |O|
# ‾‾‾‾‾‾‾
# episode: 527/1000, steps: 3, reward_total: 1, e: 0.12, time: 02:22:47
# _______
# |O|O| |
# |X|X|X|
# |O| | |
# ‾‾‾‾‾‾‾
# episode: 528/1000, steps: 3, reward_total: -2, e: 0.12, time: 02:22:47
# _______
# | | | |
# |X|X|X|
# |O|O|O|
# ‾‾‾‾‾‾‾
# episode: 529/1000, steps: 4, reward_total: 1, e: 0.12, time: 02:22:48
# _______
# |X|X|O|
# |O|X|O|
# | |O|X|
# ‾‾‾‾‾‾‾
# episode: 530/1000, steps: 3, reward_total: 1, e: 0.12, time: 02:22:48
# _______
# | |O|X|
# | |X| |
# |X|O|O|
# ‾‾‾‾‾‾‾
# episode: 531/1000, steps: 4, reward_total: 1, e: 0.11, time: 02:22:49
# _______
# |O|O|X|
# |O|O| |
# |X|X|X|
# ‾‾‾‾‾‾‾
# episode: 532/1000, steps: 4, reward_total: -2, e: 0.11, time: 02:22:50
# _______
# |X|X|O|
# | |X|O|
# |O|X|O|
# ‾‾‾‾‾‾‾
# episode: 533/1000, steps: 5, reward_total: 1, e: 0.11, time: 02:22:51
# _______
# |X|X|O|
# |O|X|X|
# |O|X|O|
# ‾‾‾‾‾‾‾
# episode: 534/1000, steps: 4, reward_total: 1, e: 0.11, time: 02:22:51
# _______
# |O|O|X|
# |O|O|X|
# |X| |X|
# ‾‾‾‾‾‾‾
# episode: 535/1000, steps: 4, reward_total: 1, e: 0.11, time: 02:22:52
# _______
# |X|O|X|
# |X|O|O|
# |X| |O|
# ‾‾‾‾‾‾‾
# episode: 536/1000, steps: 3, reward_total: 1, e: 0.11, time: 02:22:53
# _______
# | |X| |
# |O|X| |
# |O|X|O|
# ‾‾‾‾‾‾‾
# episode: 537/1000, steps: 3, reward_total: 1, e: 0.11, time: 02:22:53
# _______
# |X| |O|
# |X|O|O|
# |X| | |
# ‾‾‾‾‾‾‾
# episode: 538/1000, steps: 3, reward_total: 1, e: 0.11, time: 02:22:53
# _______
# |X| | |
# |O|X|O|
# |O| |X|
# ‾‾‾‾‾‾‾
# episode: 539/1000, steps: 3, reward_total: 1, e: 0.11, time: 02:22:54
# _______
# |O| |O|
# |X|X|X|
# |O| | |
# ‾‾‾‾‾‾‾
# episode: 540/1000, steps: 5, reward_total: 1, e: 0.11, time: 02:22:55
# _______
# |X|O|O|
# |O|X|X|
# |X|O|X|
# ‾‾‾‾‾‾‾
# episode: 541/1000, steps: 3, reward_total: -2, e: 0.11, time: 02:22:55
# _______
# |X|X|O|
# | |X|O|
# | | |O|
# ‾‾‾‾‾‾‾
# episode: 542/1000, steps: 3, reward_total: 1, e: 0.11, time: 02:22:56
# _______
# |X|O| |
# | |X| |
# |O|O|X|
# ‾‾‾‾‾‾‾
# episode: 543/1000, steps: 4, reward_total: 1, e: 0.11, time: 02:22:56
# _______
# |X| |O|
# |X|O|X|
# |X|O|O|
# ‾‾‾‾‾‾‾
# episode: 544/1000, steps: 5, reward_total: -1, e: 0.11, time: 02:22:57
# _______
# |O|X|O|
# |X|X|O|
# |X|O|X|
# ‾‾‾‾‾‾‾
# episode: 545/1000, steps: 4, reward_total: -2, e: 0.11, time: 02:22:58
# _______
# |X|O|X|
# |X|O| |
# |O|O|X|
# ‾‾‾‾‾‾‾
# episode: 546/1000, steps: 3, reward_total: 1, e: 0.11, time: 02:22:58
# _______
# | |O| |
# |O| |O|
# |X|X|X|
# ‾‾‾‾‾‾‾
# episode: 547/1000, steps: 4, reward_total: 1, e: 0.11, time: 02:22:59
# _______
# | |O|O|
# |X|O|O|
# |X|X|X|
# ‾‾‾‾‾‾‾
# episode: 548/1000, steps: 5, reward_total: 1, e: 0.11, time: 02:22:59
# _______
# |X|X|X|
# |X|O|O|
# |O|O|X|
# ‾‾‾‾‾‾‾
# episode: 549/1000, steps: 3, reward_total: 1, e: 0.11, time: 02:23:00
# _______
# | |O|O|
# |X|X|X|
# |O| | |
# ‾‾‾‾‾‾‾
# episode: 550/1000, steps: 5, reward_total: 1, e: 0.11, time: 02:23:01
# _______
# |O|X|X|
# |X|X|O|
# |X|O|O|
# ‾‾‾‾‾‾‾
# episode: 551/1000, steps: 4, reward_total: 1, e: 0.11, time: 02:23:01
# _______
# | |X|O|
# |O|O|O|
# |X|X|X|
# ‾‾‾‾‾‾‾
# episode: 552/1000, steps: 5, reward_total: -1, e: 0.11, time: 02:23:02
# _______
# |X|X|O|
# |O|O|X|
# |X|X|O|
# ‾‾‾‾‾‾‾
# episode: 553/1000, steps: 3, reward_total: 1, e: 0.11, time: 02:23:03
# _______
# | | |X|
# |O|X|O|
# |X|O| |
# ‾‾‾‾‾‾‾
# episode: 554/1000, steps: 5, reward_total: 1, e: 0.11, time: 02:23:04
# _______
# |X|O|O|
# |X|X|X|
# |X|O|O|
# ‾‾‾‾‾‾‾
# episode: 555/1000, steps: 4, reward_total: 1, e: 0.1, time: 02:23:05
# _______
# |X|O|X|
# |O|O|X|
# | |O|X|
# ‾‾‾‾‾‾‾
# episode: 556/1000, steps: 4, reward_total: 1, e: 0.1, time: 02:23:05
# _______
# |O|O|X|
# |O| |O|
# |X|X|X|
# ‾‾‾‾‾‾‾
# episode: 557/1000, steps: 3, reward_total: 1, e: 0.1, time: 02:23:06
# _______
# |X|O|O|
# | |X|O|
# | | |X|
# ‾‾‾‾‾‾‾
# episode: 558/1000, steps: 4, reward_total: -2, e: 0.1, time: 02:23:06
# _______
# |O|X|X|
# |O|O|O|
# |X|X| |
# ‾‾‾‾‾‾‾
# episode: 559/1000, steps: 3, reward_total: 1, e: 0.1, time: 02:23:07
# _______
# | | |O|
# | |O|O|
# |X|X|X|
# ‾‾‾‾‾‾‾
# episode: 560/1000, steps: 3, reward_total: 1, e: 0.1, time: 02:23:07
# _______
# |X|O|O|
# | |X| |
# | |O|X|
# ‾‾‾‾‾‾‾
# episode: 561/1000, steps: 4, reward_total: 1, e: 0.1, time: 02:23:08
# _______
# |X|O|O|
# | |X|X|
# |O|O|X|
# ‾‾‾‾‾‾‾
# episode: 562/1000, steps: 3, reward_total: 1, e: 0.1, time: 02:23:08
# _______
# |O| |X|
# | |X|O|
# |X| |O|
# ‾‾‾‾‾‾‾
# episode: 563/1000, steps: 4, reward_total: -2, e: 0.1, time: 02:23:09
# _______
# |X|O|O|
# | |X|O|
# |X|X|O|
# ‾‾‾‾‾‾‾
# episode: 564/1000, steps: 4, reward_total: 1, e: 0.1, time: 02:23:09
# _______
# |O|O|X|
# | |O|X|
# |O|X|X|
# ‾‾‾‾‾‾‾
# episode: 565/1000, steps: 4, reward_total: 1, e: 0.1, time: 02:23:10
# _______
# |O| |X|
# |O|X|O|
# |X|X|O|
# ‾‾‾‾‾‾‾
# episode: 566/1000, steps: 3, reward_total: 1, e: 0.1, time: 02:23:11
# _______
# | | |X|
# |O|X|O|
# |X|O| |
# ‾‾‾‾‾‾‾
# episode: 567/1000, steps: 5, reward_total: -1, e: 0.1, time: 02:23:11
# _______
# |O|X|O|
# |X|O|X|
# |X|O|X|
# ‾‾‾‾‾‾‾
# episode: 568/1000, steps: 3, reward_total: 1, e: 0.1, time: 02:23:12
# _______
# |X|O|O|
# | |X|O|
# | | |X|
# ‾‾‾‾‾‾‾
# episode: 569/1000, steps: 4, reward_total: 1, e: 0.099, time: 02:23:12
# _______
# |O|X| |
# |O|X|X|
# |O|X|O|
# ‾‾‾‾‾‾‾
# episode: 570/1000, steps: 5, reward_total: 1, e: 0.099, time: 02:23:13
# _______
# |X|X|O|
# |X|O|X|
# |X|O|O|
# ‾‾‾‾‾‾‾
# episode: 571/1000, steps: 3, reward_total: 1, e: 0.099, time: 02:23:14
# _______
# | | |X|
# |O|X|O|
# |X|O| |
# ‾‾‾‾‾‾‾
# episode: 572/1000, steps: 5, reward_total: 1, e: 0.098, time: 02:23:15
# _______
# |O|X|X|
# |X|O|X|
# |O|O|X|
# ‾‾‾‾‾‾‾
# episode: 573/1000, steps: 3, reward_total: 1, e: 0.098, time: 02:23:15
# _______
# | | |X|
# |O|X|O|
# |X| |O|
# ‾‾‾‾‾‾‾
# episode: 574/1000, steps: 4, reward_total: 1, e: 0.097, time: 02:23:16
# _______
# |X| |X|
# |X|O|O|
# |X|O|O|
# ‾‾‾‾‾‾‾
# episode: 575/1000, steps: 5, reward_total: 1, e: 0.097, time: 02:23:17
# _______
# |O|X|O|
# |O|X|O|
# |X|X|X|
# ‾‾‾‾‾‾‾
# episode: 576/1000, steps: 3, reward_total: 1, e: 0.097, time: 02:23:17
# _______
# |O|O|O|
# | | | |
# |X|X|X|
# ‾‾‾‾‾‾‾
# episode: 577/1000, steps: 4, reward_total: 1, e: 0.096, time: 02:23:18
# _______
# |O| |X|
# |O|X|O|
# |X|X|O|
# ‾‾‾‾‾‾‾
# episode: 578/1000, steps: 3, reward_total: 1, e: 0.096, time: 02:23:19
# _______
# |X|O|O|
# |O|X| |
# | | |X|
# ‾‾‾‾‾‾‾
# episode: 579/1000, steps: 4, reward_total: -2, e: 0.096, time: 02:23:19
# _______
# |O|X| |
# |X|X|X|
# |O|O|O|
# ‾‾‾‾‾‾‾
# episode: 580/1000, steps: 4, reward_total: -2, e: 0.095, time: 02:23:20
# _______
# |X|X|X|
# |O|X| |
# |O|O|O|
# ‾‾‾‾‾‾‾
# episode: 581/1000, steps: 4, reward_total: -2, e: 0.095, time: 02:23:20
# _______
# |X|X|O|
# |O|X|O|
# |X| |O|
# ‾‾‾‾‾‾‾
# episode: 582/1000, steps: 4, reward_total: 1, e: 0.094, time: 02:23:21
# _______
# |O|O|O|
# |X|X|X|
# |O|X| |
# ‾‾‾‾‾‾‾
# episode: 583/1000, steps: 3, reward_total: -2, e: 0.094, time: 02:23:21
# _______
# |O|O|O|
# | |X| |
# |X|X| |
# ‾‾‾‾‾‾‾
# episode: 584/1000, steps: 4, reward_total: 1, e: 0.094, time: 02:23:22
# _______
# |X|O|O|
# |O|O| |
# |X|X|X|
# ‾‾‾‾‾‾‾
# episode: 585/1000, steps: 5, reward_total: -1, e: 0.093, time: 02:23:23
# _______
# |O|X|O|
# |X|X|O|
# |X|O|X|
# ‾‾‾‾‾‾‾
# episode: 586/1000, steps: 3, reward_total: 1, e: 0.093, time: 02:23:23
# _______
# | |O|O|
# | | |O|
# |X|X|X|
# ‾‾‾‾‾‾‾
# episode: 587/1000, steps: 3, reward_total: 1, e: 0.093, time: 02:23:24
# _______
# |O|O|X|
# | |X| |
# |X|O| |
# ‾‾‾‾‾‾‾
# episode: 588/1000, steps: 4, reward_total: 1, e: 0.092, time: 02:23:24
# _______
# | |O|O|
# |O|X|O|
# |X|X|X|
# ‾‾‾‾‾‾‾
# episode: 589/1000, steps: 4, reward_total: -2, e: 0.092, time: 02:23:25
# _______
# |X|X|O|
# | |X|X|
# |O|O|O|
# ‾‾‾‾‾‾‾
# episode: 590/1000, steps: 4, reward_total: 1, e: 0.092, time: 02:23:26
# _______
# |O|O|X|
# |O|X|X|
# |X|O| |
# ‾‾‾‾‾‾‾
# episode: 591/1000, steps: 4, reward_total: 1, e: 0.091, time: 02:23:26
# _______
# |X| |O|
# |X|X|O|
# |O|O|X|
# ‾‾‾‾‾‾‾
# episode: 592/1000, steps: 4, reward_total: 1, e: 0.091, time: 02:23:27
# _______
# |X|X|O|
# |O|X| |
# |O|X|O|
# ‾‾‾‾‾‾‾
# episode: 593/1000, steps: 4, reward_total: -2, e: 0.091, time: 02:23:28
# _______
# |X|X|O|
# |X|O|O|
# |X| |O|
# ‾‾‾‾‾‾‾
# episode: 594/1000, steps: 4, reward_total: 1, e: 0.09, time: 02:23:28
# _______
# |O|X|X|
# |O|X| |
# |X|O|O|
# ‾‾‾‾‾‾‾
# episode: 595/1000, steps: 3, reward_total: 1, e: 0.09, time: 02:23:29
# _______
# |X| |O|
# | |X|O|
# |O| |X|
# ‾‾‾‾‾‾‾
# episode: 596/1000, steps: 3, reward_total: 1, e: 0.09, time: 02:23:30
# _______
# |O| | |
# |O|O| |
# |X|X|X|
# ‾‾‾‾‾‾‾
# episode: 597/1000, steps: 3, reward_total: 1, e: 0.089, time: 02:23:30
# _______
# |X| |O|
# | |X|O|
# |O| |X|
# ‾‾‾‾‾‾‾
# episode: 598/1000, steps: 4, reward_total: 1, e: 0.089, time: 02:23:31
# _______
# |X|O|O|
# |X|X| |
# |O|O|X|
# ‾‾‾‾‾‾‾
# episode: 599/1000, steps: 5, reward_total: 1, e: 0.089, time: 02:23:32
# _______
# |X|X|O|
# |O|X|X|
# |O|X|O|
# ‾‾‾‾‾‾‾
# episode: 600/1000, steps: 4, reward_total: 1, e: 0.088, time: 02:23:32
# _______
# |X| |O|
# |O|X|O|
# |X|O|X|
# ‾‾‾‾‾‾‾
# episode: 601/1000, steps: 3, reward_total: 1, e: 0.088, time: 02:23:33
# _______
# |X| | |
# |O|X|O|
# | |O|X|
# ‾‾‾‾‾‾‾
# ...
# _______
# |O|X|O|
# |O| |O|
# |X|X|X|
# ‾‾‾‾‾‾‾
# episode: 858/1000, steps: 3, reward_total: 1, e: 0.033, time: 02:26:15
# _______
# | |O| |
# | |O|O|
# |X|X|X|
# ‾‾‾‾‾‾‾
# episode: 859/1000, steps: 3, reward_total: 1, e: 0.033, time: 02:26:16
# _______
# |O|O|X|
# | |X|O|
# |X| | |
# ‾‾‾‾‾‾‾
# episode: 860/1000, steps: 4, reward_total: 1, e: 0.033, time: 02:26:16
# _______
# |O|X|O|
# | |O|O|
# |X|X|X|
# ‾‾‾‾‾‾‾
# episode: 861/1000, steps: 4, reward_total: 1, e: 0.033, time: 02:26:17
# _______
# |X|O|O|
# |X|X| |
# |O|O|X|
# ‾‾‾‾‾‾‾
# episode: 862/1000, steps: 3, reward_total: 1, e: 0.033, time: 02:26:17
# _______
# | |O|O|
# |O| | |
# |X|X|X|
# ‾‾‾‾‾‾‾
# episode: 863/1000, steps: 4, reward_total: 1, e: 0.033, time: 02:26:18
# _______
# |X|X|O|
# |O|X|O|
# |O| |X|
# ‾‾‾‾‾‾‾
# episode: 864/1000, steps: 5, reward_total: -1, e: 0.033, time: 02:26:19
# _______
# |X|O|X|
# |O|O|X|
# |X|X|O|
# ‾‾‾‾‾‾‾
# episode: 865/1000, steps: 4, reward_total: 1, e: 0.032, time: 02:26:19
# _______
# |O|O|X|
# |O|X| |
# |X|X|O|
# ‾‾‾‾‾‾‾
# episode: 866/1000, steps: 4, reward_total: 1, e: 0.032, time: 02:26:20
# _______
# |O|X|O|
# |O|X| |
# |O|X|X|
# ‾‾‾‾‾‾‾
# episode: 867/1000, steps: 4, reward_total: 1, e: 0.032, time: 02:26:20
# _______
# |X| |O|
# |X|O|O|
# |X|O|X|
# ‾‾‾‾‾‾‾
# episode: 868/1000, steps: 3, reward_total: 1, e: 0.032, time: 02:26:21
# _______
# | |O|X|
# |O|X| |
# |X|O| |
# ‾‾‾‾‾‾‾
# episode: 869/1000, steps: 4, reward_total: -2, e: 0.032, time: 02:26:21
# _______
# |X|X| |
# |O|O|O|
# |O|X|X|
# ‾‾‾‾‾‾‾
# episode: 870/1000, steps: 3, reward_total: 1, e: 0.032, time: 02:26:22
# _______
# |X|O| |
# | |X|O|
# | |O|X|
# ‾‾‾‾‾‾‾
# episode: 871/1000, steps: 4, reward_total: 1, e: 0.032, time: 02:26:23
# _______
# |O|X|O|
# |O| |O|
# |X|X|X|
# ‾‾‾‾‾‾‾
# episode: 872/1000, steps: 4, reward_total: -2, e: 0.032, time: 02:26:24
# _______
# |O|X| |
# |X|X|X|
# |O|O|O|
# ‾‾‾‾‾‾‾
# episode: 873/1000, steps: 5, reward_total: -1, e: 0.031, time: 02:26:25
# _______
# |O|X|X|
# |X|X|O|
# |O|O|X|
# ‾‾‾‾‾‾‾
# episode: 874/1000, steps: 3, reward_total: 1, e: 0.031, time: 02:26:25
# _______
# | |X| |
# |O|X|O|
# | |X|O|
# ‾‾‾‾‾‾‾
# episode: 875/1000, steps: 4, reward_total: 1, e: 0.031, time: 02:26:26
# _______
# |X|O| |
# |O|O|O|
# |X|X|X|
# ‾‾‾‾‾‾‾
# episode: 876/1000, steps: 4, reward_total: 1, e: 0.031, time: 02:26:26
# _______
# |X|O|X|
# |O|X| |
# |X|O|O|
# ‾‾‾‾‾‾‾
# episode: 877/1000, steps: 5, reward_total: 1, e: 0.031, time: 02:26:27
# _______
# |O|X|O|
# |X|X|X|
# |X|O|O|
# ‾‾‾‾‾‾‾
# episode: 878/1000, steps: 4, reward_total: -2, e: 0.031, time: 02:26:28
# _______
# |O|X|O|
# | |O|X|
# |X|X|O|
# ‾‾‾‾‾‾‾
# episode: 879/1000, steps: 4, reward_total: 1, e: 0.031, time: 02:26:28
# _______
# |O|X|X|
# | |X|O|
# |X|O|O|
# ‾‾‾‾‾‾‾
# episode: 880/1000, steps: 5, reward_total: 1, e: 0.031, time: 02:26:29
# _______
# |X|O|X|
# |O|O|X|
# |O|X|X|
# ‾‾‾‾‾‾‾
# episode: 881/1000, steps: 3, reward_total: 1, e: 0.03, time: 02:26:30
# _______
# |O| | |
# |O| |O|
# |X|X|X|
# ‾‾‾‾‾‾‾
# episode: 882/1000, steps: 3, reward_total: 1, e: 0.03, time: 02:26:30
# _______
# |O| |O|
# |O| | |
# |X|X|X|
# ‾‾‾‾‾‾‾
# episode: 883/1000, steps: 4, reward_total: 1, e: 0.03, time: 02:26:31
# _______
# |O|X|O|
# |X|X|X|
# | |O|O|
# ‾‾‾‾‾‾‾
# episode: 884/1000, steps: 3, reward_total: -2, e: 0.03, time: 02:26:31
# _______
# |X|O| |
# |X|O| |
# | |O|X|
# ‾‾‾‾‾‾‾
# episode: 885/1000, steps: 4, reward_total: 1, e: 0.03, time: 02:26:32
# _______
# |X| |O|
# |O|X|O|
# |O|X|X|
# ‾‾‾‾‾‾‾
# episode: 886/1000, steps: 3, reward_total: 1, e: 0.03, time: 02:26:32
# _______
# | | |X|
# |O|X|O|
# |X|O| |
# ‾‾‾‾‾‾‾
# episode: 887/1000, steps: 4, reward_total: 1, e: 0.03, time: 02:26:33
# _______
# |X|O|X|
# |O|X| |
# |X|O|O|
# ‾‾‾‾‾‾‾
# episode: 888/1000, steps: 4, reward_total: 1, e: 0.03, time: 02:26:33
# _______
# |O|X|O|
# |X|X|X|
# | |O|O|
# ‾‾‾‾‾‾‾
# episode: 889/1000, steps: 4, reward_total: 1, e: 0.03, time: 02:26:34
# _______
# |O| |O|
# |O|X|O|
# |X|X|X|
# ‾‾‾‾‾‾‾
# episode: 890/1000, steps: 4, reward_total: 1, e: 0.029, time: 02:26:35
# _______
# |X| |O|
# |X|O|X|
# |X|O|O|
# ‾‾‾‾‾‾‾
# episode: 891/1000, steps: 3, reward_total: 1, e: 0.029, time: 02:26:35
# _______
# |O|O|X|
# |O|X| |
# |X| | |
# ‾‾‾‾‾‾‾
# episode: 892/1000, steps: 4, reward_total: 1, e: 0.029, time: 02:26:36
# _______
# |O| |O|
# |X|X|X|
# |O|O|X|
# ‾‾‾‾‾‾‾
# episode: 893/1000, steps: 4, reward_total: -2, e: 0.029, time: 02:26:37
# _______
# |X|O|X|
# |X|O| |
# |O|O|X|
# ‾‾‾‾‾‾‾
# episode: 894/1000, steps: 4, reward_total: 1, e: 0.029, time: 02:26:38
# _______
# |O| |O|
# |X|O|O|
# |X|X|X|
# ‾‾‾‾‾‾‾
# episode: 895/1000, steps: 4, reward_total: 1, e: 0.029, time: 02:26:38
# _______
# |O|X| |
# |O|X|X|
# |O|X|O|
# ‾‾‾‾‾‾‾
# episode: 896/1000, steps: 3, reward_total: 1, e: 0.029, time: 02:26:39
# _______
# |O|X|O|
# |O|X| |
# | |X| |
# ‾‾‾‾‾‾‾
# episode: 897/1000, steps: 3, reward_total: 1, e: 0.029, time: 02:26:39
# _______
# | | |O|
# |O| |O|
# |X|X|X|
# ‾‾‾‾‾‾‾
# episode: 898/1000, steps: 3, reward_total: 1, e: 0.029, time: 02:26:40
# _______
# | | |X|
# | |X|O|
# |X|O|O|
# ‾‾‾‾‾‾‾
# episode: 899/1000, steps: 3, reward_total: 1, e: 0.029, time: 02:26:40
# _______
# | |O|O|
# | |O| |
# |X|X|X|
# ‾‾‾‾‾‾‾
# episode: 900/1000, steps: 4, reward_total: 1, e: 0.028, time: 02:26:41
# _______
# |X| |X|
# |O|X|O|
# |X|O|O|
# ‾‾‾‾‾‾‾
# episode: 901/1000, steps: 5, reward_total: 1, e: 0.028, time: 02:26:42
# _______
# |O|X|X|
# |O|X|X|
# |X|O|O|
# ‾‾‾‾‾‾‾
# episode: 902/1000, steps: 4, reward_total: 1, e: 0.028, time: 02:26:42
# _______
# |O|O|X|
# | |X|O|
# |X|X|O|
# ‾‾‾‾‾‾‾
# episode: 903/1000, steps: 3, reward_total: 1, e: 0.028, time: 02:26:43
# _______
# | |X| |
# |O|X| |
# |O|X|O|
# ‾‾‾‾‾‾‾
# episode: 904/1000, steps: 4, reward_total: 1, e: 0.028, time: 02:26:43
# _______
# |O| |X|
# |X|X|O|
# |X|O|O|
# ‾‾‾‾‾‾‾
# episode: 905/1000, steps: 3, reward_total: 1, e: 0.028, time: 02:26:44
# _______
# | | |O|
# | |O|O|
# |X|X|X|
# ‾‾‾‾‾‾‾
# episode: 906/1000, steps: 4, reward_total: 1, e: 0.028, time: 02:26:44
# _______
# |O|X| |
# |O|X|X|
# |O|X|O|
# ‾‾‾‾‾‾‾
# episode: 907/1000, steps: 4, reward_total: 1, e: 0.028, time: 02:26:45
# _______
# |X|X|O|
# | |X|O|
# |O|O|X|
# ‾‾‾‾‾‾‾
# episode: 908/1000, steps: 3, reward_total: 1, e: 0.028, time: 02:26:45
# _______
# |X|O| |
# |X|O| |
# |X| |O|
# ‾‾‾‾‾‾‾
# episode: 909/1000, steps: 4, reward_total: 1, e: 0.028, time: 02:26:46
# _______
# |O|X|O|
# |O|X| |
# |X|X|O|
# ‾‾‾‾‾‾‾
# episode: 910/1000, steps: 3, reward_total: 1, e: 0.027, time: 02:26:46
# _______
# |O| |X|
# |O|X|O|
# |X| | |
# ‾‾‾‾‾‾‾
# episode: 911/1000, steps: 4, reward_total: 1, e: 0.027, time: 02:26:47
# _______
# |O|X|O|
# |X|X| |
# |O|X|O|
# ‾‾‾‾‾‾‾
# episode: 912/1000, steps: 5, reward_total: 1, e: 0.027, time: 02:26:48
# _______
# |O|X|X|
# |X|X|O|
# |O|X|O|
# ‾‾‾‾‾‾‾
# episode: 913/1000, steps: 4, reward_total: 1, e: 0.027, time: 02:26:49
# _______
# |O| |X|
# |O|X|X|
# |X|O|O|
# ‾‾‾‾‾‾‾
# episode: 914/1000, steps: 5, reward_total: -1, e: 0.027, time: 02:26:50
# _______
# |X|X|O|
# |O|X|X|
# |X|O|O|
# ‾‾‾‾‾‾‾
# episode: 915/1000, steps: 4, reward_total: 1, e: 0.027, time: 02:26:50
# _______
# |O|O|X|
# |O|X|X|
# |X| |O|
# ‾‾‾‾‾‾‾
# episode: 916/1000, steps: 5, reward_total: 1, e: 0.027, time: 02:26:51
# _______
# |X|X|O|
# |X|X|O|
# |O|O|X|
# ‾‾‾‾‾‾‾
# episode: 917/1000, steps: 4, reward_total: 1, e: 0.027, time: 02:26:52
# _______
# |X|O|O|
# |X|O|O|
# |X| |X|
# ‾‾‾‾‾‾‾
# episode: 918/1000, steps: 4, reward_total: 1, e: 0.026, time: 02:26:53
# _______
# |X| |O|
# |X|O|X|
# |X|O|O|
# ‾‾‾‾‾‾‾
# episode: 919/1000, steps: 4, reward_total: 1, e: 0.026, time: 02:26:53
# _______
# |O|O| |
# |X|X|X|
# |O|X|O|
# ‾‾‾‾‾‾‾
# episode: 920/1000, steps: 5, reward_total: -1, e: 0.026, time: 02:26:54
# _______
# |X|O|O|
# |O|X|X|
# |X|X|O|
# ‾‾‾‾‾‾‾
# episode: 921/1000, steps: 3, reward_total: 1, e: 0.026, time: 02:26:54
# _______
# |X|O| |
# | |X| |
# |O|O|X|
# ‾‾‾‾‾‾‾
# episode: 922/1000, steps: 5, reward_total: 1, e: 0.026, time: 02:26:55
# _______
# |O|X|O|
# |X|X|X|
# |O|O|X|
# ‾‾‾‾‾‾‾
# episode: 923/1000, steps: 3, reward_total: 1, e: 0.026, time: 02:26:56
# _______
# |O| |X|
# |O|X| |
# |X| |O|
# ‾‾‾‾‾‾‾
# episode: 924/1000, steps: 4, reward_total: 1, e: 0.026, time: 02:26:56
# _______
# |X|O| |
# |O|X|O|
# |X|O|X|
# ‾‾‾‾‾‾‾
# episode: 925/1000, steps: 5, reward_total: 1, e: 0.026, time: 02:26:57
# _______
# |O|O|X|
# |X|X|O|
# |X|X|O|
# ‾‾‾‾‾‾‾
# episode: 926/1000, steps: 5, reward_total: 1, e: 0.026, time: 02:26:58
# _______
# |X|X|O|
# |O|X|X|
# |O|O|X|
# ‾‾‾‾‾‾‾
# episode: 927/1000, steps: 3, reward_total: -2, e: 0.026, time: 02:26:58
# _______
# |O|O|O|
# | | |X|
# | |X|X|
# ‾‾‾‾‾‾‾
# episode: 928/1000, steps: 3, reward_total: 1, e: 0.025, time: 02:26:59
# _______
# |X| |O|
# |X|O|O|
# |X| | |
# ‾‾‾‾‾‾‾
# episode: 929/1000, steps: 3, reward_total: 1, e: 0.025, time: 02:26:59
# _______
# | | |X|
# |O|X|O|
# |X|O| |
# ‾‾‾‾‾‾‾
# episode: 930/1000, steps: 3, reward_total: 1, e: 0.025, time: 02:27:00
# _______
# |X| |O|
# |X| |O|
# |X|O| |
# ‾‾‾‾‾‾‾
# episode: 931/1000, steps: 4, reward_total: 1, e: 0.025, time: 02:27:00
# _______
# |X|X|X|
# |O|O| |
# |O|O|X|
# ‾‾‾‾‾‾‾
# episode: 932/1000, steps: 4, reward_total: 1, e: 0.025, time: 02:27:01
# _______
# |X|X|X|
# |X|O|O|
# |O| |O|
# ‾‾‾‾‾‾‾
# episode: 933/1000, steps: 4, reward_total: 1, e: 0.025, time: 02:27:01
# _______
# |O|X|O|
# |X|X|X|
# | |O|O|
# ‾‾‾‾‾‾‾
# episode: 934/1000, steps: 5, reward_total: 1, e: 0.025, time: 02:27:02
# _______
# |O|X|O|
# |X|X|X|
# |X|O|O|
# ‾‾‾‾‾‾‾
# episode: 935/1000, steps: 3, reward_total: 1, e: 0.025, time: 02:27:03
# _______
# |X|O|O|
# | |X| |
# | |O|X|
# ‾‾‾‾‾‾‾
# episode: 936/1000, steps: 3, reward_total: 1, e: 0.025, time: 02:27:04
# _______
# |O| |X|
# |O|X|O|
# |X| | |
# ‾‾‾‾‾‾‾
# episode: 937/1000, steps: 5, reward_total: 1, e: 0.025, time: 02:27:05
# _______
# |X|X|X|
# |O|O|X|
# |O|O|X|
# ‾‾‾‾‾‾‾
# episode: 938/1000, steps: 4, reward_total: 1, e: 0.025, time: 02:27:05
# _______
# |X|O|O|
# |O| |O|
# |X|X|X|
# ‾‾‾‾‾‾‾
# episode: 939/1000, steps: 4, reward_total: 1, e: 0.024, time: 02:27:06
# _______
# |X|X|X|
# | |O|O|
# |O|X|O|
# ‾‾‾‾‾‾‾
# episode: 940/1000, steps: 3, reward_total: 1, e: 0.024, time: 02:27:06
# _______
# |O|X| |
# |O|X| |
# |O|X| |
# ‾‾‾‾‾‾‾
# episode: 941/1000, steps: 5, reward_total: 1, e: 0.024, time: 02:27:07
# _______
# |X|X|O|
# |X|O|O|
# |X|O|X|
# ‾‾‾‾‾‾‾
# episode: 942/1000, steps: 3, reward_total: -2, e: 0.024, time: 02:27:07
# _______
# |X| | |
# |O|O|O|
# |X| |X|
# ‾‾‾‾‾‾‾
# episode: 943/1000, steps: 4, reward_total: 1, e: 0.024, time: 02:27:08
# _______
# |X|X|O|
# |O|X| |
# |O|X|O|
# ‾‾‾‾‾‾‾
# episode: 944/1000, steps: 3, reward_total: 1, e: 0.024, time: 02:27:08
# _______
# |O| |O|
# |O| | |
# |X|X|X|
# ‾‾‾‾‾‾‾
# episode: 945/1000, steps: 3, reward_total: 1, e: 0.024, time: 02:27:09
# _______
# |O| |X|
# |O|O|X|
# | | |X|
# ‾‾‾‾‾‾‾
# episode: 946/1000, steps: 5, reward_total: 1, e: 0.024, time: 02:27:10
# _______
# |O|X|O|
# |O|X|X|
# |X|X|O|
# ‾‾‾‾‾‾‾
# episode: 947/1000, steps: 3, reward_total: 1, e: 0.024, time: 02:27:10
# _______
# | |X| |
# |O|X|O|
# |O|X| |
# ‾‾‾‾‾‾‾
# episode: 948/1000, steps: 4, reward_total: -2, e: 0.024, time: 02:27:11
# _______
# |X| |O|
# |O|X|O|
# |X|X|O|
# ‾‾‾‾‾‾‾
# episode: 949/1000, steps: 4, reward_total: 1, e: 0.024, time: 02:27:11
# _______
# |O|X|X|
# |O|X|O|
# |X| |O|
# ‾‾‾‾‾‾‾
# episode: 950/1000, steps: 4, reward_total: 1, e: 0.023, time: 02:27:12
# _______
# |X|O|X|
# |O|X| |
# |X|O|O|
# ‾‾‾‾‾‾‾
# episode: 951/1000, steps: 4, reward_total: 1, e: 0.023, time: 02:27:13
# _______
# |X|O|O|
# |O| |O|
# |X|X|X|
# ‾‾‾‾‾‾‾
# episode: 952/1000, steps: 4, reward_total: 1, e: 0.023, time: 02:27:13
# _______
# |O|X|O|
# |O|X| |
# |O|X|X|
# ‾‾‾‾‾‾‾
# episode: 953/1000, steps: 3, reward_total: 1, e: 0.023, time: 02:27:14
# _______
# |X| | |
# |X|O| |
# |X|O|O|
# ‾‾‾‾‾‾‾
# episode: 954/1000, steps: 4, reward_total: -2, e: 0.023, time: 02:27:14
# _______
# |X|X|X|
# |X|O| |
# |O|O|O|
# ‾‾‾‾‾‾‾
# episode: 955/1000, steps: 3, reward_total: 1, e: 0.023, time: 02:27:15
# _______
# | | |X|
# |O|X|O|
# |X| |O|
# ‾‾‾‾‾‾‾
# episode: 956/1000, steps: 3, reward_total: -2, e: 0.023, time: 02:27:15
# _______
# |O| | |
# |X|O| |
# |X|X|O|
# ‾‾‾‾‾‾‾
# episode: 957/1000, steps: 4, reward_total: 1, e: 0.023, time: 02:27:16
# _______
# |X|O|X|
# |O|X| |
# |X|O|O|
# ‾‾‾‾‾‾‾
# episode: 958/1000, steps: 3, reward_total: -2, e: 0.023, time: 02:27:17
# _______
# | |X| |
# |X|X| |
# |O|O|O|
# ‾‾‾‾‾‾‾
# episode: 959/1000, steps: 3, reward_total: 1, e: 0.023, time: 02:27:17
# _______
# | | |X|
# |O|X|O|
# |X| |O|
# ‾‾‾‾‾‾‾
# episode: 960/1000, steps: 4, reward_total: -2, e: 0.023, time: 02:27:18
# _______
# |O|X|X|
# |X|O|O|
# | |X|O|
# ‾‾‾‾‾‾‾
# episode: 961/1000, steps: 5, reward_total: -1, e: 0.023, time: 02:27:19
# _______
# |O|X|X|
# |X|X|O|
# |O|O|X|
# ‾‾‾‾‾‾‾
# episode: 962/1000, steps: 3, reward_total: 1, e: 0.022, time: 02:27:19
# _______
# |X| | |
# |X|O|O|
# |X| |O|
# ‾‾‾‾‾‾‾
# episode: 963/1000, steps: 4, reward_total: 1, e: 0.022, time: 02:27:20
# _______
# |X|O|O|
# |O|X|X|
# | |O|X|
# ‾‾‾‾‾‾‾
# episode: 964/1000, steps: 5, reward_total: 1, e: 0.022, time: 02:27:21
# _______
# |X|X|O|
# |X|O|X|
# |X|O|O|
# ‾‾‾‾‾‾‾
# episode: 965/1000, steps: 5, reward_total: 1, e: 0.022, time: 02:27:22
# _______
# |O|X|O|
# |O|X|X|
# |X|X|O|
# ‾‾‾‾‾‾‾
# episode: 966/1000, steps: 4, reward_total: 1, e: 0.022, time: 02:27:22
# _______
# |X|O|O|
# |X|X|O|
# | |O|X|
# ‾‾‾‾‾‾‾
# episode: 967/1000, steps: 4, reward_total: 1, e: 0.022, time: 02:27:23
# _______
# | |O|X|
# |O|X|X|
# |X|O|O|
# ‾‾‾‾‾‾‾
# episode: 968/1000, steps: 4, reward_total: 1, e: 0.022, time: 02:27:23
# _______
# |X|O| |
# |O|X|O|
# |X|O|X|
# ‾‾‾‾‾‾‾
# episode: 969/1000, steps: 4, reward_total: 1, e: 0.022, time: 02:27:24
# _______
# |O|X|O|
# |O|O| |
# |X|X|X|
# ‾‾‾‾‾‾‾
# episode: 970/1000, steps: 5, reward_total: -1, e: 0.022, time: 02:27:25
# _______
# |X|X|O|
# |O|O|X|
# |X|O|X|
# ‾‾‾‾‾‾‾
# episode: 971/1000, steps: 4, reward_total: 1, e: 0.022, time: 02:27:25
# _______
# |O| |X|
# |O|O|X|
# |O|X|X|
# ‾‾‾‾‾‾‾
# episode: 972/1000, steps: 3, reward_total: -2, e: 0.022, time: 02:27:26
# _______
# |X| |O|
# | |X|O|
# |X| |O|
# ‾‾‾‾‾‾‾
# episode: 973/1000, steps: 4, reward_total: 1, e: 0.021, time: 02:27:26
# _______
# |X|O|O|
# |X|X|O|
# |O| |X|
# ‾‾‾‾‾‾‾
# episode: 974/1000, steps: 4, reward_total: 1, e: 0.021, time: 02:27:27
# _______
# |O|O|X|
# |O|X|X|
# |X| |O|
# ‾‾‾‾‾‾‾
# episode: 975/1000, steps: 4, reward_total: 1, e: 0.021, time: 02:27:28
# _______
# |O|O|X|
# |O|X|O|
# |X|X| |
# ‾‾‾‾‾‾‾
# episode: 976/1000, steps: 5, reward_total: 1, e: 0.021, time: 02:27:28
# _______
# |X|X|X|
# |X|O|O|
# |O|O|X|
# ‾‾‾‾‾‾‾
# episode: 977/1000, steps: 5, reward_total: 1, e: 0.021, time: 02:27:29
# _______
# |X|O|O|
# |O|X|X|
# |O|X|X|
# ‾‾‾‾‾‾‾
# episode: 978/1000, steps: 3, reward_total: 1, e: 0.021, time: 02:27:30
# _______
# | |O| |
# |O|O| |
# |X|X|X|
# ‾‾‾‾‾‾‾
# episode: 979/1000, steps: 3, reward_total: 1, e: 0.021, time: 02:27:31
# _______
# |O| | |
# |O| |O|
# |X|X|X|
# ‾‾‾‾‾‾‾
# episode: 980/1000, steps: 3, reward_total: 1, e: 0.021, time: 02:27:31
# _______
# |X|X|X|
# |O| | |
# |O| |O|
# ‾‾‾‾‾‾‾
# episode: 981/1000, steps: 4, reward_total: 1, e: 0.021, time: 02:27:32
# _______
# |O| |O|
# |X|X|X|
# |X|O|O|
# ‾‾‾‾‾‾‾
# episode: 982/1000, steps: 5, reward_total: -1, e: 0.021, time: 02:27:33
# _______
# |X|X|O|
# |O|O|X|
# |X|X|O|
# ‾‾‾‾‾‾‾
# episode: 983/1000, steps: 5, reward_total: 1, e: 0.021, time: 02:27:33
# _______
# |O|X|X|
# |X|O|X|
# |O|O|X|
# ‾‾‾‾‾‾‾
# episode: 984/1000, steps: 3, reward_total: 1, e: 0.021, time: 02:27:34
# _______
# |X|O|O|
# |X| | |
# |X|O| |
# ‾‾‾‾‾‾‾
# episode: 985/1000, steps: 4, reward_total: 1, e: 0.02, time: 02:27:35
# _______
# |O|O|X|
# |O|X|O|
# |X|X| |
# ‾‾‾‾‾‾‾
# episode: 986/1000, steps: 4, reward_total: 1, e: 0.02, time: 02:27:35
# _______
# |O|O| |
# |X|O|O|
# |X|X|X|
# ‾‾‾‾‾‾‾
# episode: 987/1000, steps: 5, reward_total: -1, e: 0.02, time: 02:27:36
# _______
# |O|X|X|
# |X|X|O|
# |O|O|X|
# ‾‾‾‾‾‾‾
# episode: 988/1000, steps: 3, reward_total: 1, e: 0.02, time: 02:27:36
# _______
# | |O|X|
# | |X| |
# |X|O|O|
# ‾‾‾‾‾‾‾
# episode: 989/1000, steps: 4, reward_total: -2, e: 0.02, time: 02:27:37
# _______
# |O|X|X|
# |X|O|O|
# | |X|O|
# ‾‾‾‾‾‾‾
# episode: 990/1000, steps: 4, reward_total: 1, e: 0.02, time: 02:27:38
# _______
# |X|O|O|
# |X|X|O|
# |O| |X|
# ‾‾‾‾‾‾‾
# episode: 991/1000, steps: 4, reward_total: 1, e: 0.02, time: 02:27:38
# _______
# |X|X|X|
# |O|O|X|
# | |O|O|
# ‾‾‾‾‾‾‾
# episode: 992/1000, steps: 3, reward_total: 1, e: 0.02, time: 02:27:39
# _______
# |O| | |
# |X|X|X|
# |O| |O|
# ‾‾‾‾‾‾‾
# episode: 993/1000, steps: 4, reward_total: 1, e: 0.02, time: 02:27:39
# _______
# |X|X| |
# |O|X|O|
# |O|X|O|
# ‾‾‾‾‾‾‾
# episode: 994/1000, steps: 5, reward_total: 1, e: 0.02, time: 02:27:40
# _______
# |O|X|X|
# |O|X|O|
# |X|X|O|
# ‾‾‾‾‾‾‾
# episode: 995/1000, steps: 3, reward_total: 1, e: 0.02, time: 02:27:41
# _______
# |O|X| |
# |O|X| |
# | |X|O|
# ‾‾‾‾‾‾‾
# episode: 996/1000, steps: 4, reward_total: 1, e: 0.02, time: 02:27:41
# _______
# |O|X|O|
# |O| |O|
# |X|X|X|
# ‾‾‾‾‾‾‾
# episode: 997/1000, steps: 4, reward_total: 1, e: 0.019, time: 02:27:42
# _______
# |O|X|X|
# |O|X|O|
# |X|O| |
# ‾‾‾‾‾‾‾
# episode: 998/1000, steps: 5, reward_total: 1, e: 0.019, time: 02:27:43
# _______
# |X|X|O|
# |X|X|O|
# |O|O|X|
# ‾‾‾‾‾‾‾
# episode: 999/1000, steps: 4, reward_total: 1, e: 0.019, time: 02:27:44
# _______
# |O|X|X|
# |O|X|O|
# |X|O| |
# ‾‾‾‾‾‾‾
# episode: 1000/1000, steps: 4, reward_total: 1, e: 0.019, time: 02:27:44
# _______
# |X|O|O|
# |O|X|O|
# |X| |X|
# ‾‾‾‾‾‾‾
# Model saved to /content/drive/MyDrive/EE 473/TicTacToeAgent-6000-episodes-naive.pt

# %%
MODEL_PATH="/content/drive/MyDrive/EE 473/TicTacToeAgent-6000-episodes-naive.pt"
print("Mixed Opponent Model (3000 episodes) Results:")
test_saved_model(opponent_level="easy")
test_saved_model(opponent_level="hard")
# Out:
# Mixed Opponent Model (3000 episodes) Results:
# Loading Model Parameters...
# 100%|██████████| 10000/10000 [01:04<00:00, 154.15it/s]
# Win rate: 53.3%
# Draw rate: 6.95%
# Loss rate: 39.75%
# Loading Model Parameters...
# 100%|██████████| 1000/1000 [09:04<00:00,  1.84it/s]
# Win rate: 0.0%
# Draw rate: 13.6%
# Loss rate: 86.4%
