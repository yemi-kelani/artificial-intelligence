# %%
import torch

DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(DEVICE)

from DeepQAgent import DeepQAgent
from TicTacToeGame import TicTacToeGame, OPPONENT_LEVEL

import os
import sys
sys.path.append(os.path.abspath('..'))

from Utils import (
    train_agent,
    test_agent,
    set_seed
)

sys.path.remove(os.path.abspath('..'))

SEED = 100
set_seed(SEED)

# DeepQ parameters
BATCH_SIZE     = 128
NUM_EPISODES   = 2000 if torch.cuda.is_available() else 100
STATE_SPACE    = 9
ACTION_SPACE   = 9
HIDDEN_SIZE    = 128
EPSILON        = 1.0
GAMMA          = 0.99
LEARNING_RATE  = 0.001
DROPOUT        = 0.25
TRAIN_START    = 1500
NEGATIVE_SLOPE = 0.01
COMPUTER_LEVEL = OPPONENT_LEVEL.NAIVE

# save path
MODEL_PATH = "../../../trained_models/ReinforcementLearning/TicTacToeV2"
MODEL_NAME = ""

BASELINE = "TicTacToev2-Baseline-Untrained"
NAIVE_2K = "TicTacToev2-NAIVE-2K"
NAIVE_4K = "TicTacToev2-NAIVE-4K"
NAIVE_6K = "TicTacToev2-NAIVE-6K"
NAIVE_8K = "TicTacToev2-NAIVE-8K"
NAIVE_10K = "TicTacToev2-NAIVE-10K"

def get_full_model_path(agent_name: str = None):
  if agent_name is None:
    return os.path.join(MODEL_PATH, MODEL_NAME + ".pt")
  return os.path.join(MODEL_PATH, agent_name + ".pt")

def supply_model(load_if_exists: bool = True, agent_name: str = None):
  
  agent = DeepQAgent(
      device         = DEVICE,
      epsilon        = EPSILON, 
      gamma          = GAMMA,
      state_space    = STATE_SPACE, 
      action_space   = ACTION_SPACE, 
      hidden_size    = HIDDEN_SIZE,
      dropout        = DROPOUT,
      train_start    = TRAIN_START,
      batch_size     = BATCH_SIZE,
      negative_slope = NEGATIVE_SLOPE
  )

  full_model_path = get_full_model_path(agent_name)
  if load_if_exists and os.path.exists(full_model_path):
    print("Loading Model Parameters...")
    agent.load_model(filepath=full_model_path)
  
  optimizer = torch.optim.Adam(agent.parameters(), lr=LEARNING_RATE)
  criterion = torch.nn.SmoothL1Loss() # Huber Loss
  
  return agent, optimizer, criterion

def compare_to_naive(agent_name: str, num_episodes: int = 25000):
  _agent, _, _ = supply_model(load_if_exists=True, agent_name=agent_name)
  _environment = TicTacToeGame(DEVICE, None, OPPONENT_LEVEL.NAIVE, start_as_X=False)
  test_agent(_agent, _environment, num_episodes)

def compare_to_optimal(agent_name: str, num_episodes: int = 100):
  _agent, _, _ = supply_model(load_if_exists=True, agent_name=agent_name)
  _environment = TicTacToeGame(DEVICE, None, OPPONENT_LEVEL.OPTIMAL, start_as_X=False)
  test_agent(_agent, _environment, num_episodes)
# Out:
# cuda

# %%
agent, optimizer, criterion = supply_model(load_if_exists=True, agent_name=BASELINE)
environment = TicTacToeGame(DEVICE, None, OPPONENT_LEVEL.NAIVE)
reward_history = train_agent(
    agent,
    environment,
    NUM_EPISODES,
    optimizer,
    criterion,
    DEVICE,
    MODEL_PATH,
    model_name = NAIVE_2K
)

# %%
agent, optimizer, criterion = supply_model(load_if_exists=True, agent_name=NAIVE_2K)
environment = TicTacToeGame(DEVICE, None, OPPONENT_LEVEL.NAIVE)
reward_history = train_agent(
    agent,
    environment,
    NUM_EPISODES,
    optimizer,
    criterion,
    DEVICE,
    MODEL_PATH,
    model_name = NAIVE_4K
)

# %%
agent, optimizer, criterion = supply_model(load_if_exists=True, agent_name=NAIVE_4K)
environment = TicTacToeGame(DEVICE, None, OPPONENT_LEVEL.NAIVE)
reward_history = train_agent(
    agent,
    environment,
    NUM_EPISODES,
    optimizer,
    criterion,
    DEVICE,
    MODEL_PATH,
    model_name = NAIVE_6K
)

# %%
agent, optimizer, criterion = supply_model(load_if_exists=True, agent_name=NAIVE_6K)
environment = TicTacToeGame(DEVICE, None, OPPONENT_LEVEL.NAIVE)
reward_history = train_agent(
    agent,
    environment,
    NUM_EPISODES,
    optimizer,
    criterion,
    DEVICE,
    MODEL_PATH,
    model_name = NAIVE_8K
)

# %%
agent, optimizer, criterion = supply_model(load_if_exists=True, agent_name=NAIVE_8K)
environment = TicTacToeGame(DEVICE, None, OPPONENT_LEVEL.NAIVE)
reward_history = train_agent(
    agent,
    environment,
    NUM_EPISODES,
    optimizer,
    criterion,
    DEVICE,
    MODEL_PATH,
    model_name = NAIVE_10K
)
# Out:
# Loading Model Parameters...
# Model loaded from '../../../trained_models/ReinforcementLearning/TicTacToeV2\TicTacToev2-NAIVE-8K.pt'.
# episode: 1/2000, steps: 3, reward_total: -2, e: 1.0, time: 09:16:14
# _______
# |X| | |
# |X|O|O|
# |X|O|X|
# ‾‾‾‾‾‾‾
# episode: 2/2000, steps: 4, reward_total: -2, e: 1.0, time: 09:16:14
# _______
# |X|O| |
# |O|O|X|
# |X|O|X|
# ‾‾‾‾‾‾‾
# episode: 3/2000, steps: 3, reward_total: -2, e: 1.0, time: 09:16:14
# _______
# | |X| |
# |X|X|O|
# |O|X|O|
# ‾‾‾‾‾‾‾
# episode: 4/2000, steps: 5, reward_total: -1, e: 1.0, time: 09:16:14
# _______
# |X|O|X|
# |O|O|X|
# |X|X|O|
# ‾‾‾‾‾‾‾
# episode: 5/2000, steps: 3, reward_total: -2, e: 1.0, time: 09:16:14
# _______
# |X|O|X|
# | |X|O|
# |O| |X|
# ‾‾‾‾‾‾‾
# episode: 6/2000, steps: 3, reward_total: 1, e: 1.0, time: 09:16:14
# _______
# |X|X|X|
# | | |O|
# |O| | |
# ‾‾‾‾‾‾‾
# episode: 7/2000, steps: 4, reward_total: -1, e: 1.0, time: 09:16:14
# _______
# |O|X|X|
# |X|O|O|
# |X|O|X|
# ‾‾‾‾‾‾‾
# episode: 8/2000, steps: 4, reward_total: 1, e: 1.0, time: 09:16:14
# _______
# | |X|X|
# |O|X| |
# |O|X|O|
# ‾‾‾‾‾‾‾
# episode: 9/2000, steps: 4, reward_total: -1, e: 1.0, time: 09:16:14
# _______
# |X|X|O|
# |O|O|X|
# |X|O|X|
# ‾‾‾‾‾‾‾
# episode: 10/2000, steps: 4, reward_total: -2, e: 1.0, time: 09:16:14
# _______
# |X| |O|
# |O|X|O|
# |X|X|O|
# ‾‾‾‾‾‾‾
# episode: 11/2000, steps: 4, reward_total: -2, e: 1.0, time: 09:16:14
# _______
# |O|X|X|
# |X|O|X|
# |O|O|X|
# ‾‾‾‾‾‾‾
# episode: 12/2000, steps: 4, reward_total: 1, e: 1.0, time: 09:16:14
# _______
# |O|O|X|
# | | |X|
# |X|O|X|
# ‾‾‾‾‾‾‾
# episode: 13/2000, steps: 3, reward_total: 1, e: 1.0, time: 09:16:14
# _______
# |X| |O|
# | |O|X|
# |O| |X|
# ‾‾‾‾‾‾‾
# episode: 14/2000, steps: 4, reward_total: 1, e: 1.0, time: 09:16:14
# _______
# |O|O|X|
# | |X|X|
# | |O|X|
# ‾‾‾‾‾‾‾
# episode: 15/2000, steps: 2, reward_total: -2, e: 1.0, time: 09:16:14
# _______
# |X|X|X|
# |O| |O|
# | | | |
# ‾‾‾‾‾‾‾
# episode: 16/2000, steps: 5, reward_total: -1, e: 1.0, time: 09:16:14
# _______
# |X|O|X|
# |X|O|O|
# |O|X|X|
# ‾‾‾‾‾‾‾
# episode: 17/2000, steps: 4, reward_total: -2, e: 1.0, time: 09:16:14
# _______
# |O|X|X|
# |O|X|X|
# |X|O|O|
# ‾‾‾‾‾‾‾
# episode: 18/2000, steps: 4, reward_total: 1, e: 1.0, time: 09:16:14
# _______
# |X|X|X|
# | |O|X|
# |O|O| |
# ‾‾‾‾‾‾‾
# episode: 19/2000, steps: 3, reward_total: 1, e: 1.0, time: 09:16:14
# _______
# |O|O|O|
# | |X|X|
# | | |X|
# ‾‾‾‾‾‾‾
# episode: 20/2000, steps: 5, reward_total: 1, e: 1.0, time: 09:16:14
# _______
# |O|O|X|
# |O|X|X|
# |X|X|O|
# ‾‾‾‾‾‾‾
# episode: 21/2000, steps: 2, reward_total: -2, e: 1.0, time: 09:16:14
# _______
# | | |X|
# |O| |X|
# | |O|X|
# ‾‾‾‾‾‾‾
# episode: 22/2000, steps: 4, reward_total: 1, e: 1.0, time: 09:16:14
# _______
# |X|X|X|
# |O|O| |
# |O| |X|
# ‾‾‾‾‾‾‾
# episode: 23/2000, steps: 3, reward_total: 1, e: 1.0, time: 09:16:15
# _______
# |X|O| |
# |X|O| |
# | |O|X|
# ‾‾‾‾‾‾‾
# episode: 24/2000, steps: 4, reward_total: -2, e: 1.0, time: 09:16:15
# _______
# |X|X| |
# |O|O|O|
# |O|X|X|
# ‾‾‾‾‾‾‾
# episode: 25/2000, steps: 4, reward_total: -1, e: 1.0, time: 09:16:15
# _______
# |X|O|X|
# |X|O|X|
# |O|X|O|
# ‾‾‾‾‾‾‾
# episode: 26/2000, steps: 3, reward_total: -2, e: 1.0, time: 09:16:15
# _______
# |X|X| |
# |X| | |
# |O|O|O|
# ‾‾‾‾‾‾‾
# episode: 27/2000, steps: 4, reward_total: 1, e: 1.0, time: 09:16:15
# _______
# |O| |O|
# |X|O|X|
# |O|X|X|
# ‾‾‾‾‾‾‾
# episode: 28/2000, steps: 5, reward_total: 1, e: 1.0, time: 09:16:15
# _______
# |O|X|X|
# |O|X|O|
# |X|O|X|
# ‾‾‾‾‾‾‾
# episode: 29/2000, steps: 4, reward_total: 1, e: 1.0, time: 09:16:15
# _______
# |X|X|O|
# |X|O| |
# |O|X|O|
# ‾‾‾‾‾‾‾
# episode: 30/2000, steps: 5, reward_total: 1, e: 1.0, time: 09:16:15
# _______
# |X|X|O|
# |X|O|X|
# |X|O|O|
# ‾‾‾‾‾‾‾
# episode: 31/2000, steps: 4, reward_total: -2, e: 1.0, time: 09:16:15
# _______
# |X|X|O|
# |O|X|X|
# |O|O|X|
# ‾‾‾‾‾‾‾
# episode: 32/2000, steps: 4, reward_total: -2, e: 1.0, time: 09:16:15
# _______
# |X|X| |
# |O|O|O|
# |O|X|X|
# ‾‾‾‾‾‾‾
# episode: 33/2000, steps: 4, reward_total: 1, e: 1.0, time: 09:16:15
# _______
# |O|O|X|
# |X|O|X|
# | |X|O|
# ‾‾‾‾‾‾‾
# episode: 34/2000, steps: 5, reward_total: 1, e: 1.0, time: 09:16:15
# _______
# |X|O|X|
# |X|O|O|
# |X|X|O|
# ‾‾‾‾‾‾‾
# episode: 35/2000, steps: 4, reward_total: -2, e: 1.0, time: 09:16:15
# _______
# |O|O|X|
# |X|O|O|
# |X|X|X|
# ‾‾‾‾‾‾‾
# episode: 36/2000, steps: 3, reward_total: 1, e: 1.0, time: 09:16:15
# _______
# |X|X|X|
# | | | |
# |O| |O|
# ‾‾‾‾‾‾‾
# episode: 37/2000, steps: 4, reward_total: 1, e: 1.0, time: 09:16:15
# _______
# |O|X|X|
# |X|X| |
# |O|O|O|
# ‾‾‾‾‾‾‾
# episode: 38/2000, steps: 4, reward_total: 1, e: 1.0, time: 09:16:15
# _______
# | |O|X|
# |X|X|O|
# |X|O| |
# ‾‾‾‾‾‾‾
# episode: 39/2000, steps: 4, reward_total: -1, e: 1.0, time: 09:16:15
# _______
# |O|X|O|
# |X|O|X|
# |X|O|X|
# ‾‾‾‾‾‾‾
# episode: 40/2000, steps: 5, reward_total: 1, e: 1.0, time: 09:16:15
# _______
# |X|X|X|
# |O|O|X|
# |O|X|O|
# ‾‾‾‾‾‾‾
# episode: 41/2000, steps: 4, reward_total: -1, e: 1.0, time: 09:16:15
# _______
# |X|O|O|
# |O|X|X|
# |X|X|O|
# ‾‾‾‾‾‾‾
# episode: 42/2000, steps: 4, reward_total: -2, e: 1.0, time: 09:16:15
# _______
# |X|O|X|
# |X|O|X|
# | |O|O|
# ‾‾‾‾‾‾‾
# episode: 43/2000, steps: 2, reward_total: -2, e: 1.0, time: 09:16:15
# _______
# | | |X|
# |O|X| |
# |X| |O|
# ‾‾‾‾‾‾‾
# episode: 44/2000, steps: 4, reward_total: 1, e: 1.0, time: 09:16:15
# _______
# | |O|X|
# |X|X|O|
# |X| |O|
# ‾‾‾‾‾‾‾
# episode: 45/2000, steps: 3, reward_total: 1, e: 1.0, time: 09:16:15
# _______
# |O|X|X|
# | |O|X|
# | | |O|
# ‾‾‾‾‾‾‾
# episode: 46/2000, steps: 3, reward_total: 1, e: 1.0, time: 09:16:15
# _______
# | | |X|
# |O| |X|
# | |O|X|
# ‾‾‾‾‾‾‾
# episode: 47/2000, steps: 4, reward_total: 1, e: 1.0, time: 09:16:15
# _______
# | |O|O|
# |X|O|X|
# |X|O|X|
# ‾‾‾‾‾‾‾
# episode: 48/2000, steps: 4, reward_total: 1, e: 1.0, time: 09:16:15
# _______
# |X| |O|
# |X|O| |
# |X|O|X|
# ‾‾‾‾‾‾‾
# episode: 49/2000, steps: 4, reward_total: 1, e: 1.0, time: 09:16:15
# _______
# |O|X|X|
# |O|O| |
# |X|X|O|
# ‾‾‾‾‾‾‾
# episode: 50/2000, steps: 4, reward_total: 1, e: 1.0, time: 09:16:15
# _______
# | |O|X|
# |X|X|O|
# |X| |O|
# ‾‾‾‾‾‾‾
# episode: 51/2000, steps: 4, reward_total: -1, e: 1.0, time: 09:16:15
# _______
# |X|X|O|
# |O|O|X|
# |X|O|X|
# ‾‾‾‾‾‾‾
# episode: 52/2000, steps: 4, reward_total: 1, e: 1.0, time: 09:16:15
# _______
# | |X| |
# |X|X|O|
# |O|X|O|
# ‾‾‾‾‾‾‾
# episode: 53/2000, steps: 3, reward_total: -2, e: 1.0, time: 09:16:15
# _______
# | |O|X|
# | |X|O|
# |X|X|O|
# ‾‾‾‾‾‾‾
# episode: 54/2000, steps: 4, reward_total: -2, e: 1.0, time: 09:16:15
# _______
# |O|X|O|
# |X|O| |
# |X|X|O|
# ‾‾‾‾‾‾‾
# episode: 55/2000, steps: 3, reward_total: -2, e: 1.0, time: 09:16:15
# _______
# |X| |O|
# |X| |O|
# |X|O|X|
# ‾‾‾‾‾‾‾
# episode: 56/2000, steps: 5, reward_total: -1, e: 1.0, time: 09:16:15
# _______
# |X|O|X|
# |O|O|X|
# |X|X|O|
# ‾‾‾‾‾‾‾
# episode: 57/2000, steps: 4, reward_total: 1, e: 1.0, time: 09:16:15
# _______
# | |O|X|
# |X|O|O|
# |X|O|X|
# ‾‾‾‾‾‾‾
# episode: 58/2000, steps: 5, reward_total: 1, e: 1.0, time: 09:16:15
# _______
# |O|X|X|
# |O|O|X|
# |X|O|X|
# ‾‾‾‾‾‾‾
# episode: 59/2000, steps: 4, reward_total: -1, e: 1.0, time: 09:16:15
# _______
# |X|O|O|
# |O|X|X|
# |X|X|O|
# ‾‾‾‾‾‾‾
# episode: 60/2000, steps: 5, reward_total: -1, e: 1.0, time: 09:16:15
# _______
# |O|X|O|
# |O|X|X|
# |X|O|X|
# ‾‾‾‾‾‾‾
# episode: 61/2000, steps: 4, reward_total: -1, e: 1.0, time: 09:16:15
# _______
# |X|O|X|
# |X|O|X|
# |O|X|O|
# ‾‾‾‾‾‾‾
# episode: 62/2000, steps: 3, reward_total: -2, e: 1.0, time: 09:16:15
# _______
# | | |O|
# |X|O| |
# |O|X|X|
# ‾‾‾‾‾‾‾
# episode: 63/2000, steps: 4, reward_total: -2, e: 1.0, time: 09:16:15
# _______
# |X|O|O|
# |X|O|X|
# |X|X|O|
# ‾‾‾‾‾‾‾
# episode: 64/2000, steps: 4, reward_total: 1, e: 1.0, time: 09:16:15
# _______
# |X|O|O|
# | |X|X|
# | |O|X|
# ‾‾‾‾‾‾‾
# episode: 65/2000, steps: 4, reward_total: 1, e: 1.0, time: 09:16:15
# _______
# |O|O|O|
# | |X|X|
# |O|X|X|
# ‾‾‾‾‾‾‾
# episode: 66/2000, steps: 4, reward_total: 1, e: 1.0, time: 09:16:15
# _______
# |X|O| |
# | |O|O|
# |X|X|X|
# ‾‾‾‾‾‾‾
# episode: 67/2000, steps: 4, reward_total: -2, e: 1.0, time: 09:16:15
# _______
# |X|X|O|
# |X|X|O|
# |O|O|X|
# ‾‾‾‾‾‾‾
# episode: 68/2000, steps: 4, reward_total: 1, e: 1.0, time: 09:16:15
# _______
# | |X|O|
# | |O|O|
# |X|X|X|
# ‾‾‾‾‾‾‾
# episode: 69/2000, steps: 3, reward_total: 1, e: 1.0, time: 09:16:15
# _______
# | | |O|
# | |O|X|
# |O|X|X|
# ‾‾‾‾‾‾‾
# episode: 70/2000, steps: 3, reward_total: 1, e: 1.0, time: 09:16:15
# _______
# | |X| |
# |O|X| |
# | |X|O|
# ‾‾‾‾‾‾‾
# episode: 71/2000, steps: 3, reward_total: -2, e: 1.0, time: 09:16:15
# _______
# |X|X|X|
# | |O| |
# |O|X|O|
# ‾‾‾‾‾‾‾
# episode: 72/2000, steps: 5, reward_total: 1, e: 1.0, time: 09:16:15
# _______
# |X|O|O|
# |O|X|X|
# |X|O|X|
# ‾‾‾‾‾‾‾
# episode: 73/2000, steps: 3, reward_total: 1, e: 1.0, time: 09:16:15
# _______
# |O|X|X|
# |O| | |
# |O|X| |
# ‾‾‾‾‾‾‾
# episode: 74/2000, steps: 5, reward_total: -1, e: 1.0, time: 09:16:15
# _______
# |O|X|X|
# |X|O|O|
# |X|O|X|
# ‾‾‾‾‾‾‾
# episode: 75/2000, steps: 4, reward_total: 1, e: 1.0, time: 09:16:15
# _______
# |O|O|O|
# |O|X|X|
# |X| |X|
# ‾‾‾‾‾‾‾
# episode: 76/2000, steps: 4, reward_total: 1, e: 1.0, time: 09:16:15
# _______
# | |X|O|
# | |X|X|
# |O|X|O|
# ‾‾‾‾‾‾‾
# episode: 77/2000, steps: 2, reward_total: -2, e: 1.0, time: 09:16:15
# _______
# |O| | |
# |X|X|X|
# |O| | |
# ‾‾‾‾‾‾‾
# episode: 78/2000, steps: 4, reward_total: 1, e: 1.0, time: 09:16:15
# _______
# | | |X|
# |O|X|X|
# |O|O|X|
# ‾‾‾‾‾‾‾
# episode: 79/2000, steps: 3, reward_total: 1, e: 1.0, time: 09:16:15
# _______
# |O|O|O|
# | | |X|
# |X| |X|
# ‾‾‾‾‾‾‾
# episode: 80/2000, steps: 5, reward_total: 1, e: 1.0, time: 09:16:15
# _______
# |O|O|X|
# |O|O|X|
# |X|X|X|
# ‾‾‾‾‾‾‾
# episode: 81/2000, steps: 3, reward_total: -2, e: 1.0, time: 09:16:15
# _______
# |X|X|O|
# |X|O| |
# |X|O| |
# ‾‾‾‾‾‾‾
# episode: 82/2000, steps: 5, reward_total: 1, e: 1.0, time: 09:16:15
# _______
# |X|X|X|
# |X|O|O|
# |O|O|X|
# ‾‾‾‾‾‾‾
# episode: 83/2000, steps: 4, reward_total: -1, e: 1.0, time: 09:16:15
# _______
# |X|O|O|
# |O|X|X|
# |X|X|O|
# ‾‾‾‾‾‾‾
# episode: 84/2000, steps: 4, reward_total: -2, e: 1.0, time: 09:16:15
# _______
# |X|O| |
# |X|O|X|
# |O|O|X|
# ‾‾‾‾‾‾‾
# episode: 85/2000, steps: 4, reward_total: -2, e: 1.0, time: 09:16:15
# _______
# |X|O|O|
# |X|O|X|
# |X|X|O|
# ‾‾‾‾‾‾‾
# episode: 86/2000, steps: 4, reward_total: 1, e: 1.0, time: 09:16:15
# _______
# |O|O|X|
# |X| |X|
# |O| |X|
# ‾‾‾‾‾‾‾
# episode: 87/2000, steps: 3, reward_total: -2, e: 1.0, time: 09:16:15
# _______
# |X|O| |
# |X|O| |
# |X|X|O|
# ‾‾‾‾‾‾‾
# episode: 88/2000, steps: 3, reward_total: -2, e: 1.0, time: 09:16:15
# _______
# |O| | |
# |X|O|X|
# |X| |O|
# ‾‾‾‾‾‾‾
# episode: 89/2000, steps: 2, reward_total: -2, e: 1.0, time: 09:16:15
# _______
# |X|O| |
# |X| |O|
# |X| | |
# ‾‾‾‾‾‾‾
# episode: 90/2000, steps: 4, reward_total: 1, e: 1.0, time: 09:16:15
# _______
# |O| | |
# |X|X|X|
# |O|O|X|
# ‾‾‾‾‾‾‾
# episode: 91/2000, steps: 4, reward_total: -2, e: 1.0, time: 09:16:15
# _______
# |X|O|O|
# |X|O|O|
# |X|X|X|
# ‾‾‾‾‾‾‾
# episode: 92/2000, steps: 5, reward_total: 1, e: 1.0, time: 09:16:15
# _______
# |X|X|O|
# |X|O|X|
# |X|O|O|
# ‾‾‾‾‾‾‾
# episode: 93/2000, steps: 3, reward_total: -2, e: 1.0, time: 09:16:15
# _______
# |O|O|X|
# |X|X|X|
# |O| | |
# ‾‾‾‾‾‾‾
# episode: 94/2000, steps: 4, reward_total: 1, e: 1.0, time: 09:16:15
# _______
# |X| |X|
# | |X|O|
# |O|O|X|
# ‾‾‾‾‾‾‾
# episode: 95/2000, steps: 3, reward_total: -2, e: 1.0, time: 09:16:15
# _______
# |X|O|X|
# |O|X|O|
# |X| | |
# ‾‾‾‾‾‾‾
# episode: 96/2000, steps: 5, reward_total: -1, e: 1.0, time: 09:16:15
# _______
# |O|X|X|
# |X|O|O|
# |O|X|X|
# ‾‾‾‾‾‾‾
# episode: 97/2000, steps: 3, reward_total: 1, e: 1.0, time: 09:16:15
# _______
# | |X|X|
# | |X| |
# |O|O|O|
# ‾‾‾‾‾‾‾
# episode: 98/2000, steps: 4, reward_total: 1, e: 1.0, time: 09:16:15
# _______
# |O| |X|
# |O| |X|
# |X|O|X|
# ‾‾‾‾‾‾‾
# episode: 99/2000, steps: 4, reward_total: -1, e: 1.0, time: 09:16:15
# _______
# |O|X|X|
# |X|X|O|
# |O|O|X|
# ‾‾‾‾‾‾‾
# episode: 100/2000, steps: 3, reward_total: -2, e: 1.0, time: 09:16:15
# _______
# |X| | |
# |O|O|O|
# |X|X| |
# ‾‾‾‾‾‾‾
# episode: 101/2000, steps: 4, reward_total: 1, e: 1.0, time: 09:16:15
# _______
# |X|O|O|
# | |O|X|
# |O|X|X|
# ‾‾‾‾‾‾‾
# episode: 102/2000, steps: 4, reward_total: 1, e: 1.0, time: 09:16:15
# _______
# |O| |X|
# |X|X| |
# |X|O|O|
# ‾‾‾‾‾‾‾
# episode: 103/2000, steps: 4, reward_total: 1, e: 1.0, time: 09:16:15
# _______
# |X|O|O|
# |X|X|O|
# | |X|O|
# ‾‾‾‾‾‾‾
# episode: 104/2000, steps: 4, reward_total: 1, e: 1.0, time: 09:16:15
# _______
# |X|X|X|
# |X| |O|
# | |O|O|
# ‾‾‾‾‾‾‾
# episode: 105/2000, steps: 3, reward_total: -2, e: 1.0, time: 09:16:15
# _______
# |O|O| |
# |O| |X|
# |X|X|X|
# ‾‾‾‾‾‾‾
# episode: 106/2000, steps: 4, reward_total: -2, e: 1.0, time: 09:16:15
# _______
# |O|X|X|
# |O|X|X|
# |O|O| |
# ‾‾‾‾‾‾‾
# episode: 107/2000, steps: 3, reward_total: -2, e: 1.0, time: 09:16:15
# _______
# |X|O|X|
# | |X| |
# |X|O|O|
# ‾‾‾‾‾‾‾
# episode: 108/2000, steps: 5, reward_total: 1, e: 1.0, time: 09:16:15
# _______
# |O|O|X|
# |X|X|O|
# |X|O|X|
# ‾‾‾‾‾‾‾
# episode: 109/2000, steps: 2, reward_total: -2, e: 1.0, time: 09:16:15
# _______
# | | | |
# |X|X|X|
# |O|O| |
# ‾‾‾‾‾‾‾
# episode: 110/2000, steps: 4, reward_total: 1, e: 1.0, time: 09:16:15
# _______
# |X|X|X|
# |O|O| |
# |O|X| |
# ‾‾‾‾‾‾‾
# episode: 111/2000, steps: 4, reward_total: 1, e: 1.0, time: 09:16:15
# _______
# |O|X| |
# |X|O|X|
# |X|O|O|
# ‾‾‾‾‾‾‾
# episode: 112/2000, steps: 4, reward_total: 1, e: 1.0, time: 09:16:15
# _______
# |X| |O|
# |X|X|O|
# | |O|X|
# ‾‾‾‾‾‾‾
# episode: 113/2000, steps: 4, reward_total: -2, e: 1.0, time: 09:16:15
# _______
# |X|O|O|
# |X|O|X|
# |X|X|O|
# ‾‾‾‾‾‾‾
# episode: 114/2000, steps: 4, reward_total: 1, e: 1.0, time: 09:16:15
# _______
# |X|X|X|
# |O|X| |
# |O| |O|
# ‾‾‾‾‾‾‾
# episode: 115/2000, steps: 4, reward_total: -2, e: 1.0, time: 09:16:15
# _______
# |O|X|X|
# |X|O|X|
# |O|O|X|
# ‾‾‾‾‾‾‾
# episode: 116/2000, steps: 4, reward_total: -2, e: 1.0, time: 09:16:15
# _______
# |O|O|O|
# |X| |X|
# |X|O|X|
# ‾‾‾‾‾‾‾
# episode: 117/2000, steps: 4, reward_total: -1, e: 1.0, time: 09:16:15
# _______
# |O|X|X|
# |X|O|O|
# |X|O|X|
# ‾‾‾‾‾‾‾
# episode: 118/2000, steps: 4, reward_total: 1, e: 1.0, time: 09:16:15
# _______
# |O| |O|
# |X|X|X|
# | |X|O|
# ‾‾‾‾‾‾‾
# episode: 119/2000, steps: 3, reward_total: 1, e: 1.0, time: 09:16:15
# _______
# |X|O|X|
# | |O| |
# | |O|X|
# ‾‾‾‾‾‾‾
# episode: 120/2000, steps: 4, reward_total: 1, e: 1.0, time: 09:16:15
# _______
# |X|X|X|
# |O|X|O|
# |O| | |
# ‾‾‾‾‾‾‾
# episode: 121/2000, steps: 3, reward_total: -2, e: 1.0, time: 09:16:15
# _______
# |X|O| |
# |X|O|X|
# |X| |O|
# ‾‾‾‾‾‾‾
# episode: 122/2000, steps: 4, reward_total: 1, e: 1.0, time: 09:16:15
# _______
# |X|O|X|
# |O| |X|
# | |O|X|
# ‾‾‾‾‾‾‾
# episode: 123/2000, steps: 3, reward_total: -2, e: 1.0, time: 09:16:15
# _______
# | |X|O|
# |X|X|O|
# |O|X| |
# ‾‾‾‾‾‾‾
# episode: 124/2000, steps: 5, reward_total: 1, e: 1.0, time: 09:16:15
# _______
# |O|X|O|
# |O|X|O|
# |X|X|X|
# ‾‾‾‾‾‾‾
# episode: 125/2000, steps: 2, reward_total: -2, e: 1.0, time: 09:16:15
# _______
# | |O| |
# | | |O|
# |X|X|X|
# ‾‾‾‾‾‾‾
# episode: 126/2000, steps: 4, reward_total: -2, e: 1.0, time: 09:16:15
# _______
# | |X|X|
# |O|O|O|
# |X|X|O|
# ‾‾‾‾‾‾‾
# episode: 127/2000, steps: 4, reward_total: -2, e: 1.0, time: 09:16:15
# _______
# |O|O|X|
# |O|X|X|
# |X|X|O|
# ‾‾‾‾‾‾‾
# episode: 128/2000, steps: 5, reward_total: -1, e: 1.0, time: 09:16:15
# _______
# |O|X|O|
# |X|O|X|
# |X|O|X|
# ‾‾‾‾‾‾‾
# episode: 129/2000, steps: 3, reward_total: -2, e: 1.0, time: 09:16:15
# _______
# | |O|X|
# |O| |O|
# |X|X|X|
# ‾‾‾‾‾‾‾
# episode: 130/2000, steps: 4, reward_total: 1, e: 1.0, time: 09:16:15
# _______
# |X| |X|
# | |X|O|
# |O|O|X|
# ‾‾‾‾‾‾‾
# episode: 131/2000, steps: 3, reward_total: 1, e: 1.0, time: 09:16:15
# _______
# |O|O|O|
# |X| | |
# |X|X| |
# ‾‾‾‾‾‾‾
# episode: 132/2000, steps: 5, reward_total: -1, e: 1.0, time: 09:16:15
# _______
# |O|X|O|
# |X|X|O|
# |X|O|X|
# ‾‾‾‾‾‾‾
# episode: 133/2000, steps: 3, reward_total: -2, e: 1.0, time: 09:16:15
# _______
# |O|X| |
# |X|X|X|
# | |O|O|
# ‾‾‾‾‾‾‾
# episode: 134/2000, steps: 5, reward_total: 1, e: 1.0, time: 09:16:15
# _______
# |X|X|X|
# |O|O|X|
# |X|O|O|
# ‾‾‾‾‾‾‾
# episode: 135/2000, steps: 2, reward_total: -2, e: 1.0, time: 09:16:15
# _______
# |X|O|O|
# | |X| |
# | | |X|
# ‾‾‾‾‾‾‾
# episode: 136/2000, steps: 4, reward_total: 1, e: 1.0, time: 09:16:15
# _______
# |O| |O|
# |X|X|X|
# | |X|O|
# ‾‾‾‾‾‾‾
# episode: 137/2000, steps: 4, reward_total: -1, e: 1.0, time: 09:16:15
# _______
# |X|X|O|
# |O|X|X|
# |X|O|O|
# ‾‾‾‾‾‾‾
# episode: 138/2000, steps: 5, reward_total: 1, e: 1.0, time: 09:16:15
# _______
# |O|O|X|
# |X|X|X|
# |O|O|X|
# ‾‾‾‾‾‾‾
# episode: 139/2000, steps: 4, reward_total: -2, e: 1.0, time: 09:16:15
# _______
# |X|O|O|
# |X|X|X|
# |O|O|X|
# ‾‾‾‾‾‾‾
# episode: 140/2000, steps: 4, reward_total: 1, e: 1.0, time: 09:16:15
# _______
# |X|X|X|
# |O| |O|
# | |X|O|
# ‾‾‾‾‾‾‾
# episode: 141/2000, steps: 4, reward_total: -2, e: 1.0, time: 09:16:15
# _______
# |O|X|O|
# |O|X|X|
# |X|X|O|
# ‾‾‾‾‾‾‾
# episode: 142/2000, steps: 4, reward_total: 1, e: 1.0, time: 09:16:15
# _______
# | | |X|
# |O|X|O|
# |X|O|X|
# ‾‾‾‾‾‾‾
# episode: 143/2000, steps: 3, reward_total: -2, e: 1.0, time: 09:16:15
# _______
# | |X|O|
# |O|X|O|
# | |X|X|
# ‾‾‾‾‾‾‾
# episode: 144/2000, steps: 5, reward_total: 1, e: 1.0, time: 09:16:15
# _______
# |X|X|O|
# |O|X|O|
# |X|O|X|
# ‾‾‾‾‾‾‾
# episode: 145/2000, steps: 4, reward_total: 1, e: 1.0, time: 09:16:15
# _______
# |O|O|X|
# |X|O|X|
# |X| |O|
# ‾‾‾‾‾‾‾
# episode: 146/2000, steps: 3, reward_total: -2, e: 1.0, time: 09:16:15
# _______
# |X|X|O|
# |X| |O|
# | | |O|
# ‾‾‾‾‾‾‾
# episode: 147/2000, steps: 3, reward_total: -2, e: 1.0, time: 09:16:15
# _______
# |O| |X|
# | |X|O|
# |X|O|X|
# ‾‾‾‾‾‾‾
# episode: 148/2000, steps: 5, reward_total: 1, e: 1.0, time: 09:16:15
# _______
# |X|X|O|
# |O|X|O|
# |O|X|X|
# ‾‾‾‾‾‾‾
# episode: 149/2000, steps: 4, reward_total: 1, e: 1.0, time: 09:16:15
# _______
# |X| |X|
# |X|X|O|
# |O|O|O|
# ‾‾‾‾‾‾‾
# episode: 150/2000, steps: 4, reward_total: -2, e: 1.0, time: 09:16:15
# _______
# |O|X|X|
# |O|O|X|
# |O|X| |
# ‾‾‾‾‾‾‾
# episode: 151/2000, steps: 3, reward_total: -2, e: 1.0, time: 09:16:15
# _______
# |O|O|X|
# |X| |X|
# | |O|X|
# ‾‾‾‾‾‾‾
# episode: 152/2000, steps: 3, reward_total: 1, e: 1.0, time: 09:16:15
# _______
# |X| |O|
# |X|O| |
# |X| | |
# ‾‾‾‾‾‾‾
# episode: 153/2000, steps: 3, reward_total: -2, e: 1.0, time: 09:16:15
# _______
# | |X|X|
# | |X|O|
# |X|O|O|
# ‾‾‾‾‾‾‾
# episode: 154/2000, steps: 4, reward_total: -2, e: 1.0, time: 09:16:15
# _______
# | |O|X|
# |X|O|X|
# |X|O|O|
# ‾‾‾‾‾‾‾
# episode: 155/2000, steps: 2, reward_total: -2, e: 1.0, time: 09:16:15
# _______
# | | | |
# |X|X|X|
# | |O|O|
# ‾‾‾‾‾‾‾
# episode: 156/2000, steps: 4, reward_total: 1, e: 1.0, time: 09:16:15
# _______
# |X|O| |
# |O|X|O|
# | |X|X|
# ‾‾‾‾‾‾‾
# episode: 157/2000, steps: 3, reward_total: 1, e: 1.0, time: 09:16:15
# _______
# |O|X|X|
# | |O| |
# | |X|O|
# ‾‾‾‾‾‾‾
# episode: 158/2000, steps: 4, reward_total: 1, e: 1.0, time: 09:16:15
# _______
# |X|O| |
# |X|O|O|
# |X| |X|
# ‾‾‾‾‾‾‾
# episode: 159/2000, steps: 2, reward_total: -2, e: 1.0, time: 09:16:15
# _______
# |X| |O|
# | |X| |
# |O| |X|
# ‾‾‾‾‾‾‾
# episode: 160/2000, steps: 4, reward_total: -2, e: 1.0, time: 09:16:15
# _______
# |X|O|O|
# |X|X|O|
# | |X|O|
# ‾‾‾‾‾‾‾
# episode: 161/2000, steps: 2, reward_total: -2, e: 1.0, time: 09:16:15
# _______
# | |O| |
# | |O| |
# |X|X|X|
# ‾‾‾‾‾‾‾
# episode: 162/2000, steps: 4, reward_total: 1, e: 1.0, time: 09:16:15
# _______
# | |X|X|
# |O|X|O|
# |O|X| |
# ‾‾‾‾‾‾‾
# episode: 163/2000, steps: 4, reward_total: -1, e: 1.0, time: 09:16:15
# _______
# |X|X|O|
# |O|X|X|
# |X|O|O|
# ‾‾‾‾‾‾‾
# episode: 164/2000, steps: 4, reward_total: -2, e: 1.0, time: 09:16:15
# _______
# | |X|O|
# |O|O|X|
# |O|X|X|
# ‾‾‾‾‾‾‾
# episode: 165/2000, steps: 3, reward_total: -2, e: 1.0, time: 09:16:15
# _______
# |X|O|O|
# |X| |X|
# |X| |O|
# ‾‾‾‾‾‾‾
# episode: 166/2000, steps: 4, reward_total: 1, e: 1.0, time: 09:16:15
# _______
# |X|X|X|
# |O|X| |
# |O| |O|
# ‾‾‾‾‾‾‾
# episode: 167/2000, steps: 4, reward_total: -1, e: 1.0, time: 09:16:15
# _______
# |X|O|X|
# |O|O|X|
# |X|X|O|
# ‾‾‾‾‾‾‾
# episode: 168/2000, steps: 5, reward_total: 1, e: 1.0, time: 09:16:15
# _______
# |X|X|X|
# |O|O|X|
# |X|O|O|
# ‾‾‾‾‾‾‾
# episode: 169/2000, steps: 4, reward_total: 1, e: 1.0, time: 09:16:15
# _______
# |X|X|O|
# |X|O|O|
# | |X|O|
# ‾‾‾‾‾‾‾
# episode: 170/2000, steps: 3, reward_total: -2, e: 1.0, time: 09:16:15
# _______
# |X| |O|
# | |X|O|
# | |X|O|
# ‾‾‾‾‾‾‾
# episode: 171/2000, steps: 4, reward_total: 1, e: 1.0, time: 09:16:15
# _______
# |X|X|O|
# |O|O|X|
# |O| |X|
# ‾‾‾‾‾‾‾
# episode: 172/2000, steps: 5, reward_total: 1, e: 1.0, time: 09:16:15
# _______
# |O|O|X|
# |X|O|X|
# |O|X|X|
# ‾‾‾‾‾‾‾
# episode: 173/2000, steps: 3, reward_total: -2, e: 1.0, time: 09:16:15
# _______
# |X|O| |
# |O|O| |
# |X|X|X|
# ‾‾‾‾‾‾‾
# episode: 174/2000, steps: 5, reward_total: 1, e: 1.0, time: 09:16:15
# _______
# |X|X|O|
# |O|X|X|
# |O|X|O|
# ‾‾‾‾‾‾‾
# episode: 175/2000, steps: 3, reward_total: -2, e: 1.0, time: 09:16:15
# _______
# |X|O|O|
# | |X|X|
# |O| |X|
# ‾‾‾‾‾‾‾
# episode: 176/2000, steps: 4, reward_total: 1, e: 1.0, time: 09:16:15
# _______
# |X|O| |
# |X|X|O|
# |X| |O|
# ‾‾‾‾‾‾‾
# episode: 177/2000, steps: 4, reward_total: -2, e: 1.0, time: 09:16:15
# _______
# |X|O|O|
# |O|X|X|
# |O|X|X|
# ‾‾‾‾‾‾‾
# episode: 178/2000, steps: 3, reward_total: 1, e: 1.0, time: 09:16:15
# _______
# |X|O|O|
# |X| | |
# |X| | |
# ‾‾‾‾‾‾‾
# episode: 179/2000, steps: 3, reward_total: -2, e: 1.0, time: 09:16:15
# _______
# |X| |X|
# |O|O|X|
# |O| |X|
# ‾‾‾‾‾‾‾
# episode: 180/2000, steps: 3, reward_total: -2, e: 1.0, time: 09:16:15
# _______
# |O| |X|
# | |O|X|
# | |X|O|
# ‾‾‾‾‾‾‾
# episode: 181/2000, steps: 4, reward_total: 1, e: 1.0, time: 09:16:15
# _______
# |X|X|O|
# |X|O|O|
# |O|X| |
# ‾‾‾‾‾‾‾
# episode: 182/2000, steps: 5, reward_total: 1, e: 1.0, time: 09:16:15
# _______
# |X|O|X|
# |X|O|O|
# |X|X|O|
# ‾‾‾‾‾‾‾
# episode: 183/2000, steps: 4, reward_total: 1, e: 1.0, time: 09:16:15
# _______
# |O|O|O|
# | |X|X|
# |O|X|X|
# ‾‾‾‾‾‾‾
# episode: 184/2000, steps: 5, reward_total: 1, e: 1.0, time: 09:16:15
# _______
# |X|O|X|
# |O|O|X|
# |O|X|X|
# ‾‾‾‾‾‾‾
# episode: 185/2000, steps: 3, reward_total: -2, e: 1.0, time: 09:16:15
# _______
# |X|O|X|
# | |X|O|
# |X| |O|
# ‾‾‾‾‾‾‾
# episode: 186/2000, steps: 4, reward_total: -2, e: 1.0, time: 09:16:15
# _______
# |X| |O|
# |X|O|O|
# |O|X|X|
# ‾‾‾‾‾‾‾
# episode: 187/2000, steps: 4, reward_total: -1, e: 1.0, time: 09:16:15
# _______
# |X|O|X|
# |X|X|O|
# |O|X|O|
# ‾‾‾‾‾‾‾
# episode: 188/2000, steps: 3, reward_total: -2, e: 1.0, time: 09:16:15
# _______
# |X|O| |
# |X|O| |
# | |O|X|
# ‾‾‾‾‾‾‾
# episode: 189/2000, steps: 2, reward_total: -2, e: 1.0, time: 09:16:15
# _______
# |X| |O|
# | |X| |
# |O| |X|
# ‾‾‾‾‾‾‾
# episode: 190/2000, steps: 5, reward_total: -1, e: 1.0, time: 09:16:15
# _______
# |X|O|O|
# |O|X|X|
# |X|X|O|
# ‾‾‾‾‾‾‾
# episode: 191/2000, steps: 3, reward_total: -2, e: 1.0, time: 09:16:15
# _______
# |O| |O|
# |X| |O|
# |X|X|X|
# ‾‾‾‾‾‾‾
# episode: 192/2000, steps: 4, reward_total: 1, e: 1.0, time: 09:16:15
# _______
# | |X|O|
# |O|X| |
# |O|X|X|
# ‾‾‾‾‾‾‾
# episode: 193/2000, steps: 3, reward_total: -2, e: 1.0, time: 09:16:15
# _______
# |O| |O|
# |X| |O|
# |X|X|X|
# ‾‾‾‾‾‾‾
# episode: 194/2000, steps: 4, reward_total: 1, e: 1.0, time: 09:16:15
# _______
# |O|O|X|
# | |O|X|
# | |X|X|
# ‾‾‾‾‾‾‾
# episode: 195/2000, steps: 4, reward_total: 1, e: 1.0, time: 09:16:15
# _______
# |O|X|X|
# | |O|X|
# |X|O|O|
# ‾‾‾‾‾‾‾
# episode: 196/2000, steps: 5, reward_total: 1, e: 1.0, time: 09:16:15
# _______
# |X|X|X|
# |O|X|O|
# |X|O|O|
# ‾‾‾‾‾‾‾
# episode: 197/2000, steps: 4, reward_total: -1, e: 1.0, time: 09:16:15
# _______
# |X|O|X|
# |O|O|X|
# |X|X|O|
# ‾‾‾‾‾‾‾
# episode: 198/2000, steps: 4, reward_total: -2, e: 1.0, time: 09:16:15
# _______
# |O|X|X|
# |O|X| |
# |O|O|X|
# ‾‾‾‾‾‾‾
# episode: 199/2000, steps: 3, reward_total: -2, e: 1.0, time: 09:16:15
# _______
# |X|O|O|
# |X|X| |
# |X|O| |
# ‾‾‾‾‾‾‾
# episode: 200/2000, steps: 5, reward_total: 1, e: 1.0, time: 09:16:15
# _______
# |X|O|O|
# |X|X|X|
# |O|X|O|
# ‾‾‾‾‾‾‾
# episode: 201/2000, steps: 3, reward_total: -2, e: 1.0, time: 09:16:15
# _______
# | | |X|
# |X|O|X|
# |O|O|X|
# ‾‾‾‾‾‾‾
# episode: 202/2000, steps: 5, reward_total: -1, e: 1.0, time: 09:16:15
# _______
# |X|O|X|
# |X|O|O|
# |O|X|X|
# ‾‾‾‾‾‾‾
# episode: 203/2000, steps: 4, reward_total: 1, e: 1.0, time: 09:16:15
# _______
# |X|X|O|
# |X|X|O|
# | |O|O|
# ‾‾‾‾‾‾‾
# episode: 204/2000, steps: 3, reward_total: 1, e: 1.0, time: 09:16:15
# _______
# |X|O| |
# | |X|O|
# | | |X|
# ‾‾‾‾‾‾‾
# episode: 205/2000, steps: 3, reward_total: 1, e: 1.0, time: 09:16:15
# _______
# |O|O|O|
# | |X| |
# | |X|X|
# ‾‾‾‾‾‾‾
# episode: 206/2000, steps: 4, reward_total: 1, e: 1.0, time: 09:16:15
# _______
# |X|X|X|
# |O|O| |
# |O| |X|
# ‾‾‾‾‾‾‾
# episode: 207/2000, steps: 4, reward_total: 1, e: 1.0, time: 09:16:15
# _______
# |O|X|O|
# |X|O| |
# |X|X|O|
# ‾‾‾‾‾‾‾
# episode: 208/2000, steps: 5, reward_total: 1, e: 1.0, time: 09:16:15
# _______
# |O|O|X|
# |X|X|O|
# |X|X|O|
# ‾‾‾‾‾‾‾
# episode: 209/2000, steps: 3, reward_total: 1, e: 1.0, time: 09:16:15
# _______
# |X| |O|
# | |X|O|
# | |X|O|
# ‾‾‾‾‾‾‾
# episode: 210/2000, steps: 4, reward_total: -2, e: 1.0, time: 09:16:15
# _______
# |O|O|O|
# |X|O|X|
# | |X|X|
# ‾‾‾‾‾‾‾
# episode: 211/2000, steps: 3, reward_total: -2, e: 1.0, time: 09:16:15
# _______
# | |X|X|
# | |X|O|
# |X|O|O|
# ‾‾‾‾‾‾‾
# episode: 212/2000, steps: 5, reward_total: -1, e: 1.0, time: 09:16:15
# _______
# |O|X|X|
# |X|X|O|
# |O|O|X|
# ‾‾‾‾‾‾‾
# episode: 213/2000, steps: 3, reward_total: -2, e: 1.0, time: 09:16:15
# _______
# |X|O|O|
# |X|X| |
# |X|O| |
# ‾‾‾‾‾‾‾
# episode: 214/2000, steps: 3, reward_total: 1, e: 1.0, time: 09:16:15
# _______
# |O| |O|
# |X|X|X|
# | | | |
# ‾‾‾‾‾‾‾
# episode: 215/2000, steps: 4, reward_total: -1, e: 1.0, time: 09:16:15
# _______
# |O|X|X|
# |X|X|O|
# |O|O|X|
# ‾‾‾‾‾‾‾
# episode: 216/2000, steps: 3, reward_total: 1, e: 1.0, time: 09:16:15
# _______
# |X| |O|
# |X| |O|
# |X| | |
# ‾‾‾‾‾‾‾
# episode: 217/2000, steps: 4, reward_total: -2, e: 1.0, time: 09:16:15
# _______
# |X|O|O|
# |O|X|X|
# |O|X|X|
# ‾‾‾‾‾‾‾
# episode: 218/2000, steps: 4, reward_total: -2, e: 1.0, time: 09:16:15
# _______
# |O|X| |
# |X|O|X|
# |O|X|O|
# ‾‾‾‾‾‾‾
# episode: 219/2000, steps: 4, reward_total: -2, e: 1.0, time: 09:16:15
# _______
# |O|X|X|
# |X|O|X|
# |O|O|X|
# ‾‾‾‾‾‾‾
# episode: 220/2000, steps: 4, reward_total: 1, e: 1.0, time: 09:16:15
# _______
# |X|X|X|
# |O| |O|
# |X| |O|
# ‾‾‾‾‾‾‾
# episode: 221/2000, steps: 4, reward_total: 1, e: 1.0, time: 09:16:15
# _______
# |O|O|O|
# |X|O|X|
# | |X|X|
# ‾‾‾‾‾‾‾
# episode: 222/2000, steps: 3, reward_total: -2, e: 1.0, time: 09:16:15
# _______
# |X|X| |
# |O|O|O|
# | | |X|
# ‾‾‾‾‾‾‾
# episode: 223/2000, steps: 4, reward_total: -2, e: 1.0, time: 09:16:15
# _______
# |O|X|O|
# |X|X|X|
# |X|O|O|
# ‾‾‾‾‾‾‾
# episode: 224/2000, steps: 5, reward_total: -1, e: 1.0, time: 09:16:15
# _______
# |X|O|X|
# |X|O|X|
# |O|X|O|
# ‾‾‾‾‾‾‾
# episode: 225/2000, steps: 4, reward_total: -2, e: 1.0, time: 09:16:15
# _______
# |X|O|X|
# |O|X|X|
# |X|O|O|
# ‾‾‾‾‾‾‾
# episode: 226/2000, steps: 3, reward_total: 1, e: 1.0, time: 09:16:15
# _______
# | | |X|
# |O| |X|
# |O| |X|
# ‾‾‾‾‾‾‾
# episode: 227/2000, steps: 3, reward_total: 1, e: 1.0, time: 09:16:15
# _______
# |X|X|O|
# |X|O| |
# |O| | |
# ‾‾‾‾‾‾‾
# episode: 228/2000, steps: 4, reward_total: -2, e: 1.0, time: 09:16:15
# _______
# | |X|X|
# |O|O|O|
# |X|O|X|
# ‾‾‾‾‾‾‾
# episode: 229/2000, steps: 4, reward_total: -2, e: 1.0, time: 09:16:15
# _______
# |X|O|O|
# |O|O|X|
# |X|X|X|
# ‾‾‾‾‾‾‾
# episode: 230/2000, steps: 5, reward_total: -1, e: 1.0, time: 09:16:15
# _______
# |X|O|X|
# |O|X|X|
# |O|X|O|
# ‾‾‾‾‾‾‾
# episode: 231/2000, steps: 2, reward_total: -2, e: 1.0, time: 09:16:15
# _______
# |X|O| |
# |X| | |
# |X|O| |
# ‾‾‾‾‾‾‾
# episode: 232/2000, steps: 4, reward_total: -2, e: 1.0, time: 09:16:15
# _______
# |O|X|X|
# | |O|X|
# |O|X|O|
# ‾‾‾‾‾‾‾
# episode: 233/2000, steps: 4, reward_total: 1, e: 1.0, time: 09:16:15
# _______
# | |O|X|
# |X|O|O|
# |X|O|X|
# ‾‾‾‾‾‾‾
# episode: 234/2000, steps: 3, reward_total: -2, e: 1.0, time: 09:16:15
# _______
# | | |X|
# |X| |X|
# |O|O|O|
# ‾‾‾‾‾‾‾
# episode: 235/2000, steps: 3, reward_total: -2, e: 1.0, time: 09:16:15
# _______
# |O|X| |
# | |O|O|
# |X|X|X|
# ‾‾‾‾‾‾‾
# episode: 236/2000, steps: 3, reward_total: -2, e: 1.0, time: 09:16:15
# _______
# |X|O| |
# | |O|X|
# |X|O| |
# ‾‾‾‾‾‾‾
# episode: 237/2000, steps: 3, reward_total: -2, e: 1.0, time: 09:16:15
# _______
# |O|O|X|
# | | |X|
# |X|O|X|
# ‾‾‾‾‾‾‾
# episode: 238/2000, steps: 5, reward_total: -1, e: 1.0, time: 09:16:15
# _______
# |O|X|O|
# |O|X|X|
# |X|O|X|
# ‾‾‾‾‾‾‾
# episode: 239/2000, steps: 4, reward_total: -2, e: 1.0, time: 09:16:15
# _______
# |X|X|X|
# |X|O|O|
# |O|O|X|
# ‾‾‾‾‾‾‾
# episode: 240/2000, steps: 4, reward_total: 1, e: 1.0, time: 09:16:15
# _______
# |X|X|O|
# | |X| |
# |O|X|O|
# ‾‾‾‾‾‾‾
# episode: 241/2000, steps: 3, reward_total: 1, e: 1.0, time: 09:16:15
# _______
# | |X|O|
# | |O|X|
# |O| |X|
# ‾‾‾‾‾‾‾
# episode: 242/2000, steps: 4, reward_total: -2, e: 1.0, time: 09:16:15
# _______
# |O|X|X|
# |O|O|O|
# |X| |X|
# ‾‾‾‾‾‾‾
# episode: 243/2000, steps: 4, reward_total: -1, e: 1.0, time: 09:16:15
# _______
# |X|X|O|
# |O|O|X|
# |X|X|O|
# ‾‾‾‾‾‾‾
# episode: 244/2000, steps: 4, reward_total: -2, e: 1.0, time: 09:16:15
# _______
# | |X|X|
# |O|O|O|
# |X|O|X|
# ‾‾‾‾‾‾‾
# episode: 245/2000, steps: 2, reward_total: -2, e: 1.0, time: 09:16:15
# _______
# |X| |O|
# | |X| |
# | |O|X|
# ‾‾‾‾‾‾‾
# episode: 246/2000, steps: 5, reward_total: 1, e: 1.0, time: 09:16:15
# _______
# |O|X|O|
# |X|X|X|
# |X|O|O|
# ‾‾‾‾‾‾‾
# episode: 247/2000, steps: 4, reward_total: 1, e: 1.0, time: 09:16:15
# _______
# |O|O|O|
# |X|X| |
# |O|X|X|
# ‾‾‾‾‾‾‾
# episode: 248/2000, steps: 5, reward_total: -1, e: 1.0, time: 09:16:15
# _______
# |X|O|X|
# |X|X|O|
# |O|X|O|
# ‾‾‾‾‾‾‾
# episode: 249/2000, steps: 4, reward_total: 1, e: 1.0, time: 09:16:15
# _______
# |X| |X|
# |X|O|X|
# |O|O|O|
# ‾‾‾‾‾‾‾
# episode: 250/2000, steps: 3, reward_total: -2, e: 1.0, time: 09:16:15
# _______
# |X|X|O|
# | |O| |
# |O|X| |
# ‾‾‾‾‾‾‾
# episode: 251/2000, steps: 3, reward_total: -2, e: 1.0, time: 09:16:15
# _______
# |O|X|X|
# | |X|O|
# |X| |O|
# ‾‾‾‾‾‾‾
# episode: 252/2000, steps: 3, reward_total: 1, e: 1.0, time: 09:16:15
# _______
# |O| |X|
# | | |X|
# |O| |X|
# ‾‾‾‾‾‾‾
# episode: 253/2000, steps: 3, reward_total: -2, e: 1.0, time: 09:16:15
# _______
# |X|O| |
# |O|X|O|
# | |X|X|
# ‾‾‾‾‾‾‾
# episode: 254/2000, steps: 3, reward_total: -2, e: 1.0, time: 09:16:15
# _______
# |O| |X|
# |O| |X|
# |O|X| |
# ‾‾‾‾‾‾‾
# episode: 255/2000, steps: 3, reward_total: 1, e: 1.0, time: 09:16:15
# _______
# |O|O|O|
# |X| | |
# |X|X| |
# ‾‾‾‾‾‾‾
# episode: 256/2000, steps: 5, reward_total: 1, e: 1.0, time: 09:16:15
# _______
# |X|X|O|
# |O|X|O|
# |X|O|X|
# ‾‾‾‾‾‾‾
# episode: 257/2000, steps: 4, reward_total: -2, e: 1.0, time: 09:16:15
# _______
# |O|X|O|
# |X|X|O|
# |O|X|X|
# ‾‾‾‾‾‾‾
# episode: 258/2000, steps: 4, reward_total: 1, e: 1.0, time: 09:16:15
# _______
# |O|O|X|
# |O|X|X|
# |X| | |
# ‾‾‾‾‾‾‾
# episode: 259/2000, steps: 3, reward_total: -2, e: 1.0, time: 09:16:15
# _______
# |X| |O|
# |X|O| |
# |X|O|X|
# ‾‾‾‾‾‾‾
# episode: 260/2000, steps: 4, reward_total: 1, e: 1.0, time: 09:16:15
# _______
# |O| |O|
# |O| |X|
# |X|X|X|
# ‾‾‾‾‾‾‾
# episode: 261/2000, steps: 4, reward_total: -2, e: 1.0, time: 09:16:15
# _______
# |X|X|O|
# |X|X|O|
# |O|O|X|
# ‾‾‾‾‾‾‾
# episode: 262/2000, steps: 4, reward_total: 1, e: 1.0, time: 09:16:15
# _______
# |O|X| |
# | |X|O|
# |O|X|X|
# ‾‾‾‾‾‾‾
# episode: 263/2000, steps: 4, reward_total: -1, e: 1.0, time: 09:16:15
# _______
# |O|X|X|
# |X|O|O|
# |X|O|X|
# ‾‾‾‾‾‾‾
# episode: 264/2000, steps: 4, reward_total: 1, e: 1.0, time: 09:16:15
# _______
# |X| | |
# |O|X|X|
# |O|O|X|
# ‾‾‾‾‾‾‾
# episode: 265/2000, steps: 4, reward_total: -1, e: 1.0, time: 09:16:15
# _______
# |O|X|O|
# |X|X|O|
# |X|O|X|
# ‾‾‾‾‾‾‾
# episode: 266/2000, steps: 4, reward_total: 1, e: 1.0, time: 09:16:15
# _______
# |X|X|X|
# | | |O|
# |O|O|X|
# ‾‾‾‾‾‾‾
# episode: 267/2000, steps: 4, reward_total: 1, e: 1.0, time: 09:16:15
# _______
# |O|X|X|
# |X|O|O|
# |X| |O|
# ‾‾‾‾‾‾‾
# episode: 268/2000, steps: 3, reward_total: -2, e: 1.0, time: 09:16:15
# _______
# |X| |O|
# | |X|O|
# | |X|O|
# ‾‾‾‾‾‾‾
# episode: 269/2000, steps: 3, reward_total: -2, e: 1.0, time: 09:16:15
# _______
# |X|X| |
# | |X|O|
# |O|X|O|
# ‾‾‾‾‾‾‾
# episode: 270/2000, steps: 4, reward_total: 1, e: 1.0, time: 09:16:15
# _______
# | |X|X|
# |O|X| |
# |O|X|O|
# ‾‾‾‾‾‾‾
# episode: 271/2000, steps: 3, reward_total: 1, e: 1.0, time: 09:16:15
# _______
# |O|X|X|
# |X|O| |
# | | |O|
# ‾‾‾‾‾‾‾
# episode: 272/2000, steps: 4, reward_total: 1, e: 1.0, time: 09:16:15
# _______
# |O| |X|
# | |O|O|
# |X|X|X|
# ‾‾‾‾‾‾‾
# episode: 273/2000, steps: 3, reward_total: -2, e: 1.0, time: 09:16:15
# _______
# |X| |X|
# |X|O| |
# |X|O|O|
# ‾‾‾‾‾‾‾
# episode: 274/2000, steps: 3, reward_total: -2, e: 1.0, time: 09:16:15
# _______
# | |X|O|
# |X|O|X|
# |O| | |
# ‾‾‾‾‾‾‾
# episode: 275/2000, steps: 3, reward_total: -2, e: 1.0, time: 09:16:15
# _______
# |X|O|O|
# |X|X| |
# |X| |O|
# ‾‾‾‾‾‾‾
# episode: 276/2000, steps: 5, reward_total: -1, e: 1.0, time: 09:16:15
# _______
# |O|O|X|
# |X|X|O|
# |O|X|X|
# ‾‾‾‾‾‾‾
# episode: 277/2000, steps: 4, reward_total: 1, e: 1.0, time: 09:16:15
# _______
# |O|X|O|
# |X| |O|
# |X|X|O|
# ‾‾‾‾‾‾‾
# episode: 278/2000, steps: 5, reward_total: -1, e: 1.0, time: 09:16:15
# _______
# |O|X|O|
# |X|O|X|
# |X|O|X|
# ‾‾‾‾‾‾‾
# episode: 279/2000, steps: 4, reward_total: -1, e: 1.0, time: 09:16:15
# _______
# |O|X|X|
# |X|O|O|
# |X|O|X|
# ‾‾‾‾‾‾‾
# episode: 280/2000, steps: 3, reward_total: -2, e: 1.0, time: 09:16:15
# _______
# |X| | |
# |O|O|O|
# |X|X| |
# ‾‾‾‾‾‾‾
# episode: 281/2000, steps: 3, reward_total: -2, e: 1.0, time: 09:16:15
# _______
# |X|O|O|
# | |X|X|
# | |O|X|
# ‾‾‾‾‾‾‾
# episode: 282/2000, steps: 3, reward_total: -2, e: 1.0, time: 09:16:15
# _______
# |O|X|X|
# | |O|X|
# | | |O|
# ‾‾‾‾‾‾‾
# episode: 283/2000, steps: 4, reward_total: 1, e: 1.0, time: 09:16:15
# _______
# |X| |O|
# |X|O|X|
# |O|X|O|
# ‾‾‾‾‾‾‾
# episode: 284/2000, steps: 5, reward_total: 1, e: 1.0, time: 09:16:15
# _______
# |X|X|O|
# |X|O|X|
# |X|O|O|
# ‾‾‾‾‾‾‾
# episode: 285/2000, steps: 4, reward_total: -1, e: 1.0, time: 09:16:15
# _______
# |O|X|O|
# |X|X|O|
# |X|O|X|
# ‾‾‾‾‾‾‾
# episode: 286/2000, steps: 5, reward_total: 1, e: 1.0, time: 09:16:15
# _______
# |X|O|O|
# |O|X|X|
# |O|X|X|
# ‾‾‾‾‾‾‾
# episode: 287/2000, steps: 4, reward_total: -2, e: 1.0, time: 09:16:15
# _______
# |X|O|O|
# |O|X|X|
# |O|X|X|
# ‾‾‾‾‾‾‾
# episode: 288/2000, steps: 5, reward_total: 1, e: 1.0, time: 09:16:15
# _______
# |O|X|X|
# |X|X|O|
# |X|O|O|
# ‾‾‾‾‾‾‾
# episode: 289/2000, steps: 4, reward_total: 1, e: 1.0, time: 09:16:15
# _______
# |X|X|O|
# |O|O| |
# |O|X|X|
# ‾‾‾‾‾‾‾
# episode: 290/2000, steps: 3, reward_total: 1, e: 1.0, time: 09:16:15
# _______
# | | | |
# | |O|O|
# |X|X|X|
# ‾‾‾‾‾‾‾
# episode: 291/2000, steps: 4, reward_total: -2, e: 1.0, time: 09:16:15
# _______
# |O|X|X|
# |O|O|X|
# |X|O|X|
# ‾‾‾‾‾‾‾
# episode: 292/2000, steps: 4, reward_total: -2, e: 1.0, time: 09:16:15
# _______
# |O|O|O|
# |X|X|O|
# |X|X| |
# ‾‾‾‾‾‾‾
# episode: 293/2000, steps: 3, reward_total: -2, e: 1.0, time: 09:16:15
# _______
# |X| |X|
# | |X|O|
# |O|O|X|
# ‾‾‾‾‾‾‾
# episode: 294/2000, steps: 3, reward_total: -2, e: 1.0, time: 09:16:15
# _______
# | |X|X|
# | | |X|
# |O|O|O|
# ‾‾‾‾‾‾‾
# episode: 295/2000, steps: 3, reward_total: -2, e: 1.0, time: 09:16:15
# _______
# |X| |O|
# |X|O| |
# |X|X|O|
# ‾‾‾‾‾‾‾
# episode: 296/2000, steps: 4, reward_total: 1, e: 1.0, time: 09:16:15
# _______
# |X|O|O|
# |X| |X|
# |X| |O|
# ‾‾‾‾‾‾‾
# episode: 297/2000, steps: 4, reward_total: 1, e: 1.0, time: 09:16:15
# _______
# |X| |O|
# |X|O|X|
# |O|X|O|
# ‾‾‾‾‾‾‾
# episode: 298/2000, steps: 4, reward_total: -2, e: 1.0, time: 09:16:15
# _______
# |O|X|O|
# |X|O| |
# |O|X|X|
# ‾‾‾‾‾‾‾
# episode: 299/2000, steps: 4, reward_total: 1, e: 1.0, time: 09:16:15
# _______
# |X|X|O|
# |X|X|O|
# |O| |O|
# ‾‾‾‾‾‾‾
# episode: 300/2000, steps: 5, reward_total: -1, e: 1.0, time: 09:16:15
# _______
# |O|O|X|
# |X|X|O|
# |O|X|X|
# ‾‾‾‾‾‾‾
# episode: 301/2000, steps: 3, reward_total: 1, e: 1.0, time: 09:16:15
# _______
# |X| | |
# | |X|X|
# |O|O|O|
# ‾‾‾‾‾‾‾
# episode: 302/2000, steps: 5, reward_total: -1, e: 1.0, time: 09:16:15
# _______
# |X|X|O|
# |O|O|X|
# |X|O|X|
# ‾‾‾‾‾‾‾
# episode: 303/2000, steps: 3, reward_total: -2, e: 1.0, time: 09:16:15
# _______
# |O|X|X|
# | |O|X|
# |O| |X|
# ‾‾‾‾‾‾‾
# episode: 304/2000, steps: 3, reward_total: 1, e: 1.0, time: 09:16:15
# _______
# | |O| |
# |X|X|X|
# | |O| |
# ‾‾‾‾‾‾‾
# episode: 305/2000, steps: 4, reward_total: -2, e: 1.0, time: 09:16:15
# _______
# |O|O|X|
# |X|O|X|
# |O|X|X|
# ‾‾‾‾‾‾‾
# episode: 306/2000, steps: 4, reward_total: -2, e: 1.0, time: 09:16:15
# _______
# |X|X|O|
# | |O|O|
# |X|X|O|
# ‾‾‾‾‾‾‾
# episode: 307/2000, steps: 4, reward_total: -1, e: 1.0, time: 09:16:15
# _______
# |X|O|X|
# |O|X|X|
# |O|X|O|
# ‾‾‾‾‾‾‾
# episode: 308/2000, steps: 5, reward_total: -1, e: 1.0, time: 09:16:15
# _______
# |X|O|X|
# |O|X|X|
# |O|X|O|
# ‾‾‾‾‾‾‾
# episode: 309/2000, steps: 4, reward_total: -1, e: 1.0, time: 09:16:15
# _______
# |O|X|O|
# |O|X|X|
# |X|O|X|
# ‾‾‾‾‾‾‾
# episode: 310/2000, steps: 4, reward_total: 1, e: 1.0, time: 09:16:15
# _______
# |X|O| |
# |X|O|X|
# |X| |O|
# ‾‾‾‾‾‾‾
# episode: 311/2000, steps: 3, reward_total: -2, e: 1.0, time: 09:16:15
# _______
# | |O|X|
# |O|X| |
# |X|O|X|
# ‾‾‾‾‾‾‾
# episode: 312/2000, steps: 4, reward_total: 1, e: 1.0, time: 09:16:15
# _______
# |O|O|X|
# |X| |X|
# |O| |X|
# ‾‾‾‾‾‾‾
# episode: 313/2000, steps: 3, reward_total: 1, e: 1.0, time: 09:16:15
# _______
# | | |O|
# |X|O|X|
# |O|X| |
# ‾‾‾‾‾‾‾
# episode: 314/2000, steps: 4, reward_total: -2, e: 1.0, time: 09:16:15
# _______
# |X|X|O|
# |X|O|O|
# |O| |X|
# ‾‾‾‾‾‾‾
# episode: 315/2000, steps: 3, reward_total: 1, e: 1.0, time: 09:16:15
# _______
# | |O| |
# |X|O|X|
# |X|O| |
# ‾‾‾‾‾‾‾
# episode: 316/2000, steps: 4, reward_total: 1, e: 1.0, time: 09:16:15
# _______
# |X|O|O|
# | |X| |
# |X|O|X|
# ‾‾‾‾‾‾‾
# episode: 317/2000, steps: 4, reward_total: 1, e: 1.0, time: 09:16:15
# _______
# | |O|O|
# |X|X|O|
# |X|X|O|
# ‾‾‾‾‾‾‾
# episode: 318/2000, steps: 5, reward_total: 1, e: 1.0, time: 09:16:15
# _______
# |O|O|X|
# |X|X|X|
# |X|O|O|
# ‾‾‾‾‾‾‾
# episode: 319/2000, steps: 3, reward_total: -2, e: 1.0, time: 09:16:15
# _______
# |O|X| |
# |O|X|X|
# | |X|O|
# ‾‾‾‾‾‾‾
# episode: 320/2000, steps: 5, reward_total: 1, e: 1.0, time: 09:16:15
# _______
# |O|X|O|
# |X|X|X|
# |X|O|O|
# ‾‾‾‾‾‾‾
# episode: 321/2000, steps: 4, reward_total: -1, e: 1.0, time: 09:16:15
# _______
# |X|X|O|
# |O|X|X|
# |X|O|O|
# ‾‾‾‾‾‾‾
# episode: 322/2000, steps: 4, reward_total: 1, e: 1.0, time: 09:16:15
# _______
# |O|X|O|
# | |X|O|
# | |X|X|
# ‾‾‾‾‾‾‾
# episode: 323/2000, steps: 3, reward_total: -2, e: 1.0, time: 09:16:15
# _______
# |O|O|X|
# | |X| |
# |X|O|X|
# ‾‾‾‾‾‾‾
# episode: 324/2000, steps: 3, reward_total: -2, e: 1.0, time: 09:16:15
# _______
# | |O| |
# |X|O| |
# |X|O|X|
# ‾‾‾‾‾‾‾
# episode: 325/2000, steps: 4, reward_total: -1, e: 1.0, time: 09:16:15
# _______
# |O|X|O|
# |O|X|X|
# |X|O|X|
# ‾‾‾‾‾‾‾
# episode: 326/2000, steps: 5, reward_total: 1, e: 1.0, time: 09:16:15
# _______
# |X|O|O|
# |O|X|X|
# |X|O|X|
# ‾‾‾‾‾‾‾
# episode: 327/2000, steps: 4, reward_total: -2, e: 1.0, time: 09:16:15
# _______
# |X|O|X|
# |O|X|X|
# |X|O|O|
# ‾‾‾‾‾‾‾
# episode: 328/2000, steps: 4, reward_total: 1, e: 1.0, time: 09:16:15
# _______
# |X| |X|
# |O|O|X|
# | |O|X|
# ‾‾‾‾‾‾‾
# episode: 329/2000, steps: 3, reward_total: -2, e: 1.0, time: 09:16:15
# _______
# |O| |X|
# | |X|O|
# |X|X|O|
# ‾‾‾‾‾‾‾
# episode: 330/2000, steps: 4, reward_total: -2, e: 1.0, time: 09:16:15
# _______
# |X|O|X|
# |O|O|O|
# |X|X| |
# ‾‾‾‾‾‾‾
# episode: 331/2000, steps: 3, reward_total: 1, e: 1.0, time: 09:16:15
# _______
# |X| |X|
# |O|O|O|
# | | |X|
# ‾‾‾‾‾‾‾
# episode: 332/2000, steps: 4, reward_total: 1, e: 1.0, time: 09:16:15
# _______
# | |X|O|
# | |X|X|
# |O|X|O|
# ‾‾‾‾‾‾‾
# episode: 333/2000, steps: 4, reward_total: 1, e: 1.0, time: 09:16:15
# _______
# |X|X|O|
# |O|O|X|
# |O|X| |
# ‾‾‾‾‾‾‾
# episode: 334/2000, steps: 4, reward_total: -2, e: 1.0, time: 09:16:15
# _______
# |O|X|X|
# | |X|X|
# |O|O|O|
# ‾‾‾‾‾‾‾
# episode: 335/2000, steps: 4, reward_total: 1, e: 1.0, time: 09:16:15
# _______
# |O|X|X|
# |O|X|X|
# |O|O| |
# ‾‾‾‾‾‾‾
# episode: 336/2000, steps: 5, reward_total: 1, e: 1.0, time: 09:16:15
# _______
# |X|X|O|
# |X|X|O|
# |O|O|X|
# ‾‾‾‾‾‾‾
# episode: 337/2000, steps: 3, reward_total: -2, e: 1.0, time: 09:16:15
# _______
# |O|O|X|
# |X| |X|
# |O| |X|
# ‾‾‾‾‾‾‾
# episode: 338/2000, steps: 5, reward_total: 1, e: 1.0, time: 09:16:15
# _______
# |X|X|O|
# |X|O|X|
# |X|O|O|
# ‾‾‾‾‾‾‾
# episode: 339/2000, steps: 4, reward_total: 1, e: 1.0, time: 09:16:15
# _______
# |X|X|O|
# |O|O|X|
# |O|X| |
# ‾‾‾‾‾‾‾
# episode: 340/2000, steps: 5, reward_total: 1, e: 1.0, time: 09:16:15
# _______
# |O|X|X|
# |X|X|O|
# |O|X|O|
# ‾‾‾‾‾‾‾
# episode: 341/2000, steps: 4, reward_total: -2, e: 1.0, time: 09:16:15
# _______
# |O|X|O|
# |X|O|O|
# |X|X|X|
# ‾‾‾‾‾‾‾
# episode: 342/2000, steps: 4, reward_total: 1, e: 1.0, time: 09:16:15
# _______
# |O| | |
# |X|X|X|
# |O|X|O|
# ‾‾‾‾‾‾‾
# episode: 343/2000, steps: 3, reward_total: -2, e: 1.0, time: 09:16:15
# _______
# | | |O|
# |X|O|O|
# |X|X|X|
# ‾‾‾‾‾‾‾
# episode: 344/2000, steps: 3, reward_total: 1, e: 1.0, time: 09:16:15
# _______
# | |O|O|
# |X|X|X|
# | | | |
# ‾‾‾‾‾‾‾
# episode: 345/2000, steps: 4, reward_total: -2, e: 1.0, time: 09:16:15
# _______
# |X|X|X|
# |X|O|O|
# |O|X|O|
# ‾‾‾‾‾‾‾
# episode: 346/2000, steps: 4, reward_total: -2, e: 1.0, time: 09:16:15
# _______
# |O|O|O|
# | |X|X|
# |X|O|X|
# ‾‾‾‾‾‾‾
# episode: 347/2000, steps: 4, reward_total: -2, e: 1.0, time: 09:16:15
# _______
# |O|X|O|
# |X|X|O|
# |O|X|X|
# ‾‾‾‾‾‾‾
# episode: 348/2000, steps: 5, reward_total: -1, e: 1.0, time: 09:16:15
# _______
# |X|X|O|
# |O|X|X|
# |X|O|O|
# ‾‾‾‾‾‾‾
# episode: 349/2000, steps: 3, reward_total: -2, e: 1.0, time: 09:16:15
# _______
# | |X| |
# |X|X|O|
# |O|X|O|
# ‾‾‾‾‾‾‾
# episode: 350/2000, steps: 4, reward_total: 1, e: 1.0, time: 09:16:15
# _______
# |X|O| |
# |O|X|X|
# | |O|X|
# ‾‾‾‾‾‾‾
# episode: 351/2000, steps: 3, reward_total: 1, e: 1.0, time: 09:16:15
# _______
# |O| |X|
# |O| | |
# |O|X|X|
# ‾‾‾‾‾‾‾
# episode: 352/2000, steps: 5, reward_total: -1, e: 1.0, time: 09:16:15
# _______
# |O|X|O|
# |X|O|X|
# |X|O|X|
# ‾‾‾‾‾‾‾
# episode: 353/2000, steps: 3, reward_total: 1, e: 1.0, time: 09:16:15
# _______
# | |X| |
# |X|X| |
# |O|O|O|
# ‾‾‾‾‾‾‾
# episode: 354/2000, steps: 5, reward_total: 1, e: 1.0, time: 09:16:15
# _______
# |X|X|O|
# |O|X|X|
# |O|O|X|
# ‾‾‾‾‾‾‾
# episode: 355/2000, steps: 2, reward_total: -2, e: 1.0, time: 09:16:15
# _______
# | |O|X|
# |O| |X|
# | | |X|
# ‾‾‾‾‾‾‾
# episode: 356/2000, steps: 4, reward_total: 1, e: 1.0, time: 09:16:15
# _______
# |O|X| |
# |X|X|X|
# | |O|O|
# ‾‾‾‾‾‾‾
# episode: 357/2000, steps: 4, reward_total: 1, e: 1.0, time: 09:16:15
# _______
# |O|X|X|
# | |X|X|
# |O|O|O|
# ‾‾‾‾‾‾‾
# episode: 358/2000, steps: 5, reward_total: 1, e: 1.0, time: 09:16:15
# _______
# |X|O|X|
# |O|X|X|
# |X|O|O|
# ‾‾‾‾‾‾‾
# episode: 359/2000, steps: 2, reward_total: -2, e: 1.0, time: 09:16:15
# _______
# | | |X|
# |O|X|O|
# |X| | |
# ‾‾‾‾‾‾‾
# episode: 360/2000, steps: 4, reward_total: 1, e: 1.0, time: 09:16:15
# _______
# |X|O|O|
# |X|O| |
# |X| |X|
# ‾‾‾‾‾‾‾
# episode: 361/2000, steps: 4, reward_total: -2, e: 1.0, time: 09:16:15
# _______
# |O|O|X|
# |X|O|O|
# |X|X|X|
# ‾‾‾‾‾‾‾
# episode: 362/2000, steps: 3, reward_total: 1, e: 1.0, time: 09:16:15
# _______
# | | |O|
# |X|X|X|
# | |O| |
# ‾‾‾‾‾‾‾
# episode: 363/2000, steps: 3, reward_total: -2, e: 1.0, time: 09:16:15
# _______
# |O|X| |
# |O| |O|
# |X|X|X|
# ‾‾‾‾‾‾‾
# episode: 364/2000, steps: 4, reward_total: 1, e: 1.0, time: 09:16:15
# _______
# |X|O|O|
# |X|X| |
# | |O|X|
# ‾‾‾‾‾‾‾
# episode: 365/2000, steps: 3, reward_total: -2, e: 1.0, time: 09:16:15
# _______
# |O|O|X|
# |X|X| |
# |X| |O|
# ‾‾‾‾‾‾‾
# episode: 366/2000, steps: 4, reward_total: 1, e: 1.0, time: 09:16:15
# _______
# |X|X|X|
# |O| | |
# |X|O|O|
# ‾‾‾‾‾‾‾
# episode: 367/2000, steps: 4, reward_total: 1, e: 1.0, time: 09:16:15
# _______
# |O|X|O|
# |X|O|X|
# | |X|O|
# ‾‾‾‾‾‾‾
# episode: 368/2000, steps: 4, reward_total: 1, e: 1.0, time: 09:16:15
# _______
# |O|O|X|
# | | |X|
# |O|X|X|
# ‾‾‾‾‾‾‾
# episode: 369/2000, steps: 3, reward_total: -2, e: 1.0, time: 09:16:15
# _______
# |X|O| |
# |X|X| |
# |X|O|O|
# ‾‾‾‾‾‾‾
# episode: 370/2000, steps: 4, reward_total: -2, e: 1.0, time: 09:16:15
# _______
# | |O|O|
# |X|O|X|
# |X|O|X|
# ‾‾‾‾‾‾‾
# episode: 371/2000, steps: 4, reward_total: 1, e: 1.0, time: 09:16:15
# _______
# |O|X|X|
# |O|X| |
# |O|O|X|
# ‾‾‾‾‾‾‾
# episode: 372/2000, steps: 3, reward_total: 1, e: 1.0, time: 09:16:15
# _______
# | |O|X|
# |O|X| |
# |X| | |
# ‾‾‾‾‾‾‾
# episode: 373/2000, steps: 4, reward_total: -1, e: 1.0, time: 09:16:15
# _______
# |X|X|O|
# |O|O|X|
# |X|O|X|
# ‾‾‾‾‾‾‾
# episode: 374/2000, steps: 5, reward_total: 1, e: 1.0, time: 09:16:15
# _______
# |X|X|X|
# |X|O|O|
# |O|O|X|
# ‾‾‾‾‾‾‾
# episode: 375/2000, steps: 4, reward_total: -1, e: 1.0, time: 09:16:15
# _______
# |X|O|O|
# |O|X|X|
# |X|X|O|
# ‾‾‾‾‾‾‾
# episode: 376/2000, steps: 4, reward_total: -2, e: 1.0, time: 09:16:15
# _______
# |O|O|X|
# |X|O| |
# |X|O|X|
# ‾‾‾‾‾‾‾
# episode: 377/2000, steps: 4, reward_total: -1, e: 1.0, time: 09:16:15
# _______
# |X|O|X|
# |O|O|X|
# |X|X|O|
# ‾‾‾‾‾‾‾
# episode: 378/2000, steps: 4, reward_total: -2, e: 1.0, time: 09:16:15
# _______
# |X| |X|
# |X|O|X|
# |O|O|O|
# ‾‾‾‾‾‾‾
# episode: 379/2000, steps: 3, reward_total: -2, e: 1.0, time: 09:16:15
# _______
# | |O|O|
# |X| |O|
# |X|X|X|
# ‾‾‾‾‾‾‾
# episode: 380/2000, steps: 4, reward_total: -2, e: 1.0, time: 09:16:15
# _______
# |O|O|O|
# |X|X|O|
# |X|X| |
# ‾‾‾‾‾‾‾
# episode: 381/2000, steps: 4, reward_total: 1, e: 1.0, time: 09:16:15
# _______
# |X|O|X|
# |O|O|O|
# |X|X| |
# ‾‾‾‾‾‾‾
# episode: 382/2000, steps: 5, reward_total: 1, e: 1.0, time: 09:16:15
# _______
# |O|X|X|
# |X|X|O|
# |X|O|O|
# ‾‾‾‾‾‾‾
# episode: 383/2000, steps: 4, reward_total: -2, e: 1.0, time: 09:16:15
# _______
# |X|O|O|
# |O|X|X|
# |X|O|X|
# ‾‾‾‾‾‾‾
# episode: 384/2000, steps: 3, reward_total: -2, e: 1.0, time: 09:16:15
# _______
# |X|X| |
# | | |X|
# |O|O|O|
# ‾‾‾‾‾‾‾
# episode: 385/2000, steps: 4, reward_total: -2, e: 1.0, time: 09:16:15
# _______
# |O|O|X|
# |X|O|O|
# |X|X|X|
# ‾‾‾‾‾‾‾
# episode: 386/2000, steps: 4, reward_total: 1, e: 1.0, time: 09:16:15
# _______
# |X|X|X|
# |O|O| |
# |X| |O|
# ‾‾‾‾‾‾‾
# episode: 387/2000, steps: 3, reward_total: 1, e: 1.0, time: 09:16:15
# _______
# |X|X| |
# |O|O|O|
# | |X| |
# ‾‾‾‾‾‾‾
# episode: 388/2000, steps: 5, reward_total: 1, e: 1.0, time: 09:16:15
# _______
# |X|O|O|
# |X|O|X|
# |X|X|O|
# ‾‾‾‾‾‾‾
# episode: 389/2000, steps: 3, reward_total: -2, e: 1.0, time: 09:16:15
# _______
# |X| |X|
# |O|X|O|
# | |O|X|
# ‾‾‾‾‾‾‾
# episode: 390/2000, steps: 3, reward_total: -2, e: 1.0, time: 09:16:15
# _______
# | |O|X|
# | |O|X|
# |X|O| |
# ‾‾‾‾‾‾‾
# episode: 391/2000, steps: 3, reward_total: -2, e: 1.0, time: 09:16:15
# _______
# |X|X|X|
# |O|O| |
# |X|O| |
# ‾‾‾‾‾‾‾
# episode: 392/2000, steps: 4, reward_total: -2, e: 1.0, time: 09:16:15
# _______
# |O|X|X|
# |O|O|O|
# |X| |X|
# ‾‾‾‾‾‾‾
# episode: 393/2000, steps: 3, reward_total: -2, e: 1.0, time: 09:16:16
# _______
# |X|O|X|
# |X| |O|
# |X|O| |
# ‾‾‾‾‾‾‾
# episode: 394/2000, steps: 4, reward_total: -2, e: 1.0, time: 09:16:16
# _______
# | |X|X|
# |X|O|X|
# |O|O|O|
# ‾‾‾‾‾‾‾
# episode: 395/2000, steps: 2, reward_total: -2, e: 1.0, time: 09:16:16
# _______
# | |X| |
# |O|X|O|
# | |X| |
# ‾‾‾‾‾‾‾
# episode: 396/2000, steps: 4, reward_total: -2, e: 1.0, time: 09:16:16
# _______
# |X|X|O|
# |O|O|O|
# |X|X| |
# ‾‾‾‾‾‾‾
# episode: 397/2000, steps: 4, reward_total: -2, e: 1.0, time: 09:16:16
# _______
# |X|O|X|
# |X|X|O|
# |X|O|O|
# ‾‾‾‾‾‾‾
# episode: 398/2000, steps: 4, reward_total: 1, e: 1.0, time: 09:16:17
# _______
# |X|O| |
# |X|X|X|
# | |O|O|
# ‾‾‾‾‾‾‾
# episode: 399/2000, steps: 3, reward_total: -2, e: 1.0, time: 09:16:18
# _______
# | |O|X|
# |O|X|O|
# |X| |X|
# ‾‾‾‾‾‾‾
# episode: 400/2000, steps: 5, reward_total: 1, e: 0.99, time: 09:16:19
# _______
# |O|X|X|
# |X|X|O|
# |X|O|O|
# ‾‾‾‾‾‾‾
# episode: 401/2000, steps: 4, reward_total: 1, e: 0.99, time: 09:16:20
# _______
# |O|X|X|
# |X|O| |
# |O|X|O|
# ‾‾‾‾‾‾‾
# episode: 402/2000, steps: 5, reward_total: 1, e: 0.98, time: 09:16:22
# _______
# |X|X|O|
# |O|X|X|
# |O|X|O|
# ‾‾‾‾‾‾‾
# episode: 403/2000, steps: 4, reward_total: 1, e: 0.98, time: 09:16:23
# _______
# |X|X|O|
# | |O|X|
# |O|X|O|
# ‾‾‾‾‾‾‾
# episode: 404/2000, steps: 3, reward_total: -2, e: 0.97, time: 09:16:24
# _______
# |O|O|O|
# |X| |X|
# | |X| |
# ‾‾‾‾‾‾‾
# episode: 405/2000, steps: 3, reward_total: -2, e: 0.97, time: 09:16:25
# _______
# |X|X|X|
# | |O|O|
# |O| |X|
# ‾‾‾‾‾‾‾
# episode: 406/2000, steps: 5, reward_total: 1, e: 0.97, time: 09:16:26
# _______
# |O|X|X|
# |X|X|O|
# |X|O|O|
# ‾‾‾‾‾‾‾
# episode: 407/2000, steps: 3, reward_total: 1, e: 0.96, time: 09:16:27
# _______
# |O|O|O|
# | |X| |
# | |X|X|
# ‾‾‾‾‾‾‾
# episode: 408/2000, steps: 5, reward_total: -1, e: 0.96, time: 09:16:28
# _______
# |X|O|O|
# |O|X|X|
# |X|X|O|
# ‾‾‾‾‾‾‾
# episode: 409/2000, steps: 3, reward_total: -2, e: 0.96, time: 09:16:29
# _______
# | |O|O|
# |X|X|X|
# |O| |X|
# ‾‾‾‾‾‾‾
# episode: 410/2000, steps: 3, reward_total: -2, e: 0.95, time: 09:16:30
# _______
# | |X|O|
# |X| |O|
# | |X|O|
# ‾‾‾‾‾‾‾
# episode: 411/2000, steps: 4, reward_total: -2, e: 0.95, time: 09:16:31
# _______
# |O|X|X|
# |X|X|O|
# |O|X|O|
# ‾‾‾‾‾‾‾
# episode: 412/2000, steps: 4, reward_total: -2, e: 0.95, time: 09:16:32
# _______
# |X|X|O|
# |O|O|O|
# |X|X| |
# ‾‾‾‾‾‾‾
# episode: 413/2000, steps: 4, reward_total: 1, e: 0.94, time: 09:16:34
# _______
# | |O|X|
# |X|O|X|
# |X|O|O|
# ‾‾‾‾‾‾‾
# episode: 414/2000, steps: 4, reward_total: -2, e: 0.94, time: 09:16:35
# _______
# |O|X|O|
# |X|O| |
# |X|X|O|
# ‾‾‾‾‾‾‾
# episode: 415/2000, steps: 4, reward_total: 1, e: 0.93, time: 09:16:36
# _______
# |O|X|O|
# |X|O|X|
# |O| |X|
# ‾‾‾‾‾‾‾
# episode: 416/2000, steps: 3, reward_total: -2, e: 0.93, time: 09:16:37
# _______
# |O| | |
# |O|X| |
# |O|X|X|
# ‾‾‾‾‾‾‾
# episode: 417/2000, steps: 4, reward_total: -2, e: 0.93, time: 09:16:38
# _______
# |X|X|X|
# |O|X|O|
# |O|O|X|
# ‾‾‾‾‾‾‾
# episode: 418/2000, steps: 4, reward_total: 1, e: 0.92, time: 09:16:39
# _______
# |O|O| |
# |X|X|X|
# |O| |X|
# ‾‾‾‾‾‾‾
# episode: 419/2000, steps: 3, reward_total: -2, e: 0.92, time: 09:16:40
# _______
# |X|O|X|
# |O|X|O|
# |X| | |
# ‾‾‾‾‾‾‾
# episode: 420/2000, steps: 4, reward_total: 1, e: 0.92, time: 09:16:41
# _______
# |X|O|O|
# |X| |X|
# |X| |O|
# ‾‾‾‾‾‾‾
# episode: 421/2000, steps: 4, reward_total: 1, e: 0.91, time: 09:16:42
# _______
# |O|X|X|
# | |O|X|
# |O|X|O|
# ‾‾‾‾‾‾‾
# episode: 422/2000, steps: 4, reward_total: -2, e: 0.91, time: 09:16:43
# _______
# |X| |X|
# |O|O|O|
# |X|X|O|
# ‾‾‾‾‾‾‾
# episode: 423/2000, steps: 4, reward_total: 1, e: 0.91, time: 09:16:44
# _______
# |X| |O|
# |O|O|X|
# |O|X|X|
# ‾‾‾‾‾‾‾
# episode: 424/2000, steps: 5, reward_total: -1, e: 0.9, time: 09:16:46
# _______
# |X|O|X|
# |O|X|X|
# |O|X|O|
# ‾‾‾‾‾‾‾
# episode: 425/2000, steps: 4, reward_total: -2, e: 0.9, time: 09:16:47
# _______
# |X|O|O|
# |X|X|O|
# |O|X|X|
# ‾‾‾‾‾‾‾
# episode: 426/2000, steps: 3, reward_total: 1, e: 0.9, time: 09:16:48
# _______
# | | |X|
# | |X|O|
# |X| |O|
# ‾‾‾‾‾‾‾
# episode: 427/2000, steps: 4, reward_total: 1, e: 0.89, time: 09:16:49
# _______
# |O|X|X|
# |O|O|X|
# |X| |O|
# ‾‾‾‾‾‾‾
# episode: 428/2000, steps: 4, reward_total: -2, e: 0.89, time: 09:16:50
# _______
# |O| |X|
# |O|X|O|
# |O|X|X|
# ‾‾‾‾‾‾‾
# episode: 429/2000, steps: 3, reward_total: -2, e: 0.89, time: 09:16:51
# _______
# | | |X|
# |O|X|X|
# |O|O|X|
# ‾‾‾‾‾‾‾
# episode: 430/2000, steps: 4, reward_total: -2, e: 0.88, time: 09:16:52
# _______
# |X|X|O|
# |O|O| |
# |O|X|X|
# ‾‾‾‾‾‾‾
# episode: 431/2000, steps: 4, reward_total: 1, e: 0.88, time: 09:16:53
# _______
# |O|X|X|
# |O| |X|
# |O|X|O|
# ‾‾‾‾‾‾‾
# episode: 432/2000, steps: 4, reward_total: -2, e: 0.88, time: 09:16:55
# _______
# |X| |O|
# |O|O|X|
# |O|X|X|
# ‾‾‾‾‾‾‾
# episode: 433/2000, steps: 4, reward_total: -2, e: 0.87, time: 09:16:56
# _______
# |X|X|O|
# |X|O|X|
# |X|O|O|
# ‾‾‾‾‾‾‾
# episode: 434/2000, steps: 4, reward_total: 1, e: 0.87, time: 09:16:57
# _______
# | |X|O|
# |O|X|O|
# |X|X| |
# ‾‾‾‾‾‾‾
# episode: 435/2000, steps: 4, reward_total: -2, e: 0.86, time: 09:16:58
# _______
# |X|X|O|
# |X|O|X|
# |X|O|O|
# ‾‾‾‾‾‾‾
# episode: 436/2000, steps: 5, reward_total: 1, e: 0.86, time: 09:16:59
# _______
# |O|O|X|
# |X|X|O|
# |X|X|O|
# ‾‾‾‾‾‾‾
# episode: 437/2000, steps: 3, reward_total: -2, e: 0.86, time: 09:17:00
# _______
# |X|X|X|
# | | |O|
# |O|O|X|
# ‾‾‾‾‾‾‾
# episode: 438/2000, steps: 3, reward_total: -2, e: 0.86, time: 09:17:01
# ...
# _______
# | | |X|
# | |X| |
# |X|O|O|
# ‾‾‾‾‾‾‾
# episode: 1861/2000, steps: 3, reward_total: 1, e: 0.0058, time: 09:40:27
# _______
# | |X|O|
# |X|O| |
# |O| |X|
# ‾‾‾‾‾‾‾
# episode: 1862/2000, steps: 5, reward_total: 1, e: 0.0058, time: 09:40:28
# _______
# |X|X|X|
# |O|X|O|
# |O|X|O|
# ‾‾‾‾‾‾‾
# episode: 1863/2000, steps: 3, reward_total: 1, e: 0.0057, time: 09:40:29
# _______
# |X|X|O|
# | |O| |
# |O| |X|
# ‾‾‾‾‾‾‾
# episode: 1864/2000, steps: 4, reward_total: -2, e: 0.0057, time: 09:40:30
# _______
# |X| |O|
# |O|X|O|
# |X|X|O|
# ‾‾‾‾‾‾‾
# episode: 1865/2000, steps: 3, reward_total: 1, e: 0.0057, time: 09:40:31
# _______
# |X| |O|
# |X|O| |
# |O|X| |
# ‾‾‾‾‾‾‾
# episode: 1866/2000, steps: 3, reward_total: 1, e: 0.0057, time: 09:40:32
# _______
# | |O|X|
# | |X| |
# |X| |O|
# ‾‾‾‾‾‾‾
# episode: 1867/2000, steps: 2, reward_total: -2, e: 0.0057, time: 09:40:33
# _______
# | | |X|
# | |O|X|
# |O| |X|
# ‾‾‾‾‾‾‾
# episode: 1868/2000, steps: 3, reward_total: 1, e: 0.0057, time: 09:40:33
# _______
# |O|O|X|
# | |X| |
# |X| | |
# ‾‾‾‾‾‾‾
# episode: 1869/2000, steps: 4, reward_total: 1, e: 0.0056, time: 09:40:35
# _______
# |O|O|O|
# |X|X| |
# |O|X|X|
# ‾‾‾‾‾‾‾
# episode: 1870/2000, steps: 3, reward_total: -2, e: 0.0056, time: 09:40:35
# _______
# |X| |O|
# | |X|O|
# |X| |O|
# ‾‾‾‾‾‾‾
# episode: 1871/2000, steps: 3, reward_total: 1, e: 0.0056, time: 09:40:36
# _______
# |X| |O|
# |X|O| |
# |O| |X|
# ‾‾‾‾‾‾‾
# episode: 1872/2000, steps: 3, reward_total: 1, e: 0.0056, time: 09:40:37
# _______
# |O| |X|
# | |X| |
# |X| |O|
# ‾‾‾‾‾‾‾
# episode: 1873/2000, steps: 2, reward_total: -2, e: 0.0056, time: 09:40:38
# _______
# | | |O|
# | |O| |
# |X|X|X|
# ‾‾‾‾‾‾‾
# episode: 1874/2000, steps: 3, reward_total: 1, e: 0.0056, time: 09:40:39
# _______
# | | |X|
# | |X|O|
# |X| |O|
# ‾‾‾‾‾‾‾
# episode: 1875/2000, steps: 3, reward_total: -2, e: 0.0055, time: 09:40:39
# _______
# |O|X|O|
# |O|X| |
# |X|X| |
# ‾‾‾‾‾‾‾
# episode: 1876/2000, steps: 4, reward_total: 1, e: 0.0055, time: 09:40:41
# _______
# |X|O|X|
# | |X|O|
# |O| |X|
# ‾‾‾‾‾‾‾
# episode: 1877/2000, steps: 4, reward_total: 1, e: 0.0055, time: 09:40:42
# _______
# |O|X|X|
# |O|X| |
# |O|O|X|
# ‾‾‾‾‾‾‾
# episode: 1878/2000, steps: 4, reward_total: -2, e: 0.0055, time: 09:40:43
# _______
# |X| |X|
# |O|O|O|
# |X|O|X|
# ‾‾‾‾‾‾‾
# episode: 1879/2000, steps: 2, reward_total: -2, e: 0.0055, time: 09:40:43
# _______
# | |X|O|
# | |X| |
# |O|X| |
# ‾‾‾‾‾‾‾
# episode: 1880/2000, steps: 5, reward_total: -1, e: 0.0054, time: 09:40:45
# _______
# |X|O|X|
# |O|X|X|
# |O|X|O|
# ‾‾‾‾‾‾‾
# episode: 1881/2000, steps: 2, reward_total: -2, e: 0.0054, time: 09:40:45
# _______
# | | |O|
# | |O| |
# |X|X|X|
# ‾‾‾‾‾‾‾
# episode: 1882/2000, steps: 5, reward_total: -1, e: 0.0054, time: 09:40:47
# _______
# |X|O|X|
# |O|O|X|
# |X|X|O|
# ‾‾‾‾‾‾‾
# episode: 1883/2000, steps: 3, reward_total: 1, e: 0.0054, time: 09:40:48
# _______
# |X|X|O|
# | |O| |
# |O| |X|
# ‾‾‾‾‾‾‾
# episode: 1884/2000, steps: 3, reward_total: 1, e: 0.0054, time: 09:40:48
# _______
# |O|O|X|
# | |X| |
# |X| | |
# ‾‾‾‾‾‾‾
# episode: 1885/2000, steps: 3, reward_total: -2, e: 0.0054, time: 09:40:49
# _______
# |X| |O|
# |X|X|X|
# |O|O| |
# ‾‾‾‾‾‾‾
# episode: 1886/2000, steps: 5, reward_total: -1, e: 0.0053, time: 09:40:51
# _______
# |X|O|O|
# |O|X|X|
# |X|X|O|
# ‾‾‾‾‾‾‾
# episode: 1887/2000, steps: 3, reward_total: 1, e: 0.0053, time: 09:40:52
# _______
# |X| |O|
# |X|O| |
# |O| |X|
# ‾‾‾‾‾‾‾
# episode: 1888/2000, steps: 4, reward_total: 1, e: 0.0053, time: 09:40:53
# _______
# |X|O|O|
# | |X| |
# |X|O|X|
# ‾‾‾‾‾‾‾
# episode: 1889/2000, steps: 3, reward_total: 1, e: 0.0053, time: 09:40:54
# _______
# | | |O|
# |X|O| |
# |O|X|X|
# ‾‾‾‾‾‾‾
# episode: 1890/2000, steps: 3, reward_total: 1, e: 0.0053, time: 09:40:54
# _______
# |O| |X|
# | |X| |
# |X| |O|
# ‾‾‾‾‾‾‾
# episode: 1891/2000, steps: 3, reward_total: 1, e: 0.0052, time: 09:40:55
# _______
# | |X|O|
# | |O|X|
# |O| |X|
# ‾‾‾‾‾‾‾
# episode: 1892/2000, steps: 3, reward_total: 1, e: 0.0052, time: 09:40:56
# _______
# | | |X|
# | |X| |
# |X|O|O|
# ‾‾‾‾‾‾‾
# episode: 1893/2000, steps: 2, reward_total: -2, e: 0.0052, time: 09:40:57
# _______
# | | |O|
# | |O| |
# |X|X|X|
# ‾‾‾‾‾‾‾
# episode: 1894/2000, steps: 3, reward_total: 1, e: 0.0052, time: 09:40:58
# _______
# |O| |X|
# | |X|O|
# |X| | |
# ‾‾‾‾‾‾‾
# episode: 1895/2000, steps: 2, reward_total: -2, e: 0.0052, time: 09:40:58
# _______
# |X|X|X|
# | |O| |
# |O| | |
# ‾‾‾‾‾‾‾
# episode: 1896/2000, steps: 3, reward_total: 1, e: 0.0052, time: 09:40:59
# _______
# | | |X|
# | |X| |
# |X|O|O|
# ‾‾‾‾‾‾‾
# episode: 1897/2000, steps: 4, reward_total: -1, e: 0.0052, time: 09:41:00
# _______
# |X|X|O|
# |O|O|X|
# |X|X|O|
# ‾‾‾‾‾‾‾
# episode: 1898/2000, steps: 3, reward_total: 1, e: 0.0051, time: 09:41:01
# _______
# | |O|X|
# | |X|O|
# |X| | |
# ‾‾‾‾‾‾‾
# episode: 1899/2000, steps: 3, reward_total: -2, e: 0.0051, time: 09:41:02
# _______
# |X| |O|
# |O|O| |
# |X|X|X|
# ‾‾‾‾‾‾‾
# episode: 1900/2000, steps: 4, reward_total: 1, e: 0.0051, time: 09:41:03
# _______
# |X| |O|
# | |X|O|
# |X|O|X|
# ‾‾‾‾‾‾‾
# episode: 1901/2000, steps: 4, reward_total: 1, e: 0.0051, time: 09:41:04
# _______
# |O|X|X|
# |X|O| |
# |O|X|O|
# ‾‾‾‾‾‾‾
# episode: 1902/2000, steps: 3, reward_total: 1, e: 0.0051, time: 09:41:05
# _______
# | | |X|
# |O|X| |
# |X|O| |
# ‾‾‾‾‾‾‾
# episode: 1903/2000, steps: 3, reward_total: -2, e: 0.0051, time: 09:41:06
# _______
# |X| |O|
# |O|O| |
# |X|X|X|
# ‾‾‾‾‾‾‾
# episode: 1904/2000, steps: 3, reward_total: 1, e: 0.005, time: 09:41:07
# _______
# | | |X|
# | |X| |
# |X|O|O|
# ‾‾‾‾‾‾‾
# episode: 1905/2000, steps: 3, reward_total: 1, e: 0.005, time: 09:41:07
# _______
# |X|X|O|
# | |O|X|
# |O| | |
# ‾‾‾‾‾‾‾
# episode: 1906/2000, steps: 3, reward_total: 1, e: 0.005, time: 09:41:08
# _______
# |O| |X|
# | |X| |
# |X| |O|
# ‾‾‾‾‾‾‾
# episode: 1907/2000, steps: 4, reward_total: 1, e: 0.005, time: 09:41:09
# _______
# |X| |X|
# |X|O|X|
# |O|O|O|
# ‾‾‾‾‾‾‾
# episode: 1908/2000, steps: 4, reward_total: 1, e: 0.005, time: 09:41:11
# _______
# |X|O|X|
# | |X| |
# |O|O|X|
# ‾‾‾‾‾‾‾
# episode: 1909/2000, steps: 4, reward_total: -1, e: 0.0049, time: 09:41:12
# _______
# |X|X|O|
# |O|O|X|
# |X|X|O|
# ‾‾‾‾‾‾‾
# episode: 1910/2000, steps: 3, reward_total: 1, e: 0.0049, time: 09:41:13
# _______
# | | |X|
# |O|X| |
# |X|O| |
# ‾‾‾‾‾‾‾
# episode: 1911/2000, steps: 4, reward_total: 1, e: 0.0049, time: 09:41:14
# _______
# |O| |O|
# |O|X|X|
# |O|X|X|
# ‾‾‾‾‾‾‾
# episode: 1912/2000, steps: 3, reward_total: 1, e: 0.0049, time: 09:41:15
# _______
# | |O|X|
# | |X| |
# |X|O| |
# ‾‾‾‾‾‾‾
# episode: 1913/2000, steps: 3, reward_total: 1, e: 0.0049, time: 09:41:15
# _______
# | |X|O|
# | |O|X|
# |O| |X|
# ‾‾‾‾‾‾‾
# episode: 1914/2000, steps: 5, reward_total: 1, e: 0.0049, time: 09:41:17
# _______
# |X|O|X|
# |X|O|O|
# |X|X|O|
# ‾‾‾‾‾‾‾
# episode: 1915/2000, steps: 3, reward_total: 1, e: 0.0048, time: 09:41:18
# _______
# | |X|O|
# |X|O|X|
# |O| | |
# ‾‾‾‾‾‾‾
# episode: 1916/2000, steps: 3, reward_total: 1, e: 0.0048, time: 09:41:19
# _______
# | | |X|
# | |X| |
# |X|O|O|
# ‾‾‾‾‾‾‾
# episode: 1917/2000, steps: 4, reward_total: -1, e: 0.0048, time: 09:41:20
# _______
# |O|X|O|
# |X|O|X|
# |X|O|X|
# ‾‾‾‾‾‾‾
# episode: 1918/2000, steps: 3, reward_total: 1, e: 0.0048, time: 09:41:21
# _______
# | |O|X|
# | |X|O|
# |X| | |
# ‾‾‾‾‾‾‾
# episode: 1919/2000, steps: 3, reward_total: 1, e: 0.0048, time: 09:41:21
# _______
# | |X|O|
# | |O|X|
# |O| |X|
# ‾‾‾‾‾‾‾
# episode: 1920/2000, steps: 3, reward_total: 1, e: 0.0048, time: 09:41:22
# _______
# | |O|X|
# |O|X| |
# |X| | |
# ‾‾‾‾‾‾‾
# episode: 1921/2000, steps: 3, reward_total: 1, e: 0.0048, time: 09:41:23
# _______
# | |X|O|
# |X|O| |
# |O|X| |
# ‾‾‾‾‾‾‾
# episode: 1922/2000, steps: 3, reward_total: 1, e: 0.0047, time: 09:41:24
# _______
# | | |X|
# | |X| |
# |X|O|O|
# ‾‾‾‾‾‾‾
# episode: 1923/2000, steps: 3, reward_total: 1, e: 0.0047, time: 09:41:25
# _______
# | |X|O|
# |X|O| |
# |O|X| |
# ‾‾‾‾‾‾‾
# episode: 1924/2000, steps: 3, reward_total: 1, e: 0.0047, time: 09:41:26
# _______
# | |O|X|
# | |X| |
# |X|O| |
# ‾‾‾‾‾‾‾
# episode: 1925/2000, steps: 4, reward_total: -1, e: 0.0047, time: 09:41:27
# _______
# |O|X|O|
# |X|O|X|
# |X|O|X|
# ‾‾‾‾‾‾‾
# episode: 1926/2000, steps: 3, reward_total: 1, e: 0.0047, time: 09:41:28
# _______
# | | |X|
# | |X|O|
# |X| |O|
# ‾‾‾‾‾‾‾
# episode: 1927/2000, steps: 4, reward_total: 1, e: 0.0047, time: 09:41:29
# _______
# |O|X|X|
# |X|O| |
# |O|X|O|
# ‾‾‾‾‾‾‾
# episode: 1928/2000, steps: 3, reward_total: 1, e: 0.0046, time: 09:41:30
# _______
# |O|O|X|
# | |X| |
# |X| | |
# ‾‾‾‾‾‾‾
# episode: 1929/2000, steps: 4, reward_total: 1, e: 0.0046, time: 09:41:31
# _______
# |O|X|O|
# | |O|X|
# |X|X|O|
# ‾‾‾‾‾‾‾
# episode: 1930/2000, steps: 3, reward_total: 1, e: 0.0046, time: 09:41:32
# _______
# | | |X|
# |O|X| |
# |X|O| |
# ‾‾‾‾‾‾‾
# episode: 1931/2000, steps: 2, reward_total: -2, e: 0.0046, time: 09:41:32
# _______
# | | |O|
# | |O| |
# |X|X|X|
# ‾‾‾‾‾‾‾
# episode: 1932/2000, steps: 4, reward_total: 1, e: 0.0046, time: 09:41:33
# _______
# |X|O|O|
# |O|X| |
# |X| |X|
# ‾‾‾‾‾‾‾
# episode: 1933/2000, steps: 3, reward_total: -2, e: 0.0046, time: 09:41:34
# _______
# | | |O|
# |X|X|X|
# |O|X|O|
# ‾‾‾‾‾‾‾
# episode: 1934/2000, steps: 4, reward_total: -2, e: 0.0046, time: 09:41:35
# _______
# |O|O|X|
# |X|O| |
# |X|O|X|
# ‾‾‾‾‾‾‾
# episode: 1935/2000, steps: 4, reward_total: -2, e: 0.0045, time: 09:41:36
# _______
# |X|X|X|
# |O|O|X|
# |O|X|O|
# ‾‾‾‾‾‾‾
# episode: 1936/2000, steps: 3, reward_total: -2, e: 0.0045, time: 09:41:37
# _______
# |O| |X|
# |O|X| |
# |O| |X|
# ‾‾‾‾‾‾‾
# episode: 1937/2000, steps: 3, reward_total: -2, e: 0.0045, time: 09:41:38
# _______
# | | |O|
# |X|X|X|
# |O|X|O|
# ‾‾‾‾‾‾‾
# episode: 1938/2000, steps: 3, reward_total: 1, e: 0.0045, time: 09:41:39
# _______
# | | |X|
# | |X| |
# |X|O|O|
# ‾‾‾‾‾‾‾
# episode: 1939/2000, steps: 3, reward_total: 1, e: 0.0045, time: 09:41:40
# _______
# |X| |O|
# |X|O| |
# |O|X| |
# ‾‾‾‾‾‾‾
# episode: 1940/2000, steps: 3, reward_total: 1, e: 0.0045, time: 09:41:41
# _______
# |O| |X|
# | |X| |
# |X| |O|
# ‾‾‾‾‾‾‾
# episode: 1941/2000, steps: 3, reward_total: 1, e: 0.0045, time: 09:41:42
# _______
# |X| |O|
# |X|O|X|
# |O| | |
# ‾‾‾‾‾‾‾
# episode: 1942/2000, steps: 4, reward_total: 1, e: 0.0044, time: 09:41:43
# _______
# |O| |X|
# | |O|O|
# |X|X|X|
# ‾‾‾‾‾‾‾
# episode: 1943/2000, steps: 4, reward_total: -2, e: 0.0044, time: 09:41:44
# _______
# |X|X|X|
# |O|O|X|
# |O|X|O|
# ‾‾‾‾‾‾‾
# episode: 1944/2000, steps: 3, reward_total: 1, e: 0.0044, time: 09:41:45
# _______
# | | |X|
# | |X| |
# |X|O|O|
# ‾‾‾‾‾‾‾
# episode: 1945/2000, steps: 4, reward_total: -2, e: 0.0044, time: 09:41:46
# _______
# |O|O|X|
# |X|O|O|
# |X|X|X|
# ‾‾‾‾‾‾‾
# episode: 1946/2000, steps: 4, reward_total: -2, e: 0.0044, time: 09:41:47
# _______
# |X| |X|
# |O|O|O|
# |X|X|O|
# ‾‾‾‾‾‾‾
# episode: 1947/2000, steps: 4, reward_total: -2, e: 0.0044, time: 09:41:48
# _______
# |O|X|O|
# |X|X|X|
# |O|O|X|
# ‾‾‾‾‾‾‾
# episode: 1948/2000, steps: 3, reward_total: 1, e: 0.0043, time: 09:41:49
# _______
# | | |X|
# |O|X|O|
# |X| | |
# ‾‾‾‾‾‾‾
# episode: 1949/2000, steps: 3, reward_total: 1, e: 0.0043, time: 09:41:50
# _______
# | | |O|
# |X|O| |
# |O|X|X|
# ‾‾‾‾‾‾‾
# episode: 1950/2000, steps: 3, reward_total: 1, e: 0.0043, time: 09:41:51
# _______
# | |O|X|
# |O|X| |
# |X| | |
# ‾‾‾‾‾‾‾
# episode: 1951/2000, steps: 4, reward_total: 1, e: 0.0043, time: 09:41:52
# _______
# |X|X|O|
# |O|O|O|
# |X| |X|
# ‾‾‾‾‾‾‾
# episode: 1952/2000, steps: 4, reward_total: 1, e: 0.0043, time: 09:41:53
# _______
# |X| |X|
# | |X|O|
# |O|O|X|
# ‾‾‾‾‾‾‾
# episode: 1953/2000, steps: 3, reward_total: 1, e: 0.0043, time: 09:41:54
# _______
# | |X|O|
# |X|O| |
# |O| |X|
# ‾‾‾‾‾‾‾
# episode: 1954/2000, steps: 4, reward_total: -2, e: 0.0043, time: 09:41:55
# _______
# |X| |X|
# |O|O|O|
# |X|O|X|
# ‾‾‾‾‾‾‾
# episode: 1955/2000, steps: 4, reward_total: -1, e: 0.0042, time: 09:41:56
# _______
# |O|X|X|
# |X|O|O|
# |O|X|X|
# ‾‾‾‾‾‾‾
# episode: 1956/2000, steps: 3, reward_total: 1, e: 0.0042, time: 09:41:57
# _______
# | | |X|
# | |X|O|
# |X|O| |
# ‾‾‾‾‾‾‾
# episode: 1957/2000, steps: 2, reward_total: -2, e: 0.0042, time: 09:41:57
# _______
# |X| |O|
# | |X| |
# |O| |X|
# ‾‾‾‾‾‾‾
# episode: 1958/2000, steps: 3, reward_total: 1, e: 0.0042, time: 09:41:58
# _______
# | | |X|
# | |X|O|
# |X|O| |
# ‾‾‾‾‾‾‾
# episode: 1959/2000, steps: 3, reward_total: 1, e: 0.0042, time: 09:41:59
# _______
# |X|X|O|
# | |O| |
# |O|X| |
# ‾‾‾‾‾‾‾
# episode: 1960/2000, steps: 3, reward_total: -2, e: 0.0042, time: 09:42:00
# _______
# |O| |X|
# |O|X| |
# |O| |X|
# ‾‾‾‾‾‾‾
# episode: 1961/2000, steps: 4, reward_total: 1, e: 0.0042, time: 09:42:01
# _______
# |O|X|O|
# |X|O|X|
# |X| |O|
# ‾‾‾‾‾‾‾
# episode: 1962/2000, steps: 3, reward_total: 1, e: 0.0041, time: 09:42:02
# _______
# | | |X|
# | |X|O|
# |X| |O|
# ‾‾‾‾‾‾‾
# episode: 1963/2000, steps: 4, reward_total: 1, e: 0.0041, time: 09:42:03
# _______
# |X| |O|
# |X|X|O|
# |O|X|O|
# ‾‾‾‾‾‾‾
# episode: 1964/2000, steps: 5, reward_total: 1, e: 0.0041, time: 09:42:04
# _______
# |X|X|X|
# |O|X|O|
# |O|X|O|
# ‾‾‾‾‾‾‾
# episode: 1965/2000, steps: 4, reward_total: 1, e: 0.0041, time: 09:42:06
# _______
# |O|X|X|
# |O|O| |
# |O|X|X|
# ‾‾‾‾‾‾‾
# episode: 1966/2000, steps: 3, reward_total: 1, e: 0.0041, time: 09:42:06
# _______
# | | |X|
# |O|X|O|
# |X| | |
# ‾‾‾‾‾‾‾
# episode: 1967/2000, steps: 3, reward_total: 1, e: 0.0041, time: 09:42:07
# _______
# | | |O|
# | |O|X|
# |O|X|X|
# ‾‾‾‾‾‾‾
# episode: 1968/2000, steps: 3, reward_total: 1, e: 0.0041, time: 09:42:08
# _______
# |O| |X|
# | |X| |
# |X| |O|
# ‾‾‾‾‾‾‾
# episode: 1969/2000, steps: 4, reward_total: 1, e: 0.004, time: 09:42:09
# _______
# |O|X|X|
# | |O|X|
# |O|X|O|
# ‾‾‾‾‾‾‾
# episode: 1970/2000, steps: 3, reward_total: 1, e: 0.004, time: 09:42:10
# _______
# | |O|X|
# | |X|O|
# |X| | |
# ‾‾‾‾‾‾‾
# episode: 1971/2000, steps: 4, reward_total: -1, e: 0.004, time: 09:42:11
# _______
# |O|X|X|
# |X|O|O|
# |O|X|X|
# ‾‾‾‾‾‾‾
# episode: 1972/2000, steps: 3, reward_total: 1, e: 0.004, time: 09:42:12
# _______
# | | |X|
# | |X|O|
# |X| |O|
# ‾‾‾‾‾‾‾
# episode: 1973/2000, steps: 3, reward_total: 1, e: 0.004, time: 09:42:13
# _______
# | |X|O|
# | |O|X|
# |O|X| |
# ‾‾‾‾‾‾‾
# episode: 1974/2000, steps: 3, reward_total: -2, e: 0.004, time: 09:42:14
# _______
# |X|O|X|
# | |O| |
# |X|O| |
# ‾‾‾‾‾‾‾
# episode: 1975/2000, steps: 3, reward_total: 1, e: 0.004, time: 09:42:14
# _______
# | |X|O|
# |X|O|X|
# |O| | |
# ‾‾‾‾‾‾‾
# episode: 1976/2000, steps: 3, reward_total: 1, e: 0.004, time: 09:42:15
# _______
# | | |X|
# | |X|O|
# |X|O| |
# ‾‾‾‾‾‾‾
# episode: 1977/2000, steps: 3, reward_total: 1, e: 0.0039, time: 09:42:16
# _______
# |X|X|O|
# | |O| |
# |O| |X|
# ‾‾‾‾‾‾‾
# episode: 1978/2000, steps: 4, reward_total: 1, e: 0.0039, time: 09:42:17
# _______
# |O| |X|
# |X|X| |
# |X|O|O|
# ‾‾‾‾‾‾‾
# episode: 1979/2000, steps: 3, reward_total: 1, e: 0.0039, time: 09:42:18
# _______
# | | |O|
# | |O|X|
# |O|X|X|
# ‾‾‾‾‾‾‾
# episode: 1980/2000, steps: 3, reward_total: 1, e: 0.0039, time: 09:42:19
# _______
# | |O|X|
# | |X|O|
# |X| | |
# ‾‾‾‾‾‾‾
# episode: 1981/2000, steps: 3, reward_total: 1, e: 0.0039, time: 09:42:20
# _______
# | |X|O|
# | |O|X|
# |O|X| |
# ‾‾‾‾‾‾‾
# episode: 1982/2000, steps: 3, reward_total: 1, e: 0.0039, time: 09:42:21
# _______
# | |O|X|
# |O|X| |
# |X| | |
# ‾‾‾‾‾‾‾
# episode: 1983/2000, steps: 4, reward_total: 1, e: 0.0039, time: 09:42:22
# _______
# |O|X|X|
# | |O|X|
# |O|X|O|
# ‾‾‾‾‾‾‾
# episode: 1984/2000, steps: 3, reward_total: -2, e: 0.0038, time: 09:42:22
# _______
# |X|O|X|
# | |O| |
# |X|O| |
# ‾‾‾‾‾‾‾
# episode: 1985/2000, steps: 4, reward_total: -1, e: 0.0038, time: 09:42:24
# _______
# |O|X|X|
# |X|O|O|
# |O|X|X|
# ‾‾‾‾‾‾‾
# episode: 1986/2000, steps: 3, reward_total: 1, e: 0.0038, time: 09:42:24
# _______
# | | |X|
# |O|X| |
# |X|O| |
# ‾‾‾‾‾‾‾
# episode: 1987/2000, steps: 3, reward_total: 1, e: 0.0038, time: 09:42:25
# _______
# |X| |O|
# |X|O| |
# |O|X| |
# ‾‾‾‾‾‾‾
# episode: 1988/2000, steps: 3, reward_total: 1, e: 0.0038, time: 09:42:26
# _______
# | | |X|
# |O|X| |
# |X|O| |
# ‾‾‾‾‾‾‾
# episode: 1989/2000, steps: 3, reward_total: 1, e: 0.0038, time: 09:42:27
# _______
# |X| |O|
# |X|O|X|
# |O| | |
# ‾‾‾‾‾‾‾
# episode: 1990/2000, steps: 3, reward_total: 1, e: 0.0038, time: 09:42:28
# _______
# |O| |X|
# | |X| |
# |X|O| |
# ‾‾‾‾‾‾‾
# episode: 1991/2000, steps: 4, reward_total: 1, e: 0.0038, time: 09:42:29
# _______
# |O|X|X|
# | |O|X|
# |O|X|O|
# ‾‾‾‾‾‾‾
# episode: 1992/2000, steps: 3, reward_total: 1, e: 0.0038, time: 09:42:30
# _______
# | | |X|
# |O|X|O|
# |X| | |
# ‾‾‾‾‾‾‾
# episode: 1993/2000, steps: 3, reward_total: -2, e: 0.0037, time: 09:42:30
# _______
# | | |O|
# |O|O|X|
# |X|X|X|
# ‾‾‾‾‾‾‾
# episode: 1994/2000, steps: 3, reward_total: 1, e: 0.0037, time: 09:42:31
# _______
# | |O|X|
# | |X| |
# |X| |O|
# ‾‾‾‾‾‾‾
# episode: 1995/2000, steps: 4, reward_total: 1, e: 0.0037, time: 09:42:32
# _______
# |O|X|O|
# |X|O|X|
# |X| |O|
# ‾‾‾‾‾‾‾
# episode: 1996/2000, steps: 3, reward_total: 1, e: 0.0037, time: 09:42:33
# _______
# | | |X|
# | |X| |
# |X|O|O|
# ‾‾‾‾‾‾‾
# episode: 1997/2000, steps: 4, reward_total: 1, e: 0.0037, time: 09:42:34
# _______
# |O|X|X|
# |X|O|X|
# |O| |O|
# ‾‾‾‾‾‾‾
# episode: 1998/2000, steps: 4, reward_total: -2, e: 0.0037, time: 09:42:36
# _______
# |X|O|X|
# | |O|X|
# |X|O|O|
# ‾‾‾‾‾‾‾
# episode: 1999/2000, steps: 4, reward_total: 1, e: 0.0037, time: 09:42:37
# _______
# |O| |O|
# |X|O|X|
# |X|X|O|
# ‾‾‾‾‾‾‾
# episode: 2000/2000, steps: 3, reward_total: 1, e: 0.0036, time: 09:42:38
# _______
# |O| |X|
# |O|X| |
# |X| | |
# ‾‾‾‾‾‾‾
# Model saved to '../../../trained_models/ReinforcementLearning/TicTacToeV2\TicTacToev2-NAIVE-10K.pt'.

# %% [markdown]
# ##### Comparing the NAIVE models to a Naive opponent.

# %%
compare_to_naive(NAIVE_2K)
# Out:
# Loading Model Parameters...
# Model loaded from '../../../trained_models/ReinforcementLearning/TicTacToeV2\TicTacToev2-NAIVE-2K.pt'.
# 100%|██████████| 25000/25000 [01:53<00:00, 220.73it/s]
# Win rate:  72.604%
# Draw rate: 7.084%
# Loss rate: 20.312%

# %%
compare_to_naive(NAIVE_4K)
# Out:
# Loading Model Parameters...
# Model loaded from '../../../trained_models/ReinforcementLearning/TicTacToeV2\TicTacToev2-NAIVE-4K.pt'.
# 100%|██████████| 25000/25000 [01:52<00:00, 221.79it/s]
# Win rate:  69.188%
# Draw rate: 7.236%
# Loss rate: 23.576%

# %%
compare_to_naive(NAIVE_6K)
# Out:
# Loading Model Parameters...
# Model loaded from '../../../trained_models/ReinforcementLearning/TicTacToeV2\TicTacToev2-NAIVE-6K.pt'.
# 100%|██████████| 25000/25000 [01:50<00:00, 225.28it/s]
# Win rate:  73.988%
# Draw rate: 5.264%
# Loss rate: 20.748%

# %%
compare_to_naive(NAIVE_8K)
# Out:
# Loading Model Parameters...
# Model loaded from '../../../trained_models/ReinforcementLearning/TicTacToeV2\TicTacToev2-NAIVE-8K.pt'.
# 100%|██████████| 25000/25000 [01:56<00:00, 215.35it/s]
# Win rate:  65.188%
# Draw rate: 5.576%
# Loss rate: 29.236%

# %%
compare_to_naive(NAIVE_10K)
# Out:
# Loading Model Parameters...
# Model loaded from '../../../trained_models/ReinforcementLearning/TicTacToeV2\TicTacToev2-NAIVE-10K.pt'.
# 100%|██████████| 25000/25000 [01:54<00:00, 219.28it/s]
# Win rate:  66.86%
# Draw rate: 6.52%
# Loss rate: 26.62%

# %% [markdown]
# ##### Comparing NAIVE models to Optimal opponent.

# %%
compare_to_optimal(BASELINE)
# Out:
# Loading Model Parameters...
# Model loaded from '../../../trained_models/ReinforcementLearning/TicTacToeV2\TicTacToev2-Baseline-Untrained.pt'.
# 100%|██████████| 100/100 [09:15<00:00,  5.56s/it]
# Win rate:  0.0%
# Draw rate: 5.0%
# Loss rate: 95.0%

# %%
compare_to_optimal(NAIVE_2K)
# Out:
# Loading Model Parameters...
# Model loaded from '../../../trained_models/ReinforcementLearning/TicTacToeV2\TicTacToev2-NAIVE-2K.pt'.
# 100%|██████████| 100/100 [09:59<00:00,  6.00s/it]
# Win rate:  20.0%
# Draw rate: 4.0%
# Loss rate: 76.0%

# %%
compare_to_optimal(NAIVE_4K)
# Out:
# Loading Model Parameters...
# Model loaded from '../../../trained_models/ReinforcementLearning/TicTacToeV2\TicTacToev2-NAIVE-4K.pt'.
# 100%|██████████| 100/100 [09:28<00:00,  5.68s/it]
# Win rate:  28.0%
# Draw rate: 10.0%
# Loss rate: 62.0%

# %%
compare_to_optimal(NAIVE_6K)
# Out:
# Loading Model Parameters...
# Model loaded from '../../../trained_models/ReinforcementLearning/TicTacToeV2\TicTacToev2-NAIVE-6K.pt'.
# 100%|██████████| 100/100 [09:45<00:00,  5.85s/it]
# Win rate:  27.0%
# Draw rate: 0.0%
# Loss rate: 73.0%

# %%
compare_to_optimal(NAIVE_8K)
# Out:
# Loading Model Parameters...
# Model loaded from '../../../trained_models/ReinforcementLearning/TicTacToeV2\TicTacToev2-NAIVE-8K.pt'.
# 100%|██████████| 100/100 [09:38<00:00,  5.79s/it]
# Win rate:  15.0%
# Draw rate: 0.0%
# Loss rate: 85.0%

# %%
compare_to_optimal(NAIVE_10K)
# Out:
# Loading Model Parameters...
# Model loaded from '../../../trained_models/ReinforcementLearning/TicTacToeV2\TicTacToev2-NAIVE-10K.pt'.
# 100%|██████████| 100/100 [09:41<00:00,  5.82s/it]
# Win rate:  12.0%
# Draw rate: 0.0%
# Loss rate: 88.0%

# %% [markdown]
# The NAIVE_2K and NAIVE_4K models seem to perform well against the the Naive opponent, and better than the others against the Optimal Opponent.
