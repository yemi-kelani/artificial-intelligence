# %%
import torch

DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
from DeepQAgent import DeepQAgent
from TicTacToeGame import TicTacToeGame, OPPONENT_LEVEL

import os
import sys
sys.path.append(os.path.abspath('..'))

from Utils import (
    train_agent,
    test_agent,
    set_seed
)

sys.path.remove(os.path.abspath('..'))

# %%
SEED = 100
set_seed(SEED)

# %%
# DeepQ parameters
BATCH_SIZE     = 128
NUM_EPISODES   = 5000 if torch.cuda.is_available() else 100
STATE_SPACE    = 9
ACTION_SPACE   = 9
HIDDEN_SIZE    = 128
EPSILON        = 1.0
GAMMA          = 0.99
LEARNING_RATE  = 0.001
DROPOUT        = 0.25
TRAIN_START    = 1000
NEGATIVE_SLOPE = 0.01
COMPUTER_LEVEL = OPPONENT_LEVEL.NAIVE

# save path
MODEL_PATH = "../../../trained_models/TicTacToeV2"
MODEL_NAME = f"TicTacToe-{COMPUTER_LEVEL.name}-{NUM_EPISODES}"

# %%
def get_full_model_path():
  return os.path.join(MODEL_PATH, MODEL_NAME)

def supply_model(load_if_exists: bool = True):
  
  agent = DeepQAgent(
      device         = DEVICE,
      epsilon        = EPSILON, 
      gamma          = GAMMA,
      state_space    = STATE_SPACE, 
      action_space   = ACTION_SPACE, 
      hidden_size    = HIDDEN_SIZE,
      dropout        = DROPOUT,
      train_start    = TRAIN_START,
      batch_size     = BATCH_SIZE,
      negative_slope = NEGATIVE_SLOPE
  )

  full_model_path = get_full_model_path()
  if load_if_exists and os.path.exists(full_model_path):
    print("Loading Model Parameters...")
    agent.load_model(filepath=full_model_path)
  
  optimizer = torch.optim.Adam(agent.parameters(), lr=LEARNING_RATE)
  criterion = torch.nn.SmoothL1Loss() # Huber Loss
  
  return agent, optimizer, criterion

# %% [markdown]
# #### Baseline Models
# For comparison, this is how an untrained model performs against a naive opponent.

# %%
baseline, _, _ = supply_model(load_if_exists=False)
environment = TicTacToeGame(DEVICE, OPPONENT_LEVEL.NAIVE)
test_agent(baseline, environment, 10000, DEVICE)
# Out:
#   1%|          | 74/10000 [00:00<00:13, 739.57it/s]
# _______
# | |X|X|
# |X|X|O|
# |O|O|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|O|
# |X|O|X|
# |X|O|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O| |
# |X| |O|
# |X|X|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|O|
# |O|O|X|
# |X|X|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|O|
# |X|X|X|
# |X|O|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|O|
# |O| |X|
# |O|X|X|
# ‾‾‾‾‾‾‾
# _______
# | |O| |
# | | |O|
# |X|X|X|
# ‾‾‾‾‾‾‾
# _______
# |X|X|X|
# |O|X|O|
# |O|O|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O| |
# |X|X|O|
# |X| |O|
# ‾‾‾‾‾‾‾
# _______
# | |X|X|
# | | |X|
# |O|O|O|
# ‾‾‾‾‾‾‾
# _______
# |X|O| |
# | |X|O|
# |X|O|X|
# ‾‾‾‾‾‾‾
# _______
# | |X|X|
# |O|O|O|
# |X|O|X|
# ‾‾‾‾‾‾‾
# _______
# | |O| |
# |X|X|X|
# | | |O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|X|
# |O|O|X|
# | | |X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|O|
# |X|X|O|
# | |X|O|
# ‾‾‾‾‾‾‾
# _______
# | |X|X|
# | |O|X|
# |O|O|X|
# ‾‾‾‾‾‾‾
# _______
# | |O|X|
# | |O|O|
# |X|X|X|
# ‾‾‾‾‾‾‾
# _______
# |O|X|O|
# | |X|X|
# | |X|O|
# ‾‾‾‾‾‾‾
# _______
# |X|O| |
# |X|X|O|
# | |O|X|
# ‾‾‾‾‾‾‾
# _______
# | |X|X|
# |O|O|O|
# | | |X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|O|
# |X|O|X|
# |X|X|O|
# ‾‾‾‾‾‾‾
# _______
# | |X|O|
# |O|O|X|
# |O|X|X|
# ‾‾‾‾‾‾‾
# _______
# |X|X|O|
# |X|O|O|
# |X|O|X|
# ‾‾‾‾‾‾‾
# _______
# |O|X|O|
# | |X|O|
# | |X|X|
# ‾‾‾‾‾‾‾
# _______
# | |X|O|
# |X|X|O|
# |X|O|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|O|
# |O| |X|
# |O|X|X|
# ‾‾‾‾‾‾‾
# _______
# | |O| |
# |X|X|X|
# |X|O|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|X|
# | |O|X|
# | |O|X|
# ‾‾‾‾‾‾‾
# _______
# | |O| |
# |X|X|X|
# | | |O|
# ‾‾‾‾‾‾‾
# _______
# | |X|X|
# |O| |X|
# |O|O|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O| |
# |X|X|O|
# |X| |O|
# ‾‾‾‾‾‾‾
# _______
# | |X|X|
# |O|X|X|
# |O|O|O|
# ‾‾‾‾‾‾‾
# _______
# |X|O|X|
# |X|X|O|
# |O|X|O|
# ‾‾‾‾‾‾‾
# _______
# | |X|O|
# | |O|X|
# |O| |X|
# ‾‾‾‾‾‾‾
# _______
# |X|O| |
# |X|X|X|
# | |O|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|X|
# |O|O|X|
# | |X|O|
# ‾‾‾‾‾‾‾
# _______
# | |O| |
# |X|X|X|
# |X|O|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|O|
# |O|O|X|
# |X|X|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O| |
# |X| |X|
# |X|O|O|
# ‾‾‾‾‾‾‾
# _______
# |X|X|X|
# |O|O|X|
# |O|X|O|
# ‾‾‾‾‾‾‾
# _______
# |X|O|X|
# |X|X|O|
# |X|O|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|O|
# |O|X|X|
# |X|O|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|O|
# | | |O|
# |X|X|X|
# ‾‾‾‾‾‾‾
# _______
# |O|X|O|
# | |O|X|
# |X|X|O|
# ‾‾‾‾‾‾‾
# _______
# | |O|O|
# |X|X|O|
# |X|X|O|
# ‾‾‾‾‾‾‾
# _______
# | |X|X|
# |O|O|X|
# |O| |X|
# ‾‾‾‾‾‾‾
# _______
# | |O|X|
# | |X|O|
# |X|X|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|X|
# |O|X|O|
# |X|O|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|X|
# |X|O|O|
# |X|X|O|
# ‾‾‾‾‾‾‾
# _______
# | |X|O|
# |O|O|X|
# |O|X|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|X|
# |X|O|O|
# |X|X|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|X|
# | |O|X|
# | |O|X|
# ‾‾‾‾‾‾‾
# _______
# | |O|X|
# | |X|O|
# |X|X|O|
# ‾‾‾‾‾‾‾
# _______
# |X|X|O|
# |O|X|X|
# |O|O|X|
# ‾‾‾‾‾‾‾
# _______
# |X|X|O|
# | |X|X|
# |O|O|O|
# ‾‾‾‾‾‾‾
# _______
# | |X|X|
# |O|O|X|
# |O| |X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|X|
# | |X|X|
# |O|O|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|X|
# |X|O|O|
# |O|X|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|O|
# | |X|O|
# |X|X|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|X|
# |O| |X|
# | |O|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|O|
# |X| |X|
# |X| |O|
# ‾‾‾‾‾‾‾
# _______
# |X|X|O|
# |O|O|X|
# |X|O|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|O|
# |X|X|X|
# |O|X|O|
# ‾‾‾‾‾‾‾
# _______
# |X|X|X|
# |O|X|O|
# |O|O|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|X|
# |X|O|O|
# |X|X|O|
# ‾‾‾‾‾‾‾
# _______
# | |X|X|
# |O|O|X|
# | |O|X|
# ‾‾‾‾‾‾‾
# _______
# |X|X|O|
# | |O|X|
# |O|X|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|X|
# |O| |X|
# | |O|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|O|
# |X|X|X|
# | | |O|
# ‾‾‾‾‾‾‾
# _______
# | |X|X|
# |O|O|X|
# |O| |X|
# ‾‾‾‾‾‾‾
# _______
# | |X|X|
# | |X|O|
# |X|O|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|X|
# |O| |O|
# |O|X|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|X|
# | |X|O|
# |X| |O|
# ‾‾‾‾‾‾‾
# _______
# | |X|X|
# |O|O|X|
# |O| |X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|O|
# |X|X|X|
# |O|X|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|X|
# |X|O|O|
# |O|X|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|O|
# |X|X|O|
# | |X|O|
# ‾‾‾‾‾‾‾
# _______
# | |X|X|
# | |O|X|
# |O|O|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|X|
# |X|X|O|
# |O|O|X|
# ‾‾‾‾‾‾‾
# _______
# | |X|O|
# | |O|X|
# |O| |X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|O|
# |X|O|X|
# |X|X|O|
# ‾‾‾‾‾‾‾
# _______
# |X|X|O|
# |O|O|X|
# |X|O|X|
# ‾‾‾‾‾‾‾
# _______
# | |X|O|
# |X|X|X|
# | |O|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X| |
# |O| |X|
# |O| |X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|X|
# |X|X|O|
# |O|X|O|
# ‾‾‾‾‾‾‾
# _______
# |X|X|O|
# |O|O|X|
# |X|O|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|X|
# |X|O|O|
# |X|X|O|
# ‾‾‾‾‾‾‾
# _______
# | |X|O|
# | |O|X|
# |O| |X|
# ‾‾‾‾‾‾‾
# _______
# |X|X|O|
# |X| | |
# |X|O|O|
# ‾‾‾‾‾‾‾
# _______
# | |X|X|
# |O|O|X|
# | |O|X|
# ‾‾‾‾‾‾‾
# _______
# |X|X|O|
# | |X|O|
# | |O|X|
# ‾‾‾‾‾‾‾
# _______
# |O|X|O|
# |O|O|X|
# |X|X|X|
# ‾‾‾‾‾‾‾
# _______
# | |X|O|
# | |X| |
# | |X|O|
# ‾‾‾‾‾‾‾
# _______
# | |X|X|
# |O| |X|
# |O|O|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|O|
# |X|X|X|
# |X|O|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|X|
# | |O|X|
# | |O|X|
# ‾‾‾‾‾‾‾
# _______
# | |O|X|
# |X|O|X|
# |X|O|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|O|
# |O| |X|
# |O|X|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O| |
# | |X|O|
# | | |X|
# ‾‾‾‾‾‾‾
# _______
# |O|X|X|
# | |O|X|
# | |O|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|O|
# | |X|O|
# |X|X|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|X|
# |O|X|X|
# |X|O|O|
# ‾‾‾‾‾‾‾
# _______
# |X|O|O|
# |X|X|X|
# |O|X|O|
# ‾‾‾‾‾‾‾
# _______
# |X|X|O|
# |O|O|X|
# |X|O|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|X|
# |X|O|O|
# |X|X|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|O|
# |O|X|X|
# |X|O|X|
# ‾‾‾‾‾‾‾
# _______
# | |O|X|
# | |X|O|
# |X|X|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|X|
# | |O|X|
# | |O|X|
# ‾‾‾‾‾‾‾
# _______
# | |O|O|
# |X|X|O|
# |X|X|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|X|
# |O| |O|
# |O|X|X|
# ‾‾‾‾‾‾‾
# _______
# |X|X|O|
# |O|X|X|
# |X|O|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|X|
# | | |X|
# |O|O|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|X|
# |X|O|O|
# |X|X|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|X|
# |X|O|O|
# |O|X|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|O|
# |X|X|O|
# | |X|O|
# ‾‾‾‾‾‾‾
# _______
# | |X|X|
# |O|O|O|
# | | |X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|X|
# |X|O|X|
# | |O|O|
# ‾‾‾‾‾‾‾
# _______
# | |X|X|
# |O|O|O|
# | | |X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|X|
# |X|O|O|
# |X|X|O|
# ‾‾‾‾‾‾‾
# _______
# |X|X|X|
# |O|O|X|
# |O|X|O|
# ‾‾‾‾‾‾‾
# _______
# | |X|O|
# | |X| |
# | |X|O|
# ‾‾‾‾‾‾‾
# _______
# | |X|O|
# |O|O|X|
# |O|X|X|
# ‾‾‾‾‾‾‾
# _______
# | |O|O|
# |X|X|O|
# |X|X|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X| |
# |O| |X|
# |O| |X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|X|
# |X| |O|
# |X| |O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|X|
# |O|O|O|
# | |X|X|
# ‾‾‾‾‾‾‾
# _______
# | |O| |
# | | |O|
# |X|X|X|
# ‾‾‾‾‾‾‾
# _______
# |O|X|X|
# |O|O|X|
# | |X|O|
# ‾‾‾‾‾‾‾
# _______
# | |O|X|
# | |X|O|
# |X|O|X|
# ‾‾‾‾‾‾‾
# _______
# | |X|X|
# |O|O|X|
# |O| |X|
# ‾‾‾‾‾‾‾
# _______
# |X|X|O|
# |X|O|O|
# |X|O|X|
# ‾‾‾‾‾‾‾
# _______
# |O|X|O|
# | |O|X|
# |O|X|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O| |
# | |X|O|
# | | |X|
# ‾‾‾‾‾‾‾
# _______
# |O|X|X|
# |O| |X|
# |O|X|O|
# ‾‾‾‾‾‾‾
# _______
# | |O| |
# |X|X|X|
# | | |O|
# ‾‾‾‾‾‾‾
# _______
# | |X|X|
# |O|O|O|
# |X|O|X|
# ‾‾‾‾‾‾‾
# _______
# | |O| |
# |X|X|X|
# | | |O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|O|
# |O|O|X|
# |X|X|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|X|
# |X|O|O|
# |X|X|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|O|
# |O| |X|
# |O|X|X|
# ‾‾‾‾‾‾‾
# _______
# | |X| |
# | |X|O|
# | |X|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|X|
# |O|X|O|
# |X|O|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O| |
# |X| |O|
# |X|X|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|O|
# |O|X|X|
# |X|O|X|
# ‾‾‾‾‾‾‾
#   2%|▏         | 224/10000 [00:00<00:14, 676.73it/s]
# _______
# | |O|O|
# |X| |O|
# |X|X|X|
# ‾‾‾‾‾‾‾
# _______
# |X|X|O|
# |O|O|X|
# |X|O|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|O|
# |X|O|X|
# |X|X|O|
# ‾‾‾‾‾‾‾
# _______
# |X|X|O|
# |O|X|X|
# |O|O|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|O|
# |X|X|X|
# |X|O|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|X|
# |O|O|X|
# | | |X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|X|
# |X|X|O|
# |O|X|O|
# ‾‾‾‾‾‾‾
# _______
# | |X|X|
# | | |X|
# |O|O|O|
# ‾‾‾‾‾‾‾
# _______
# | |O|X|
# | |X|O|
# |X|X|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|X|
# |O|O|O|
# | |X|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O| |
# |X|X|O|
# |X| |O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|X|
# |O| |O|
# |O|X|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|X|
# |X|O|O|
# |X|X|O|
# ‾‾‾‾‾‾‾
# _______
# | |X|X|
# |O|X|X|
# |O|O|O|
# ‾‾‾‾‾‾‾
# _______
# |X|O|O|
# |X|X|X|
# | | |O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|X|
# |X|O|O|
# |X|O|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|X|
# | |X|O|
# | |O|X|
# ‾‾‾‾‾‾‾
# _______
# |O|X|X|
# |O| |X|
# | |O|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|O|
# |X|X|O|
# | |X|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|X|
# |X|O|O|
# |O|X|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|O|
# |X|X|O|
# | |X|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|O|
# | |O|X|
# |O|X|X|
# ‾‾‾‾‾‾‾
# _______
# | |X|O|
# | |X| |
# | |X|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|X|
# |O| |O|
# |O|X|X|
# ‾‾‾‾‾‾‾
# _______
# | |O| |
# |X|X|X|
# |X|O|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|O|
# |O| |X|
# |O|X|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|X|
# | |O|X|
# |X|O|O|
# ‾‾‾‾‾‾‾
# _______
# | |X|X|
# |O|O|O|
# | | |X|
# ‾‾‾‾‾‾‾
# _______
# |X|O| |
# |X|X|O|
# | |O|X|
# ‾‾‾‾‾‾‾
# _______
# |O|X|O|
# | |O|X|
# |X|X|O|
# ‾‾‾‾‾‾‾
# _______
# | |O|X|
# |X|O|X|
# |X|O|O|
# ‾‾‾‾‾‾‾
# _______
# | |X|O|
# |O|O|X|
# |O|X|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|X|
# | |O|X|
# |X|O|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X| |
# |O| |X|
# |O| |X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|O|
# | |X|O|
# |X|X|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|O|
# | |X|O|
# | |X|X|
# ‾‾‾‾‾‾‾
# _______
# |X|X|O|
# | |X|O|
# |X|O|O|
# ‾‾‾‾‾‾‾
# _______
# | |X|O|
# |O|O|X|
# |O|X|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O| |
# |X| |O|
# |X|X|O|
# ‾‾‾‾‾‾‾
# _______
# | |X|X|
# |O|O|O|
# |O|X|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|X|
# |X|X|O|
# |X|O|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|X|
# |O|O|X|
# | | |X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|X|
# |O|O|X|
# |X|X|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|O|
# |O| |X|
# |O|X|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O| |
# |X|X|X|
# | |O|O|
# ‾‾‾‾‾‾‾
# _______
# |X|X|O|
# |O|X|X|
# |O|O|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O| |
# | |X|O|
# |X|O|X|
# ‾‾‾‾‾‾‾
# _______
# |O|X|O|
# |O|O|X|
# |X|X|X|
# ‾‾‾‾‾‾‾
# _______
# | |O|X|
# | |X| |
# |X| |O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|X|
# |O|X|O|
# |X|O|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|O|
# |X|O|X|
# |X|X|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|O|
# |X|O|X|
# |X|O|X|
# ‾‾‾‾‾‾‾
# _______
# | |X|X|
# |X|X|O|
# |O|O|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|O|
# |O|X|X|
# |X|O|X|
# ‾‾‾‾‾‾‾
# _______
# |X|X|O|
# |X|O|X|
# |X|O|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|X|
# |O|X|O|
# |X|O|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|O|
# |X|X|O|
# |X|O|X|
# ‾‾‾‾‾‾‾
# _______
# |O|X|O|
# |O| |X|
# |O|X|X|
# ‾‾‾‾‾‾‾
# _______
# |X|X|O|
# | | |O|
# | |X|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|O|
# | |X|X|
# | |X|O|
# ‾‾‾‾‾‾‾
# _______
# |X|X|X|
# | | |O|
# |X|O|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|X|
# |O| |X|
# |O|X|O|
# ‾‾‾‾‾‾‾
# _______
# |X|X|X|
# | | |O|
# | | |O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|X|
# |O|X|O|
# |X|O|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|X|
# |X|O|O|
# | |O|X|
# ‾‾‾‾‾‾‾
# _______
# | |X|X|
# | |O|X|
# |O|O|X|
# ‾‾‾‾‾‾‾
# _______
# | |O|O|
# |X|X|O|
# |X|X|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|X|
# |O|X|O|
# |X|O|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|O|
# | |X|O|
# |X|X|O|
# ‾‾‾‾‾‾‾
# _______
# |X|X|O|
# |O|O|X|
# |X|O|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|O|
# |X|X|X|
# |O|X|O|
# ‾‾‾‾‾‾‾
# _______
# |X|X|O|
# |O|X|X|
# |O|O|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|X|
# |X|X|O|
# |O|X|O|
# ‾‾‾‾‾‾‾
# _______
# | |X|X|
# |O| |X|
# |O|O|X|
# ‾‾‾‾‾‾‾
# _______
# |X|X|O|
# | |X|O|
# |X|O|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|X|
# |X|X|O|
# |O|O|X|
# ‾‾‾‾‾‾‾
# _______
# |X|X|O|
# |O|O|X|
# |X|X|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|X|
# |O|X|X|
# |X|O|O|
# ‾‾‾‾‾‾‾
# _______
# | |O|O|
# |X|X|O|
# |X|X|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|X|
# | |O|X|
# |O| |X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|X|
# |X|X|O|
# |O|X|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|X|
# | |O|X|
# |O| |X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|X|
# | |X|O|
# | |O|X|
# ‾‾‾‾‾‾‾
# _______
# |O|X|X|
# | |O|X|
# | |O|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|X|
# |X|O|O|
# |X|X|O|
# ‾‾‾‾‾‾‾
# _______
# | |X|O|
# |O|O|X|
# |O|X|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O| |
# |X|X|O|
# |X| |O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|X|
# | |O|X|
# | |O|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|O|
# |X| |X|
# |X| |O|
# ‾‾‾‾‾‾‾
# _______
# | |X|X|
# |O| |X|
# |O|O|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|X|
# |X|X|O|
# |O|X|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|X|
# |O| |O|
# |O|X|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|O|
# |X|O|X|
# |X|X|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|O|
# |X|O|X|
# |X|O|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O| |
# |X|X|O|
# |X| |O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|X|
# | |O|X|
# | |O|X|
# ‾‾‾‾‾‾‾
# _______
# | |O|O|
# | |X|O|
# |X|X|X|
# ‾‾‾‾‾‾‾
# _______
# |O|X|X|
# | |O|X|
# |O| |X|
# ‾‾‾‾‾‾‾
# _______
# |X|X|O|
# |X|O|X|
# |X|O|O|
# ‾‾‾‾‾‾‾
# _______
# | |X|X|
# |O| |X|
# |O|O|X|
# ‾‾‾‾‾‾‾
# _______
# | |O|X|
# |X|O|O|
# |X|O|X|
# ‾‾‾‾‾‾‾
# _______
# |X|X|O|
# |O|X|X|
# |O|O|X|
# ‾‾‾‾‾‾‾
# _______
# | |O|X|
# | |X|X|
# |X|O|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|O|
# | |O|X|
# |O|X|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|O|
# |X|X|X|
# |O|X|O|
# ‾‾‾‾‾‾‾
# _______
# | |X|O|
# | |O|X|
# |O| |X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|X|
# |X|O|O|
# |X|X|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X| |
# |O| |X|
# |O| |X|
# ‾‾‾‾‾‾‾
# _______
# |X|O| |
# |X| |O|
# |X|X|O|
# ‾‾‾‾‾‾‾
# _______
# | |X|X|
# |O|O|X|
# | |O|X|
# ‾‾‾‾‾‾‾
# _______
# |X|X|O|
# |X|O|X|
# |X|O|O|
# ‾‾‾‾‾‾‾
# _______
# |X|X|X|
# |O|X|O|
# |O|O|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|O|
# |X|X|O|
# | |X|O|
# ‾‾‾‾‾‾‾
# _______
# |X|X|X|
# |O|X|O|
# |O|O|X|
# ‾‾‾‾‾‾‾
# _______
# | |O|X|
# |X|O|O|
# |X|O|X|
# ‾‾‾‾‾‾‾
# _______
# | |X|X|
# |O|O|X|
# |O| |X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|O|
# |X|O|X|
# |X|X|O|
# ‾‾‾‾‾‾‾
# _______
# | |X|O|
# |O|O|X|
# |O|X|X|
# ‾‾‾‾‾‾‾
# _______
# | |O| |
# | | |O|
# |X|X|X|
# ‾‾‾‾‾‾‾
# _______
# | |X|O|
# |O|O|X|
# |O|X|X|
# ‾‾‾‾‾‾‾
# _______
# |X|X|O|
# | |X|X|
# |O|O|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|O|
# |X|O|X|
# |X|O|X|
# ‾‾‾‾‾‾‾
# _______
# | |O|X|
# |X|X|X|
# | |O|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|O|
# |O|O|X|
# |X|X|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|X|
# |X|O|O|
# |X|X|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|X|
# |O|X|X|
# |X|O|O|
# ‾‾‾‾‾‾‾
# _______
# |X|X|O|
# |X|O|X|
# |X|O|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|X|
# | |O|X|
# | |O|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|O|
# |X|O|O|
# |X|X|X|
# ‾‾‾‾‾‾‾
# _______
# |O|X|X|
# |O|X|O|
# |X|O|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|X|
# |X|O|O|
# |O|X|X|
# ‾‾‾‾‾‾‾
# _______
# |O|X|O|
# |O|X|X|
# |X|O|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|X|
# | |X|O|
# | |O|X|
# ‾‾‾‾‾‾‾
# _______
# |O|X|X|
# | |X|X|
# |O|O|O|
# ‾‾‾‾‾‾‾
# _______
# |X|O|O|
# |X| |X|
# |X| |O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|O|
# |O|O|X|
# |X|X|X|
# ‾‾‾‾‾‾‾
# _______
# | |O|O|
# |X|X|O|
# |X|X|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|O|
# |O|O|X|
# |X|X|X|
# ‾‾‾‾‾‾‾
# _______
# |X|X|O|
# |X|O|X|
# |X|O|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|X|
# |X|X|O|
# |O|O|X|
# ‾‾‾‾‾‾‾
# _______
# |X|X|O|
# |X|O|X|
# |X|O|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X| |
# |O| |X|
# |O| |X|
# ‾‾‾‾‾‾‾
# _______
# |X|X|X|
# | |X|O|
# | |O|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|O|
# |O|X|X|
# |X|O|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|X|
# |X|O|O|
# |X|X|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|X|
# | |O|X|
# | |O|X|
# ‾‾‾‾‾‾‾
#   4%|▍         | 386/10000 [00:00<00:12, 752.06it/s]
# _______
# | |O| |
# |X|X|X|
# |X|O|O|
# ‾‾‾‾‾‾‾
# _______
# | |X|O|
# |O|X|O|
# | |X|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O| |
# | |X|O|
# | | |X|
# ‾‾‾‾‾‾‾
# _______
# | |X|X|
# | |O|X|
# |O|O|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|O|
# |X|X|O|
# | |X|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|O|
# |O|O|X|
# |X|X|X|
# ‾‾‾‾‾‾‾
# _______
# | |O| |
# | | |O|
# |X|X|X|
# ‾‾‾‾‾‾‾
# _______
# |O|X|X|
# | |O|X|
# |X|O|O|
# ‾‾‾‾‾‾‾
# _______
# | |O| |
# |X|X|X|
# |X|O|O|
# ‾‾‾‾‾‾‾
# _______
# | |X|O|
# |O|X|X|
# | |X|O|
# ‾‾‾‾‾‾‾
# _______
# |X|O|O|
# | |X|O|
# |X|X|O|
# ‾‾‾‾‾‾‾
# _______
# | |X|X|
# |O|O|X|
# | |O|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|X|
# |X|O|O|
# |X|X|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|O|
# | |O|X|
# |O|X|X|
# ‾‾‾‾‾‾‾
# _______
# | |O|X|
# | |X|O|
# |X|X|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|O|
# |X|O|X|
# |X|O|X|
# ‾‾‾‾‾‾‾
# _______
# | |O|X|
# |X|O|X|
# |X|O|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|X|
# |X|O|O|
# |O|X|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O| |
# | |X|O|
# | | |X|
# ‾‾‾‾‾‾‾
# _______
# |O|X|O|
# |X|O|X|
# |X|O|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|O|
# |X|O|X|
# |X|X|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|O|
# |X|O|X|
# |X|O|X|
# ‾‾‾‾‾‾‾
# _______
# | |X|O|
# | | |O|
# |X|X|O|
# ‾‾‾‾‾‾‾
# _______
# |X|X|O|
# |O|O|X|
# |X|O|X|
# ‾‾‾‾‾‾‾
# _______
# | |O|O|
# |X|X|O|
# |X|X|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|X|
# |O| |X|
# | |O|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O| |
# |X|X|O|
# |X| |O|
# ‾‾‾‾‾‾‾
# _______
# |O|X| |
# |O| |X|
# |O| |X|
# ‾‾‾‾‾‾‾
# _______
# | |O|X|
# |X|X|X|
# | |O|O|
# ‾‾‾‾‾‾‾
# _______
# | |X|X|
# |O|O|O|
# |O|X|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|X|
# |X|O|O|
# |X|X|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|O|
# |O| |X|
# |O|X|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|X|
# |X| |O|
# |X| |O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|O|
# |O| |X|
# |O|X|X|
# ‾‾‾‾‾‾‾
# _______
# | |O|X|
# |X|O|X|
# |X|O|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|O|
# |O|O|X|
# |X|X|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|O|
# | |X|O|
# |X|X|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|X|
# |X|O|O|
# |X|O|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|O|
# |X|X|O|
# | |X|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|O|
# |O| |X|
# |O|X|X|
# ‾‾‾‾‾‾‾
# _______
# | |O| |
# |X|X|X|
# | | |O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|X|
# |O|O|O|
# | |X|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O| |
# |X| |O|
# |X|O|X|
# ‾‾‾‾‾‾‾
# _______
# |O|X|X|
# |O|O|X|
# | |X|O|
# ‾‾‾‾‾‾‾
# _______
# | |O|X|
# |X|O|X|
# |X|O|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|X|
# |X|X|O|
# |O|O|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|X|
# |X|O|O|
# |X|X|O|
# ‾‾‾‾‾‾‾
# _______
# | |X|X|
# |O| |X|
# |O|O|X|
# ‾‾‾‾‾‾‾
# _______
# | |X|O|
# | | |O|
# |X|X|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|X|
# |X|X|O|
# |O|O|X|
# ‾‾‾‾‾‾‾
# _______
# | |O| |
# | | |O|
# |X|X|X|
# ‾‾‾‾‾‾‾
# _______
# |O|X|X|
# | |O|X|
# |O| |X|
# ‾‾‾‾‾‾‾
# _______
# | |O|O|
# |X|X|O|
# |X|X|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|X|
# |O| |X|
# | |O|X|
# ‾‾‾‾‾‾‾
# _______
# | |O| |
# |X|X|X|
# | | |O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|X|
# | |O|X|
# | | |O|
# ‾‾‾‾‾‾‾
# _______
# |X|X|O|
# |X| | |
# |X|O|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|X|
# |O| |O|
# |O|X|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|X|
# |X| |O|
# |X| |O|
# ‾‾‾‾‾‾‾
# _______
# | |X|X|
# |O|O|O|
# | | |X|
# ‾‾‾‾‾‾‾
# _______
# | |O|X|
# |X|O|X|
# |X|O|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|X|
# |O|X|O|
# |X|O|X|
# ‾‾‾‾‾‾‾
# _______
# | |O| |
# |X|X|X|
# | | |O|
# ‾‾‾‾‾‾‾
# _______
# | |X|X|
# |O| |X|
# |O|O|X|
# ‾‾‾‾‾‾‾
# _______
# | |O|X|
# | |X|O|
# |X|O|X|
# ‾‾‾‾‾‾‾
# _______
# |O|X|O|
# |X|X|X|
# |O|O|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|X|
# | |O|X|
# |X|O|O|
# ‾‾‾‾‾‾‾
# _______
# | |X|X|
# |O|O|X|
# | |O|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|X|
# | |X|O|
# |X| |O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|X|
# | |O|X|
# |O| |X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|X|
# |X|O|O|
# |X|X|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|O|
# |O|X|X|
# |X|O|X|
# ‾‾‾‾‾‾‾
# _______
# | |O|X|
# | |X| |
# |X| |O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|X|
# |X|O|O|
# |O|X|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|X|
# |X|X|O|
# |O|X|O|
# ‾‾‾‾‾‾‾
# _______
# | |X|X|
# |O|O|O|
# | | |X|
# ‾‾‾‾‾‾‾
# _______
# |X|O| |
# |X| |O|
# |X|X|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|X|
# |X|X|O|
# |O|O|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|X|
# |X|X|O|
# |O|X|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X| |
# |O| |X|
# |O| |X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|O|
# |X|X|O|
# | |X|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|X|
# |O|O|O|
# | |X|X|
# ‾‾‾‾‾‾‾
# _______
# | |X|O|
# | |X| |
# | |X|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|X|
# | |O|X|
# |X|O|O|
# ‾‾‾‾‾‾‾
# _______
# | |O| |
# |X|X|X|
# |X|O|O|
# ‾‾‾‾‾‾‾
# _______
# | |X|X|
# |O|O|O|
# |X|O|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|X|
# |X|X|O|
# |O|X|O|
# ‾‾‾‾‾‾‾
# _______
# | |X|X|
# | |O|X|
# |O|O|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|X|
# |X|O|X|
# | |O|O|
# ‾‾‾‾‾‾‾
# _______
# |X|X|X|
# |O|X|O|
# |O|O|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|O|
# | |X|O|
# | |X|X|
# ‾‾‾‾‾‾‾
# _______
# | |X|X|
# |O| |X|
# |O|O|X|
# ‾‾‾‾‾‾‾
# _______
# | |O|X|
# |X|X|X|
# | |O|O|
# ‾‾‾‾‾‾‾
# _______
# | |X|X|
# |O|O|X|
# |O| |X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|X|
# |X|X|O|
# |O|X|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|O|
# |X|O|X|
# |X|O|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|O|
# |X|X|O|
# |X|O|X|
# ‾‾‾‾‾‾‾
# _______
# |O|X|X|
# |O|O|X|
# | | |X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|X|
# |X|O|O|
# |X|X|O|
# ‾‾‾‾‾‾‾
# _______
# | |X|X|
# |O|O|X|
# |O| |X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|O|
# |X|X|O|
# | |X|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|X|
# | | |X|
# |O|O|X|
# ‾‾‾‾‾‾‾
# _______
# | |O|O|
# |X|X|O|
# |X|X|O|
# ‾‾‾‾‾‾‾
# _______
# | |X|X|
# |O| |X|
# |O|O|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|O|
# |X|X|O|
# | |X|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|O|
# |X|X|X|
# |O|O|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|X|
# |X|X|O|
# |O|O|X|
# ‾‾‾‾‾‾‾
# _______
# |O|X|O|
# |O|O|X|
# |X|X|X|
# ‾‾‾‾‾‾‾
# _______
# |X|X|X|
# |O|O|X|
# |X|O|O|
# ‾‾‾‾‾‾‾
# _______
# | |X|X|
# |O|O|O|
# |O|X|X|
# ‾‾‾‾‾‾‾
# _______
# |X|X|O|
# |X|O|X|
# |X|O|O|
# ‾‾‾‾‾‾‾
# _______
# | |X|X|
# |O|O|X|
# | |O|X|
# ‾‾‾‾‾‾‾
# _______
# | |O|X|
# | |X|O|
# |X|O|X|
# ‾‾‾‾‾‾‾
# _______
# |O|X|X|
# |X|X|O|
# |O|O|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|X|
# |X|X|O|
# |O|X|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|X|
# |O| |X|
# | |O|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|X|
# |X|X|O|
# |O|X|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|O|
# | |O|X|
# |O|X|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|X|
# |X|O|O|
# |X|X|O|
# ‾‾‾‾‾‾‾
# _______
# |X|X|O|
# |O|X|X|
# |O|O|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O| |
# |X| |O|
# |X|X|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|O|
# |O|O|X|
# |X|X|X|
# ‾‾‾‾‾‾‾
# _______
# | |O|O|
# |X|X|O|
# |X|X|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|X|
# | |O|X|
# |O|X|O|
# ‾‾‾‾‾‾‾
# _______
# |X|X|O|
# |X|O|O|
# |X|O|X|
# ‾‾‾‾‾‾‾
# _______
# |O|X|X|
# |O|O|X|
# | | |X|
# ‾‾‾‾‾‾‾
# _______
# |X|O| |
# |X| |X|
# |X|O|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|X|
# |O| |X|
# |O|X|O|
# ‾‾‾‾‾‾‾
# _______
# |X|X|X|
# |X| |O|
# | |O|O|
# ‾‾‾‾‾‾‾
# _______
# | |X|X|
# |O|O|O|
# |O|X|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|X|
# | |O|X|
# |X|O|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|O|
# | |X|O|
# | |X|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O| |
# | |X|O|
# |X|O|X|
# ‾‾‾‾‾‾‾
# _______
# | |X|X|
# |O| |X|
# |O|O|X|
# ‾‾‾‾‾‾‾
# _______
# | |O|X|
# |X|O|O|
# |X|O|X|
# ‾‾‾‾‾‾‾
# _______
# | |X|X|
# |O|X|X|
# |O|O|O|
# ‾‾‾‾‾‾‾
# _______
# |X|O| |
# |X| |O|
# |X|O|X|
# ‾‾‾‾‾‾‾
# _______
# | |X|O|
# |O|O|X|
# |O|X|X|
# ‾‾‾‾‾‾‾
# _______
# |X|X|X|
# |X|O|O|
# |X|O|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|X|
# | |O|X|
# | |O|X|
# ‾‾‾‾‾‾‾
# _______
# | |O|X|
# |X|X|X|
# | |O|O|
# ‾‾‾‾‾‾‾
# _______
# | |X|O|
# | |O|X|
# |O| |X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|X|
# |X|X|O|
# |O|X|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|X|
# |X|X|O|
# |O|O|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|X|
# | |O|O|
# |X|O|X|
# ‾‾‾‾‾‾‾
# _______
# |O|X|X|
# | |O|X|
# |O| |X|
# ‾‾‾‾‾‾‾
# _______
# |X|X|O|
# | |X|O|
# |X|O|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|X|
# |O| |O|
# |O|X|X|
# ‾‾‾‾‾‾‾
# _______
# |O|X|O|
# |X|X|X|
# |X|O|O|
# ‾‾‾‾‾‾‾
# _______
# | |X|O|
# | |X|O|
# |O|X|X|
# ‾‾‾‾‾‾‾
# _______
# |X|X|O|
# |O|X|O|
# |X|O|X|
# ‾‾‾‾‾‾‾
# _______
# |O|X|X|
# | |O|X|
# | |O|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|O|
# |X|X|O|
# | |X|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|O|
# |O|O|X|
# |X|X|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|X|
# |X|O|O|
# |O|X|X|
# ‾‾‾‾‾‾‾
# _______
# |O|X|O|
# | |O|X|
# |O|X|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|X|
# |X|X|O|
# |O|X|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X| |
# |O| |X|
# |O| |X|
# ‾‾‾‾‾‾‾
# _______
# | |X|X|
# |X|X|O|
# |O|O|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|O|
# |X|O|X|
# |X|O|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O| |
# |X|X|O|
# |X| |O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|X|
# | | |X|
# |O|O|X|
# ‾‾‾‾‾‾‾
#   5%|▌         | 544/10000 [00:00<00:12, 767.21it/s]
# _______
# |X|X|X|
# | | |O|
# |X|O|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|X|
# |O|O|X|
# | | |X|
# ‾‾‾‾‾‾‾
# _______
# | |O|X|
# | |X|O|
# |X|O|X|
# ‾‾‾‾‾‾‾
# _______
# | |X|X|
# |O| |X|
# |O|O|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|O|
# |X|X|O|
# | |X|O|
# ‾‾‾‾‾‾‾
# _______
# | |X|O|
# |O|O|X|
# |O|X|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|X|
# |X|O|O|
# |X|X|O|
# ‾‾‾‾‾‾‾
# _______
# | |X|O|
# | |O|X|
# |O| |X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|X|
# | |O|X|
# |X|O|O|
# ‾‾‾‾‾‾‾
# _______
# | |X|X|
# |O| |X|
# |O|O|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O| |
# |X| |O|
# |X|O|X|
# ‾‾‾‾‾‾‾
# _______
# |O|X|X|
# |O|O|X|
# | | |X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|X|
# |X|X|O|
# |O|O|X|
# ‾‾‾‾‾‾‾
# _______
# |X|X|O|
# |O|O|X|
# |X|X|O|
# ‾‾‾‾‾‾‾
# _______
# | |X|X|
# |X|O|X|
# |O|O|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|O|
# |O|O|X|
# |X|X|X|
# ‾‾‾‾‾‾‾
# _______
# | |O|O|
# |X|X|O|
# |X|X|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|X|
# |X|O|O|
# |O|X|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|O|
# |X|O|O|
# |X|X|X|
# ‾‾‾‾‾‾‾
# _______
# | |X|O|
# |O|X|O|
# | |X|X|
# ‾‾‾‾‾‾‾
# _______
# | |X|X|
# |X|X|O|
# |O|O|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|X|
# | | |X|
# |O|O|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|X|
# |X|X|O|
# |O|O|X|
# ‾‾‾‾‾‾‾
# _______
# |O|X|O|
# |O| |X|
# |O|X|X|
# ‾‾‾‾‾‾‾
# _______
# |X|X|X|
# | | |O|
# |X|O|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|O|
# |O|X|X|
# |X|O|X|
# ‾‾‾‾‾‾‾
# _______
# | |O|X|
# |X|O|X|
# |X|O|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|O|
# |X|X|X|
# |O|O|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|X|
# |X|O|O|
# |X|X|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|O|
# |O|O|X|
# |X|X|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|X|
# | |O|O|
# |X|O|X|
# ‾‾‾‾‾‾‾
# _______
# | |X|X|
# |O| |X|
# |O|O|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|O|
# |X|X|X|
# |O|X|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|X|
# |X|O|O|
# |O|X|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|X|
# |X|X|O|
# |X|O|O|
# ‾‾‾‾‾‾‾
# _______
# | |X|O|
# |O|X|O|
# | |X|X|
# ‾‾‾‾‾‾‾
# _______
# | |X|O|
# |X|X|X|
# | |O|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|O|
# |X|X|X|
# |O|O|X|
# ‾‾‾‾‾‾‾
# _______
# | |O|X|
# |X|O|X|
# |X|O|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|X|
# |X|O|O|
# |O|X|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|X|
# |X|O|O|
# |X|X|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|O|
# |O| |X|
# |O|X|X|
# ‾‾‾‾‾‾‾
# _______
# |X|X|X|
# |X|O|O|
# |X|O|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|O|
# |O|O|X|
# |X|X|X|
# ‾‾‾‾‾‾‾
# _______
# |X|X|O|
# |X|O|X|
# |X|O|O|
# ‾‾‾‾‾‾‾
# _______
# |X|X|O|
# |O|O|X|
# |X|O|X|
# ‾‾‾‾‾‾‾
# _______
# |X|X| |
# |X| |O|
# |X|O|O|
# ‾‾‾‾‾‾‾
# _______
# | |X|X|
# | |O|X|
# |O|O|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|X|
# |X|X|O|
# |O|X|O|
# ‾‾‾‾‾‾‾
# _______
# | |X|X|
# |O|O|O|
# |X|O|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|O|
# |X|O|X|
# |X|X|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|O|
# |O|X|X|
# |X|O|X|
# ‾‾‾‾‾‾‾
# _______
# | |O|X|
# | |X|O|
# |X|X|O|
# ‾‾‾‾‾‾‾
# _______
# | |X|X|
# | |O|X|
# |O|O|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O| |
# |X|X|O|
# | |O|X|
# ‾‾‾‾‾‾‾
# _______
# |X|X|O|
# |O|X|X|
# |O|O|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|X|
# |X|O|O|
# |X|X|O|
# ‾‾‾‾‾‾‾
# _______
# |X|X|O|
# |O|X|X|
# |O|O|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O| |
# |X| |X|
# |X|O|O|
# ‾‾‾‾‾‾‾
# _______
# | |X|X|
# |O| |X|
# |O|O|X|
# ‾‾‾‾‾‾‾
# _______
# | |O|X|
# |X|X|O|
# |X| |O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|X|
# | |O|X|
# |O| |X|
# ‾‾‾‾‾‾‾
# _______
# |O|O|X|
# | |O|X|
# |X|X|O|
# ‾‾‾‾‾‾‾
# _______
# | |X|O|
# |O|O|X|
# |O|X|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O| |
# |X| |O|
# |X|O|X|
# ‾‾‾‾‾‾‾
# _______
# |X|X|O|
# |O|X|X|
# |O|O|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|X|
# |X|O|O|
# |X|X|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|O|
# |O| |X|
# |O|X|X|
# ‾‾‾‾‾‾‾
# _______
# |X|X|X|
# |X| |O|
# | |O|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|X|
# |O|O|X|
# | |X|O|
# ‾‾‾‾‾‾‾
# _______
# |X|O| |
# | |X|O|
# | | |X|
# ‾‾‾‾‾‾‾
# _______
# |O|X|X|
# |X|O|O|
# |O|X|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|X|
# |X|O|X|
# |O|X|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|X|
# | |O|X|
# |O| |X|
# ‾‾‾‾‾‾‾
# _______
# |X|X|O|
# |X|O|X|
# |X|O|O|
# ‾‾‾‾‾‾‾
# _______
# | |X|O|
# | |X|X|
# |O|X|O|
# ‾‾‾‾‾‾‾
# _______
# |X|O|X|
# |X|O|O|
# |X|X|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|X|
# | |O|X|
# | |O|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|X|
# |X|X|O|
# |X|O|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|X|
# |O|O|X|
# | | |X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|X|
# | |O|O|
# |X|O|X|
# ‾‾‾‾‾‾‾
# _______
# |O|X|X|
# |O| |O|
# |O|X|X|
# ‾‾‾‾‾‾‾
# _______
# | |O|X|
# | |X|O|
# |X| | |
# ‾‾‾‾‾‾‾
# _______
# | |X|O|
# | |O|O|
# |X|X|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|X|
# |X|O|X|
# | |O|O|
# ‾‾‾‾‾‾‾
# _______
# |X|X|X|
# |O|X|O|
# |O|O|X|
# ‾‾‾‾‾‾‾
# _______
# | |O|O|
# |X|X|X|
# |X| |O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|X|
# | |O|X|
# | | |O|
# ‾‾‾‾‾‾‾
# _______
# |X|X|X|
# | | |O|
# | | |O|
# ‾‾‾‾‾‾‾
# _______
# |X|X|O|
# |O|X|X|
# |O|O|X|
# ‾‾‾‾‾‾‾
# _______
# |X|X|X|
# |X|O|O|
# |O|O|X|
# ‾‾‾‾‾‾‾
# _______
# | |X|O|
# | |X|X|
# |O|X|O|
# ‾‾‾‾‾‾‾
# _______
# |X|O|O|
# | |X|O|
# | |X|X|
# ‾‾‾‾‾‾‾
# _______
# | |X|X|
# |O|O|X|
# | |O|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|X|
# |X| |O|
# |X| |O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|X|
# |O| |O|
# |O|X|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O| |
# | |X|O|
# | | |X|
# ‾‾‾‾‾‾‾
# _______
# |O|X|O|
# |O|X|X|
# |X|O|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|O|
# | |X|O|
# |X|X|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|X|
# |O|O|X|
# | |X|O|
# ‾‾‾‾‾‾‾
# _______
# | |O|O|
# |X|X|O|
# |X|X|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|O|
# |O| |X|
# |O|X|X|
# ‾‾‾‾‾‾‾
# _______
# | |O|X|
# | |X|O|
# |X|O|X|
# ‾‾‾‾‾‾‾
# _______
# | |X|X|
# | |O|X|
# |O|O|X|
# ‾‾‾‾‾‾‾
# _______
# | |O|X|
# |X|O|X|
# |X|O|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|O|
# | |O|X|
# |O|X|X|
# ‾‾‾‾‾‾‾
# _______
# |X|X|O|
# | |X|O|
# |X|O|O|
# ‾‾‾‾‾‾‾
# _______
# | |X|O|
# |O|X|X|
# | |X|O|
# ‾‾‾‾‾‾‾
# _______
# |X|O|X|
# |X|X|O|
# |X|O|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|X|
# |O|X|X|
# |X|O|O|
# ‾‾‾‾‾‾‾
# _______
# |X|X|O|
# |X|O|X|
# |X|O|O|
# ‾‾‾‾‾‾‾
# _______
# | |X|X|
# | |O|X|
# |O|O|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|X|
# |X|O|X|
# | |O|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|X|
# | |O|X|
# | |O|X|
# ‾‾‾‾‾‾‾
# _______
# |X|X|O|
# | |X|O|
# | |O|X|
# ‾‾‾‾‾‾‾
# _______
# |O|X|X|
# |O| |O|
# |O|X|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|O|
# |O|X|X|
# |X|X|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X| |
# |O| |X|
# |O| |X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|O|
# |X|X|O|
# |O|X|X|
# ‾‾‾‾‾‾‾
# _______
# | |X|X|
# |O| |X|
# |O|O|X|
# ‾‾‾‾‾‾‾
# _______
# |X|X|O|
# | |X|O|
# |X|O|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|O|
# |O| |X|
# |O|X|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|X|
# |X|O|X|
# | |O|O|
# ‾‾‾‾‾‾‾
# _______
# | |X|X|
# |O| |X|
# |O|O|X|
# ‾‾‾‾‾‾‾
# _______
# | |X|O|
# |X|O|X|
# |O|X|O|
# ‾‾‾‾‾‾‾
# _______
# |X|X|X|
# |O|X|O|
# |O|O|X|
# ‾‾‾‾‾‾‾
# _______
# |X|X|X|
# |X|O|O|
# |X|O|O|
# ‾‾‾‾‾‾‾
# _______
# | |X|X|
# |O|O|X|
# | |O|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|O|
# | | |O|
# |X|X|X|
# ‾‾‾‾‾‾‾
# _______
# | |X|X|
# | |O|X|
# |O|O|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O| |
# |X| |X|
# |X|O|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|O|
# |O|X|X|
# |X|O|X|
# ‾‾‾‾‾‾‾
# _______
# |X|X|O|
# |X|X|O|
# | |O|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|X|
# |O|O|X|
# | | |X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|O|
# |X|X|O|
# | |X|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X| |
# |O| |X|
# |O| |X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|O|
# |X|O|X|
# |X|X|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|X|
# | |O|X|
# | |O|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|X|
# |X|O|O|
# |O|X|X|
# ‾‾‾‾‾‾‾
# _______
# |O|X|X|
# | |O|X|
# |O| |X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|X|
# |X| |O|
# |X| |O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|O|
# |O|O|X|
# |X|X|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|X|
# |X|O|O|
# |X|X|O|
# ‾‾‾‾‾‾‾
# _______
# |X|X|X|
# |O|X|O|
# |O|O|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|X|
# |X|O|O|
# |X|X|O|
# ‾‾‾‾‾‾‾
# _______
# | |X|X|
# |O|O|O|
# | | |X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|O|
# |X|O|O|
# |X|X|X|
# ‾‾‾‾‾‾‾
# _______
# | |X|X|
# |O|O|X|
# |O| |X|
# ‾‾‾‾‾‾‾
# _______
# |X|X|O|
# | |X|X|
# |O|O|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|X|
# |O| |X|
# |O|X|O|
# ‾‾‾‾‾‾‾
# _______
# |X|O| |
# |X| |X|
# |X|O|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|X|
# | |X|X|
# |O|O|O|
# ‾‾‾‾‾‾‾
# _______
# |X|O|X|
# |X|O|O|
# |X|X|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|X|
# |O| |X|
# | |O|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O| |
# |X| |O|
# |X|O|X|
# ‾‾‾‾‾‾‾
# _______
# |X|X|X|
# |O|X|O|
# |O|O|X|
# ‾‾‾‾‾‾‾
# _______
# |X|X|X|
# |X|O|O|
# |X|O|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|X|
# |O|X|X|
# |X|O|O|
# ‾‾‾‾‾‾‾
# _______
# | |O|O|
# |X|X|O|
# |X|X|O|
# ‾‾‾‾‾‾‾
#   7%|▋         | 703/10000 [00:00<00:11, 778.27it/s]
# _______
# |X|X|O|
# |O|X|X|
# |O|O|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|X|
# |X|X|O|
# |O|O|X|
# ‾‾‾‾‾‾‾
# _______
# | |X|X|
# |O|O|O|
# |O|X|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|X|
# |X|X|O|
# |X|O|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|X|
# | |O|X|
# | |O|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|O|
# |X|X|O|
# | |X|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|X|
# |X|O|O|
# |O|X|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|O|
# |X|X|X|
# |X|O|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|X|
# |X|O|O|
# |O|X|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|O|
# | |X|O|
# |X|X|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|O|
# |O|O|X|
# |X|X|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|X|
# |X|O|X|
# | |O|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X| |
# |O| |X|
# |O| |X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|O|
# |X|X|O|
# |X|O|X|
# ‾‾‾‾‾‾‾
# _______
# |O|X|X|
# | |O|X|
# |O| |X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|O|
# |X|X|O|
# |O|X|X|
# ‾‾‾‾‾‾‾
# _______
# |O|X|X|
# |O| |O|
# |O|X|X|
# ‾‾‾‾‾‾‾
# _______
# |X|X|O|
# |X|O|O|
# |X|O|X|
# ‾‾‾‾‾‾‾
# _______
# |O|X|X|
# |O| |X|
# |O|X|O|
# ‾‾‾‾‾‾‾
# _______
# |X|O|X|
# |X|O|O|
# |X|X|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X| |
# |O| |X|
# |O| |X|
# ‾‾‾‾‾‾‾
# _______
# |X|X|X|
# | |O|O|
# | |X|O|
# ‾‾‾‾‾‾‾
# _______
# |X|X|O|
# |O|O|X|
# |X|O|X|
# ‾‾‾‾‾‾‾
# _______
# | |O|X|
# |X|X|O|
# |X| |O|
# ‾‾‾‾‾‾‾
# _______
# | |X|X|
# |O|O|O|
# | | |X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|X|
# |X| |O|
# |X| |O|
# ‾‾‾‾‾‾‾
# _______
# | |X|X|
# |O|O|X|
# | |O|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|X|
# |X|O|O|
# | |O|X|
# ‾‾‾‾‾‾‾
# _______
# |O|X|O|
# |O| |X|
# |O|X|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|X|
# | |X|O|
# |X| |O|
# ‾‾‾‾‾‾‾
# _______
# |O|X| |
# |O| |X|
# |O| |X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|X|
# |X|O|O|
# |X|X|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|X|
# | | |X|
# |O|O|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|X|
# |X|O|O|
# |X|X|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|O|
# |X|X|X|
# |O|O|X|
# ‾‾‾‾‾‾‾
# _______
# | |O|X|
# |X|O|X|
# |X|O|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|O|
# | |X|O|
# | |X|X|
# ‾‾‾‾‾‾‾
# _______
# | |O|O|
# |X|X|O|
# |X|X|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|X|
# | | |X|
# |O|O|X|
# ‾‾‾‾‾‾‾
# _______
# |X|X|X|
# |X| |O|
# | |O|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|O|
# |O| |X|
# |O|X|X|
# ‾‾‾‾‾‾‾
# _______
# | |O|O|
# |X|X|X|
# | |X|O|
# ‾‾‾‾‾‾‾
# _______
# | |X|O|
# | |O|X|
# |O| |X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|O|
# |X| |X|
# |X| |O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|O|
# |X|O|X|
# |X|O|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|X|
# | |X|O|
# |X| |O|
# ‾‾‾‾‾‾‾
# _______
# | |X|X|
# |O|O|O|
# | | |X|
# ‾‾‾‾‾‾‾
# _______
# |X|X|O|
# |X|O|O|
# |X|O|X|
# ‾‾‾‾‾‾‾
# _______
# | |X|O|
# |O|O|X|
# |O|X|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|X|
# |X|O|O|
# | |O|X|
# ‾‾‾‾‾‾‾
# _______
# |O|X|X|
# |O| |X|
# | |O|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|X|
# |X|X|O|
# |O|X|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|X|
# |O|X|O|
# |X|O|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|X|
# |X|O|O|
# |X|X|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|O|
# | |O|X|
# |O|X|X|
# ‾‾‾‾‾‾‾
# _______
# |X|X|O|
# |X|O|O|
# |X|O|X|
# ‾‾‾‾‾‾‾
# _______
# |O|X|X|
# |O| |O|
# |O|X|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O| |
# |X| |O|
# |X|O|X|
# ‾‾‾‾‾‾‾
# _______
# |X|X|X|
# |O|O|X|
# |O|X|O|
# ‾‾‾‾‾‾‾
# _______
# |X|O|X|
# |X|O|O|
# |X|X|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|O|
# |O| |X|
# |O|X|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|O|
# |X|X|O|
# |O|X|X|
# ‾‾‾‾‾‾‾
# _______
# | |X|X|
# |O|O|X|
# | |O|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|X|
# |X|O|X|
# |O|X|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|O|
# |O|X|X|
# |X|O|X|
# ‾‾‾‾‾‾‾
# _______
# |X|X|X|
# | | |O|
# |X|O|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|O|
# | |O|X|
# |O|X|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|X|
# |X|X|O|
# |O|X|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|X|
# |O|X|O|
# |X|O|X|
# ‾‾‾‾‾‾‾
# _______
# | |O|O|
# |X|X|X|
# |X| |O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|X|
# |X|X|O|
# |O|O|X|
# ‾‾‾‾‾‾‾
# _______
# | |O|X|
# |X|X|O|
# |X| |O|
# ‾‾‾‾‾‾‾
# _______
# | |X|X|
# |O| |X|
# |O|O|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|X|
# |X|X|O|
# |O|X|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|X|
# | |O|X|
# | | |O|
# ‾‾‾‾‾‾‾
# _______
# |X|O|X|
# |X|O|O|
# |X|X|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|O|
# |O| |X|
# |O|X|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|X|
# |X|O|O|
# |O|X|X|
# ‾‾‾‾‾‾‾
# _______
# |O|X|X|
# | |O|X|
# | |O|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|X|
# |X|O|X|
# |O|X|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|O|
# |X|O|X|
# |X|O|X|
# ‾‾‾‾‾‾‾
# _______
# | |O|X|
# | |X|X|
# |X|O|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|X|
# | |O|X|
# |O| |X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|O|
# |X|X|X|
# | | |O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|X|
# |O|O|X|
# | | |X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|X|
# |X|X|O|
# |O|X|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|O|
# |O|O|X|
# |X|X|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|O|
# |X|X|O|
# | |X|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|X|
# |O| |X|
# | |O|X|
# ‾‾‾‾‾‾‾
# _______
# |X|X|X|
# | |X|O|
# | |O|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|X|
# | | |X|
# |O|O|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O| |
# |X|X|O|
# |X| |O|
# ‾‾‾‾‾‾‾
# _______
# |O|X| |
# |O| |X|
# |O| |X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|X|
# |X|O|X|
# |O|X|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|O|
# |O|X|X|
# |X|O|X|
# ‾‾‾‾‾‾‾
# _______
# | |X|O|
# | |X| |
# | |X|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|O|
# | |O|X|
# |O|X|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|O|
# | | |O|
# |X|X|X|
# ‾‾‾‾‾‾‾
# _______
# | |X|O|
# |O|O|X|
# |O|X|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|O|
# |O|X|X|
# |X|X|O|
# ‾‾‾‾‾‾‾
# _______
# | |X|X|
# |O|O|O|
# |O|X|X|
# ‾‾‾‾‾‾‾
# _______
# | |O|X|
# | |X| |
# |X| |O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|X|
# |O| |X|
# | |O|X|
# ‾‾‾‾‾‾‾
# _______
# |X|X|O|
# |X| | |
# |X|O|O|
# ‾‾‾‾‾‾‾
# _______
# | |X|X|
# |O|O|X|
# |O| |X|
# ‾‾‾‾‾‾‾
# _______
# | |O|X|
# | |X|O|
# |X|X|O|
# ‾‾‾‾‾‾‾
# _______
# |X|X|X|
# |O|O|X|
# |O|X|O|
# ‾‾‾‾‾‾‾
# _______
# | |O|O|
# |X|X|O|
# |X|X|O|
# ‾‾‾‾‾‾‾
# _______
# | |X|X|
# |O| |X|
# |O|O|X|
# ‾‾‾‾‾‾‾
# _______
# | |X|O|
# |X|X|O|
# |X|O|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|O|
# |O|O|X|
# |X|X|X|
# ‾‾‾‾‾‾‾
# _______
# | |O| |
# |X|X|X|
# | | |O|
# ‾‾‾‾‾‾‾
# _______
# | |X|X|
# |O|O|O|
# |O|X|X|
# ‾‾‾‾‾‾‾
# _______
# | |O|X|
# | |X|O|
# |X| | |
# ‾‾‾‾‾‾‾
# _______
# |O|X|O|
# |O| |X|
# |O|X|X|
# ‾‾‾‾‾‾‾
# _______
# |X|X|O|
# |X|O|O|
# |X|O|X|
# ‾‾‾‾‾‾‾
# _______
# |O|X|X|
# |O|O|X|
# | | |X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|X|
# |X|O|O|
# |X|X|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|X|
# |X|O|O|
# |O|X|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|X|
# |X|X|O|
# |O|X|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|X|
# | | |X|
# |O|O|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O| |
# |X|X|O|
# |X| |O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|X|
# | |O|X|
# | | |O|
# ‾‾‾‾‾‾‾
# _______
# |X|O|X|
# |X|O|O|
# | |O|X|
# ‾‾‾‾‾‾‾
# _______
# |O|X|X|
# | |O|X|
# | |O|X|
# ‾‾‾‾‾‾‾
# _______
# |X|X|O|
# |X|O|X|
# |X|O|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|X|
# |O|O|X|
# | |X|O|
# ‾‾‾‾‾‾‾
# _______
# |X|O| |
# |X| |O|
# |X|O|X|
# ‾‾‾‾‾‾‾
# _______
# | |X|O|
# | |O|X|
# |O| |X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|O|
# |X|X|O|
# |X|O|X|
# ‾‾‾‾‾‾‾
# _______
# | |X|X|
# |O|O|X|
# |O| |X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|X|
# |X|O|O|
# |X|X|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|X|
# |O| |X|
# |O|X|O|
# ‾‾‾‾‾‾‾
# _______
# |X|X|O|
# |X|O|X|
# |X|O|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|O|
# | |O|X|
# |O|X|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|X|
# |X|X|O|
# |O|O|X|
# ‾‾‾‾‾‾‾
# _______
# | |X|O|
# | |X|O|
# |O|X|X|
# ‾‾‾‾‾‾‾
# _______
# | |O|X|
# |X|X|X|
# | |O|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|X|
# |O| |O|
# |O|X|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|O|
# | |X|O|
# |X|X|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|X|
# | |O|X|
# |O|X|O|
# ‾‾‾‾‾‾‾
# _______
# |X|O|X|
# |X|O|O|
# |X|X|O|
# ‾‾‾‾‾‾‾
# _______
# | |X|X|
# | |O|X|
# |O|O|X|
# ‾‾‾‾‾‾‾
# _______
# | |O|X|
# |X|X|X|
# | |O|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|O|
# | |O|X|
# |O|X|X|
# ‾‾‾‾‾‾‾
# _______
# | |O|X|
# | |X| |
# |X| |O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|X|
# | |O|X|
# |O| |X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|X|
# |X|O|O|
# | |O|X|
# ‾‾‾‾‾‾‾
# _______
# |O|X|X|
# | | |X|
# |O|O|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|X|
# |X|X|O|
# |O|X|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|X|
# |O|O|X|
# | |X|O|
# ‾‾‾‾‾‾‾
# _______
# |O|O|O|
# | |X|X|
# |X|X|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X| |
# |O| |X|
# |O| |X|
# ‾‾‾‾‾‾‾
# _______
# | |X|O|
# |X|X|O|
# |X|O|O|
# ‾‾‾‾‾‾‾
# _______
# | |X|X|
# |O|O|X|
# |O| |X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|O|
# |X|O|X|
# |X|X|O|
# ‾‾‾‾‾‾‾
# _______
# | |X|X|
# |O| |X|
# |O|O|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|O|
# |X|X|X|
# |O|X|O|
# ‾‾‾‾‾‾‾
# _______
# | |X|X|
# |O|O|O|
# | | |X|
# ‾‾‾‾‾‾‾
# _______
# | |O| |
# |X|X|X|
# |X|O|O|
# ‾‾‾‾‾‾‾
# _______
# | |X|X|
# |O|O|O|
# |O|X|X|
# ‾‾‾‾‾‾‾
# _______
# | |X|O|
# | |X| |
# | |X|O|
# ‾‾‾‾‾‾‾
#   9%|▊         | 867/10000 [00:01<00:11, 789.20it/s]
# _______
# |O|X|X|
# | |O|X|
# | |O|X|
# ‾‾‾‾‾‾‾
# _______
# | |O|X|
# |X|O|X|
# |X|O|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|X|
# |O| |X|
# | |O|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O| |
# |X|X|X|
# | |O|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|O|
# |O| |X|
# |O|X|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|X|
# |X|X|O|
# |O|X|O|
# ‾‾‾‾‾‾‾
# _______
# |X|X|X|
# |O|X|O|
# |O|O|X|
# ‾‾‾‾‾‾‾
# _______
# | |O| |
# | | |O|
# |X|X|X|
# ‾‾‾‾‾‾‾
# _______
# |X|X|O|
# |O|O|X|
# |X|O|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|X|
# |X|O|X|
# | |O|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|X|
# |O|O|O|
# | |X|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|X|
# | |X|O|
# |X| |O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|X|
# |O| |X|
# | |O|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O| |
# |X| |X|
# |X|O|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|X|
# |O|O|O|
# | |X|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|O|
# |X|X|O|
# |O|X|X|
# ‾‾‾‾‾‾‾
# _______
# |O|X|X|
# |O|O|X|
# | | |X|
# ‾‾‾‾‾‾‾
# _______
# |X|O| |
# |X|X|O|
# | |O|X|
# ‾‾‾‾‾‾‾
# _______
# |X|X|O|
# |O|O|X|
# |X|X|O|
# ‾‾‾‾‾‾‾
# _______
# |X|O|X|
# |X|X|O|
# |O|X|O|
# ‾‾‾‾‾‾‾
# _______
# | |X|O|
# | |X|O|
# |O|X|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|X|
# |X|O|X|
# |O|X|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|X|
# |X|O|O|
# |O|X|X|
# ‾‾‾‾‾‾‾
# _______
# | |O| |
# |X|X|X|
# | | |O|
# ‾‾‾‾‾‾‾
# _______
# | |X|O|
# |O|X|O|
# | |X|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|X|
# |X| |O|
# |X| |O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|O|
# | |X|O|
# | |X|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|X|
# |X|O|O|
# |X|X|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|X|
# |X|O|O|
# |O|X|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|O|
# |X|O|X|
# |X|X|O|
# ‾‾‾‾‾‾‾
# _______
# |X|X|X|
# |O|X|O|
# |O|O|X|
# ‾‾‾‾‾‾‾
# _______
# | |X|O|
# |X|X|O|
# |X|O|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|O|
# | |O|X|
# |O|X|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|X|
# |X|X|O|
# |O|X|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|O|
# |X|O|X|
# |X|O|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|O|
# | |X|O|
# |X|X|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|X|
# |X|O|O|
# |X|O|X|
# ‾‾‾‾‾‾‾
# _______
# | |O|O|
# |X|X|X|
# | |X|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|O|
# | |O|X|
# |O|X|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|X|
# | |X|X|
# |O|O|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|O|
# |O|O|X|
# |X|X|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|X|
# |X|O|X|
# | |O|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|X|
# |O|O|X|
# | | |X|
# ‾‾‾‾‾‾‾
# _______
# | |O|X|
# | |X|X|
# |X|O|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|X|
# | |O|X|
# |O| |X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|O|
# |X|X|O|
# |O|X|X|
# ‾‾‾‾‾‾‾
# _______
# |X|X|X|
# |O|X|O|
# |O|O|X|
# ‾‾‾‾‾‾‾
# _______
# | |O|X|
# | |X|O|
# |X|O|X|
# ‾‾‾‾‾‾‾
# _______
# |O|X|X|
# |X|O|O|
# |O|X|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|X|
# |X|X|O|
# |O|X|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|X|
# | |X|X|
# |O|O|O|
# ‾‾‾‾‾‾‾
# _______
# | |O|O|
# |X|X|X|
# | |X|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|O|
# |O| |X|
# |O|X|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|X|
# |X|O|X|
# | |O|O|
# ‾‾‾‾‾‾‾
# _______
# |X|X|O|
# |O|X|X|
# |O|O|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|X|
# |X| |O|
# |X| |O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|O|
# |O|X|X|
# |X|O|X|
# ‾‾‾‾‾‾‾
# _______
# | |O|X|
# | |X|O|
# |X|O|X|
# ‾‾‾‾‾‾‾
# _______
# |O|X|X|
# |X|O|O|
# |O|X|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|O|
# |X|O|X|
# |X|X|O|
# ‾‾‾‾‾‾‾
# _______
# | |X|O|
# | |O|O|
# |X|X|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|O|
# |O|X|X|
# |X|X|O|
# ‾‾‾‾‾‾‾
# _______
# | |X|O|
# | |X|X|
# |O|X|O|
# ‾‾‾‾‾‾‾
# _______
# |X|O|X|
# |X|X|O|
# |O|X|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|X|
# |O|O|O|
# | |X|X|
# ‾‾‾‾‾‾‾
# _______
# |X|X|O|
# |X|O|X|
# |X|O|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|X|
# | |O|X|
# | |O|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|X|
# |X|X|O|
# |O|O|X|
# ‾‾‾‾‾‾‾
# _______
# |O|X|O|
# |O| |X|
# |O|X|X|
# ‾‾‾‾‾‾‾
# _______
# |O|O|O|
# | |X|X|
# |X|X|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|X|
# | |O|X|
# | |O|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|O|
# |X|O|O|
# |X|X|X|
# ‾‾‾‾‾‾‾
# _______
# |O|X|X|
# |X|X|O|
# |O|O|X|
# ‾‾‾‾‾‾‾
# _______
# |X|X|O|
# |O|O|X|
# |X|X|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|X|
# |O|O|X|
# | | |X|
# ‾‾‾‾‾‾‾
# _______
# |X|O| |
# |X| |O|
# |X|X|O|
# ‾‾‾‾‾‾‾
# _______
# |X|X|X|
# |O|O|X|
# |O|X|O|
# ‾‾‾‾‾‾‾
# _______
# |X|X|O|
# | |X|X|
# |O|O|O|
# ‾‾‾‾‾‾‾
# _______
# |X|X|X|
# |O|X|O|
# |O|O|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|X|
# |X|O|O|
# |X|X|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|O|
# |O| |X|
# |O|X|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|X|
# |X|O|O|
# |X|X|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|X|
# | |O|X|
# | |O|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|O|
# | |X|O|
# |X|X|O|
# ‾‾‾‾‾‾‾
# _______
# | |X|O|
# | |O|X|
# |O| |X|
# ‾‾‾‾‾‾‾
# _______
# | |O|X|
# |X|X|O|
# |X| |O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|X|
# |O| |O|
# |O|X|X|
# ‾‾‾‾‾‾‾
# _______
# | |O|X|
# |X|X|O|
# |X| |O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|X|
# |O|O|O|
# | |X|X|
# ‾‾‾‾‾‾‾
# _______
# | |O|O|
# |X|X|O|
# |X|X|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|O|
# |O| |X|
# |O|X|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|O|
# |X|X|O|
# | |X|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|X|
# | |O|X|
# |O| |X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|X|
# | |O|X|
# |X|O|O|
# ‾‾‾‾‾‾‾
# _______
# |X|X|O|
# |O|O|X|
# |X|O|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|O|
# |X|O|X|
# |X|X|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|O|
# |O|X|X|
# |X|O|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|X|
# | |O|O|
# |X|O|X|
# ‾‾‾‾‾‾‾
# _______
# | |X|X|
# | |O|X|
# |O|O|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|O|
# |O|X|X|
# |X|X|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X| |
# |O| |X|
# |O| |X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|O|
# |X|O|X|
# |X|X|O|
# ‾‾‾‾‾‾‾
# _______
# | |X|X|
# |O| |X|
# |O|O|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|X|
# | |O|X|
# |X|O|O|
# ‾‾‾‾‾‾‾
# _______
# | |X|O|
# |O|O|X|
# |O|X|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|X|
# |X|O|O|
# | |O|X|
# ‾‾‾‾‾‾‾
# _______
# |O|X| |
# |O| |X|
# |O| |X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|X|
# | |O|O|
# |X|O|X|
# ‾‾‾‾‾‾‾
# _______
# |O|X|X|
# |O| |X|
# | |O|X|
# ‾‾‾‾‾‾‾
# _______
# |X|X|O|
# |X|O|X|
# |X|O|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|O|
# |X|X|X|
# |O|O|X|
# ‾‾‾‾‾‾‾
# _______
# |X|X|X|
# | | | |
# | |O|O|
# ‾‾‾‾‾‾‾
# _______
# | |X|O|
# | |O|X|
# |O| |X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|X|
# |X|O|O|
# |X|X|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|O|
# |O|O|X|
# |X|X|X|
# ‾‾‾‾‾‾‾
# _______
# | |O|X|
# |X|O|X|
# |X|O|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|O|
# |X|X|X|
# |O|O|X|
# ‾‾‾‾‾‾‾
# _______
# | |O|X|
# | |X| |
# |X| |O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|X|
# | |O|X|
# | | |O|
# ‾‾‾‾‾‾‾
# _______
# | |O|X|
# |X|X|O|
# |X| |O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|O|
# | |X|O|
# | |X|X|
# ‾‾‾‾‾‾‾
# _______
# | |O|X|
# | |X|X|
# |X|O|O|
# ‾‾‾‾‾‾‾
# _______
# | |X|X|
# |O|O|O|
# |X|O|X|
# ‾‾‾‾‾‾‾
# _______
# |X|X|O|
# |X|O|X|
# |X|O|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|X|
# |O|O|X|
# | | |X|
# ‾‾‾‾‾‾‾
# _______
# | |O|O|
# |X|X|X|
# | |X|O|
# ‾‾‾‾‾‾‾
# _______
# | |X|X|
# |O|O|X|
# | |O|X|
# ‾‾‾‾‾‾‾
# _______
# | |O|O|
# |X|X|O|
# |X|X|O|
# ‾‾‾‾‾‾‾
# _______
# |X|X|X|
# |O|O|X|
# |O|X|O|
# ‾‾‾‾‾‾‾
# _______
# |X|O|X|
# |X|X|O|
# |X|O|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|X|
# |O| |X|
# | |O|X|
# ‾‾‾‾‾‾‾
# _______
# |X|X|O|
# |X|X|O|
# | |O|O|
# ‾‾‾‾‾‾‾
# _______
# | |X|O|
# | |X|X|
# |O|X|O|
# ‾‾‾‾‾‾‾
# _______
# |X|O|O|
# |X|X|O|
# | |X|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|X|
# | |O|X|
# | |O|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|X|
# | |O|X|
# |X|O|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|X|
# | |O|X|
# | |O|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|O|
# | |X|O|
# |X|X|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|O|
# |X|X|X|
# |O|O|X|
# ‾‾‾‾‾‾‾
# _______
# | |X|O|
# | |X| |
# | |X|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|O|
# |X|X|X|
# |O|O|X|
# ‾‾‾‾‾‾‾
# _______
# | |O|O|
# |X|X|O|
# |X|X|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|O|
# |O| |X|
# |O|X|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|O|
# |X|X|O|
# |O|X|X|
# ‾‾‾‾‾‾‾
# _______
# |O|X|X|
# | | |X|
# |O|O|X|
# ‾‾‾‾‾‾‾
# _______
# | |X|X|
# |X|O|X|
# |O|O|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|O|
# |X|O|X|
# |X|O|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|X|
# | |X|X|
# |O|O|O|
# ‾‾‾‾‾‾‾
# _______
# | |X|X|
# |O|O|O|
# |O|X|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O| |
# |X| | |
# |X| |O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|X|
# |O|X|O|
# |X|O|X|
# ‾‾‾‾‾‾‾
# _______
# | |O|O|
# | |X|O|
# |X|X|X|
# ‾‾‾‾‾‾‾
# _______
# | |X|O|
# | |O|O|
# |X|X|X|
# ‾‾‾‾‾‾‾
# _______
# |X|X|O|
# |X|X|O|
# |O|O|X|
# ‾‾‾‾‾‾‾
# _______
# | |X|X|
# |O|O|X|
# |O| |X|
# ‾‾‾‾‾‾‾
# _______
# |X|X|X|
# |X|O|O|
# |X|O|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|O|
# |O| |X|
# |O|X|X|
# ‾‾‾‾‾‾‾
# _______
# | |O|O|
# | |X|O|
# |X|X|X|
# ‾‾‾‾‾‾‾
# _______
# |O|X|X|
# | |O|X|
# |O| |X|
# ‾‾‾‾‾‾‾
# _______
# | |O|X|
# |X|X|X|
# | |O|O|
# ‾‾‾‾‾‾‾
# _______
# | |X|X|
# |O|O|O|
# | | |X|
# ‾‾‾‾‾‾‾
#  10%|█         | 1028/10000 [00:01<00:11, 789.17it/s]
# _______
# | |X|O|
# |X|X|O|
# |X|O|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X| |
# |O| |X|
# |O| |X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|X|
# |X|X|O|
# |O|X|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|O|
# | |O|X|
# |X|X|O|
# ‾‾‾‾‾‾‾
# _______
# |X|X|O|
# | |X|O|
# | |O|X|
# ‾‾‾‾‾‾‾
# _______
# |O|X|X|
# | |O|X|
# | |O|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|O|
# | |X|O|
# |X|X|O|
# ‾‾‾‾‾‾‾
# _______
# |X|X|X|
# |O|X|O|
# |O|O|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|X|
# |X|O|O|
# |X|X|O|
# ‾‾‾‾‾‾‾
# _______
# | |X|X|
# |O|O|X|
# |O| |X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|O|
# |X|X|O|
# | |X|O|
# ‾‾‾‾‾‾‾
# _______
# |X|X|X|
# |O|X|O|
# |O|O|X|
# ‾‾‾‾‾‾‾
# _______
# | |X|X|
# |X|X|O|
# |O|O|O|
# ‾‾‾‾‾‾‾
# _______
# | |X|O|
# |O|O|X|
# |O|X|X|
# ‾‾‾‾‾‾‾
# _______
# | |O|O|
# |X|X|O|
# |X|X|O|
# ‾‾‾‾‾‾‾
# _______
# |X|X|O|
# |O|X|X|
# |O|O|X|
# ‾‾‾‾‾‾‾
# _______
# | |O|O|
# |X|X|O|
# |X|X|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|O|
# |O| |X|
# |O|X|X|
# ‾‾‾‾‾‾‾
# _______
# | |O|X|
# |X|X|O|
# |X| |O|
# ‾‾‾‾‾‾‾
# _______
# |X|X|X|
# |O|O|X|
# |O|X|O|
# ‾‾‾‾‾‾‾
# _______
# |X|O|X|
# |X|X|O|
# |O|X|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|X|
# |X|O|O|
# |X|O|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|X|
# |X|O|O|
# |O|X|X|
# ‾‾‾‾‾‾‾
# _______
# |O|X| |
# |O| |X|
# |O| |X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|O|
# |O|X|X|
# |X|X|O|
# ‾‾‾‾‾‾‾
# _______
# | |X|X|
# |O| |X|
# |O|O|X|
# ‾‾‾‾‾‾‾
# _______
# |X|X|X|
# | | |O|
# |X|O|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|X|
# |O| |O|
# |O|X|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|X|
# |X|X|O|
# |O|X|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|X|
# | |O|X|
# |O| |X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|X|
# |X|O|X|
# | |O|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X| |
# |O| |X|
# |O| |X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|O|
# | |X|O|
# |X|X|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|O|
# | |O|X|
# |O|X|X|
# ‾‾‾‾‾‾‾
# _______
# | |X|O|
# | | |O|
# |X|X|O|
# ‾‾‾‾‾‾‾
# _______
# | |X|X|
# |O|O|X|
# |O| |X|
# ‾‾‾‾‾‾‾
# _______
# | |O|O|
# |X|X|O|
# |X|X|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|O|
# | |O|X|
# |X|X|O|
# ‾‾‾‾‾‾‾
# _______
# |X|O|X|
# | |O|X|
# |X|O|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|X|
# |O| |X|
# | |O|X|
# ‾‾‾‾‾‾‾
# _______
# |X|X|O|
# |X|O|O|
# |X|O|X|
# ‾‾‾‾‾‾‾
# _______
# |O|X|X|
# | | |X|
# |O|O|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|X|
# |X|O|O|
# |O|X|X|
# ‾‾‾‾‾‾‾
# _______
# |X|X|X|
# |O|O|X|
# |X|O|O|
# ‾‾‾‾‾‾‾
# _______
# |X|O|X|
# |X|O|O|
# |O|X|X|
# ‾‾‾‾‾‾‾
# _______
# | |X|O|
# | |O|O|
# |X|X|X|
# ‾‾‾‾‾‾‾
# _______
# | |O|X|
# | |X|O|
# |X|X|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|X|
# |O| |O|
# |O|X|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|X|
# |X|O|O|
# |X|X|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|X|
# | |O|X|
# |O| |X|
# ‾‾‾‾‾‾‾
# _______
# | |O|O|
# |X|X|X|
# | |X|O|
# ‾‾‾‾‾‾‾
# _______
# | |X|O|
# | |O|X|
# |O| |X|
# ‾‾‾‾‾‾‾
# _______
# | |O|X|
# | |X|X|
# |X|O|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|X|
# | |O|X|
# |O| |X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|X|
# |X|X|O|
# |X|O|O|
# ‾‾‾‾‾‾‾
# _______
# | |X|X|
# |O|O|X|
# |O| |X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|O|
# |X|X|O|
# |X|O|X|
# ‾‾‾‾‾‾‾
# _______
# | |X|O|
# | |O|X|
# |O| |X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|O|
# |X|X|O|
# |X|O|X|
# ‾‾‾‾‾‾‾
# _______
# | |X|O|
# | |O|X|
# |O| |X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|X|
# |X|X|O|
# |O|X|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|X|
# |X|X|O|
# |O|O|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|O|
# |X|X|O|
# |O|X|X|
# ‾‾‾‾‾‾‾
# _______
# |O|X|O|
# |O| |X|
# |O|X|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|X|
# |X|X|O|
# |X|O|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|X|
# |O| |O|
# |O|X|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O| |
# |X|X|X|
# | |O|O|
# ‾‾‾‾‾‾‾
# _______
# |X|X|O|
# |O|X|X|
# |O|O|X|
# ‾‾‾‾‾‾‾
# _______
# |X|X|X|
# | | |O|
# | | |O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|X|
# | | |X|
# |O|O|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|X|
# |X|X|O|
# |O|X|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|X|
# |O|X|O|
# |X|O|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|X|
# |X|O|X|
# |O|X|O|
# ‾‾‾‾‾‾‾
# _______
# | |X|X|
# |O|O|X|
# |O| |X|
# ‾‾‾‾‾‾‾
# _______
# |X|X|O|
# |X|X|O|
# | |O|O|
# ‾‾‾‾‾‾‾
# _______
# | |X|O|
# |O|O|X|
# |O|X|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O| |
# |X| |O|
# |X|O|X|
# ‾‾‾‾‾‾‾
# _______
# |O|X|O|
# |O|O|X|
# |X|X|X|
# ‾‾‾‾‾‾‾
# _______
# | |X|O|
# |X| |O|
# | |X|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|X|
# |X|O|O|
# |O|X|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|O|
# |O|X|X|
# |X|X|O|
# ‾‾‾‾‾‾‾
# _______
# | |X|O|
# |O|O|X|
# |O|X|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|X|
# |X|O|O|
# |X|X|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|X|
# | |X|X|
# |O|O|O|
# ‾‾‾‾‾‾‾
# _______
# | |X|X|
# | |X|O|
# |X|O|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|O|
# |X|X|X|
# |O|O|X|
# ‾‾‾‾‾‾‾
# _______
# | |O|X|
# |X|O|O|
# |X|O|X|
# ‾‾‾‾‾‾‾
# _______
# |O|X|O|
# |X|X|X|
# |O|O|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|X|
# |X|X|O|
# |O|X|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|X|
# |O|O|O|
# | |X|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|X|
# |X|X|O|
# |O|X|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|X|
# |X|X|O|
# |O|O|X|
# ‾‾‾‾‾‾‾
# _______
# | |O|X|
# | |X|O|
# |X|O|X|
# ‾‾‾‾‾‾‾
# _______
# | |X|O|
# |O|O|X|
# |O|X|X|
# ‾‾‾‾‾‾‾
# _______
# |X|X|X|
# |X|O|O|
# |X|O|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|O|
# |O| |X|
# |O|X|X|
# ‾‾‾‾‾‾‾
# _______
# |X|X|O|
# |X|O|X|
# |X|O|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|O|
# | |O|X|
# |O|X|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|X|
# |O|O|X|
# |X|X|O|
# ‾‾‾‾‾‾‾
# _______
# | |X|X|
# |O|O|O|
# |O|X|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|X|
# |X|X|O|
# |O|X|O|
# ‾‾‾‾‾‾‾
# _______
# | |X|X|
# |O|O|O|
# | | |X|
# ‾‾‾‾‾‾‾
# _______
# |X|O| |
# |X| | |
# |X| |O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|X|
# |X|O|O|
# |O|X|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|O|
# |X|X|X|
# |O|X|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|X|
# |O|O|X|
# | |X|O|
# ‾‾‾‾‾‾‾
# _______
# |X|X|O|
# |X|X|O|
# | |O|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|X|
# |O| |O|
# |O|X|X|
# ‾‾‾‾‾‾‾
# _______
# | |X|O|
# | |X| |
# | |X|O|
# ‾‾‾‾‾‾‾
# _______
# | |X|O|
# | |X|X|
# |O|X|O|
# ‾‾‾‾‾‾‾
# _______
# |X|X|X|
# |X|O|O|
# |X|O|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|X|
# |X|O|O|
# |O|X|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|X|
# |X|O|O|
# |X|X|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|X|
# | |O|X|
# | |O|X|
# ‾‾‾‾‾‾‾
# _______
# | |O|O|
# |X|X|X|
# | |X|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|X|
# |O| |X|
# |O|X|O|
# ‾‾‾‾‾‾‾
# _______
# |X|O|X|
# | |X|O|
# |X| |O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|X|
# | | |X|
# |O|O|X|
# ‾‾‾‾‾‾‾
# _______
# | |X|X|
# | |X|O|
# |X|O|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|O|
# | |O|X|
# |X|X|O|
# ‾‾‾‾‾‾‾
# _______
# | |O|X|
# | |X|O|
# |X| | |
# ‾‾‾‾‾‾‾
# _______
# |O|X|O|
# |O| |X|
# |O|X|X|
# ‾‾‾‾‾‾‾
# _______
# | |O|X|
# | |X|O|
# |X|X|O|
# ‾‾‾‾‾‾‾
# _______
# | |X|X|
# | |O|X|
# |O|O|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|O|
# |X|X|X|
# |O|X|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|X|
# |X|X|O|
# |O|O|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|O|
# |X| |X|
# |X| |O|
# ‾‾‾‾‾‾‾
# _______
# |X|X|X|
# |O|X|O|
# |O|O|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|X|
# |X|O|O|
# |X|X|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|X|
# |O| |X|
# |O|X|O|
# ‾‾‾‾‾‾‾
# _______
# |X|X|O|
# | |X|O|
# |X|O|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|X|
# |O| |O|
# |O|X|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|X|
# |X|O|X|
# | |O|O|
# ‾‾‾‾‾‾‾
# _______
# | |X|X|
# |O|O|X|
# |O| |X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|O|
# |X|X|X|
# |O|X|O|
# ‾‾‾‾‾‾‾
# _______
# | |X|X|
# |O|O|O|
# | | |X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|O|
# |X|O|X|
# |X|X|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|X|
# |O| |O|
# |O|X|X|
# ‾‾‾‾‾‾‾
# _______
# | |O| |
# |X|X|X|
# |X|O|O|
# ‾‾‾‾‾‾‾
# _______
# | |X|O|
# | |O|X|
# |O| |X|
# ‾‾‾‾‾‾‾
# _______
# |X|O| |
# |X|X|O|
# |X| |O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|X|
# |O| |X|
# | |O|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|X|
# |X|O|X|
# |O|X|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|X|
# |X|O|O|
# |O|X|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|O|
# |X|X|X|
# |O|X|O|
# ‾‾‾‾‾‾‾
# _______
# |X|X|O|
# |O|X|X|
# |O|O|X|
# ‾‾‾‾‾‾‾
# _______
# | |X|O|
# | | |O|
# |X|X|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|X|
# |X|X|O|
# |O|O|X|
# ‾‾‾‾‾‾‾
# _______
# | |O|X|
# |X|X|X|
# | |O|O|
# ‾‾‾‾‾‾‾
# _______
# |X|X|X|
# |O|O|X|
# |O|X|O|
# ‾‾‾‾‾‾‾
# _______
# |X|O| |
# |X|X|X|
# | |O|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|O|
# |O|X|X|
# |X|O|X|
# ‾‾‾‾‾‾‾
# _______
# |X|X|X|
# | |X|O|
# | |O|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|O|
# |O| |X|
# |O|X|X|
# ‾‾‾‾‾‾‾
# _______
# |X|X|O|
# |X| | |
# |X|O|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|X|
# |X|O|O|
# |O|X|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|X|
# |X|X|O|
# |O|X|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|X|
# |O|X|O|
# |X|O|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|X|
# |X|O|O|
# |X|X|O|
# ‾‾‾‾‾‾‾
# _______
# | |X|X|
# |O|O|O|
# | | |X|
# ‾‾‾‾‾‾‾
#  12%|█▏        | 1189/10000 [00:01<00:11, 796.42it/s]
# _______
# |X|O|X|
# |X|X|O|
# |X|O|O|
# ‾‾‾‾‾‾‾
# _______
# | |X|X|
# |O|O|X|
# | |O|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|X|
# | |O|X|
# |X|O|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|X|
# | |O|X|
# |O|X|O|
# ‾‾‾‾‾‾‾
# _______
# |X|O|X|
# |X|X|O|
# |O|X|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|X|
# |X|O|O|
# |X|O|X|
# ‾‾‾‾‾‾‾
# _______
# | |X|O|
# |X|X|O|
# |X|O|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|X|
# |O| |X|
# | |O|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O| |
# |X| |O|
# |X|X|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|O|
# |O| |X|
# |O|X|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|X|
# |X|O|O|
# | |O|X|
# ‾‾‾‾‾‾‾
# _______
# |O|X|X|
# | | |X|
# |O|O|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|X|
# |X|X|O|
# |O|O|X|
# ‾‾‾‾‾‾‾
# _______
# |X|X|O|
# |O|O|X|
# |X|O|X|
# ‾‾‾‾‾‾‾
# _______
# | |O|O|
# |X|X|O|
# |X|X|O|
# ‾‾‾‾‾‾‾
# _______
# | |X|O|
# | |O|X|
# |O| |X|
# ‾‾‾‾‾‾‾
# _______
# |X|X|O|
# |X|X|O|
# | |O|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|X|
# |X|O|O|
# |O|X|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|O|
# |X|X|X|
# |X|O|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|O|
# |O|O|X|
# |X|X|X|
# ‾‾‾‾‾‾‾
# _______
# | |O|X|
# |X|O|O|
# |X|O|X|
# ‾‾‾‾‾‾‾
# _______
# |O|X|X|
# |O|O|O|
# | |X|X|
# ‾‾‾‾‾‾‾
# _______
# | |O|X|
# |X|O|X|
# |X|O|O|
# ‾‾‾‾‾‾‾
# _______
# |X|X|O|
# |O|X|X|
# |O|O|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|O|
# |X|X|X|
# |O|X|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|X|
# | |O|X|
# | |O|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|O|
# | |X|O|
# |X|X|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|X|
# | |O|X|
# |O|X|O|
# ‾‾‾‾‾‾‾
# _______
# |X|O| |
# |X| | |
# |X| |O|
# ‾‾‾‾‾‾‾
# _______
# | |X|X|
# | |O|X|
# |O|O|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O| |
# |X| | |
# |X| |O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|X|
# | |O|X|
# | |O|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|X|
# |X|O|O|
# | |O|X|
# ‾‾‾‾‾‾‾
# _______
# | |X|X|
# | |O|X|
# |O|O|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|X|
# | |O|X|
# |X|O|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|O|
# | |X|O|
# | |X|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O| |
# |X|X|O|
# | |O|X|
# ‾‾‾‾‾‾‾
# _______
# |O|X|O|
# |O| |X|
# |O|X|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|X|
# |X|X|O|
# |O|O|X|
# ‾‾‾‾‾‾‾
# _______
# | |X|O|
# |O|O|X|
# |O|X|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|X|
# |X|O|O|
# |X|X|O|
# ‾‾‾‾‾‾‾
# _______
# |X|X|O|
# |O|O|X|
# |X|O|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|X|
# |X|O|O|
# |X|X|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|X|
# | |O|X|
# | | |O|
# ‾‾‾‾‾‾‾
# _______
# | |O|X|
# | |X| |
# |X| |O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|X|
# |O|X|X|
# |X|O|O|
# ‾‾‾‾‾‾‾
# _______
# |X|X|O|
# |X|O|X|
# |X|O|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|X|
# |X|O|O|
# |X|O|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|O|
# |X|X|O|
# | |X|O|
# ‾‾‾‾‾‾‾
# _______
# | |X|X|
# |O|O|O|
# | | |X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|X|
# |X|X|O|
# |O|X|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|X|
# |X|O|O|
# |O|X|X|
# ‾‾‾‾‾‾‾
# _______
# | |O|O|
# | |X|O|
# |X|X|X|
# ‾‾‾‾‾‾‾
# _______
# | |X|X|
# |O|O|X|
# |O| |X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|X|
# |X| |O|
# |X| |O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|O|
# | |O|X|
# |O|X|X|
# ‾‾‾‾‾‾‾
# _______
# | |O|X|
# |X|O|X|
# |X|O|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|X|
# | |O|X|
# |O| |X|
# ‾‾‾‾‾‾‾
# _______
# | |O|X|
# | |X|X|
# |X|O|O|
# ‾‾‾‾‾‾‾
# _______
# | |X|X|
# |O|O|X|
# | |O|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O| |
# |X| |O|
# |X|X|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|X|
# | | |X|
# |O|O|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|X|
# |X|O|X|
# |O|X|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|O|
# |O| |X|
# |O|X|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|O|
# |X|X|O|
# | |X|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X| |
# |O| |X|
# |O| |X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|X|
# |X| |O|
# |X| |O|
# ‾‾‾‾‾‾‾
# _______
# |X|X|X|
# |O|X|O|
# |O|O|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O| |
# | |X|O|
# | | |X|
# ‾‾‾‾‾‾‾
# _______
# |O|X|X|
# |O|X|X|
# |X|O|O|
# ‾‾‾‾‾‾‾
# _______
# | |O|X|
# |X|X|X|
# | |O|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|O|
# |O| |X|
# |O|X|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|X|
# |X|X|O|
# |O|X|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|O|
# |O|O|X|
# |X|X|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|X|
# |X|O|O|
# |X|X|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|X|
# |O|O|O|
# | |X|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|X|
# |X|O|X|
# |O|X|O|
# ‾‾‾‾‾‾‾
# _______
# | |X|O|
# |O|O|X|
# |O|X|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|X|
# |X|O|X|
# | |O|O|
# ‾‾‾‾‾‾‾
# _______
# | |X|O|
# | |X|O|
# |O|X|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|X|
# | |X|X|
# |O|O|O|
# ‾‾‾‾‾‾‾
# _______
# | |X|O|
# | |O|O|
# |X|X|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|X|
# |X|O|O|
# |X|X|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|X|
# |O| |X|
# |O|X|O|
# ‾‾‾‾‾‾‾
# _______
# |X|O|X|
# | |O|X|
# |X|O|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|X|
# |O| |X|
# | |O|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O| |
# |X|X|O|
# |X| |O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|X|
# |X|X|O|
# |O|O|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|O|
# |X|X|O|
# | |X|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|O|
# |X|X|X|
# |O|O|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|X|
# |X|X|O|
# |O|O|X|
# ‾‾‾‾‾‾‾
# _______
# | |X|X|
# |O| |X|
# |O|O|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|X|
# |X|O|X|
# |O|X|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|O|
# | |X|O|
# | |X|X|
# ‾‾‾‾‾‾‾
# _______
# | |O| |
# |X|X|X|
# |X|O|O|
# ‾‾‾‾‾‾‾
# _______
# ...
# |O|X|O|
# ‾‾‾‾‾‾‾
# _______
# |X|O|O|
# |O|X|X|
# |X|X|O|
# ‾‾‾‾‾‾‾
# _______
# | |X|X|
# |O| |X|
# |O|O|X|
# ‾‾‾‾‾‾‾
# _______
# | |X|O|
# |X|X|O|
# |X|O|O|
# ‾‾‾‾‾‾‾
# _______
# | |X|O|
# | |O|X|
# |O| |X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|X|
# |X|O|O|
# |X|X|O|
# ‾‾‾‾‾‾‾
# _______
# |X|X|X|
# |O|X|O|
# |O|O|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|O|
# |O|X|X|
# |X|X|O|
# ‾‾‾‾‾‾‾
# _______
# | |X|O|
# |O|X|O|
# | |X|X|
# ‾‾‾‾‾‾‾
# _______
# | |O|X|
# |X|O|O|
# |X|O|X|
# ‾‾‾‾‾‾‾
# _______
# |O|X|X|
# | |O|X|
# | | |O|
# ‾‾‾‾‾‾‾
# _______
# |X|O|X|
# |X|O|O|
# |X|X|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|O|
# | |X|O|
# | |X|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|X|
# |X|X|O|
# |O|X|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|X|
# | | |X|
# |O|O|X|
# ‾‾‾‾‾‾‾
# _______
# | |O|X|
# |X|X|O|
# |X| |O|
# ‾‾‾‾‾‾‾
# _______
# | |X|X|
# |O|O|O|
# |O|X|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|O|
# |X|O|X|
# |X|X|O|
# ‾‾‾‾‾‾‾
# _______
# |X|X|X|
# |O|O|X|
# |O|X|O|
# ‾‾‾‾‾‾‾
# _______
# |X|X|O|
# |O|X|X|
# |X|O|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|X|
# | |O|X|
# |O| |X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|X|
# |X|O|O|
# |X|X|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|X|
# | | |X|
# |O|O|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|O|
# |X|O|O|
# |X|X|X|
# ‾‾‾‾‾‾‾
# _______
# |O|X|X|
# | |O|X|
# |O|X|O|
# ‾‾‾‾‾‾‾
# _______
# | |O|O|
# |X|X|O|
# |X|X|O|
# ‾‾‾‾‾‾‾
# _______
# |X|X|X|
# |O|X|O|
# |O|O|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|X|
# |X|O|O|
# |X|X|O|
# ‾‾‾‾‾‾‾
# _______
# | |X|X|
# |O| |X|
# |O|O|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|X|
# |X| |O|
# |X| |O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|X|
# |O| |X|
# |O|X|O|
# ‾‾‾‾‾‾‾
# _______
# |X|O|O|
# |X|O|X|
# |X|X|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|O|
# | |O|X|
# |O|X|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O| |
# |X|X|O|
# |X| |O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|O|
# |O|O|X|
# |X|X|X|
# ‾‾‾‾‾‾‾
# _______
# |X|X|O|
# |X|O|X|
# |X|O|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|X|
# | |O|X|
# | |O|X|
# ‾‾‾‾‾‾‾
# _______
# | |X|X|
# |X|X|O|
# |O|O|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|O|
# |O| |X|
# |O|X|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O| |
# | |X|O|
# | | |X|
# ‾‾‾‾‾‾‾
# _______
# |X|X|O|
# |O|X|X|
# |O|O|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|O|
# | | |O|
# |X|X|X|
# ‾‾‾‾‾‾‾
# _______
# | |X|X|
# |O|O|O|
# |O|X|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|X|
# |X|O|O|
# |X|X|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|O|
# |O| |X|
# |O|X|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|O|
# | |X|O|
# |X|X|O|
# ‾‾‾‾‾‾‾
# _______
# | |X|X|
# | | |X|
# |O|O|O|
# ‾‾‾‾‾‾‾
# _______
# | |O|X|
# | |X|O|
# |X|X|O|
# ‾‾‾‾‾‾‾
# _______
# | |X|X|
# |O|O|X|
# | |O|X|
# ‾‾‾‾‾‾‾
# _______
# |X|X|O|
# |X|O|X|
# |X|O|O|
# ‾‾‾‾‾‾‾
#  97%|█████████▋| 9737/10000 [00:12<00:00, 782.96it/s]
# _______
# |O|X|O|
# |O|X|X|
# |X|O|X|
# ‾‾‾‾‾‾‾
# _______
# | |X|O|
# |X|X|X|
# | |O|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|O|
# | |O|X|
# |O|X|X|
# ‾‾‾‾‾‾‾
# _______
# | |O| |
# |X|X|X|
# |X|O|O|
# ‾‾‾‾‾‾‾
# _______
# | |X|X|
# |O|O|O|
# |O|X|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|X|
# |X|X|O|
# |O|X|O|
# ‾‾‾‾‾‾‾
# _______
# | |X|O|
# |O|O|X|
# |O|X|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|O|
# | |X|O|
# |X|X|O|
# ‾‾‾‾‾‾‾
# _______
# | |X|O|
# |O|X|O|
# | |X|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|X|
# | |X|O|
# | |O|X|
# ‾‾‾‾‾‾‾
# _______
# |O|X|X|
# |O|X|O|
# |X|O|X|
# ‾‾‾‾‾‾‾
# _______
# | |O|X|
# | |X|O|
# |X|X|O|
# ‾‾‾‾‾‾‾
# _______
# |X|X|O|
# |O|X|X|
# |O|O|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|O|
# |X|X|X|
# |X|O|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|O|
# |O| |X|
# |O|X|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|X|
# |X|O|X|
# | |O|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|O|
# | |O|X|
# |O|X|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|X|
# |X|O|X|
# | |O|O|
# ‾‾‾‾‾‾‾
# _______
# |X|X|X|
# |O|O|X|
# |O|X|O|
# ‾‾‾‾‾‾‾
# _______
# |X|X|O|
# |X|O|X|
# |X|O|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|X|
# |X|O|O|
# |O|X|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|X|
# |X|O|X|
# | |O|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X| |
# |O| |X|
# |O| |X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|O|
# |X|X|O|
# | |X|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|X|
# | | |X|
# |O|O|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|X|
# |X|X|O|
# |X|O|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|O|
# | |O|X|
# |O|X|X|
# ‾‾‾‾‾‾‾
# _______
# |X|X|O|
# |X|O|X|
# |X|O|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|X|
# | |O|X|
# | |O|X|
# ‾‾‾‾‾‾‾
# _______
# | |X|O|
# | | |O|
# |X|X|O|
# ‾‾‾‾‾‾‾
# _______
# |X|X|O|
# |O|X|X|
# |O|O|X|
# ‾‾‾‾‾‾‾
# _______
# | |X|X|
# | |X|O|
# |X|O|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|O|
# |O| |X|
# |O|X|X|
# ‾‾‾‾‾‾‾
# _______
# | |X|O|
# | |X| |
# | |X|O|
# ‾‾‾‾‾‾‾
# _______
# | |X|X|
# |O| |X|
# |O|O|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|X|
# |X|X|O|
# |X|O|O|
# ‾‾‾‾‾‾‾
# _______
# |X|X|X|
# |O|X|O|
# |O|O|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|X|
# |X|X|O|
# |O|X|O|
# ‾‾‾‾‾‾‾
# _______
# | |X|X|
# | |O|X|
# |O|O|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O| |
# |X| | |
# |X| |O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|O|
# |O|X|X|
# |X|O|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|X|
# |X|O|X|
# |O|X|O|
# ‾‾‾‾‾‾‾
# _______
# | |X|X|
# | | |X|
# |O|O|O|
# ‾‾‾‾‾‾‾
# _______
# |X|O|O|
# |X|X|O|
# |X|O|X|
# ‾‾‾‾‾‾‾
# _______
# |O|X|O|
# |O|X|X|
# |X|O|X|
# ‾‾‾‾‾‾‾
# _______
# | |X|X|
# |X|X|O|
# |O|O|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|X|
# |O| |O|
# |O|X|X|
# ‾‾‾‾‾‾‾
# _______
# | |X|O|
# |X| |O|
# | |X|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|X|
# |O|O|X|
# | | |X|
# ‾‾‾‾‾‾‾
# _______
# |X|X|O|
# | |X|O|
# |X|O|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|X|
# |O|O|O|
# | |X|X|
# ‾‾‾‾‾‾‾
# _______
# | |O|X|
# |X|O|X|
# |X|O|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|O|
# |O|X|X|
# |X|O|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|X|
# |X|O|O|
# |X|X|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|X|
# |O|X|X|
# |X|O|O|
# ‾‾‾‾‾‾‾
# _______
# | |X|O|
# |X|X|O|
# |X|O|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|O|
# | |O|X|
# |O|X|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|X|
# |X|O|O|
# |X|X|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|X|
# | |O|X|
# | |O|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O| |
# |X| |O|
# |X|O|X|
# ‾‾‾‾‾‾‾
# _______
# |O|X|O|
# | |O|X|
# |O|X|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|O|
# |X|O|X|
# |X|X|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X| |
# |O| |X|
# |O| |X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|X|
# |X| |O|
# |X| |O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|X|
# |O|O|X|
# | | |X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|X|
# |X|O|O|
# |X|X|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|X|
# |O| |X|
# | |O|X|
# ‾‾‾‾‾‾‾
# _______
# | |O|X|
# |X|O|X|
# |X|O|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X| |
# |O| |X|
# |O| |X|
# ‾‾‾‾‾‾‾
# _______
# | |X|O|
# | |X| |
# | |X|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|O|
# |X|X|X|
# |O|O|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|X|
# |X|X|O|
# |O|X|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|X|
# |X|X|O|
# |O|O|X|
# ‾‾‾‾‾‾‾
# _______
# | |X|X|
# | |X|O|
# |X|O|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|X|
# |O| |O|
# |O|X|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|O|
# | |X|O|
# | |X|X|
# ‾‾‾‾‾‾‾
# _______
# |X|X|X|
# |O|O|X|
# |O|X|O|
# ‾‾‾‾‾‾‾
# _______
# |X|O|O|
# |X| |X|
# |X| |O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|O|
# |O| |X|
# |O|X|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|X|
# | |X|X|
# |O|O|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|X|
# |O|O|X|
# | | |X|
# ‾‾‾‾‾‾‾
# _______
# | |X|O|
# |X| |O|
# | |X|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|X|
# |X|O|O|
# |O|X|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|O|
# |X|O|O|
# |X|X|X|
# ‾‾‾‾‾‾‾
# _______
# |O|X|O|
# | |O|X|
# |O|X|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O| |
# |X| |O|
# |X|X|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|X|
# |O|O|O|
# | |X|X|
# ‾‾‾‾‾‾‾
# _______
# | |O|X|
# | |X|O|
# |X|X|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|O|
# |O| |X|
# |O|X|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O| |
# |X| |X|
# |X|O|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|O|
# | |X|O|
# | |X|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|X|
# |X|X|O|
# |O|X|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|X|
# | | |X|
# |O|O|X|
# ‾‾‾‾‾‾‾
# _______
# |X|X|O|
# | |X|O|
# |X|O|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|X|
# |O|O|O|
# | |X|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|O|
# |X|O|X|
# |X|X|O|
# ‾‾‾‾‾‾‾
# _______
# |X|X|O|
# |O|O|X|
# |X|O|X|
# ‾‾‾‾‾‾‾
# _______
# | |O|X|
# |X|O|X|
# |X|O|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|X|
# |O|O|X|
# | | |X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|O|
# |X|X|X|
# |X|O|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|X|
# | |O|X|
# |X|O|O|
# ‾‾‾‾‾‾‾
# _______
# | |O|X|
# | |X|O|
# |X|X|O|
# ‾‾‾‾‾‾‾
# _______
# | |X|X|
# |O| |X|
# |O|O|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|O|
# |X|X|O|
# |X|O|X|
# ‾‾‾‾‾‾‾
# _______
# |O|X|O|
# | |O|X|
# |O|X|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|O|
# |X|X|O|
# |X|O|X|
# ‾‾‾‾‾‾‾
# _______
# |O|X|X|
# |O|O|X|
# | | |X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|O|
# | |X|O|
# |X|X|O|
# ‾‾‾‾‾‾‾
# _______
# | |X|X|
# |O|O|X|
# |O| |X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|O|
# | |X|O|
# | |X|X|
# ‾‾‾‾‾‾‾
# _______
# | |X|O|
# | |O|X|
# |O| |X|
# ‾‾‾‾‾‾‾
# _______
# |X|X|O|
# | |X|X|
# |O|O|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|O|
# |X|X|X|
# |O|O|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|O|
# |X|X|X|
# |O|X|O|
# ‾‾‾‾‾‾‾
# _______
# | |X|X|
# | |O|X|
# |O|O|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O| |
# | |X|O|
# | | |X|
# ‾‾‾‾‾‾‾
# _______
# | |X|X|
# |O|X|X|
# |O|O|O|
# ‾‾‾‾‾‾‾
# _______
# |X|O|X|
# |X|O|O|
# |X|X|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|O|
# |O|X|X|
# |X|O|X|
# ‾‾‾‾‾‾‾
# _______
# |X|X|X|
# |X| |O|
# | |O|O|
# ‾‾‾‾‾‾‾
# _______
# | |X|X|
# |O|O|X|
# |O| |X|
# ‾‾‾‾‾‾‾
# _______
# | |X|X|
# |X|X|O|
# |O|O|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|X|
# |O| |O|
# |O|X|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|X|
# | |X|O|
# |X| |O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|X|
# | |O|X|
# | |O|X|
# ‾‾‾‾‾‾‾
# _______
# |X|X|O|
# | |X|X|
# |O|O|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|X|
# |X|X|O|
# |O|O|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|X|
# |X|X|O|
# |O|X|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|X|
# |X|O|O|
# |O|X|X|
# ‾‾‾‾‾‾‾
# _______
# | |O| |
# | | |O|
# |X|X|X|
# ‾‾‾‾‾‾‾
# _______
# | |X|X|
# |O|O|X|
# |O| |X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|O|
# |X|O|X|
# |X|X|O|
# ‾‾‾‾‾‾‾
# _______
# | |X|O|
# |O|O|X|
# |O|X|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|O|
# |X|X|O|
# |O|X|X|
# ‾‾‾‾‾‾‾
# _______
# | |X|X|
# |O| |X|
# |O|O|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|X|
# |X|X|O|
# |O|X|O|
# ‾‾‾‾‾‾‾
# _______
# | |X|O|
# |O|O|X|
# |O|X|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|X|
# | |X|X|
# |O|O|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|X|
# | |O|X|
# |O| |X|
# ‾‾‾‾‾‾‾
# _______
# |O|O|O|
# | |X|X|
# |X|X|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|X|
# |O| |O|
# |O|X|X|
# ‾‾‾‾‾‾‾
# _______
# | |O| |
# | | |O|
# |X|X|X|
# ‾‾‾‾‾‾‾
# _______
# | |X|X|
# |O|O|O|
# |O|X|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|X|
# |X|O|X|
# | |O|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|X|
# | |O|X|
# | |O|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|O|
# |X|X|O|
# | |X|O|
# ‾‾‾‾‾‾‾
# _______
# |X|X|X|
# |O|O|X|
# |X|O|O|
# ‾‾‾‾‾‾‾
# _______
# |X|X|O|
# |X|X|O|
# | |O|O|
# ‾‾‾‾‾‾‾
# _______
# |X|X|X|
# |O|X|O|
# |O|O|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|X|
# |X|O|O|
# |X|X|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|X|
# |X|O|O|
# |X|O|X|
# ‾‾‾‾‾‾‾
# _______
# | |O|X|
# | |X|O|
# |X|O|X|
# ‾‾‾‾‾‾‾
# _______
# | |X|X|
# |O|O|X|
# | |O|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|X|
# |X|O|O|
# |X|X|O|
# ‾‾‾‾‾‾‾
# _______
# |X|X|O|
# |O|X|X|
# |O|O|X|
# ‾‾‾‾‾‾‾
# _______
# | |O|X|
# | |X|O|
# |X|X|O|
# ‾‾‾‾‾‾‾
# _______
# | |X|X|
# |O|O|O|
# | | |X|
# ‾‾‾‾‾‾‾
# _______
# | |O|O|
# |X|X|X|
# | |X|O|
# ‾‾‾‾‾‾‾
#  99%|█████████▉| 9894/10000 [00:12<00:00, 776.93it/s]
# _______
# |X|X|O|
# |O|O|X|
# |X|O|X|
# ‾‾‾‾‾‾‾
# _______
# |X|X|O|
# |X|O|X|
# |X|O|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|X|
# | |O|X|
# |O|X|O|
# ‾‾‾‾‾‾‾
# _______
# |X|O|X|
# |X|O|O|
# |X|X|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|X|
# |O|O|X|
# | | |X|
# ‾‾‾‾‾‾‾
# _______
# |X|X|O|
# |X|O|X|
# |X|O|O|
# ‾‾‾‾‾‾‾
# _______
# |X|X|O|
# |O|X|X|
# |O|O|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O| |
# |X|X|X|
# | |O|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X| |
# |O| |X|
# |O| |X|
# ‾‾‾‾‾‾‾
# _______
# |X|O| |
# | |X|O|
# | | |X|
# ‾‾‾‾‾‾‾
# _______
# | |X|O|
# | |X|X|
# |O|X|O|
# ‾‾‾‾‾‾‾
# _______
# |X|O|O|
# |X|O|X|
# |X|X|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|X|
# | |O|X|
# | |O|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|X|
# |X|O|X|
# |O|X|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|O|
# |X|X|X|
# |O|O|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|X|
# |X|O|X|
# |O|X|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|X|
# | |O|X|
# | |O|X|
# ‾‾‾‾‾‾‾
# _______
# | |O| |
# |X|X|X|
# | | |O|
# ‾‾‾‾‾‾‾
# _______
# |O|X| |
# |O| |X|
# |O| |X|
# ‾‾‾‾‾‾‾
# _______
# |X|X|O|
# |X|X|O|
# | |O|O|
# ‾‾‾‾‾‾‾
# _______
# | |X|O|
# |O|O|X|
# |O|X|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|X|
# |X|X|O|
# |O|X|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|O|
# | |O|X|
# |O|X|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|O|
# |X|X|X|
# |O|X|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|O|
# |X|O|X|
# |X|O|X|
# ‾‾‾‾‾‾‾
# _______
# |X|X|O|
# |X| | |
# |X|O|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|X|
# |X|O|O|
# |O|X|X|
# ‾‾‾‾‾‾‾
# _______
# |X|X|O|
# | | |O|
# | |X|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X| |
# |O| |X|
# |O| |X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|X|
# |X|X|O|
# |O|X|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|X|
# | |O|X|
# | | |O|
# ‾‾‾‾‾‾‾
# _______
# |X|O|O|
# | |X|O|
# |X|X|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|O|
# |O|O|X|
# |X|X|X|
# ‾‾‾‾‾‾‾
# _______
# | |O|X|
# |X|X|O|
# |X| |O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|O|
# |O|X|X|
# |X|O|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|X|
# | |O|O|
# |X|O|X|
# ‾‾‾‾‾‾‾
# _______
# | |X|X|
# |O|O|X|
# |O| |X|
# ‾‾‾‾‾‾‾
# _______
# |X|O| |
# |X| |X|
# |X|O|O|
# ‾‾‾‾‾‾‾
# _______
# | |X|X|
# | | |X|
# |O|O|O|
# ‾‾‾‾‾‾‾
# _______
# |X|O|X|
# |X|X|O|
# |O|X|O|
# ‾‾‾‾‾‾‾
# _______
# | |X|O|
# |O|O|X|
# |O|X|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|X|
# |X|X|O|
# |X|O|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|X|
# |O|O|O|
# | |X|X|
# ‾‾‾‾‾‾‾
# _______
# | |X|O|
# |X| |O|
# | |X|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|X|
# |O|O|O|
# | |X|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|X|
# |X|X|O|
# |O|X|O|
# ‾‾‾‾‾‾‾
# _______
# | |X|O|
# | |X|X|
# |O|X|O|
# ‾‾‾‾‾‾‾
# _______
# |X|O|X|
# |X|O|O|
# |X|X|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X| |
# |O| |X|
# |O| |X|
# ‾‾‾‾‾‾‾
# _______
# |X|X|X|
# | |O|O|
# | |O|X|
# ‾‾‾‾‾‾‾
# _______
# |O|X|X|
# | |O|X|
# | |O|X|
# ‾‾‾‾‾‾‾
# _______
# | |X|X|
# |X|X|O|
# |O|O|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|O|
# |O| |X|
# |O|X|X|
# ‾‾‾‾‾‾‾
# _______
# |X|X|O|
# |X|O|X|
# |X|O|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|X|
# |O|O|X|
# | | |X|
# ‾‾‾‾‾‾‾
# _______
# | |O|X|
# | |X|O|
# |X|X|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|X|
# | |O|X|
# |O| |X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|X|
# |X|O|O|
# |X|X|O|
# ‾‾‾‾‾‾‾
# _______
# | |X|X|
# | | |X|
# |O|O|O|
# ‾‾‾‾‾‾‾
# _______
# | |X|O|
# |X|X|X|
# | |O|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|X|
# | |O|X|
# | |O|X|
# ‾‾‾‾‾‾‾
# _______
# | |O|X|
# |X|X|O|
# |X| |O|
# ‾‾‾‾‾‾‾
# _______
# |X|X|X|
# |O|X|O|
# |O|O|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|X|
# |X|O|O|
# |X|X|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|X|
# |O|O|O|
# | |X|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|X|
# | |O|X|
# |X|O|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|O|
# | |O|X|
# |O|X|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|O|
# | |X|O|
# |X|X|O|
# ‾‾‾‾‾‾‾
# _______
# | |X|O|
# | |O|X|
# |O| |X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|O|
# |O|X|X|
# |X|X|O|
# ‾‾‾‾‾‾‾
# _______
# | |X|O|
# |O|O|X|
# |O|X|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O| |
# | |X|O|
# | | |X|
# ‾‾‾‾‾‾‾
# _______
# |O|X|X|
# | |O|X|
# | | |O|
# ‾‾‾‾‾‾‾
# _______
# |X|X|X|
# |X| |O|
# | |O|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|O|
# |O|X|X|
# |X|O|X|
# ‾‾‾‾‾‾‾
# _______
# | |X|O|
# |X|O|X|
# |O|X|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|X|
# |O|O|O|
# | |X|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|X|
# |X|X|O|
# |X|O|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X| |
# |O| |X|
# |O| |X|
# ‾‾‾‾‾‾‾
# _______
# | |X|O|
# |X|X|O|
# |X|O|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|O|
# |X|X|X|
# |O|O|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|X|
# |X|X|O|
# |O|X|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X| |
# |O| |X|
# |O| |X|
# ‾‾‾‾‾‾‾
# _______
# | |X|X|
# |X|X|O|
# |O|O|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|O|
# |O|O|X|
# |X|X|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|O|
# |X|X|X|
# |O|X|O|
# ‾‾‾‾‾‾‾
# _______
# |X|X|O|
# |O|O|X|
# |X|O|X|
# ‾‾‾‾‾‾‾
# _______
# | |O|X|
# | |X|O|
# |X|O|X|
# ‾‾‾‾‾‾‾
# _______
# |O|X|X|
# |O|X|O|
# |X|O|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O| |
# |X|X|O|
# |X| |O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|O|
# |X|O|X|
# |X|O|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O| |
# | |X|O|
# | | |X|
# ‾‾‾‾‾‾‾
# _______
# | |X|X|
# |O|O|X|
# | |O|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|X|
# |X|X|O|
# |X|O|O|
# ‾‾‾‾‾‾‾
# _______
# |X|X|O|
# |O|X|X|
# |O|O|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|X|
# |X|X|O|
# |O|X|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|O|
# |O| |X|
# |O|X|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O| |
# |X|X|O|
# |X| |O|
# ‾‾‾‾‾‾‾
# _______
# | |X|X|
# |O| |X|
# |O|O|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|O|
# |X|O|X|
# |X|X|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|O|
# | |X|O|
# | |X|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|X|
# | |O|X|
# |X|O|O|
# ‾‾‾‾‾‾‾
# _______
# |X|X|O|
# |O|X|X|
# |O|O|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O| |
# | |X|O|
# |X|O|X|
# ‾‾‾‾‾‾‾
# _______
# | |X|X|
# |O|O|O|
# | | |X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|X|
# | |X|O|
# | |O|X|
# ‾‾‾‾‾‾‾
# _______
# |O|X|X|
# |O| |X|
# |O|X|O|
# ‾‾‾‾‾‾‾
# _______
# | |O|X|
# |X|X|O|
# |X| |O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|O|
# |O| |X|
# |O|X|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|O|
# |X| |X|
# |X| |O|
# ‾‾‾‾‾‾‾
# _______
# |X|X|O|
# |O|O|X|
# |X|O|X|
# ‾‾‾‾‾‾‾
# _______
# | |X|X|
# |X|X|O|
# |O|O|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|X|
# | |O|X|
# |O|X|O|
# ‾‾‾‾‾‾‾
# _______
# | |X|O|
# |X|X|X|
# | |O|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|X|
# |O| |O|
# |O|X|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|X|
# |X|X|O|
# |X|O|O|
# ‾‾‾‾‾‾‾
# 100%|██████████| 10000/10000 [00:13<00:00, 766.51it/s]
# _______
# | |X|X|
# | | |X|
# |O|O|O|
# ‾‾‾‾‾‾‾
# _______
# |X|O| |
# |X| |X|
# |X|O|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|X|
# |O|O|X|
# | | |X|
# ‾‾‾‾‾‾‾
# _______
# | |O|X|
# | |X|O|
# |X|O|X|
# ‾‾‾‾‾‾‾
# _______
# |O|X|X|
# | | |X|
# |O|O|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|X|
# |X|O|X|
# |O|X|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|X|
# | |O|X|
# | |O|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|X|
# |X|X|O|
# |O|X|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|X|
# | |O|X|
# | | |O|
# ‾‾‾‾‾‾‾
# _______
# |X|O| |
# |X| |O|
# |X|X|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|X|
# |O|O|X|
# | | |X|
# ‾‾‾‾‾‾‾
# _______
# |X|O| |
# | |X|O|
# | | |X|
# ‾‾‾‾‾‾‾
# _______
# |O|X|X|
# | |O|X|
# |O| |X|
# ‾‾‾‾‾‾‾
# _______
# | |O|X|
# |X|O|X|
# |X|O|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|X|
# |O| |X|
# | |O|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|X|
# |X| |O|
# |X| |O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|X|
# | |O|X|
# | |O|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|O|
# | |X|O|
# | |X|X|
# ‾‾‾‾‾‾‾
# _______
# |O|X|X|
# | |O|X|
# |O|X|O|
# ‾‾‾‾‾‾‾
# _______
# |X|O|X|
# |X|O|O|
# |X|X|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|X|
# |X|O|O|
# |O|X|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O| |
# |X| |O|
# |X|X|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|O|
# |O|X|X|
# |X|O|X|
# ‾‾‾‾‾‾‾
# _______
# |X|X|X|
# | | |O|
# |X|O|O|
# ‾‾‾‾‾‾‾
# _______
# |X|X|O|
# |O|X|X|
# |O|O|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|X|
# |X|O|O|
# |X|X|O|
# ‾‾‾‾‾‾‾
# _______
# | |X|O|
# | |X|O|
# |O|X|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|O|
# |O|X|X|
# |X|X|O|
# ‾‾‾‾‾‾‾
# _______
# |X|X|X|
# |O|X|O|
# |O|O|X|
# ‾‾‾‾‾‾‾
# _______
# | |O|O|
# |X|X|X|
# |X| |O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|X|
# | |O|X|
# | |O|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|O|
# |X|X|O|
# | |X|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|X|
# | | |X|
# |O|O|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|X|
# |X|X|O|
# |O|X|O|
# ‾‾‾‾‾‾‾
# _______
# | |X|O|
# | |O|X|
# |O| |X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|X|
# |X|O|X|
# |O|X|O|
# ‾‾‾‾‾‾‾
# _______
# | |X|X|
# |O|O|X|
# | |O|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|O|
# | |X|O|
# |X|X|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|X|
# |O|X|O|
# |X|O|X|
# ‾‾‾‾‾‾‾
# _______
# | |X|O|
# |X|X|X|
# | |O|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|X|
# | |O|X|
# |O| |X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|X|
# | |O|X|
# |X|O|O|
# ‾‾‾‾‾‾‾
# _______
# |X|X|X|
# |O|X|O|
# |O|O|X|
# ‾‾‾‾‾‾‾
# _______
# |X|X|O|
# |X|O|X|
# |X|O|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|X|
# |O|X|X|
# |X|O|O|
# ‾‾‾‾‾‾‾
# _______
# |X|X|X|
# | | |O|
# | | |O|
# ‾‾‾‾‾‾‾
# _______
# |O|X| |
# |O| |X|
# |O| |X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|X|
# | |X|X|
# |O|O|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X| |
# |O| |X|
# |O| |X|
# ‾‾‾‾‾‾‾
# _______
# |X|X|O|
# | | |O|
# | |X|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|O|
# |O|X|X|
# |X|O|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|O|
# |X|O|X|
# |X|X|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|O|
# |O|O|X|
# |X|X|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|X|
# | |O|O|
# |X|O|X|
# ‾‾‾‾‾‾‾
# _______
# |O|X|X|
# | |O|X|
# |O|X|O|
# ‾‾‾‾‾‾‾
# _______
# |X|O|O|
# |X|X|O|
# |X|O|X|
# ‾‾‾‾‾‾‾
# _______
# |O|X|X|
# |O| |X|
# | |O|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|O|
# | |X|O|
# |X|X|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X| |
# |O| |X|
# |O| |X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|O|
# |X|O|O|
# |X|X|X|
# ‾‾‾‾‾‾‾
# _______
# |O|X|O|
# |X|X|X|
# |O|O|X|
# ‾‾‾‾‾‾‾
# _______
# | |O|X|
# | |X| |
# |X| |O|
# ‾‾‾‾‾‾‾
# _______
# |X|X|O|
# |O|O|X|
# |X|O|X|
# ‾‾‾‾‾‾‾
# _______
# | |O|O|
# | |X|O|
# |X|X|X|
# ‾‾‾‾‾‾‾
# _______
# | |X|O|
# |O|X|X|
# | |X|O|
# ‾‾‾‾‾‾‾
# _______
# |X|O|X|
# |X|X|O|
# |O|X|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|O|
# |O| |X|
# |O|X|X|
# ‾‾‾‾‾‾‾
# _______
# |X|X|O|
# | |X|O|
# |X|O|O|
# ‾‾‾‾‾‾‾
# _______
# |O|X|O|
# |O|X|X|
# |X|O|X|
# ‾‾‾‾‾‾‾
# _______
# |X|O|X|
# | |O|O|
# |X|O|X|
# ‾‾‾‾‾‾‾
# _______
# | |X|O|
# | |O|X|
# |O| |X|
# ‾‾‾‾‾‾‾
#
# Win rate:  38.91%
# Draw rate: 11.03%
# Loss rate: 50.06%

# %% [markdown]
# #### Trial 1: Experimentation

# %%
agent, optimizer, criterion = supply_model()
environment = TicTacToeGame(DEVICE, OPPONENT_LEVEL.NAIVE)
reward_history = train_agent(
    agent,
    environment     = environment,
    num_episodes    = NUM_EPISODES,
    optimizer       = optimizer,
    criterion       = criterion,
    device          = DEVICE,
    save_path       = MODEL_PATH,
    model_name      = MODEL_NAME
)
test_agent(
    agent,
    environment     = environment,
    num_episodes    = NUM_EPISODES
)
# Out:
# episode: 1/100, steps: 4, reward_total: 1, e: 1.0, time: 22:52:28
# _______
# |X| |X|
# |O|O|O|
# |X|O|X|
# ‾‾‾‾‾‾‾
# episode: 2/100, steps: 4, reward_total: 1, e: 1.0, time: 22:52:28
# _______
# |X|O| |
# |O|X|O|
# |X| |X|
# ‾‾‾‾‾‾‾
# episode: 3/100, steps: 3, reward_total: -2, e: 1.0, time: 22:52:28
# _______
# |X| |X|
# |O|X| |
# |X|O|O|
# ‾‾‾‾‾‾‾
# episode: 4/100, steps: 4, reward_total: 1, e: 1.0, time: 22:52:28
# _______
# |O|O|X|
# | |X| |
# |X|O|X|
# ‾‾‾‾‾‾‾
# episode: 5/100, steps: 2, reward_total: -2, e: 1.0, time: 22:52:28
# _______
# | | |X|
# |O| |X|
# |O| |X|
# ‾‾‾‾‾‾‾
# episode: 6/100, steps: 5, reward_total: 1, e: 1.0, time: 22:52:28
# _______
# |X|O|O|
# |X|X|O|
# |X|O|X|
# ‾‾‾‾‾‾‾
# episode: 7/100, steps: 4, reward_total: -1, e: 1.0, time: 22:52:28
# _______
# |X|O|X|
# |X|X|O|
# |O|X|O|
# ‾‾‾‾‾‾‾
# episode: 8/100, steps: 5, reward_total: 1, e: 1.0, time: 22:52:28
# _______
# |X|O|O|
# |X|X|O|
# |O|X|X|
# ‾‾‾‾‾‾‾
# episode: 9/100, steps: 3, reward_total: 1, e: 1.0, time: 22:52:28
# _______
# |X| |X|
# |O|O|O|
# | |X| |
# ‾‾‾‾‾‾‾
# episode: 10/100, steps: 4, reward_total: -2, e: 1.0, time: 22:52:28
# _______
# |X|X|O|
# |O|O|X|
# |O| |X|
# ‾‾‾‾‾‾‾
# episode: 11/100, steps: 4, reward_total: -1, e: 1.0, time: 22:52:28
# _______
# |X|O|X|
# |O|O|X|
# |X|X|O|
# ‾‾‾‾‾‾‾
# episode: 12/100, steps: 4, reward_total: -2, e: 1.0, time: 22:52:28
# _______
# |O|X|O|
# |X|O|X|
# |X| |O|
# ‾‾‾‾‾‾‾
# episode: 13/100, steps: 4, reward_total: -2, e: 1.0, time: 22:52:28
# _______
# |O|X|X|
# |O|X|X|
# |X|O|O|
# ‾‾‾‾‾‾‾
# episode: 14/100, steps: 5, reward_total: 1, e: 1.0, time: 22:52:28
# _______
# |X|O|X|
# |X|X|O|
# |O|O|X|
# ‾‾‾‾‾‾‾
# episode: 15/100, steps: 3, reward_total: -2, e: 1.0, time: 22:52:28
# _______
# | |X|X|
# |O|X|O|
# |X| |O|
# ‾‾‾‾‾‾‾
# episode: 16/100, steps: 4, reward_total: 1, e: 1.0, time: 22:52:28
# _______
# | |X|O|
# |O| |O|
# |X|X|X|
# ‾‾‾‾‾‾‾
# episode: 17/100, steps: 4, reward_total: 1, e: 1.0, time: 22:52:28
# _______
# |O|O|O|
# | |X|X|
# |X|X|O|
# ‾‾‾‾‾‾‾
# episode: 18/100, steps: 5, reward_total: 1, e: 1.0, time: 22:52:28
# _______
# |O|O|X|
# |O|X|X|
# |X|X|O|
# ‾‾‾‾‾‾‾
# episode: 19/100, steps: 3, reward_total: 1, e: 1.0, time: 22:52:28
# _______
# |O| |X|
# |O| | |
# |O|X|X|
# ‾‾‾‾‾‾‾
# episode: 20/100, steps: 4, reward_total: 1, e: 1.0, time: 22:52:28
# _______
# |O|X| |
# | |X|X|
# |O|X|O|
# ‾‾‾‾‾‾‾
# episode: 21/100, steps: 3, reward_total: -2, e: 1.0, time: 22:52:28
# _______
# |O|X|O|
# |O|X| |
# | |X|X|
# ‾‾‾‾‾‾‾
# episode: 22/100, steps: 5, reward_total: 1, e: 1.0, time: 22:52:28
# _______
# |X|O|O|
# |O|X|X|
# |X|O|X|
# ‾‾‾‾‾‾‾
# episode: 23/100, steps: 3, reward_total: -2, e: 1.0, time: 22:52:28
# _______
# |X|O|O|
# | |X| |
# |O|X|X|
# ‾‾‾‾‾‾‾
# episode: 24/100, steps: 5, reward_total: 1, e: 1.0, time: 22:52:28
# _______
# |X|X|O|
# |X|X|O|
# |O|O|X|
# ‾‾‾‾‾‾‾
# episode: 25/100, steps: 4, reward_total: -1, e: 1.0, time: 22:52:28
# _______
# |O|X|X|
# |X|O|O|
# |X|O|X|
# ‾‾‾‾‾‾‾
# episode: 26/100, steps: 4, reward_total: -2, e: 1.0, time: 22:52:28
# _______
# | |O|O|
# |X|O|X|
# |O|X|X|
# ‾‾‾‾‾‾‾
# episode: 27/100, steps: 3, reward_total: -2, e: 1.0, time: 22:52:28
# _______
# | |O|X|
# | |O|X|
# |O|X|X|
# ‾‾‾‾‾‾‾
# episode: 28/100, steps: 5, reward_total: 1, e: 1.0, time: 22:52:28
# _______
# |X|O|X|
# |X|O|O|
# |X|X|O|
# ‾‾‾‾‾‾‾
# episode: 29/100, steps: 4, reward_total: 1, e: 1.0, time: 22:52:28
# _______
# |X| |X|
# |X|O|X|
# |O|O|O|
# ‾‾‾‾‾‾‾
# episode: 30/100, steps: 3, reward_total: -2, e: 1.0, time: 22:52:28
# _______
# |O| |X|
# |X|O| |
# | |X|O|
# ‾‾‾‾‾‾‾
# episode: 31/100, steps: 4, reward_total: 1, e: 1.0, time: 22:52:28
# _______
# |O|X|X|
# |O|O|O|
# | |X|X|
# ‾‾‾‾‾‾‾
# episode: 32/100, steps: 4, reward_total: -2, e: 1.0, time: 22:52:28
# _______
# |O|X| |
# |X|O|X|
# |X|O|O|
# ‾‾‾‾‾‾‾
# episode: 33/100, steps: 4, reward_total: -1, e: 1.0, time: 22:52:28
# _______
# |X|O|X|
# |X|O|X|
# |O|X|O|
# ‾‾‾‾‾‾‾
# episode: 34/100, steps: 4, reward_total: -2, e: 1.0, time: 22:52:28
# _______
# | |O|X|
# |X|O|O|
# |X|O|X|
# ‾‾‾‾‾‾‾
# episode: 35/100, steps: 4, reward_total: -1, e: 1.0, time: 22:52:28
# _______
# |X|X|O|
# |O|O|X|
# |X|X|O|
# ‾‾‾‾‾‾‾
# episode: 36/100, steps: 4, reward_total: -2, e: 1.0, time: 22:52:28
# _______
# |X|O|O|
# |X|O|X|
# | |O|X|
# ‾‾‾‾‾‾‾
# episode: 37/100, steps: 4, reward_total: -2, e: 1.0, time: 22:52:28
# _______
# |O|X|O|
# |O|O|X|
# |X|X|X|
# ‾‾‾‾‾‾‾
# episode: 38/100, steps: 5, reward_total: 1, e: 1.0, time: 22:52:28
# _______
# |X|X|O|
# |X|O|O|
# |X|O|X|
# ‾‾‾‾‾‾‾
# episode: 39/100, steps: 3, reward_total: 1, e: 1.0, time: 22:52:28
# _______
# |X|X|O|
# |X| |O|
# | | |O|
# ‾‾‾‾‾‾‾
# episode: 40/100, steps: 4, reward_total: 1, e: 1.0, time: 22:52:28
# _______
# |X|X|O|
# |O|X| |
# | |X|O|
# ‾‾‾‾‾‾‾
# episode: 41/100, steps: 3, reward_total: -2, e: 1.0, time: 22:52:28
# _______
# |O| |X|
# | |O|X|
# |X|O|X|
# ‾‾‾‾‾‾‾
# episode: 42/100, steps: 4, reward_total: 1, e: 1.0, time: 22:52:28
# _______
# |X|O|X|
# |X| |O|
# |X| |O|
# ‾‾‾‾‾‾‾
# episode: 43/100, steps: 4, reward_total: -2, e: 1.0, time: 22:52:28
# _______
# |X|X|O|
# |X|X|O|
# |O|O|X|
# ‾‾‾‾‾‾‾
# episode: 44/100, steps: 3, reward_total: -2, e: 1.0, time: 22:52:28
# _______
# | |O| |
# |X|O|X|
# | |O|X|
# ‾‾‾‾‾‾‾
# episode: 45/100, steps: 4, reward_total: -2, e: 1.0, time: 22:52:28
# _______
# |X|O|X|
# |X|X|O|
# |O|O|X|
# ‾‾‾‾‾‾‾
# episode: 46/100, steps: 5, reward_total: 1, e: 1.0, time: 22:52:28
# _______
# |X|O|O|
# |O|O|X|
# |X|X|X|
# ‾‾‾‾‾‾‾
# episode: 47/100, steps: 4, reward_total: -2, e: 1.0, time: 22:52:28
# _______
# |X|O|O|
# |X|O|X|
# |X|X|O|
# ‾‾‾‾‾‾‾
# episode: 48/100, steps: 4, reward_total: -2, e: 1.0, time: 22:52:28
# _______
# |X|O|X|
# |X|O|X|
# |O|O| |
# ‾‾‾‾‾‾‾
# episode: 49/100, steps: 4, reward_total: 1, e: 1.0, time: 22:52:28
# _______
# |X|O| |
# |O|O|X|
# |X|O|X|
# ‾‾‾‾‾‾‾
# episode: 50/100, steps: 3, reward_total: -2, e: 1.0, time: 22:52:28
# _______
# | |X| |
# |X| |X|
# |O|O|O|
# ‾‾‾‾‾‾‾
# episode: 51/100, steps: 4, reward_total: -2, e: 1.0, time: 22:52:28
# _______
# |X|X|O|
# |X|X|O|
# |O|O|X|
# ‾‾‾‾‾‾‾
# episode: 52/100, steps: 4, reward_total: 1, e: 1.0, time: 22:52:28
# _______
# |O|O| |
# |O|X| |
# |X|X|X|
# ‾‾‾‾‾‾‾
# episode: 53/100, steps: 3, reward_total: -2, e: 1.0, time: 22:52:28
# _______
# |X|X|X|
# | |O|O|
# |O| |X|
# ‾‾‾‾‾‾‾
# episode: 54/100, steps: 4, reward_total: -2, e: 1.0, time: 22:52:28
# _______
# |X|X|O|
# |O|O|X|
# |O| |X|
# ‾‾‾‾‾‾‾
# episode: 55/100, steps: 3, reward_total: -2, e: 1.0, time: 22:52:28
# _______
# |X| | |
# |O|X|O|
# |O|X|X|
# ‾‾‾‾‾‾‾
# episode: 56/100, steps: 5, reward_total: -1, e: 1.0, time: 22:52:28
# _______
# |X|O|O|
# |O|X|X|
# |X|X|O|
# ‾‾‾‾‾‾‾
# episode: 57/100, steps: 3, reward_total: -2, e: 1.0, time: 22:52:28
# _______
# |O| |X|
# |O|O| |
# |X|X|X|
# ‾‾‾‾‾‾‾
# episode: 58/100, steps: 4, reward_total: -2, e: 1.0, time: 22:52:28
# _______
# |O| |X|
# |X|O|O|
# |X|X|O|
# ‾‾‾‾‾‾‾
# episode: 59/100, steps: 2, reward_total: -2, e: 1.0, time: 22:52:28
# _______
# | |O| |
# |X|X|X|
# | |O| |
# ‾‾‾‾‾‾‾
# episode: 60/100, steps: 3, reward_total: 1, e: 1.0, time: 22:52:28
# _______
# |O|X| |
# | |X| |
# | |X|O|
# ‾‾‾‾‾‾‾
# episode: 61/100, steps: 3, reward_total: -2, e: 1.0, time: 22:52:28
# _______
# |X|O|O|
# |X| | |
# |X|X|O|
# ‾‾‾‾‾‾‾
# episode: 62/100, steps: 4, reward_total: -2, e: 1.0, time: 22:52:28
# _______
# |X|O|X|
# |O|O|O|
# |X| |X|
# ‾‾‾‾‾‾‾
# episode: 63/100, steps: 4, reward_total: -1, e: 1.0, time: 22:52:28
# _______
# |X|O|X|
# |X|X|O|
# |O|X|O|
# ‾‾‾‾‾‾‾
# episode: 64/100, steps: 4, reward_total: -2, e: 1.0, time: 22:52:28
# _______
# |O|O| |
# |O|X|X|
# |O|X|X|
# ‾‾‾‾‾‾‾
# episode: 65/100, steps: 4, reward_total: 1, e: 1.0, time: 22:52:28
# _______
# |X|X|O|
# |O| |O|
# |X|X|O|
# ‾‾‾‾‾‾‾
# episode: 66/100, steps: 4, reward_total: 1, e: 1.0, time: 22:52:28
# _______
# |O|O|X|
# |O| | |
# |X|X|X|
# ‾‾‾‾‾‾‾
# episode: 67/100, steps: 3, reward_total: -2, e: 1.0, time: 22:52:28
# _______
# |X|O|O|
# | |X|O|
# | |X|X|
# ‾‾‾‾‾‾‾
# episode: 68/100, steps: 4, reward_total: -2, e: 1.0, time: 22:52:28
# _______
# |X| |O|
# |X|O|X|
# |O|O|X|
# ‾‾‾‾‾‾‾
# episode: 69/100, steps: 4, reward_total: -2, e: 1.0, time: 22:52:28
# _______
# |O|X|O|
# |X|X|O|
# |O|X|X|
# ‾‾‾‾‾‾‾
# episode: 70/100, steps: 4, reward_total: 1, e: 1.0, time: 22:52:28
# _______
# |O| |X|
# |O|X|X|
# | |O|X|
# ‾‾‾‾‾‾‾
# episode: 71/100, steps: 2, reward_total: -2, e: 1.0, time: 22:52:28
# _______
# |O| |O|
# |X|X|X|
# | | | |
# ‾‾‾‾‾‾‾
# episode: 72/100, steps: 4, reward_total: -2, e: 1.0, time: 22:52:28
# _______
# |O|X| |
# |O|O|X|
# |O|X|X|
# ‾‾‾‾‾‾‾
# episode: 73/100, steps: 4, reward_total: 1, e: 1.0, time: 22:52:28
# _______
# |O|O| |
# |O|X|X|
# |O|X|X|
# ‾‾‾‾‾‾‾
# episode: 74/100, steps: 5, reward_total: -1, e: 1.0, time: 22:52:28
# _______
# |X|O|O|
# |O|X|X|
# |X|X|O|
# ‾‾‾‾‾‾‾
# episode: 75/100, steps: 4, reward_total: -2, e: 1.0, time: 22:52:28
# _______
# |O|O|X|
# |X|X|X|
# |O|O|X|
# ‾‾‾‾‾‾‾
# episode: 76/100, steps: 4, reward_total: -2, e: 1.0, time: 22:52:28
# _______
# |O| |X|
# |X|O|O|
# |X|X|O|
# ‾‾‾‾‾‾‾
# episode: 77/100, steps: 2, reward_total: -2, e: 1.0, time: 22:52:28
# _______
# |X|X|X|
# |O|O| |
# | | | |
# ‾‾‾‾‾‾‾
# episode: 78/100, steps: 3, reward_total: -2, e: 1.0, time: 22:52:28
# _______
# |X|X|O|
# | |X|O|
# | | |O|
# ‾‾‾‾‾‾‾
# episode: 79/100, steps: 4, reward_total: 1, e: 1.0, time: 22:52:28
# _______
# |X|O|X|
# |X|X| |
# |O|O|O|
# ‾‾‾‾‾‾‾
# episode: 80/100, steps: 4, reward_total: -2, e: 1.0, time: 22:52:28
# _______
# |O|O|O|
# | |X|X|
# |O|X|X|
# ‾‾‾‾‾‾‾
# episode: 81/100, steps: 3, reward_total: -2, e: 1.0, time: 22:52:28
# _______
# |X| |X|
# | |X|O|
# |X|O|O|
# ‾‾‾‾‾‾‾
# episode: 82/100, steps: 5, reward_total: -1, e: 1.0, time: 22:52:28
# _______
# |X|O|O|
# |O|X|X|
# |X|X|O|
# ‾‾‾‾‾‾‾
# episode: 83/100, steps: 4, reward_total: -2, e: 1.0, time: 22:52:28
# _______
# |X|X|O|
# |X|O|X|
# |X|O|O|
# ‾‾‾‾‾‾‾
# episode: 84/100, steps: 4, reward_total: -2, e: 1.0, time: 22:52:28
# _______
# |X|X|O|
# |X| |X|
# |O|O|O|
# ‾‾‾‾‾‾‾
# episode: 85/100, steps: 4, reward_total: 1, e: 1.0, time: 22:52:28
# _______
# |X|X| |
# |O|O|O|
# |X|O|X|
# ‾‾‾‾‾‾‾
# episode: 86/100, steps: 5, reward_total: 1, e: 1.0, time: 22:52:28
# _______
# |X|X|X|
# |O|O|X|
# |O|X|O|
# ‾‾‾‾‾‾‾
# episode: 87/100, steps: 3, reward_total: 1, e: 1.0, time: 22:52:28
# _______
# |O|X|X|
# |O| | |
# |O|X| |
# ‾‾‾‾‾‾‾
# episode: 88/100, steps: 4, reward_total: 1, e: 1.0, time: 22:52:28
# _______
# |O|O| |
# |X|X|X|
# |X|O| |
# ‾‾‾‾‾‾‾
# episode: 89/100, steps: 3, reward_total: 1, e: 1.0, time: 22:52:28
# _______
# | |X|O|
# |X|O|X|
# |O| | |
# ‾‾‾‾‾‾‾
# episode: 90/100, steps: 4, reward_total: 1, e: 1.0, time: 22:52:28
# _______
# |X|O|O|
# | |X| |
# |O|X|X|
# ‾‾‾‾‾‾‾
# episode: 91/100, steps: 4, reward_total: -2, e: 1.0, time: 22:52:28
# _______
# |O|X|O|
# |O|O|X|
# |X|X|X|
# ‾‾‾‾‾‾‾
# episode: 92/100, steps: 5, reward_total: 1, e: 1.0, time: 22:52:28
# _______
# |O|X|X|
# |O|O|X|
# |X|O|X|
# ‾‾‾‾‾‾‾
# episode: 93/100, steps: 3, reward_total: -2, e: 1.0, time: 22:52:28
# _______
# |X|X|X|
# |O| |O|
# |X| |O|
# ‾‾‾‾‾‾‾
# episode: 94/100, steps: 3, reward_total: 1, e: 1.0, time: 22:52:28
# _______
# | |O|X|
# | |X|O|
# |X| | |
# ‾‾‾‾‾‾‾
# episode: 95/100, steps: 3, reward_total: -2, e: 1.0, time: 22:52:28
# _______
# |X| | |
# |X|X|O|
# |X|O|O|
# ‾‾‾‾‾‾‾
# episode: 96/100, steps: 4, reward_total: -2, e: 1.0, time: 22:52:28
# _______
# |X| |X|
# |O|O|O|
# |X|O|X|
# ‾‾‾‾‾‾‾
# episode: 97/100, steps: 3, reward_total: -2, e: 1.0, time: 22:52:28
# _______
# | |O| |
# |X|X|X|
# |X|O|O|
# ‾‾‾‾‾‾‾
# episode: 98/100, steps: 4, reward_total: 1, e: 1.0, time: 22:52:28
# _______
# |O|O|X|
# | |X|X|
# |X| |O|
# ‾‾‾‾‾‾‾
# episode: 99/100, steps: 4, reward_total: -1, e: 1.0, time: 22:52:28
# _______
# |O|X|O|
# |X|X|O|
# |X|O|X|
# ‾‾‾‾‾‾‾
# episode: 100/100, steps: 4, reward_total: 1, e: 1.0, time: 22:52:28
# _______
# |O| | |
# |O|X|O|
# |X|X|X|
# ‾‾‾‾‾‾‾
# Model saved to '../../../trained_models/TicTacToeV2/TicTacToe-NAIVE-100.pt'.
# 100%|██████████| 100/100 [00:00<00:00, 763.90it/s]
# Win rate:  47.0%
# Draw rate: 7.0%
# Loss rate: 46.0%
